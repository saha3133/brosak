# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import time

import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)


N_ITERATIONS = 4
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE = np.array([10.0, 10.0])
N_MPC = 20
OBSTACLE_INFO = None # まずは障害物なしで実行

# ----------------------------------------------------------------------------------
# 真のシステム
# ----------------------------------------------------------------------------------
class TrueVehicle:
    def __init__(self, dt=0.1):
        self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u
        # GPRが学習すべき、モデル化されていない非線形項
        drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt
        vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2
        py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])

# ----------------------------------------------------------------------------------
# ガウス過程回帰モデル (ダイナミクス学習)
# ----------------------------------------------------------------------------------
class GPRModel:
    def __init__(self, nx, nu, dt, obstacle_info):
        self.nx, self.nu = nx, nu
        self.dt=DT
        self.obstacle_info=OBSTACLE_INFO
        self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu))
        self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx

    def add_data(self, x, u, x_next):
        # nominal モデルからの誤差（デルタ）を学習ターゲットにする
        delta_real = (x_next - x) / self.dt
        delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])])
        self.Y_data = np.vstack([self.Y_data, error])

    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始...")
        for i in range(self.nx):
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100)
            self.models[i] = model
        self.is_trained = True
        print("GPR: 学習完了")

    def predict(self, x, u):
        if not self.is_trained:
            return np.zeros(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        return means

# ----------------------------------------------------------------------------------
# MPCコントローラ
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, dt, obstacle_info):
        self.nx, self.nu, self.N, self.dt = nx, nu, N, dt
        self.obstacle_info = obstacle_info
        self.u_prev_sol = np.zeros((nu, N))

    def solve(self, x_current, gpr_model, x_goal):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)
        X = opti.variable(self.nx, self.N + 1)
        
        cost = 0
        opti.subject_to(X[:, 0] == x_current)

        error_mean = gpr_model.predict(x_current, np.zeros(self.nu))
        
        for k in range(self.N):
            x_k, u_k = X[:, k], U[:, k]
            delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
            delta_pred = delta_nominal + error_mean
            x_next_pred = x_k + delta_pred * self.dt
            opti.subject_to(X[:, k+1] == x_next_pred)

            cost += ca.sumsqr(x_k[:2] - x_goal) * self.dt
            cost += ca.sumsqr(u_k) * self.dt * 0.01

        cost += ca.sumsqr(X[:2, self.N] - x_goal) * 20.0

        opti.minimize(cost)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))

        opti.set_initial(X, np.tile(x_current, (self.N + 1, 1)).T)
        opti.set_initial(U, self.u_prev_sol)
        
        s_opts = {'print_level': 0}
        opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}, error: {e}")
            return np.zeros(self.nu)

# ----------------------------------------------------------------------------------
# Main Simulation Loop
# ----------------------------------------------------------------------------------
def main():
    vehicle = TrueVehicle(dt=DT)
    gpr_model = GPRModel(nx=NX, nu=NU, dt=DT, obstacle_info=OBSTACLE_INFO)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)

    all_trajectories, final_costs = [], []

    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE)
        total_cost = 0
        iteration_data = []

        for step in range(SIM_STEPS):
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE)
            x_next = vehicle.dynamics(current_x, u_optimal)
            
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data.append((current_x, u_optimal, x_next))
            current_x = x_next

            if np.linalg.norm(current_x[:2] - GOAL_STATE) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！")
                break
        
        all_trajectories.append(np.array([d[0] for d in iteration_data]))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")

        for x, u, x_n in iteration_data:
            gpr_model.add_data(x, u, x_n)
        gpr_model.train()

    # 結果の可視化 
    plt.figure(figsize=(10, 10))
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE[0], GOAL_STATE[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡')
    plt.legend()
    plt.axis('equal')
    plt.show()

    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移')
    plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト')
    plt.xticks(range(1, N_ITERATIONS + 1))
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/4
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  22.00us (  2.44us)         9
#        nlp_g  |        0 (       0)  25.00us (  2.78us)         9
#   nlp_grad_f  |        0 (       0)  42.00us (  4.20us)        10
#   nlp_hess_l  |        0 (       0)  26.00us (  3.25us)         8
#    nlp_jac_g  |        0 (       0)  80.00us (  8.00us)        10
#        total  |        0 (       0)   5.51ms (  5.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  36.00us (  2.77us)        13
#        nlp_g  |        0 (       0)  42.00us (  3.23us)        13
#   nlp_grad_f  |        0 (       0)  50.00us (  4.17us)        12
#   nlp_hess_l  |        0 (       0)  32.00us (  3.20us)        10
#    nlp_jac_g  |        0 (       0) 108.00us (  9.00us)        12
#        total  |  15.00ms ( 15.00ms)   6.97ms (  6.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  53.00us (  4.42us)        12
#        nlp_g  |        0 (       0)  39.00us (  3.25us)        12
#   nlp_grad_f  |        0 (       0)  55.00us (  4.23us)        13
#   nlp_hess_l  |        0 (       0)  41.00us (  3.73us)        11
#    nlp_jac_g  |        0 (       0) 118.00us (  9.08us)        13
#        total  |   7.00ms (  7.00ms)   7.82ms (  7.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  43.00us (  3.58us)        12
#        nlp_g  |   1.00ms ( 83.33us) 123.00us ( 10.25us)        12
#   nlp_grad_f  |        0 (       0)  55.00us (  4.23us)        13
#   nlp_hess_l  |        0 (       0) 164.00us ( 14.91us)        11
#    nlp_jac_g  |        0 (       0) 117.00us (  9.00us)        13
#        total  |   4.00ms (  4.00ms)   8.22ms (  8.22ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  56.00us (  3.73us)        15
#        nlp_g  |        0 (       0)  51.00us (  3.40us)        15
#   nlp_grad_f  |        0 (       0)  76.00us (  4.75us)        16
#   nlp_hess_l  |        0 (       0)  59.00us (  4.21us)        14
#    nlp_jac_g  |        0 (       0) 169.00us ( 10.56us)        16
#        total  |   2.00ms (  2.00ms)   9.29ms (  9.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  34.00us (  2.27us)        15
#        nlp_g  |        0 (       0)  38.00us (  2.53us)        15
#   nlp_grad_f  |        0 (       0)  55.00us (  3.93us)        14
#   nlp_hess_l  |        0 (       0)  50.00us (  4.17us)        12
#    nlp_jac_g  |        0 (       0) 114.00us (  8.14us)        14
#        total  |        0 (       0)   8.05ms (  8.05ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.45us)        11
#        nlp_g  |        0 (       0)  31.00us (  2.82us)        11
#   nlp_grad_f  |        0 (       0)  47.00us (  3.92us)        12
#   nlp_hess_l  |        0 (       0)  31.00us (  3.10us)        10
#    nlp_jac_g  |        0 (       0) 108.00us (  9.00us)        12
#        total  |        0 (       0)   6.63ms (  6.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  28.00us (  2.55us)        11
#        nlp_g  |        0 (       0)  33.00us (  3.00us)        11
#   nlp_grad_f  |        0 (       0)  47.00us (  3.92us)        12
#   nlp_hess_l  |        0 (       0)  34.00us (  3.40us)        10
#    nlp_jac_g  |        0 (       0) 102.00us (  8.50us)        12
#        total  |  16.00ms ( 16.00ms)   6.90ms (  6.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.67us)        12
#        nlp_g  |        0 (       0)  35.00us (  2.92us)        12
#   nlp_grad_f  |        0 (       0)  48.00us (  3.69us)        13
#   nlp_hess_l  |        0 (       0)  37.00us (  3.36us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us) 116.00us (  8.92us)        13
#        total  |  17.00ms ( 17.00ms)   7.48ms (  7.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  33.00us (  2.54us)        13
#        nlp_g  |        0 (       0)  42.00us (  3.23us)        13
#   nlp_grad_f  |        0 (       0)  53.00us (  3.79us)        14
#   nlp_hess_l  |   1.00ms ( 83.33us)  45.00us (  3.75us)        12
#    nlp_jac_g  |        0 (       0) 117.00us (  8.36us)        14
#        total  |  16.00ms ( 16.00ms)   8.14ms (  8.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  42.00us (  3.00us)        14
#        nlp_g  |        0 (       0)  43.00us (  3.07us)        14
#   nlp_grad_f  |        0 (       0)  56.00us (  3.73us)        15
#   nlp_hess_l  |        0 (       0)  52.00us (  4.00us)        13
#    nlp_jac_g  |        0 (       0) 124.00us (  8.27us)        15
#        total  |  23.00ms ( 23.00ms)   8.89ms (  8.89ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  33.00us (  2.75us)        12
#        nlp_g  |        0 (       0)  33.00us (  2.75us)        12
#   nlp_grad_f  |        0 (       0)  52.00us (  4.00us)        13
#   nlp_hess_l  |        0 (       0)  32.00us (  2.91us)        11
#    nlp_jac_g  |        0 (       0) 107.00us (  8.23us)        13
#        total  |   1.00ms (  1.00ms)   7.27ms (  7.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  28.00us (  2.33us)        12
#        nlp_g  |        0 (       0)  35.00us (  2.92us)        12
#   nlp_grad_f  |        0 (       0)  53.00us (  4.08us)        13
#   nlp_hess_l  |        0 (       0)  34.00us (  3.09us)        11
#    nlp_jac_g  |        0 (       0) 109.00us (  8.38us)        13
#        total  |        0 (       0)   7.23ms (  7.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  35.00us (  2.92us)        12
#        nlp_g  |        0 (       0)  39.00us (  3.25us)        12
#   nlp_grad_f  |        0 (       0)  60.00us (  4.62us)        13
#   nlp_hess_l  |        0 (       0)  34.00us (  3.09us)        11
#    nlp_jac_g  |        0 (       0) 111.00us (  8.54us)        13
#        total  |   8.00ms (  8.00ms)   7.57ms (  7.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  46.00us (  3.54us)        13
#        nlp_g  |        0 (       0)  50.00us (  3.85us)        13
#   nlp_grad_f  |        0 (       0)  84.00us (  6.00us)        14
#   nlp_hess_l  |        0 (       0)  45.00us (  3.75us)        12
#    nlp_jac_g  |        0 (       0) 129.00us (  9.21us)        14
#        total  |   9.00ms (  9.00ms)   8.58ms (  8.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  37.00us (  2.64us)        14
#        nlp_g  |        0 (       0)  36.00us (  2.57us)        14
#   nlp_grad_f  |        0 (       0)  63.00us (  4.20us)        15
#   nlp_hess_l  |        0 (       0)  42.00us (  3.23us)        13
#    nlp_jac_g  |        0 (       0) 120.00us (  8.00us)        15
#        total  |  21.00ms ( 21.00ms)   8.36ms (  8.36ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  33.00us (  2.75us)        12
#        nlp_g  |        0 (       0)  36.00us (  3.00us)        12
#   nlp_grad_f  |        0 (       0)  52.00us (  4.00us)        13
#   nlp_hess_l  |        0 (       0)  39.00us (  3.55us)        11
#    nlp_jac_g  |        0 (       0) 108.00us (  8.31us)        13
#        total  |   8.00ms (  8.00ms)   7.58ms (  7.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  34.00us (  2.62us)        13
#        nlp_g  |        0 (       0)  39.00us (  3.00us)        13
#   nlp_grad_f  |        0 (       0)  55.00us (  3.93us)        14
#   nlp_hess_l  |        0 (       0)  39.00us (  3.25us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us) 117.00us (  8.36us)        14
#        total  |   8.00ms (  8.00ms)   7.91ms (  7.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)  28.00us (  2.55us)        11
#        nlp_g  |        0 (       0)  28.00us (  2.55us)        11
#   nlp_grad_f  |        0 (       0)  52.00us (  4.33us)        12
#   nlp_hess_l  |        0 (       0)  32.00us (  3.20us)        10
#    nlp_jac_g  |        0 (       0) 101.00us (  8.42us)        12
#        total  |   7.00ms (  7.00ms)   6.59ms (  6.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  38.00us (  2.92us)        13
#        nlp_g  |        0 (       0)  44.00us (  3.38us)        13
#   nlp_grad_f  |        0 (       0)  62.00us (  4.43us)        14
#   nlp_hess_l  |        0 (       0)  42.00us (  3.50us)        12
#    nlp_jac_g  |        0 (       0) 123.00us (  8.79us)        14
#        total  |   9.00ms (  9.00ms)   8.51ms (  8.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  44.00us (  3.67us)        12
#        nlp_g  |        0 (       0)  50.00us (  4.17us)        12
#   nlp_grad_f  |        0 (       0)  86.00us (  6.62us)        13
#   nlp_hess_l  |        0 (       0)  45.00us (  4.09us)        11
#    nlp_jac_g  |        0 (       0) 159.00us ( 12.23us)        13
#        total  |   7.00ms (  7.00ms)   8.06ms (  8.06ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  37.00us (  2.64us)        14
#        nlp_g  |        0 (       0)  38.00us (  2.71us)        14
#   nlp_grad_f  |        0 (       0)  58.00us (  3.87us)        15
#   nlp_hess_l  |        0 (       0)  40.00us (  3.08us)        13
#    nlp_jac_g  |        0 (       0) 117.00us (  7.80us)        15
#        total  |   8.00ms (  8.00ms)   8.32ms (  8.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  43.00us (  2.87us)        15
#        nlp_g  |        0 (       0)  42.00us (  2.80us)        15
#   nlp_grad_f  |        0 (       0)  64.00us (  4.00us)        16
#   nlp_hess_l  |        0 (       0)  45.00us (  3.21us)        14
#    nlp_jac_g  |        0 (       0) 133.00us (  8.31us)        16
#        total  |  16.00ms ( 16.00ms)   9.14ms (  9.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  31.00us (  3.10us)        10
#        nlp_g  |        0 (       0)  34.00us (  3.40us)        10
#   nlp_grad_f  |        0 (       0)  46.00us (  4.18us)        11
#   nlp_hess_l  |        0 (       0)  32.00us (  3.56us)         9
#    nlp_jac_g  |        0 (       0)  99.00us (  9.00us)        11
#        total  |   4.00ms (  4.00ms)   6.48ms (  6.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  26.00us (  2.89us)         9
#        nlp_g  |        0 (       0)  26.00us (  2.89us)         9
#   nlp_grad_f  |        0 (       0)  37.00us (  3.70us)        10
#   nlp_hess_l  |        0 (       0)  26.00us (  3.25us)         8
#    nlp_jac_g  |        0 (       0)  81.00us (  8.10us)        10
#        total  |  15.00ms ( 15.00ms)   5.50ms (  5.50ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  24.00us (  3.00us)         8
#        nlp_g  |        0 (       0)  34.00us (  4.25us)         8
#   nlp_grad_f  |        0 (       0)  37.00us (  4.11us)         9
#   nlp_hess_l  |        0 (       0)  26.00us (  3.71us)         7
#    nlp_jac_g  |        0 (       0)  81.00us (  9.00us)         9
#        total  |  17.00ms ( 17.00ms)   5.35ms (  5.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  23.00us (  2.87us)         8
#        nlp_g  |        0 (       0)  21.00us (  2.62us)         8
#   nlp_grad_f  |        0 (       0)  37.00us (  4.11us)         9
#   nlp_hess_l  |        0 (       0)  31.00us (  4.43us)         7
#    nlp_jac_g  |        0 (       0)  75.00us (  8.33us)         9
#        total  |  16.00ms ( 16.00ms)   5.02ms (  5.02ms)         1
# ステップ 27 でゴールに到達！
# イテレーション 1 の総コスト: 237.78
# GPR: 学習開始...
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:166: RuntimeWarning:overflow encountered in divide
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:138: RuntimeWarning:invalid value encountered in add
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\rbf.py:178: RuntimeWarning:invalid value encountered in multiply
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in square
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:243: RuntimeWarning:invalid value encountered in divide
# GPR: 学習完了
#
# ==================================================
# 反復学習: イテレーション 2/4
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  24.00us (  2.67us)         9
#        nlp_g  |        0 (       0)  32.00us (  3.56us)         9
#   nlp_grad_f  |        0 (       0)  43.00us (  4.30us)        10
#   nlp_hess_l  |        0 (       0)  28.00us (  3.50us)         8
#    nlp_jac_g  |   1.00ms (100.00us) 121.00us ( 12.10us)        10
#        total  |   6.00ms (  6.00ms)   6.07ms (  6.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.70us)        10
#        nlp_g  |        0 (       0)  27.00us (  2.70us)        10
#   nlp_grad_f  |        0 (       0)  51.00us (  4.64us)        11
#   nlp_hess_l  |        0 (       0)  31.00us (  3.44us)         9
#    nlp_jac_g  |        0 (       0)  92.00us (  8.36us)        11
#        total  |   6.00ms (  6.00ms)   6.02ms (  6.02ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  35.00us (  2.33us)        15
#        nlp_g  |        0 (       0)  41.00us (  2.73us)        15
#   nlp_grad_f  |        0 (       0)  59.00us (  3.69us)        16
#   nlp_hess_l  |        0 (       0)  49.00us (  3.50us)        14
#    nlp_jac_g  |        0 (       0) 134.00us (  8.37us)        16
#        total  |        0 (       0)   8.67ms (  8.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.67us)        12
#        nlp_g  |   1.00ms ( 83.33us)  39.00us (  3.25us)        12
#   nlp_grad_f  |        0 (       0)  50.00us (  3.85us)        13
#   nlp_hess_l  |        0 (       0)  37.00us (  3.36us)        11
#    nlp_jac_g  |        0 (       0) 107.00us (  8.23us)        13
#        total  |   8.00ms (  8.00ms)   7.72ms (  7.72ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  29.00us (  2.64us)        11
#        nlp_g  |        0 (       0)  45.00us (  4.09us)        11
#   nlp_grad_f  |        0 (       0)  69.00us (  5.75us)        12
#   nlp_hess_l  |        0 (       0)  33.00us (  3.30us)        10
#    nlp_jac_g  |        0 (       0) 109.00us (  9.08us)        12
#        total  |   7.00ms (  7.00ms)   7.17ms (  7.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.67us)        12
#        nlp_g  |        0 (       0)  33.00us (  2.75us)        12
#   nlp_grad_f  |        0 (       0)  47.00us (  3.62us)        13
#   nlp_hess_l  |        0 (       0)  34.00us (  3.09us)        11
#    nlp_jac_g  |        0 (       0) 107.00us (  8.23us)        13
#        total  |  15.00ms ( 15.00ms)   7.25ms (  7.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  31.00us (  2.58us)        12
#        nlp_g  |        0 (       0)  33.00us (  2.75us)        12
#   nlp_grad_f  |        0 (       0)  51.00us (  3.92us)        13
#   nlp_hess_l  |        0 (       0)  32.00us (  2.91us)        11
#    nlp_jac_g  |        0 (       0) 109.00us (  8.38us)        13
#        total  |        0 (       0)   7.07ms (  7.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.45us)        11
#        nlp_g  |        0 (       0)  29.00us (  2.64us)        11
#   nlp_grad_f  |        0 (       0)  46.00us (  3.83us)        12
#   nlp_hess_l  |        0 (       0)  34.00us (  3.40us)        10
#    nlp_jac_g  |        0 (       0)  97.00us (  8.08us)        12
#        total  |        0 (       0)   6.58ms (  6.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  33.00us (  2.54us)        13
#        nlp_g  |        0 (       0)  39.00us (  3.00us)        13
#   nlp_grad_f  |        0 (       0)  57.00us (  4.07us)        14
#   nlp_hess_l  |        0 (       0)  42.00us (  3.50us)        12
#    nlp_jac_g  |        0 (       0) 127.00us (  9.07us)        14
#        total  |   8.00ms (  8.00ms)   7.69ms (  7.69ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  39.00us (  2.60us)        15
#        nlp_g  |        0 (       0)  54.00us (  3.60us)        15
#   nlp_grad_f  |        0 (       0)  67.00us (  4.19us)        16
#   nlp_hess_l  |        0 (       0)  45.00us (  3.21us)        14
#    nlp_jac_g  |        0 (       0) 148.00us (  9.25us)        16
#        total  |  16.00ms ( 16.00ms)  10.18ms ( 10.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  44.00us (  2.93us)        15
#        nlp_g  |        0 (       0)  45.00us (  3.00us)        15
#   nlp_grad_f  |        0 (       0)  64.00us (  4.00us)        16
#   nlp_hess_l  |        0 (       0)  50.00us (  3.57us)        14
#    nlp_jac_g  |        0 (       0) 142.00us (  8.87us)        16
#        total  |   5.00ms (  5.00ms)   9.09ms (  9.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  33.00us (  2.54us)        13
#        nlp_g  |        0 (       0)  43.00us (  3.31us)        13
#   nlp_grad_f  |        0 (       0)  62.00us (  4.43us)        14
#   nlp_hess_l  |        0 (       0)  40.00us (  3.33us)        12
#    nlp_jac_g  |        0 (       0) 125.00us (  8.93us)        14
#        total  |        0 (       0)   7.79ms (  7.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  42.00us (  2.80us)        15
#        nlp_g  |        0 (       0)  50.00us (  3.33us)        15
#   nlp_grad_f  |        0 (       0)  63.00us (  3.94us)        16
#   nlp_hess_l  |        0 (       0)  42.00us (  3.00us)        14
#    nlp_jac_g  |        0 (       0) 138.00us (  8.62us)        16
#        total  |  15.00ms ( 15.00ms)   9.17ms (  9.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  34.00us (  2.62us)        13
#        nlp_g  |        0 (       0)  48.00us (  3.69us)        13
#   nlp_grad_f  |        0 (       0)  58.00us (  4.14us)        14
#   nlp_hess_l  |        0 (       0)  41.00us (  3.42us)        12
#    nlp_jac_g  |        0 (       0) 132.00us (  9.43us)        14
#        total  |  16.00ms ( 16.00ms)   8.44ms (  8.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  43.00us (  2.87us)        15
#        nlp_g  |        0 (       0)  42.00us (  2.80us)        15
#   nlp_grad_f  |        0 (       0)  67.00us (  4.19us)        16
#   nlp_hess_l  |        0 (       0)  49.00us (  3.50us)        14
#    nlp_jac_g  |        0 (       0) 143.00us (  8.94us)        16
#        total  |   4.00ms (  4.00ms)   8.88ms (  8.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.29us)        14
#        nlp_g  |        0 (       0)  38.00us (  2.71us)        14
#   nlp_grad_f  |        0 (       0)  64.00us (  4.27us)        15
#   nlp_hess_l  |        0 (       0)  41.00us (  3.15us)        13
#    nlp_jac_g  |        0 (       0) 128.00us (  8.53us)        15
#        total  |   8.00ms (  8.00ms)   8.17ms (  8.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.29us)        14
#        nlp_g  |        0 (       0)  43.00us (  3.07us)        14
#   nlp_grad_f  |        0 (       0)  57.00us (  3.80us)        15
#   nlp_hess_l  |        0 (       0)  41.00us (  3.15us)        13
#    nlp_jac_g  |        0 (       0) 124.00us (  8.27us)        15
#        total  |   8.00ms (  8.00ms)   8.27ms (  8.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  39.00us (  2.60us)        15
#        nlp_g  |        0 (       0)  71.00us (  4.73us)        15
#   nlp_grad_f  |        0 (       0)  60.00us (  3.75us)        16
#   nlp_hess_l  |        0 (       0)  49.00us (  3.50us)        14
#    nlp_jac_g  |        0 (       0) 137.00us (  8.56us)        16
#        total  |  18.00ms ( 18.00ms)   9.61ms (  9.61ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  44.00us (  3.14us)        14
#        nlp_g  |        0 (       0)  47.00us (  3.36us)        14
#   nlp_grad_f  |        0 (       0)  61.00us (  4.07us)        15
#   nlp_hess_l  |        0 (       0)  50.00us (  3.85us)        13
#    nlp_jac_g  |        0 (       0) 163.00us ( 10.87us)        15
#        total  |   5.00ms (  5.00ms)   9.15ms (  9.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.25us)        12
#        nlp_g  |        0 (       0)  39.00us (  3.25us)        12
#   nlp_grad_f  |        0 (       0)  48.00us (  3.69us)        13
#   nlp_hess_l  |        0 (       0)  34.00us (  3.09us)        11
#    nlp_jac_g  |        0 (       0) 105.00us (  8.08us)        13
#        total  |        0 (       0)   6.98ms (  6.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  25.00us (  2.27us)        11
#        nlp_g  |        0 (       0)  31.00us (  2.82us)        11
#   nlp_grad_f  |        0 (       0)  42.00us (  3.50us)        12
#   nlp_hess_l  |        0 (       0)  29.00us (  2.90us)        10
#    nlp_jac_g  |        0 (       0)  98.00us (  8.17us)        12
#        total  |        0 (       0)   6.44ms (  6.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  36.00us (  2.40us)        15
#        nlp_g  |        0 (       0)  42.00us (  2.80us)        15
#   nlp_grad_f  |        0 (       0)  63.00us (  3.94us)        16
#   nlp_hess_l  |        0 (       0)  45.00us (  3.21us)        14
#    nlp_jac_g  |        0 (       0) 138.00us (  8.62us)        16
#        total  |  15.00ms ( 15.00ms)   8.70ms (  8.70ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  35.00us (  2.92us)        12
#        nlp_g  |        0 (       0)  50.00us (  4.17us)        12
#   nlp_grad_f  |        0 (       0)  54.00us (  4.15us)        13
#   nlp_hess_l  |        0 (       0)  43.00us (  3.91us)        11
#    nlp_jac_g  |        0 (       0) 127.00us (  9.77us)        13
#        total  |  14.00ms ( 14.00ms)   8.03ms (  8.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  3.20us)        10
#        nlp_g  |        0 (       0)  43.00us (  4.30us)        10
#   nlp_grad_f  |        0 (       0)  48.00us (  4.36us)        11
#   nlp_hess_l  |        0 (       0)  35.00us (  3.89us)         9
#    nlp_jac_g  |        0 (       0) 111.00us ( 10.09us)        11
#        total  |  16.00ms ( 16.00ms)   6.75ms (  6.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  23.00us (  2.30us)        10
#        nlp_g  |        0 (       0)  29.00us (  2.90us)        10
#   nlp_grad_f  |        0 (       0)  47.00us (  4.27us)        11
#   nlp_hess_l  |        0 (       0)  27.00us (  3.00us)         9
#    nlp_jac_g  |        0 (       0)  96.00us (  8.73us)        11
#        total  |   7.00ms (  7.00ms)   6.10ms (  6.10ms)         1
# ステップ 25 でゴールに到達！
# イテレーション 2 の総コスト: 236.67
# GPR: 学習開始...
# GPR: 学習完了
#
# ==================================================
# 反復学習: イテレーション 3/4
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  30.00us (  2.73us)        11
#        nlp_g  |        0 (       0)  36.00us (  3.27us)        11
#   nlp_grad_f  |        0 (       0)  61.00us (  5.08us)        12
#   nlp_hess_l  |        0 (       0)  33.00us (  3.30us)        10
#    nlp_jac_g  |        0 (       0) 110.00us (  9.17us)        12
#        total  |   6.00ms (  6.00ms)   6.97ms (  6.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  24.00us (  2.40us)        10
#        nlp_g  |        0 (       0)  31.00us (  3.10us)        10
#   nlp_grad_f  |   1.00ms ( 90.91us)  44.00us (  4.00us)        11
#   nlp_hess_l  |        0 (       0)  33.00us (  3.67us)         9
#    nlp_jac_g  |        0 (       0)  91.00us (  8.27us)        11
#        total  |   6.00ms (  6.00ms)   6.04ms (  6.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  39.00us (  2.60us)        15
#        nlp_g  |        0 (       0)  45.00us (  3.00us)        15
#   nlp_grad_f  |        0 (       0)  63.00us (  3.94us)        16
#   nlp_hess_l  |        0 (       0)  46.00us (  3.29us)        14
#    nlp_jac_g  |        0 (       0) 132.00us (  8.25us)        16
#        total  |   9.00ms (  9.00ms)   8.87ms (  8.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  30.00us (  2.50us)        12
#        nlp_g  |        0 (       0)  35.00us (  2.92us)        12
#   nlp_grad_f  |        0 (       0)  49.00us (  3.77us)        13
#   nlp_hess_l  |        0 (       0)  33.00us (  3.00us)        11
#    nlp_jac_g  |        0 (       0) 108.00us (  8.31us)        13
#        total  |   8.00ms (  8.00ms)   7.34ms (  7.34ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  28.00us (  2.55us)        11
#        nlp_g  |        0 (       0)  35.00us (  3.18us)        11
#   nlp_grad_f  |        0 (       0)  50.00us (  4.17us)        12
#   nlp_hess_l  |        0 (       0)  65.00us (  6.50us)        10
#    nlp_jac_g  |        0 (       0) 121.00us ( 10.08us)        12
#        total  |   7.00ms (  7.00ms)   7.19ms (  7.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.25us)        12
#        nlp_g  |        0 (       0)  33.00us (  2.75us)        12
#   nlp_grad_f  |        0 (       0)  59.00us (  4.54us)        13
#   nlp_hess_l  |        0 (       0)  35.00us (  3.18us)        11
#    nlp_jac_g  |        0 (       0) 118.00us (  9.08us)        13
#        total  |   7.00ms (  7.00ms)   7.18ms (  7.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.67us)        12
#        nlp_g  |        0 (       0)  34.00us (  2.83us)        12
#   nlp_grad_f  |        0 (       0)  54.00us (  4.15us)        13
#   nlp_hess_l  |        0 (       0)  34.00us (  3.09us)        11
#    nlp_jac_g  |        0 (       0) 114.00us (  8.77us)        13
#        total  |   8.00ms (  8.00ms)   7.19ms (  7.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  26.00us (  2.36us)        11
#        nlp_g  |        0 (       0)  31.00us (  2.82us)        11
#   nlp_grad_f  |        0 (       0)  47.00us (  3.92us)        12
#   nlp_hess_l  |        0 (       0)  29.00us (  2.90us)        10
#    nlp_jac_g  |        0 (       0)  97.00us (  8.08us)        12
#        total  |   2.00ms (  2.00ms)   6.60ms (  6.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.46us)        13
#        nlp_g  |        0 (       0)  38.00us (  2.92us)        13
#   nlp_grad_f  |        0 (       0)  56.00us (  4.00us)        14
#   nlp_hess_l  |        0 (       0)  40.00us (  3.33us)        12
#    nlp_jac_g  |        0 (       0) 126.00us (  9.00us)        14
#        total  |   8.00ms (  8.00ms)   7.87ms (  7.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  38.00us (  2.53us)        15
#        nlp_g  |        0 (       0)  51.00us (  3.40us)        15
#   nlp_grad_f  |        0 (       0)  65.00us (  4.06us)        16
#   nlp_hess_l  |        0 (       0)  44.00us (  3.14us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us) 148.00us (  9.25us)        16
#        total  |  10.00ms ( 10.00ms)   9.31ms (  9.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  43.00us (  2.87us)        15
#        nlp_g  |        0 (       0)  50.00us (  3.33us)        15
#   nlp_grad_f  |        0 (       0)  60.00us (  3.75us)        16
#   nlp_hess_l  |        0 (       0)  47.00us (  3.36us)        14
#    nlp_jac_g  |        0 (       0) 143.00us (  8.94us)        16
#        total  |   9.00ms (  9.00ms)   9.13ms (  9.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  34.00us (  2.62us)        13
#        nlp_g  |        0 (       0)  42.00us (  3.23us)        13
#   nlp_grad_f  |        0 (       0)  51.00us (  3.64us)        14
#   nlp_hess_l  |        0 (       0)  36.00us (  3.00us)        12
#    nlp_jac_g  |        0 (       0) 126.00us (  9.00us)        14
#        total  |   8.00ms (  8.00ms)   7.82ms (  7.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  42.00us (  2.80us)        15
#        nlp_g  |        0 (       0)  45.00us (  3.00us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)  61.00us (  3.81us)        16
#   nlp_hess_l  |        0 (       0)  42.00us (  3.00us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us) 133.00us (  8.31us)        16
#        total  |   8.00ms (  8.00ms)   8.94ms (  8.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  39.00us (  3.00us)        13
#        nlp_g  |        0 (       0)  45.00us (  3.46us)        13
#   nlp_grad_f  |        0 (       0)  62.00us (  4.43us)        14
#   nlp_hess_l  |        0 (       0)  43.00us (  3.58us)        12
#    nlp_jac_g  |        0 (       0) 138.00us (  9.86us)        14
#        total  |  11.00ms ( 11.00ms)   8.18ms (  8.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  50.00us (  3.33us)        15
#        nlp_g  |        0 (       0)  54.00us (  3.60us)        15
#   nlp_grad_f  |        0 (       0) 101.00us (  6.31us)        16
#   nlp_hess_l  |        0 (       0)  51.00us (  3.64us)        14
#    nlp_jac_g  |        0 (       0) 152.00us (  9.50us)        16
#        total  |  17.00ms ( 17.00ms)   9.81ms (  9.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.29us)        14
#        nlp_g  |        0 (       0)  46.00us (  3.29us)        14
#   nlp_grad_f  |        0 (       0)  63.00us (  4.20us)        15
#   nlp_hess_l  |        0 (       0)  50.00us (  3.85us)        13
#    nlp_jac_g  |        0 (       0) 134.00us (  8.93us)        15
#        total  |   6.00ms (  6.00ms)   8.58ms (  8.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  36.00us (  2.57us)        14
#        nlp_g  |        0 (       0)  40.00us (  2.86us)        14
#   nlp_grad_f  |        0 (       0)  57.00us (  3.80us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)  42.00us (  3.23us)        13
#    nlp_jac_g  |        0 (       0) 124.00us (  8.27us)        15
#        total  |   8.00ms (  8.00ms)   8.20ms (  8.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  40.00us (  2.67us)        15
#        nlp_g  |        0 (       0)  51.00us (  3.40us)        15
#   nlp_grad_f  |        0 (       0)  91.00us (  5.69us)        16
#   nlp_hess_l  |        0 (       0)  48.00us (  3.43us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us) 136.00us (  8.50us)        16
#        total  |   9.00ms (  9.00ms)   9.17ms (  9.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  33.00us (  2.36us)        14
#        nlp_g  |        0 (       0)  41.00us (  2.93us)        14
#   nlp_grad_f  |        0 (       0)  63.00us (  4.20us)        15
#   nlp_hess_l  |        0 (       0)  40.00us (  3.08us)        13
#    nlp_jac_g  |        0 (       0) 161.00us ( 10.73us)        15
#        total  |   8.00ms (  8.00ms)   8.22ms (  8.22ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  30.00us (  2.50us)        12
#        nlp_g  |        0 (       0)  34.00us (  2.83us)        12
#   nlp_grad_f  |        0 (       0)  58.00us (  4.46us)        13
#   nlp_hess_l  |        0 (       0)  37.00us (  3.36us)        11
#    nlp_jac_g  |        0 (       0) 118.00us (  9.08us)        13
#        total  |   7.00ms (  7.00ms)   7.16ms (  7.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.45us)        11
#        nlp_g  |        0 (       0)  31.00us (  2.82us)        11
#   nlp_grad_f  |        0 (       0)  47.00us (  3.92us)        12
#   nlp_hess_l  |   1.00ms (100.00us)  38.00us (  3.80us)        10
#    nlp_jac_g  |        0 (       0)  98.00us (  8.17us)        12
#        total  |   7.00ms (  7.00ms)   6.66ms (  6.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  37.00us (  2.47us)        15
#        nlp_g  |        0 (       0)  44.00us (  2.93us)        15
#   nlp_grad_f  |        0 (       0)  59.00us (  3.69us)        16
#   nlp_hess_l  |        0 (       0)  44.00us (  3.14us)        14
#    nlp_jac_g  |        0 (       0) 137.00us (  8.56us)        16
#        total  |   9.00ms (  9.00ms)   8.88ms (  8.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  31.00us (  2.58us)        12
#        nlp_g  |        0 (       0)  37.00us (  3.08us)        12
#   nlp_grad_f  |        0 (       0)  48.00us (  3.69us)        13
#   nlp_hess_l  |        0 (       0)  34.00us (  3.09us)        11
#    nlp_jac_g  |        0 (       0) 110.00us (  8.46us)        13
#        total  |   7.00ms (  7.00ms)   7.16ms (  7.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.70us)        10
#        nlp_g  |        0 (       0)  36.00us (  3.60us)        10
#   nlp_grad_f  |        0 (       0)  49.00us (  4.45us)        11
#   nlp_hess_l  |        0 (       0)  31.00us (  3.44us)         9
#    nlp_jac_g  |        0 (       0) 104.00us (  9.45us)        11
#        total  |   6.00ms (  6.00ms)   6.43ms (  6.43ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  29.00us (  2.90us)        10
#        nlp_g  |        0 (       0)  40.00us (  4.00us)        10
#   nlp_grad_f  |        0 (       0)  47.00us (  4.27us)        11
#   nlp_hess_l  |        0 (       0)  35.00us (  3.89us)         9
#    nlp_jac_g  |   1.00ms ( 90.91us) 100.00us (  9.09us)        11
#        total  |   7.00ms (  7.00ms)   6.41ms (  6.41ms)         1
# ステップ 25 でゴールに到達！
# イテレーション 3 の総コスト: 236.67
# GPR: 学習開始...
# GPR: 学習完了
#
# ==================================================
# 反復学習: イテレーション 4/4
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  35.00us (  3.18us)        11
#        nlp_g  |        0 (       0)  34.00us (  3.09us)        11
#   nlp_grad_f  |        0 (       0)  57.00us (  4.75us)        12
#   nlp_hess_l  |        0 (       0)  34.00us (  3.40us)        10
#    nlp_jac_g  |        0 (       0) 114.00us (  9.50us)        12
#        total  |   2.00ms (  2.00ms)   6.78ms (  6.78ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  21.00us (  2.10us)        10
#        nlp_g  |        0 (       0)  29.00us (  2.90us)        10
#   nlp_grad_f  |        0 (       0)  44.00us (  4.00us)        11
#   nlp_hess_l  |        0 (       0)  30.00us (  3.33us)         9
#    nlp_jac_g  |        0 (       0)  91.00us (  8.27us)        11
#        total  |        0 (       0)   5.96ms (  5.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  48.00us (  3.20us)        15
#        nlp_g  |        0 (       0)  45.00us (  3.00us)        15
#   nlp_grad_f  |        0 (       0)  61.00us (  3.81us)        16
#   nlp_hess_l  |        0 (       0)  43.00us (  3.07us)        14
#    nlp_jac_g  |        0 (       0) 128.00us (  8.00us)        16
#        total  |   2.00ms (  2.00ms)   8.97ms (  8.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  33.00us (  2.75us)        12
#        nlp_g  |        0 (       0)  34.00us (  2.83us)        12
#   nlp_grad_f  |        0 (       0)  48.00us (  3.69us)        13
#   nlp_hess_l  |        0 (       0)  35.00us (  3.18us)        11
#    nlp_jac_g  |        0 (       0) 112.00us (  8.62us)        13
#        total  |   6.00ms (  6.00ms)   7.07ms (  7.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  32.00us (  2.91us)        11
#        nlp_g  |        0 (       0)  40.00us (  3.64us)        11
#   nlp_grad_f  |        0 (       0)  49.00us (  4.08us)        12
#   nlp_hess_l  |        0 (       0)  53.00us (  5.30us)        10
#    nlp_jac_g  |        0 (       0) 108.00us (  9.00us)        12
#        total  |   8.00ms (  8.00ms)   6.88ms (  6.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  34.00us (  2.83us)        12
#        nlp_g  |        0 (       0)  42.00us (  3.50us)        12
#   nlp_grad_f  |        0 (       0)  49.00us (  3.77us)        13
#   nlp_hess_l  |        0 (       0)  36.00us (  3.27us)        11
#    nlp_jac_g  |        0 (       0) 105.00us (  8.08us)        13
#        total  |   8.00ms (  8.00ms)   7.29ms (  7.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  30.00us (  2.50us)        12
#        nlp_g  |        0 (       0)  37.00us (  3.08us)        12
#   nlp_grad_f  |        0 (       0)  50.00us (  3.85us)        13
#   nlp_hess_l  |        0 (       0)  34.00us (  3.09us)        11
#    nlp_jac_g  |        0 (       0) 115.00us (  8.85us)        13
#        total  |  11.00ms ( 11.00ms)   7.38ms (  7.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  29.00us (  2.64us)        11
#        nlp_g  |        0 (       0)  37.00us (  3.36us)        11
#   nlp_grad_f  |        0 (       0)  49.00us (  4.08us)        12
#   nlp_hess_l  |        0 (       0)  36.00us (  3.60us)        10
#    nlp_jac_g  |        0 (       0) 102.00us (  8.50us)        12
#        total  |   7.00ms (  7.00ms)   6.71ms (  6.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  34.00us (  2.62us)        13
#        nlp_g  |        0 (       0)  42.00us (  3.23us)        13
#   nlp_grad_f  |        0 (       0)  51.00us (  3.64us)        14
#   nlp_hess_l  |        0 (       0)  39.00us (  3.25us)        12
#    nlp_jac_g  |        0 (       0) 120.00us (  8.57us)        14
#        total  |   8.00ms (  8.00ms)   7.87ms (  7.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  40.00us (  2.67us)        15
#        nlp_g  |        0 (       0)  57.00us (  3.80us)        15
#   nlp_grad_f  |        0 (       0)  61.00us (  3.81us)        16
#   nlp_hess_l  |        0 (       0)  51.00us (  3.64us)        14
#    nlp_jac_g  |        0 (       0) 145.00us (  9.06us)        16
#        total  |   9.00ms (  9.00ms)   9.11ms (  9.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  38.00us (  2.53us)        15
#        nlp_g  |        0 (       0)  52.00us (  3.47us)        15
#   nlp_grad_f  |        0 (       0)  63.00us (  3.94us)        16
#   nlp_hess_l  |        0 (       0)  44.00us (  3.14us)        14
#    nlp_jac_g  |   2.00ms (125.00us) 135.00us (  8.44us)        16
#        total  |   9.00ms (  9.00ms)   9.28ms (  9.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  31.00us (  2.38us)        13
#        nlp_g  |        0 (       0)  40.00us (  3.08us)        13
#   nlp_grad_f  |        0 (       0)  55.00us (  3.93us)        14
#   nlp_hess_l  |        0 (       0)  39.00us (  3.25us)        12
#    nlp_jac_g  |        0 (       0) 120.00us (  8.57us)        14
#        total  |   5.00ms (  5.00ms)   7.81ms (  7.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  35.00us (  2.33us)        15
#        nlp_g  |        0 (       0)  44.00us (  2.93us)        15
#   nlp_grad_f  |        0 (       0)  58.00us (  3.62us)        16
#   nlp_hess_l  |        0 (       0)  42.00us (  3.00us)        14
#    nlp_jac_g  |        0 (       0) 133.00us (  8.31us)        16
#        total  |   9.00ms (  9.00ms)   8.85ms (  8.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  31.00us (  2.38us)        13
#        nlp_g  |        0 (       0)  38.00us (  2.92us)        13
#   nlp_grad_f  |        0 (       0)  52.00us (  3.71us)        14
#   nlp_hess_l  |        0 (       0)  43.00us (  3.58us)        12
#    nlp_jac_g  |        0 (       0) 125.00us (  8.93us)        14
#        total  |        0 (       0)   7.62ms (  7.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  40.00us (  2.67us)        15
#        nlp_g  |        0 (       0)  52.00us (  3.47us)        15
#   nlp_grad_f  |        0 (       0)  62.00us (  3.87us)        16
#   nlp_hess_l  |        0 (       0)  57.00us (  4.07us)        14
#    nlp_jac_g  |        0 (       0) 141.00us (  8.81us)        16
#        total  |  14.00ms ( 14.00ms)   9.31ms (  9.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  36.00us (  2.57us)        14
#        nlp_g  |        0 (       0)  43.00us (  3.07us)        14
#   nlp_grad_f  |        0 (       0)  56.00us (  3.73us)        15
#   nlp_hess_l  |        0 (       0)  44.00us (  3.38us)        13
#    nlp_jac_g  |        0 (       0) 156.00us ( 10.40us)        15
#        total  |  17.00ms ( 17.00ms)   8.67ms (  8.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  34.00us (  2.43us)        14
#        nlp_g  |        0 (       0)  41.00us (  2.93us)        14
#   nlp_grad_f  |        0 (       0)  73.00us (  4.87us)        15
#   nlp_hess_l  |        0 (       0)  45.00us (  3.46us)        13
#    nlp_jac_g  |        0 (       0) 127.00us (  8.47us)        15
#        total  |   4.00ms (  4.00ms)   8.28ms (  8.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  36.00us (  2.40us)        15
#        nlp_g  |        0 (       0)  42.00us (  2.80us)        15
#   nlp_grad_f  |        0 (       0)  59.00us (  3.69us)        16
#   nlp_hess_l  |        0 (       0)  41.00us (  2.93us)        14
#    nlp_jac_g  |        0 (       0) 131.00us (  8.19us)        16
#        total  |   9.00ms (  9.00ms)   8.79ms (  8.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  31.00us (  2.21us)        14
#        nlp_g  |        0 (       0)  45.00us (  3.21us)        14
#   nlp_grad_f  |        0 (       0)  62.00us (  4.13us)        15
#   nlp_hess_l  |        0 (       0)  42.00us (  3.23us)        13
#    nlp_jac_g  |        0 (       0) 125.00us (  8.33us)        15
#        total  |   8.00ms (  8.00ms)   8.40ms (  8.40ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  29.00us (  2.42us)        12
#        nlp_g  |        0 (       0)  37.00us (  3.08us)        12
#   nlp_grad_f  |        0 (       0)  48.00us (  3.69us)        13
#   nlp_hess_l  |        0 (       0)  35.00us (  3.18us)        11
#    nlp_jac_g  |        0 (       0) 114.00us (  8.77us)        13
#        total  |   7.00ms (  7.00ms)   7.00ms (  7.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  29.00us (  2.64us)        11
#        nlp_g  |        0 (       0)  34.00us (  3.09us)        11
#   nlp_grad_f  |        0 (       0)  54.00us (  4.50us)        12
#   nlp_hess_l  |        0 (       0)  32.00us (  3.20us)        10
#    nlp_jac_g  |        0 (       0) 102.00us (  8.50us)        12
#        total  |   6.00ms (  6.00ms)   6.60ms (  6.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  37.00us (  2.47us)        15
#        nlp_g  |        0 (       0)  50.00us (  3.33us)        15
#   nlp_grad_f  |        0 (       0)  63.00us (  3.94us)        16
#   nlp_hess_l  |        0 (       0)  44.00us (  3.14us)        14
#    nlp_jac_g  |        0 (       0) 138.00us (  8.62us)        16
#        total  |   9.00ms (  9.00ms)   8.82ms (  8.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  30.00us (  2.50us)        12
#        nlp_g  |        0 (       0)  36.00us (  3.00us)        12
#   nlp_grad_f  |        0 (       0)  51.00us (  3.92us)        13
#   nlp_hess_l  |        0 (       0)  39.00us (  3.55us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us) 115.00us (  8.85us)        13
#        total  |   7.00ms (  7.00ms)   7.27ms (  7.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  27.00us (  2.70us)        10
#        nlp_g  |        0 (       0)  35.00us (  3.50us)        10
#   nlp_grad_f  |        0 (       0)  45.00us (  4.09us)        11
#   nlp_hess_l  |        0 (       0)  28.00us (  3.11us)         9
#    nlp_jac_g  |        0 (       0) 105.00us (  9.55us)        11
#        total  |   7.00ms (  7.00ms)   6.20ms (  6.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  24.00us (  2.40us)        10
#        nlp_g  |        0 (       0)  32.00us (  3.20us)        10
#   nlp_grad_f  |        0 (       0)  41.00us (  3.73us)        11
#   nlp_hess_l  |        0 (       0)  30.00us (  3.33us)         9
#    nlp_jac_g  |        0 (       0)  93.00us (  8.45us)        11
#        total  |   6.00ms (  6.00ms)   6.05ms (  6.05ms)         1
# ステップ 25 でゴールに到達！
# イテレーション 4 の総コスト: 236.67
# GPR: 学習開始...
# GPR: 学習完了
