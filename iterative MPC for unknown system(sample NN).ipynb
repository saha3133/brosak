# %% [markdown]
# NNを元に2次関数の終端コストを決定

# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import torch
import torch.nn as nn
import torch.optim as optim
import time

# (Matplotlibの設定は変更なし)
import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)

# ==================================================================================
# シミュレーション全体の設定パラメータ
# ==================================================================================
N_ITERATIONS = 5
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE = np.array([10.0, 10.0])
N_MPC = 20
M_MPC = 25
OBSTACLE_INFO = {'pos': np.array([5.0, 5.0]), 'rad': 1.5}


# ----------------------------------------------------------------------------------
# Component 1: TerminalCostNN & 学習関数
# ----------------------------------------------------------------------------------
class TerminalCostNN(nn.Module):
    def __init__(self, n_input):
        super(TerminalCostNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_input, 64), nn.ReLU(),
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.layers(x)

def train_terminal_cost_net(net, trajectory_data):
    if len(trajectory_data) < 10: return
    print("NN: 終端コストの学習開始...")
    optimizer = optim.Adam(net.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    states = torch.tensor(np.array([d[0] for d in trajectory_data]), dtype=torch.float32)
    costs_to_go = []
    running_cost = 0
    for _, stage_cost in reversed(trajectory_data):
        running_cost += stage_cost
        costs_to_go.append(running_cost)
    costs_to_go.reverse()
    labels = torch.tensor(costs_to_go, dtype=torch.float32).view(-1, 1)
    for epoch in range(100):
        optimizer.zero_grad(); outputs = net(states); loss = criterion(outputs, labels)
        loss.backward(); optimizer.step()
    print(f"NN: 学習完了。最終損失: {loss.item():.4f}")

# (TrueVehicle, GPRModelクラスは変更なし)
class TrueVehicle:
    def __init__(self, dt=0.1): self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u; drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt; vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2; py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])
class GPRModel:
    def __init__(self, nx, nu, dt, obstacle_info):
        self.nx, self.nu = nx, nu
        self.dt=DT
        self.obstacle_info=OBSTACLE_INFO
        self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu))
        self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx

    def add_data(self, x, u, x_next):
        # 公称モデルからの誤差（デルタ）を学習ターゲットにする
        delta_real = (x_next - x) / self.dt
        delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])])
        self.Y_data = np.vstack([self.Y_data, error])

    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始...")
        for i in range(self.nx):
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100)
            self.models[i] = model
        self.is_trained = True
        print("GPR: 学習完了")

    def predict(self, x, u):
        if not self.is_trained:
            return np.zeros(self.nx), np.ones(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        variances = np.array([m.predict(xu)[1][0, 0] if m else 1.0 for m in self.models])
        return means, variances

# ----------------------------------------------------------------------------------
# Component 3: MPCController
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, M, dt, obstacle_info):
        self.nx, self.nu, self.N, self.M, self.dt = nx, nu, N, M, dt
        self.obstacle_info = obstacle_info; self.u_prev_sol = np.zeros((nu, N))

    # ✅ 変更点：NNをアドバイザーとして使う方式に変更
    def solve(self, x_current, gpr_model, x_goal, terminal_cost_net, is_first_iteration):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)

        # --- ステップ１：NNで「賢い目標地点」を大まかに探す ---
        if is_first_iteration:
            # 最初のイテレーションではNNが未学習なので、ゴールをそのまま使う
            smart_target = x_goal
        else:
            # 現在位置から周辺のいくつかの候補点を生成
            num_candidates = 20
            candidates_pos = np.random.randn(num_candidates, 2) * 2.0 + x_current[:2]
            candidates_vel = np.zeros((num_candidates, 2))
            candidates = np.hstack([candidates_pos, candidates_vel])
            
            # NNで各候補点のコストを評価
            candidates_torch = torch.tensor(candidates, dtype=torch.float32)
            with torch.no_grad():
                costs = terminal_cost_net(candidates_torch).numpy().flatten()
            
            # 最もコストが低い候補点を「賢い目標地点」とする
            smart_target = candidates_pos[np.argmin(costs)]

        error_mean, error_var = gpr_model.predict(x_current, np.zeros(self.nu))
        error_std = np.sqrt(np.maximum(error_var, 1e-6)); error_std_capped = np.minimum(error_std, 0.2)
        error_samples = np.random.normal(loc=error_mean, scale=error_std_capped, size=(self.M, self.nx))
        
        all_scenario_costs = []
        for m in range(self.M):
            X_scenario = opti.variable(self.nx, self.N + 1); cost_scenario = 0
            opti.subject_to(X_scenario[:, 0] == x_current)
            for k in range(self.N):
                x_k, u_k = X_scenario[:, k], U[:, k]
                delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
                delta_pred = delta_nominal + error_samples[m, :]
                x_next_pred = x_k + delta_pred * self.dt
                opti.subject_to(X_scenario[:, k+1] == x_next_pred)
                cost_scenario += ca.sumsqr(x_k[:2] - x_goal) * self.dt + ca.sumsqr(u_k) * self.dt * 0.01
                if self.obstacle_info:
                    dist_to_obs = ca.norm_2(x_k[:2] - self.obstacle_info['pos'])
                    penalty = ca.fmax(0, self.obstacle_info['rad'] - dist_to_obs)
                    cost_scenario += 500.0 * penalty**2
            
            # --- ステップ２：MPCの終端コストとして、その「賢い目標地点」を目指す ---
            terminal_state = X_scenario[:, self.N]
            cost_scenario += ca.sumsqr(terminal_state[:2] - smart_target) * 10.0

            all_scenario_costs.append(cost_scenario)
        
        #total_objective = ca.mean(ca.vertcat(*all_scenario_costs))
        total_objective = ca.sum1(ca.vertcat(*all_scenario_costs)) / len(all_scenario_costs)
        opti.minimize(total_objective)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))
        opti.set_initial(U, self.u_prev_sol)
        s_opts = {'print_level': 0}; opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}"); return np.zeros(self.nu)

# ----------------------------------------------------------------------------------
# Main Simulation Loop
# ----------------------------------------------------------------------------------
def main():
    vehicle = TrueVehicle(dt=DT)
    gpr_model = GPRModel(nx=NX, nu=NU,dt=DT, obstacle_info=OBSTACLE_INFO)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, M=M_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)
    terminal_cost_net = TerminalCostNN(n_input=NX)
    all_trajectories, final_costs = [], []
    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE); total_cost = 0
        iteration_data_for_gpr, iteration_data_for_cost_learning = [], []
        for step in range(SIM_STEPS):
            is_first_iter = (i == 0)
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE, terminal_cost_net, is_first_iter)
            x_next = vehicle.dynamics(current_x, u_optimal)
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data_for_gpr.append((current_x, u_optimal, x_next))
            iteration_data_for_cost_learning.append((current_x, stage_cost))
            current_x = x_next
            if np.linalg.norm(current_x[:2] - GOAL_STATE) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！"); break
        all_trajectories.append(np.array([d[0] for d in iteration_data_for_cost_learning]))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")
        for x, u, x_n in iteration_data_for_gpr:
            gpr_model.add_data(x, u, x_n)
        gpr_model.train()
        train_terminal_cost_net(terminal_cost_net, iteration_data_for_cost_learning)
    # (可視化コードは変更なし)
    plt.figure(figsize=(10, 10))
    if OBSTACLE_INFO:
        obs_circle = plt.Circle(OBSTACLE_INFO['pos'], OBSTACLE_INFO['rad'], color='r', alpha=0.5, label='障害物')
        plt.gca().add_patch(obs_circle)
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE[0], GOAL_STATE[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡（NNアドバイザー方式）'); plt.legend(); plt.axis('equal'); plt.show()
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移'); plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト'); plt.xticks(range(1, N_ITERATIONS + 1)); plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (187.50us)   5.46ms (170.69us)        32
#        nlp_g  |   3.00ms ( 93.75us)   3.94ms (123.09us)        32
#   nlp_grad_f  |  10.00ms (303.03us)   9.90ms (299.88us)        33
#   nlp_hess_l  |  29.00ms (935.48us)  21.10ms (680.58us)        31
#    nlp_jac_g  |   5.00ms (151.52us)  10.89ms (329.94us)        33
#        total  | 288.00ms (288.00ms) 300.03ms (300.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (153.85us)   5.29ms (203.35us)        26
#        nlp_g  |   3.00ms (115.38us)   3.91ms (150.27us)        26
#   nlp_grad_f  |   4.00ms (148.15us)   9.77ms (362.04us)        27
#   nlp_hess_l  |  29.00ms (  1.16ms)  20.06ms (802.48us)        25
#    nlp_jac_g  |  22.00ms (814.81us)  10.64ms (393.93us)        27
#        total  | 233.00ms (233.00ms) 238.67ms (238.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   8.00ms (296.30us)   5.04ms (186.78us)        27
#        nlp_g  |   1.00ms ( 37.04us)   3.72ms (137.74us)        27
#   nlp_grad_f  |   2.00ms ( 71.43us)   9.12ms (325.79us)        28
#   nlp_hess_l  |  16.00ms (615.38us)  19.32ms (743.23us)        26
#    nlp_jac_g  |   7.00ms (250.00us)   9.94ms (355.00us)        28
#        total  | 264.00ms (264.00ms) 263.06ms (263.06ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.68ms (180.12us)        26
#        nlp_g  |   1.00ms ( 38.46us)   3.27ms (125.96us)        26
#   nlp_grad_f  |   4.00ms (148.15us)   8.07ms (298.89us)        27
#   nlp_hess_l  |  12.00ms (480.00us)  17.48ms (699.24us)        25
#    nlp_jac_g  |   8.00ms (296.30us)   8.83ms (327.22us)        27
#        total  | 250.00ms (250.00ms) 255.13ms (255.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.81ms (165.18us)        17
#        nlp_g  |   1.00ms ( 58.82us)   2.00ms (117.71us)        17
#   nlp_grad_f  |  16.00ms (888.89us)   5.21ms (289.39us)        18
#   nlp_hess_l  |   1.00ms ( 62.50us)  10.14ms (634.00us)        16
#    nlp_jac_g  |  17.00ms (944.44us)   5.64ms (313.22us)        18
#        total  | 141.00ms (141.00ms) 128.89ms (128.89ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.45ms (164.48us)        21
#        nlp_g  |        0 (       0)   2.43ms (115.95us)        21
#   nlp_grad_f  |   1.00ms ( 45.45us)   6.30ms (286.55us)        22
#   nlp_hess_l  |        0 (       0)  12.75ms (637.60us)        20
#    nlp_jac_g  |  15.00ms (681.82us)   6.93ms (315.14us)        22
#        total  | 168.00ms (168.00ms) 160.91ms (160.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.61ms (173.73us)        15
#        nlp_g  |        0 (       0)   1.92ms (128.33us)        15
#   nlp_grad_f  |   5.00ms (312.50us)   5.22ms (326.44us)        16
#   nlp_hess_l  |   7.00ms (500.00us)  10.14ms (724.57us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   5.42ms (338.62us)        16
#        total  | 123.00ms (123.00ms) 116.37ms (116.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (187.50us)   2.53ms (158.06us)        16
#        nlp_g  |   2.00ms (125.00us)   1.80ms (112.31us)        16
#   nlp_grad_f  |   5.00ms (294.12us)   4.74ms (278.65us)        17
#   nlp_hess_l  |   7.00ms (466.67us)   8.89ms (592.67us)        15
#    nlp_jac_g  |   4.00ms (235.29us)   5.24ms (308.00us)        17
#        total  | 120.00ms (120.00ms) 120.40ms (120.40ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.40ms (171.79us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.70ms (121.64us)        14
#   nlp_grad_f  |  12.00ms (800.00us)   5.05ms (336.87us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   9.17ms (705.38us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   5.00ms (333.27us)        15
#        total  | 110.00ms (110.00ms) 110.07ms (110.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.00ms (154.23us)        13
#        nlp_g  |        0 (       0)   1.48ms (113.85us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   4.23ms (302.21us)        14
#   nlp_hess_l  |   4.00ms (333.33us)   7.52ms (626.42us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.40ms (314.07us)        14
#        total  | 100.00ms (100.00ms) 103.97ms (103.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.75ms (171.87us)        16
#        nlp_g  |        0 (       0)   2.00ms (124.94us)        16
#   nlp_grad_f  |        0 (       0)   5.33ms (313.53us)        17
#   nlp_hess_l  |   2.00ms (133.33us)   9.85ms (656.80us)        15
#    nlp_jac_g  |        0 (       0)   5.60ms (329.24us)        17
#        total  | 133.00ms (133.00ms) 130.68ms (130.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (117.65us)   2.71ms (159.47us)        17
#        nlp_g  |   1.00ms ( 58.82us)   1.83ms (107.94us)        17
#   nlp_grad_f  |        0 (       0)   5.03ms (314.25us)        16
#   nlp_hess_l  |  23.00ms (  1.64ms)   9.38ms (670.07us)        14
#    nlp_jac_g  |        0 (       0)   5.24ms (327.75us)        16
#        total  | 116.00ms (116.00ms) 119.28ms (119.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.04ms (157.00us)        13
#        nlp_g  |        0 (       0)   1.49ms (115.00us)        13
#   nlp_grad_f  |        0 (       0)   4.19ms (299.50us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.16ms (596.50us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.29ms (306.79us)        14
#        total  | 100.00ms (100.00ms) 101.20ms (101.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.51ms (167.20us)        15
#        nlp_g  |        0 (       0)   1.68ms (112.27us)        15
#   nlp_grad_f  |        0 (       0)   4.78ms (298.94us)        16
#   nlp_hess_l  |   2.00ms (142.86us)   9.02ms (644.50us)        14
#    nlp_jac_g  |        0 (       0)   5.16ms (322.50us)        16
#        total  | 134.00ms (134.00ms) 125.23ms (125.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.31ms (154.20us)        15
#        nlp_g  |        0 (       0)   1.54ms (102.93us)        15
#   nlp_grad_f  |        0 (       0)   4.65ms (290.87us)        16
#   nlp_hess_l  |  15.00ms (  1.07ms)   8.26ms (590.36us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   4.64ms (289.81us)        16
#        total  | 122.00ms (122.00ms) 118.03ms (118.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.92ms (148.08us)        13
#        nlp_g  |        0 (       0)   1.30ms (100.15us)        13
#   nlp_grad_f  |        0 (       0)   3.70ms (264.64us)        14
#   nlp_hess_l  |   1.00ms ( 83.33us)   7.14ms (594.75us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   3.97ms (283.93us)        14
#        total  |  99.00ms ( 99.00ms)  97.42ms ( 97.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.23ms (148.73us)        15
#        nlp_g  |        0 (       0)   1.67ms (111.07us)        15
#   nlp_grad_f  |        0 (       0)   4.26ms (266.12us)        16
#   nlp_hess_l  |        0 (       0)   8.13ms (580.50us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   4.64ms (289.87us)        16
#        total  | 116.00ms (116.00ms) 112.94ms (112.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   1.95ms (150.15us)        13
#        nlp_g  |        0 (       0)   1.31ms (100.54us)        13
#   nlp_grad_f  |        0 (       0)   3.75ms (268.21us)        14
#   nlp_hess_l  |        0 (       0)   7.38ms (615.17us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.06ms (290.00us)        14
#        total  | 103.00ms (103.00ms) 102.74ms (102.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.17ms (144.87us)        15
#        nlp_g  |        0 (       0)   1.53ms (102.07us)        15
#   nlp_grad_f  |        0 (       0)   4.43ms (276.87us)        16
#   nlp_hess_l  |  16.00ms (  1.14ms)   8.16ms (582.57us)        14
#    nlp_jac_g  |        0 (       0)   4.52ms (282.62us)        16
#        total  | 120.00ms (120.00ms) 114.55ms (114.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   1.78ms (137.31us)        13
#        nlp_g  |        0 (       0)   1.31ms (100.77us)        13
#   nlp_grad_f  |        0 (       0)   3.79ms (270.43us)        14
#   nlp_hess_l  |  14.00ms (  1.17ms)   6.57ms (547.50us)        12
#    nlp_jac_g  |        0 (       0)   4.27ms (304.86us)        14
#        total  |  86.00ms ( 86.00ms)  95.66ms ( 95.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.03ms (144.79us)        14
#        nlp_g  |        0 (       0)   1.38ms ( 98.50us)        14
#   nlp_grad_f  |        0 (       0)   3.98ms (265.47us)        15
#   nlp_hess_l  |  32.00ms (  2.46ms)   7.69ms (591.62us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.15ms (276.47us)        15
#        total  |  99.00ms ( 99.00ms) 103.28ms (103.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.93ms (148.77us)        13
#        nlp_g  |        0 (       0)   1.42ms (109.31us)        13
#   nlp_grad_f  |        0 (       0)   4.00ms (286.07us)        14
#   nlp_hess_l  |        0 (       0)   7.50ms (625.33us)        12
#    nlp_jac_g  |        0 (       0)   4.25ms (303.50us)        14
#        total  | 100.00ms (100.00ms) 107.16ms (107.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.13ms (152.07us)        14
#        nlp_g  |        0 (       0)   1.60ms (114.14us)        14
#   nlp_grad_f  |        0 (       0)   4.53ms (302.07us)        15
#   nlp_hess_l  |  16.00ms (  1.23ms)   7.94ms (610.69us)        13
#    nlp_jac_g  |        0 (       0)   4.93ms (328.60us)        15
#        total  | 109.00ms (109.00ms) 108.09ms (108.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.83ms (152.58us)        12
#        nlp_g  |        0 (       0)   1.30ms (108.75us)        12
#   nlp_grad_f  |  13.00ms (  1.00ms)   3.83ms (294.31us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   6.83ms (621.18us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   4.12ms (316.77us)        13
#        total  |  83.00ms ( 83.00ms)  92.45ms ( 92.45ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.07ms (158.92us)        13
#        nlp_g  |        0 (       0)   1.57ms (120.92us)        13
#   nlp_grad_f  |        0 (       0)   4.50ms (321.64us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.79ms (649.17us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.75ms (339.21us)        14
#        total  |  97.00ms ( 97.00ms) 108.38ms (108.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.12ms (163.31us)        13
#        nlp_g  |        0 (       0)   1.55ms (119.00us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.49ms (320.64us)        14
#   nlp_hess_l  |        0 (       0)   7.57ms (630.75us)        12
#    nlp_jac_g  |        0 (       0)   4.68ms (334.00us)        14
#        total  | 109.00ms (109.00ms) 106.12ms (106.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (307.69us)   2.23ms (171.92us)        13
#        nlp_g  |        0 (       0)   1.60ms (123.46us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.56ms (325.86us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.38ms (614.92us)        12
#    nlp_jac_g  |        0 (       0)   4.98ms (355.64us)        14
#        total  |  99.00ms ( 99.00ms) 106.90ms (106.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.06ms (158.54us)        13
#        nlp_g  |        0 (       0)   1.49ms (114.77us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.25ms (303.50us)        14
#   nlp_hess_l  |  16.00ms (  1.33ms)   7.57ms (630.67us)        12
#    nlp_jac_g  |        0 (       0)   4.44ms (317.14us)        14
#        total  | 114.00ms (114.00ms) 103.84ms (103.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.25ms)   1.91ms (159.08us)        12
#        nlp_g  |        0 (       0)   1.28ms (107.00us)        12
#   nlp_grad_f  |        0 (       0)   3.60ms (277.31us)        13
#   nlp_hess_l  |   3.00ms (272.73us)   6.86ms (623.27us)        11
#    nlp_jac_g  |  15.00ms (  1.15ms)   4.07ms (313.00us)        13
#        total  |  96.00ms ( 96.00ms)  96.37ms ( 96.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.24ms (177.86us)         7
#        nlp_g  |        0 (       0) 905.00us (129.29us)         7
#   nlp_grad_f  |        0 (       0)   5.01ms (626.50us)         8
#   nlp_hess_l  |  11.00ms (  1.83ms)   4.31ms (718.33us)         6
#    nlp_jac_g  |   6.00ms (750.00us)   3.40ms (425.50us)         8
#        total  |  55.00ms ( 55.00ms)  59.20ms ( 59.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.27ms (158.50us)         8
#        nlp_g  |   1.00ms (125.00us) 924.00us (115.50us)         8
#   nlp_grad_f  |        0 (       0)   2.88ms (320.11us)         9
#   nlp_hess_l  |        0 (       0)   4.51ms (644.57us)         7
#    nlp_jac_g  |   1.00ms (111.11us)   3.09ms (342.89us)         9
#        total  |  66.00ms ( 66.00ms)  66.13ms ( 66.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.27ms (181.86us)         7
#        nlp_g  |        0 (       0) 916.00us (130.86us)         7
#   nlp_grad_f  |        0 (       0)   2.34ms (292.62us)         8
#   nlp_hess_l  |        0 (       0)   4.14ms (690.00us)         6
#    nlp_jac_g  |        0 (       0)   2.47ms (308.62us)         8
#        total  |  67.00ms ( 67.00ms)  61.37ms ( 61.37ms)         1
# ステップ 32 でゴールに到達！
# イテレーション 1 の総コスト: 309.19
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 15248.7217
#
# ==================================================
# 反復学習: イテレーション 2/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (272.73us)   1.67ms (151.55us)        11
#        nlp_g  |        0 (       0)   1.18ms (107.09us)        11
#   nlp_grad_f  |        0 (       0)   3.54ms (295.42us)        12
#   nlp_hess_l  |        0 (       0)   6.11ms (610.60us)        10
#    nlp_jac_g  |   2.00ms (166.67us)   3.69ms (307.67us)        12
#        total  |  80.00ms ( 80.00ms)  88.48ms ( 88.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.70ms (154.36us)        11
#        nlp_g  |        0 (       0)   1.21ms (109.64us)        11
#   nlp_grad_f  |        0 (       0)   3.59ms (299.58us)        12
#   nlp_hess_l  |        0 (       0)   6.38ms (637.80us)        10
#    nlp_jac_g  |   1.00ms ( 83.33us)   3.89ms (324.42us)        12
#        total  |  86.00ms ( 86.00ms)  88.73ms ( 88.73ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   1.80ms (163.91us)        11
#        nlp_g  |        0 (       0)   1.42ms (128.73us)        11
#   nlp_grad_f  |        0 (       0)   3.82ms (318.50us)        12
#   nlp_hess_l  |        0 (       0)   6.37ms (637.40us)        10
#    nlp_jac_g  |        0 (       0)   4.12ms (343.25us)        12
#        total  |  81.00ms ( 81.00ms)  89.94ms ( 89.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.64ms (164.00us)        10
#        nlp_g  |        0 (       0)   1.24ms (124.50us)        10
#   nlp_grad_f  |        0 (       0)   3.42ms (311.36us)        11
#   nlp_hess_l  |  18.00ms (  2.00ms)   5.75ms (638.78us)         9
#    nlp_jac_g  |        0 (       0)   3.73ms (339.55us)        11
#        total  |  83.00ms ( 83.00ms)  81.03ms ( 81.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.65ms (183.22us)         9
#        nlp_g  |        0 (       0)   1.14ms (126.67us)         9
#   nlp_grad_f  |  17.00ms (  1.70ms)   3.18ms (318.50us)        10
#   nlp_hess_l  |  15.00ms (  1.87ms)   5.02ms (627.25us)         8
#    nlp_jac_g  |   2.00ms (200.00us)   3.11ms (311.20us)        10
#        total  |  83.00ms ( 83.00ms)  73.45ms ( 73.45ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.36ms (151.56us)         9
#        nlp_g  |  16.00ms (  1.78ms) 954.00us (106.00us)         9
#   nlp_grad_f  |        0 (       0)   3.06ms (306.10us)        10
#   nlp_hess_l  |        0 (       0)   4.82ms (602.62us)         8
#    nlp_jac_g  |  18.00ms (  1.80ms)   3.33ms (333.20us)        10
#        total  |  74.00ms ( 74.00ms)  72.66ms ( 72.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.36ms (151.00us)         9
#        nlp_g  |        0 (       0) 975.00us (108.33us)         9
#   nlp_grad_f  |        0 (       0)   2.65ms (264.90us)        10
#   nlp_hess_l  |  15.00ms (  1.87ms)   4.96ms (619.75us)         8
#    nlp_jac_g  |   2.00ms (200.00us)   2.86ms (286.40us)        10
#        total  |  60.00ms ( 60.00ms)  69.99ms ( 69.99ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.07ms (159.54us)        13
#        nlp_g  |        0 (       0)   1.47ms (113.08us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.30ms (307.36us)        14
#   nlp_hess_l  |  28.00ms (  2.33ms)   7.88ms (656.67us)        12
#    nlp_jac_g  |        0 (       0)   4.69ms (334.71us)        14
#        total  | 114.00ms (114.00ms) 111.60ms (111.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.39ms (159.13us)        15
#        nlp_g  |        0 (       0)   1.62ms (108.07us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   4.58ms (286.37us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us)   8.61ms (615.29us)        14
#    nlp_jac_g  |        0 (       0)   4.71ms (294.37us)        16
#        total  | 149.00ms (149.00ms) 144.74ms (144.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.13ms (141.80us)        15
#        nlp_g  |        0 (       0)   1.45ms ( 96.73us)        15
#   nlp_grad_f  |        0 (       0)   4.34ms (271.25us)        16
#   nlp_hess_l  |  10.00ms (714.29us)   7.88ms (563.14us)        14
#    nlp_jac_g  |  28.00ms (  1.75ms)   4.80ms (299.75us)        16
#        total  | 134.00ms (134.00ms) 139.03ms (139.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 55.56us)   2.61ms (144.89us)        18
#        nlp_g  |        0 (       0)   1.84ms (102.50us)        18
#   nlp_grad_f  |   2.00ms (105.26us)   5.07ms (267.00us)        19
#   nlp_hess_l  |        0 (       0)   9.74ms (573.18us)        17
#    nlp_jac_g  |   2.00ms (105.26us)   5.55ms (292.00us)        19
#        total  | 160.00ms (160.00ms) 170.49ms (170.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.39ms (159.20us)        15
#        nlp_g  |        0 (       0)   1.69ms (112.73us)        15
#   nlp_grad_f  |        0 (       0)   4.54ms (283.50us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us)   8.83ms (630.71us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   4.79ms (299.50us)        16
#        total  | 151.00ms (151.00ms) 146.40ms (146.40ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.08ms (160.08us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.42ms (109.31us)        13
#   nlp_grad_f  |        0 (       0)   4.24ms (302.93us)        14
#   nlp_hess_l  |  16.00ms (  1.33ms)   7.44ms (620.08us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.53ms (323.93us)        14
#        total  | 100.00ms (100.00ms) 101.13ms (101.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (363.64us)   1.61ms (146.73us)        11
#        nlp_g  |   2.00ms (181.82us)   1.09ms ( 98.73us)        11
#   nlp_grad_f  |        0 (       0)   3.38ms (281.83us)        12
#   nlp_hess_l  |   5.00ms (500.00us)   5.92ms (591.70us)        10
#    nlp_jac_g  |        0 (       0)   3.75ms (312.42us)        12
#        total  |  85.00ms ( 85.00ms)  85.52ms ( 85.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   1.60ms (160.20us)        10
#        nlp_g  |   2.00ms (200.00us)   1.05ms (105.50us)        10
#   nlp_grad_f  |        0 (       0)   3.37ms (306.45us)        11
#   nlp_hess_l  |   5.00ms (555.56us)   5.47ms (608.00us)         9
#    nlp_jac_g  |        0 (       0)   3.57ms (324.27us)        11
#        total  |  74.00ms ( 74.00ms)  78.42ms ( 78.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   1.67ms (167.40us)        10
#        nlp_g  |        0 (       0)   1.17ms (116.60us)        10
#   nlp_grad_f  |        0 (       0)   3.57ms (324.73us)        11
#   nlp_hess_l  |  13.00ms (  1.44ms)   5.90ms (655.89us)         9
#    nlp_jac_g  |   2.00ms (181.82us)   3.81ms (346.55us)        11
#        total  |  84.00ms ( 84.00ms)  81.74ms ( 81.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.57ms (156.70us)        10
#        nlp_g  |        0 (       0)   1.11ms (110.80us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   3.37ms (306.64us)        11
#   nlp_hess_l  |  12.00ms (  1.33ms)   5.83ms (647.56us)         9
#    nlp_jac_g  |   1.00ms ( 90.91us)   3.55ms (322.91us)        11
#        total  |  82.00ms ( 82.00ms)  80.63ms ( 80.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.00ms (166.58us)        12
#        nlp_g  |        0 (       0)   1.41ms (117.92us)        12
#   nlp_grad_f  |   1.00ms ( 76.92us)   3.70ms (284.69us)        13
#   nlp_hess_l  |        0 (       0)   6.70ms (609.09us)        11
#    nlp_jac_g  |        0 (       0)   3.91ms (300.54us)        13
#        total  | 100.00ms (100.00ms)  97.88ms ( 97.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 50.00us)   3.11ms (155.40us)        20
#        nlp_g  |   2.00ms (100.00us)   2.12ms (105.95us)        20
#   nlp_grad_f  |        0 (       0)   5.77ms (275.00us)        21
#   nlp_hess_l  |  12.00ms (631.58us)  11.73ms (617.16us)        19
#    nlp_jac_g  |        0 (       0)   6.27ms (298.81us)        21
#        total  | 195.00ms (195.00ms) 183.67ms (183.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.06ms (160.84us)        19
#        nlp_g  |        0 (       0)   2.08ms (109.42us)        19
#   nlp_grad_f  |        0 (       0)   5.70ms (285.15us)        20
#   nlp_hess_l  |   1.00ms ( 55.56us)  11.50ms (639.11us)        18
#    nlp_jac_g  |        0 (       0)   6.15ms (307.65us)        20
#        total  | 183.00ms (183.00ms) 188.86ms (188.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.73ms (170.87us)        16
#        nlp_g  |        0 (       0)   1.79ms (112.00us)        16
#   nlp_grad_f  |   1.00ms ( 58.82us)   4.87ms (286.24us)        17
#   nlp_hess_l  |   2.00ms (133.33us)   9.44ms (629.13us)        15
#    nlp_jac_g  |        0 (       0)   5.36ms (315.53us)        17
#        total  | 135.00ms (135.00ms) 126.72ms (126.72ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.08ms (148.29us)        14
#        nlp_g  |        0 (       0)   1.44ms (102.64us)        14
#   nlp_grad_f  |        0 (       0)   4.33ms (288.87us)        15
#   nlp_hess_l  |  15.00ms (  1.15ms)   7.51ms (577.69us)        13
#    nlp_jac_g  |        0 (       0)   4.49ms (299.53us)        15
#        total  | 100.00ms (100.00ms) 111.53ms (111.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.46ms (176.00us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.73ms (123.64us)        14
#   nlp_grad_f  |        0 (       0)   4.93ms (328.87us)        15
#   nlp_hess_l  |  45.00ms (  3.46ms)   7.98ms (614.08us)        13
#    nlp_jac_g  |  15.00ms (  1.00ms)   4.96ms (330.93us)        15
#        total  | 114.00ms (114.00ms) 114.35ms (114.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (410.26us)   6.32ms (162.18us)        39
#        nlp_g  |   1.00ms ( 25.64us)   4.49ms (115.03us)        39
#   nlp_grad_f  |        0 (       0)  11.87ms (296.75us)        40
#   nlp_hess_l  |   1.00ms ( 26.32us)  24.49ms (644.45us)        38
#    nlp_jac_g  |  48.00ms (  1.20ms)  12.51ms (312.77us)        40
#        total  | 449.00ms (449.00ms) 438.14ms (438.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   1.93ms (161.17us)        12
#        nlp_g  |        0 (       0)   1.28ms (106.33us)        12
#   nlp_grad_f  |        0 (       0)   3.75ms (288.38us)        13
#   nlp_hess_l  |        0 (       0)   6.58ms (598.64us)        11
#    nlp_jac_g  |   2.00ms (153.85us)   4.03ms (310.08us)        13
#        total  | 100.00ms (100.00ms)  96.59ms ( 96.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 58.82us)   2.67ms (157.00us)        17
#        nlp_g  |        0 (       0)   1.92ms (112.82us)        17
#   nlp_grad_f  |        0 (       0)   5.14ms (285.72us)        18
#   nlp_hess_l  |  15.00ms (937.50us)   9.62ms (601.25us)        16
#    nlp_jac_g  |        0 (       0)   5.35ms (297.33us)        18
#        total  | 133.00ms (133.00ms) 131.75ms (131.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.94ms (149.08us)        13
#        nlp_g  |        0 (       0)   1.27ms ( 97.46us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   3.77ms (269.07us)        14
#   nlp_hess_l  |   5.00ms (416.67us)   6.96ms (580.33us)        12
#    nlp_jac_g  |        0 (       0)   3.91ms (279.14us)        14
#        total  | 100.00ms (100.00ms)  97.27ms ( 97.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.38ms (159.00us)        15
#        nlp_g  |        0 (       0)   1.68ms (112.00us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   4.95ms (309.62us)        16
#   nlp_hess_l  |   7.00ms (500.00us)   8.75ms (624.79us)        14
#    nlp_jac_g  |        0 (       0)   5.17ms (323.19us)        16
#        total  | 116.00ms (116.00ms) 117.02ms (117.02ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.14ms (164.85us)        13
#        nlp_g  |        0 (       0)   1.53ms (117.62us)        13
#   nlp_grad_f  |        0 (       0)   3.94ms (281.79us)        14
#   nlp_hess_l  |        0 (       0)   7.77ms (647.75us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.23ms (301.93us)        14
#        total  | 119.00ms (119.00ms) 105.50ms (105.50ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (941.18us)   2.72ms (159.94us)        17
#        nlp_g  |        0 (       0)   1.82ms (106.94us)        17
#   nlp_grad_f  |        0 (       0)   5.11ms (283.89us)        18
#   nlp_hess_l  |  21.00ms (  1.31ms)   9.92ms (619.87us)        16
#    nlp_jac_g  |        0 (       0)   5.36ms (297.83us)        18
#        total  | 146.00ms (146.00ms) 134.00ms (134.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.01ms (154.69us)        13
#        nlp_g  |        0 (       0)   1.40ms (107.38us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   4.04ms (288.86us)        14
#   nlp_hess_l  |        0 (       0)   7.20ms (599.92us)        12
#    nlp_jac_g  |        0 (       0)   4.37ms (312.50us)        14
#        total  | 102.00ms (102.00ms) 103.26ms (103.26ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.61ms (146.27us)        11
#        nlp_g  |        0 (       0)   1.28ms (116.64us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.61ms (300.83us)        12
#   nlp_hess_l  |        0 (       0)   5.75ms (575.00us)        10
#    nlp_jac_g  |        0 (       0)   3.98ms (332.00us)        12
#        total  |  83.00ms ( 83.00ms)  85.92ms ( 85.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (416.67us)   1.97ms (164.25us)        12
#        nlp_g  |        0 (       0)   1.38ms (115.08us)        12
#   nlp_grad_f  |   5.00ms (384.62us)   3.96ms (304.92us)        13
#   nlp_hess_l  |   9.00ms (818.18us)   7.49ms (681.27us)        11
#    nlp_jac_g  |   2.00ms (153.85us)   4.28ms (329.15us)        13
#        total  |  92.00ms ( 92.00ms)  92.76ms ( 92.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.63ms (164.62us)        16
#        nlp_g  |   2.00ms (125.00us)   1.91ms (119.44us)        16
#   nlp_grad_f  |   1.00ms ( 58.82us)   4.82ms (283.65us)        17
#   nlp_hess_l  |  18.00ms (  1.20ms)   9.56ms (637.53us)        15
#    nlp_jac_g  |   2.00ms (117.65us)   5.26ms (309.53us)        17
#        total  | 124.00ms (124.00ms) 123.71ms (123.71ms)         1
# ステップ 34 でゴールに到達！
# イテレーション 2 の総コスト: 261.79
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 5198.3159
#
# ==================================================
# 反復学習: イテレーション 3/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (200.00us)   2.57ms (171.07us)        15
#        nlp_g  |   3.00ms (200.00us)   1.79ms (119.33us)        15
#   nlp_grad_f  |   4.00ms (250.00us)   4.80ms (300.00us)        16
#   nlp_hess_l  |   7.00ms (500.00us)   9.20ms (657.36us)        14
#    nlp_jac_g  |   7.00ms (437.50us)   5.12ms (320.25us)        16
#        total  | 115.00ms (115.00ms) 114.61ms (114.61ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   1.82ms (151.83us)        12
#        nlp_g  |        0 (       0)   1.30ms (108.00us)        12
#   nlp_grad_f  |  16.00ms (  1.23ms)   3.87ms (297.54us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   6.87ms (625.00us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   3.91ms (301.00us)        13
#        total  |  83.00ms ( 83.00ms)  89.49ms ( 89.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   1.57ms (157.10us)        10
#        nlp_g  |        0 (       0)   1.13ms (112.70us)        10
#   nlp_grad_f  |   5.00ms (454.55us)   3.29ms (299.45us)        11
#   nlp_hess_l  |   6.00ms (666.67us)   5.74ms (638.22us)         9
#    nlp_jac_g  |   4.00ms (363.64us)   3.43ms (311.73us)        11
#        total  |  76.00ms ( 76.00ms)  76.27ms ( 76.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   1.75ms (159.36us)        11
#        nlp_g  |   1.00ms ( 90.91us)   1.20ms (109.00us)        11
#   nlp_grad_f  |   3.00ms (250.00us)   3.45ms (287.58us)        12
#   nlp_hess_l  |   7.00ms (700.00us)   6.92ms (692.10us)        10
#    nlp_jac_g  |   5.00ms (416.67us)   3.64ms (303.33us)        12
#        total  |  86.00ms ( 86.00ms)  84.97ms ( 84.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   1.76ms (175.90us)        10
#        nlp_g  |        0 (       0)   1.15ms (115.40us)        10
#   nlp_grad_f  |   1.00ms ( 90.91us)   3.34ms (303.55us)        11
#   nlp_hess_l  |   6.00ms (666.67us)   6.04ms (671.33us)         9
#    nlp_jac_g  |   2.00ms (181.82us)   3.53ms (320.82us)        11
#        total  |  82.00ms ( 82.00ms)  79.41ms ( 79.41ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.95ms (158.00us)        25
#        nlp_g  |  15.00ms (600.00us)   2.73ms (109.24us)        25
#   nlp_grad_f  |   1.00ms ( 38.46us)   7.24ms (278.58us)        26
#   nlp_hess_l  |   4.00ms (166.67us)  14.56ms (606.54us)        24
#    nlp_jac_g  |  20.00ms (769.23us)   7.54ms (290.15us)        26
#        total  | 253.00ms (253.00ms) 244.47ms (244.47ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 76.92us)   4.60ms (176.96us)        26
#        nlp_g  |   4.00ms (153.85us)   3.43ms (131.85us)        26
#   nlp_grad_f  |   5.00ms (185.19us)   7.70ms (285.19us)        27
#   nlp_hess_l  |  22.00ms (880.00us)  16.69ms (667.76us)        25
#    nlp_jac_g  |  19.00ms (703.70us)   8.44ms (312.56us)        27
#        total  | 249.00ms (249.00ms) 248.73ms (248.73ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (368.42us)   3.11ms (163.95us)        19
#        nlp_g  |   2.00ms (105.26us)   2.11ms (111.26us)        19
#   nlp_grad_f  |   3.00ms (166.67us)   5.30ms (294.44us)        18
#   nlp_hess_l  |  10.00ms (625.00us)  10.56ms (660.06us)        16
#    nlp_jac_g  |   6.00ms (333.33us)   5.54ms (307.72us)        18
#        total  | 155.00ms (155.00ms) 155.43ms (155.43ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 71.43us)   4.71ms (168.25us)        28
#        nlp_g  |   1.00ms ( 35.71us)   3.38ms (120.57us)        28
#   nlp_grad_f  |   4.00ms (148.15us)   8.10ms (299.96us)        27
#   nlp_hess_l  |  24.00ms (960.00us)  16.38ms (655.36us)        25
#    nlp_jac_g  |   1.00ms ( 37.04us)   8.88ms (329.04us)        27
#        total  | 233.00ms (233.00ms) 233.23ms (233.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.83ms (153.08us)        25
#        nlp_g  |        0 (       0)   2.70ms (107.84us)        25
#   nlp_grad_f  |        0 (       0)   7.60ms (292.35us)        26
#   nlp_hess_l  |  23.00ms (958.33us)  14.85ms (618.67us)        24
#    nlp_jac_g  |   9.00ms (346.15us)   8.05ms (309.58us)        26
#        total  | 234.00ms (234.00ms) 241.87ms (241.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   8.00ms (216.22us)   6.59ms (178.22us)        37
#        nlp_g  |  16.00ms (432.43us)   4.78ms (129.27us)        37
#   nlp_grad_f  |   7.00ms (184.21us)  11.14ms (293.11us)        38
#   nlp_hess_l  |  15.00ms (416.67us)  24.46ms (679.36us)        36
#    nlp_jac_g  |  10.00ms (263.16us)  12.06ms (317.29us)        38
#        total  | 421.00ms (421.00ms) 427.92ms (427.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 31.25us)   4.78ms (149.53us)        32
#        nlp_g  |  17.00ms (531.25us)   3.31ms (103.31us)        32
#   nlp_grad_f  |  13.00ms (464.29us)   8.04ms (287.07us)        28
#   nlp_hess_l  |   6.00ms (230.77us)  16.31ms (627.46us)        26
#    nlp_jac_g  |   1.00ms ( 35.71us)   8.41ms (300.21us)        28
#        total  | 267.00ms (267.00ms) 267.30ms (267.30ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   1.75ms (174.90us)        10
#        nlp_g  |   2.00ms (200.00us)   1.18ms (117.90us)        10
#   nlp_grad_f  |   1.00ms ( 90.91us)   3.24ms (294.36us)        11
#   nlp_hess_l  |   2.00ms (222.22us)   5.67ms (630.56us)         9
#    nlp_jac_g  |   1.00ms ( 90.91us)   3.33ms (303.18us)        11
#        total  |  78.00ms ( 78.00ms)  77.76ms ( 77.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (150.00us)   3.42ms (170.80us)        20
#        nlp_g  |        0 (       0)   2.73ms (136.60us)        20
#   nlp_grad_f  |   8.00ms (380.95us)   6.56ms (312.38us)        21
#   nlp_hess_l  |  14.00ms (736.84us)  12.67ms (667.00us)        19
#    nlp_jac_g  |   6.00ms (285.71us)   6.93ms (330.00us)        21
#        total  | 205.00ms (205.00ms) 204.53ms (204.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (153.85us)   2.38ms (183.15us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.72ms (132.38us)        13
#   nlp_grad_f  |   4.00ms (285.71us)   4.52ms (322.79us)        14
#   nlp_hess_l  |   8.00ms (666.67us)   7.90ms (658.00us)        12
#    nlp_jac_g  |   3.00ms (214.29us)   4.85ms (346.21us)        14
#        total  | 103.00ms (103.00ms) 102.90ms (102.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   2.80ms (254.55us)        11
#        nlp_g  |   2.00ms (181.82us)   1.97ms (179.55us)        11
#   nlp_grad_f  |   6.00ms (500.00us)   5.06ms (421.58us)        12
#   nlp_hess_l  |   8.00ms (800.00us)   8.46ms (846.50us)        10
#    nlp_jac_g  |   8.00ms (666.67us)   5.21ms (434.17us)        12
#        total  |  99.00ms ( 99.00ms)  98.88ms ( 98.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.04ms (203.90us)        10
#        nlp_g  |   1.00ms (100.00us)   1.27ms (127.30us)        10
#   nlp_grad_f  |   8.00ms (727.27us)   3.92ms (356.64us)        11
#   nlp_hess_l  |   8.00ms (888.89us)   7.37ms (818.56us)         9
#    nlp_jac_g  |   2.00ms (181.82us)   3.61ms (328.18us)        11
#        total  |  92.00ms ( 92.00ms)  92.88ms ( 92.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (411.76us)   3.53ms (207.71us)        17
#        nlp_g  |   2.00ms (117.65us)   2.46ms (144.71us)        17
#   nlp_grad_f  |   5.00ms (277.78us)   6.17ms (342.61us)        18
#   nlp_hess_l  |  16.00ms (  1.00ms)  11.50ms (718.81us)        16
#    nlp_jac_g  |   3.00ms (166.67us)   6.32ms (350.89us)        18
#        total  | 160.00ms (160.00ms) 159.57ms (159.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (285.71us)   2.56ms (182.57us)        14
#        nlp_g  |        0 (       0)   1.87ms (133.43us)        14
#   nlp_grad_f  |   5.00ms (333.33us)   5.01ms (333.93us)        15
#   nlp_hess_l  |  11.00ms (846.15us)   9.20ms (707.54us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   5.50ms (366.40us)        15
#        total  | 114.00ms (114.00ms) 113.60ms (113.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (230.77us)   5.54ms (212.96us)        26
#        nlp_g  |   2.00ms ( 76.92us)   3.73ms (143.50us)        26
#   nlp_grad_f  |   7.00ms (259.26us)   9.97ms (369.30us)        27
#   nlp_hess_l  |  27.00ms (  1.08ms)  19.40ms (776.16us)        25
#    nlp_jac_g  |   8.00ms (296.30us)  10.28ms (380.63us)        27
#        total  | 265.00ms (265.00ms) 255.49ms (255.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (357.14us)   2.99ms (213.93us)        14
#        nlp_g  |   1.00ms ( 71.43us)   2.10ms (149.93us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   5.85ms (389.80us)        15
#   nlp_hess_l  |  10.00ms (769.23us)  10.55ms (811.69us)        13
#    nlp_jac_g  |   9.00ms (600.00us)   6.02ms (401.47us)        15
#        total  | 121.00ms (121.00ms) 121.40ms (121.40ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 55.56us)   3.19ms (177.28us)        18
#        nlp_g  |        0 (       0)   2.32ms (128.72us)        18
#   nlp_grad_f  |  11.00ms (578.95us)   6.42ms (338.11us)        19
#   nlp_hess_l  |  32.00ms (  1.88ms)  12.60ms (741.06us)        17
#    nlp_jac_g  |   1.00ms ( 52.63us)   6.75ms (355.53us)        19
#        total  | 133.00ms (133.00ms) 140.73ms (140.73ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (538.46us)   2.59ms (199.00us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.89ms (145.77us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   4.76ms (339.79us)        14
#   nlp_hess_l  |   5.00ms (416.67us)   9.12ms (759.67us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   5.26ms (375.93us)        14
#        total  | 114.00ms (114.00ms) 113.09ms (113.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 58.82us)   6.46ms (190.06us)        34
#        nlp_g  |   1.00ms ( 29.41us)   4.56ms (134.24us)        34
#   nlp_grad_f  |   4.00ms (114.29us)  11.00ms (314.34us)        35
#   nlp_hess_l  |  13.00ms (393.94us)  22.78ms (690.45us)        33
#    nlp_jac_g  |        0 (       0)  11.71ms (334.69us)        35
#        total  | 365.00ms (365.00ms) 352.99ms (352.99ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.24ms (190.47us)        17
#        nlp_g  |        0 (       0)   2.22ms (130.41us)        17
#   nlp_grad_f  |   1.00ms ( 55.56us)   6.20ms (344.50us)        18
#   nlp_hess_l  |   2.00ms (125.00us)  11.30ms (706.50us)        16
#    nlp_jac_g  |  33.00ms (  1.83ms)   6.57ms (364.83us)        18
#        total  | 133.00ms (133.00ms) 143.25ms (143.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.04ms (178.88us)        17
#        nlp_g  |        0 (       0)   2.18ms (128.35us)        17
#   nlp_grad_f  |   1.00ms ( 55.56us)   6.40ms (355.72us)        18
#   nlp_hess_l  |  12.00ms (750.00us)  11.00ms (687.50us)        16
#    nlp_jac_g  |        0 (       0)   6.71ms (372.94us)        18
#        total  | 133.00ms (133.00ms) 143.85ms (143.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 27.03us)   7.32ms (197.76us)        37
#        nlp_g  |  11.00ms (297.30us)   5.23ms (141.32us)        37
#   nlp_grad_f  |  16.00ms (421.05us)  13.65ms (359.18us)        38
#   nlp_hess_l  |  11.00ms (305.56us)  26.20ms (727.72us)        36
#    nlp_jac_g  |   6.00ms (157.89us)  13.93ms (366.50us)        38
#        total  | 433.00ms (433.00ms) 422.44ms (422.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.60ms (185.79us)        14
#        nlp_g  |        0 (       0)   1.79ms (128.00us)        14
#   nlp_grad_f  |        0 (       0)   5.09ms (339.20us)        15
#   nlp_hess_l  |  16.00ms (  1.23ms)   9.15ms (704.00us)        13
#    nlp_jac_g  |  31.00ms (  2.07ms)   5.31ms (353.73us)        15
#        total  | 116.00ms (116.00ms) 115.00ms (115.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.71ms (193.71us)        14
#        nlp_g  |        0 (       0)   1.90ms (135.57us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   5.29ms (352.67us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   9.88ms (760.38us)        13
#    nlp_jac_g  |  19.00ms (  1.27ms)   5.49ms (366.27us)        15
#        total  | 116.00ms (116.00ms) 122.65ms (122.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.33ms (179.46us)        13
#        nlp_g  |   4.00ms (307.69us)   1.67ms (128.54us)        13
#   nlp_grad_f  |        0 (       0)   4.60ms (328.86us)        14
#   nlp_hess_l  |   6.00ms (500.00us)   7.93ms (660.92us)        12
#    nlp_jac_g  |        0 (       0)   4.78ms (341.50us)        14
#        total  | 107.00ms (107.00ms) 105.74ms (105.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.02ms (168.42us)        12
#        nlp_g  |        0 (       0)   1.44ms (120.25us)        12
#   nlp_grad_f  |        0 (       0)   4.16ms (320.23us)        13
#   nlp_hess_l  |  12.00ms (  1.09ms)   7.12ms (647.55us)        11
#    nlp_jac_g  |        0 (       0)   4.45ms (342.15us)        13
#        total  | 100.00ms (100.00ms)  99.99ms ( 99.99ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 3 の総コスト: 260.51
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 3140.5984
#
# ==================================================
# 反復学習: イテレーション 4/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.36ms (157.33us)        15
#        nlp_g  |        0 (       0)   1.70ms (113.40us)        15
#   nlp_grad_f  |        0 (       0)   4.97ms (310.50us)        16
#   nlp_hess_l  |  18.00ms (  1.29ms)   9.00ms (642.64us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   5.44ms (339.87us)        16
#        total  | 116.00ms (116.00ms) 119.13ms (119.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.07ms (159.38us)        13
#        nlp_g  |        0 (       0)   1.44ms (110.77us)        13
#   nlp_grad_f  |        0 (       0)   4.19ms (299.36us)        14
#   nlp_hess_l  |  17.00ms (  1.42ms)   7.69ms (640.50us)        12
#    nlp_jac_g  |        0 (       0)   4.61ms (329.00us)        14
#        total  | 102.00ms (102.00ms) 103.23ms (103.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.93ms (193.30us)        10
#        nlp_g  |        0 (       0)   1.32ms (132.00us)        10
#   nlp_grad_f  |        0 (       0)   3.81ms (346.09us)        11
#   nlp_hess_l  |        0 (       0)   7.18ms (797.56us)         9
#    nlp_jac_g  |   1.00ms ( 90.91us)   3.92ms (356.45us)        11
#        total  |  85.00ms ( 85.00ms)  88.86ms ( 88.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   2.44ms (203.42us)        12
#        nlp_g  |        0 (       0)   1.62ms (134.67us)        12
#   nlp_grad_f  |        0 (       0)   4.59ms (353.15us)        13
#   nlp_hess_l  |  16.00ms (  1.45ms)   8.38ms (761.91us)        11
#    nlp_jac_g  |        0 (       0)   4.84ms (372.08us)        13
#        total  | 100.00ms (100.00ms) 104.59ms (104.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.81ms (181.40us)        10
#        nlp_g  |        0 (       0)   1.25ms (125.40us)        10
#   nlp_grad_f  |        0 (       0)   3.58ms (325.64us)        11
#   nlp_hess_l  |   2.00ms (222.22us)   6.50ms (722.11us)         9
#    nlp_jac_g  |        0 (       0)   3.89ms (353.36us)        11
#        total  |  84.00ms ( 84.00ms)  85.24ms ( 85.24ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
# ...
#        nlp_f  |        0 (       0)   2.14ms (194.36us)        11
#        nlp_g  |        0 (       0)   1.53ms (138.82us)        11
#   nlp_grad_f  |        0 (       0)   4.19ms (349.42us)        12
#   nlp_hess_l  |  14.00ms (  1.40ms)   7.53ms (752.70us)        10
#    nlp_jac_g  |        0 (       0)   4.49ms (374.00us)        12
#        total  |  81.00ms ( 81.00ms)  88.44ms ( 88.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.89ms (192.60us)        15
#        nlp_g  |        0 (       0)   1.93ms (128.67us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   5.66ms (353.50us)        16
#   nlp_hess_l  |        0 (       0)  10.53ms (752.50us)        14
#    nlp_jac_g  |        0 (       0)   5.78ms (361.06us)        16
#        total  | 134.00ms (134.00ms) 126.13ms (126.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.25ms (149.87us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.60ms (106.73us)        15
#   nlp_grad_f  |        0 (       0)   4.47ms (279.31us)        16
#   nlp_hess_l  |  15.00ms (  1.07ms)   8.46ms (604.00us)        14
#    nlp_jac_g  |  15.00ms (937.50us)   4.86ms (303.75us)        16
#        total  |  98.00ms ( 98.00ms) 111.53ms (111.53ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 4 の総コスト: 259.90
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 1047.9178
#
# ==================================================
# 反復学習: イテレーション 5/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  13.00ms (  1.00ms)   2.34ms (180.23us)        13
#        nlp_g  |        0 (       0)   1.73ms (132.85us)        13
#   nlp_grad_f  |        0 (       0)   4.33ms (309.07us)        14
#   nlp_hess_l  |   7.00ms (583.33us)   8.93ms (744.33us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.75ms (339.50us)        14
#        total  | 119.00ms (119.00ms) 107.49ms (107.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (111.11us)   1.56ms (172.89us)         9
#        nlp_g  |        0 (       0)   1.13ms (125.33us)         9
#   nlp_grad_f  |   2.00ms (200.00us)   3.21ms (321.40us)        10
#   nlp_hess_l  |        0 (       0)   5.56ms (694.75us)         8
#    nlp_jac_g  |        0 (       0)   3.57ms (357.00us)        10
#        total  |  66.00ms ( 66.00ms)  72.30ms ( 72.30ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   2.04ms (203.60us)        10
#        nlp_g  |        0 (       0)   1.29ms (128.70us)        10
#   nlp_grad_f  |   4.00ms (363.64us)   3.69ms (335.27us)        11
#   nlp_hess_l  |   6.00ms (666.67us)   6.78ms (753.78us)         9
#    nlp_jac_g  |   1.00ms ( 90.91us)   3.97ms (361.36us)        11
#        total  |  81.00ms ( 81.00ms)  80.65ms ( 80.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   1.66ms (166.30us)        10
#        nlp_g  |   2.00ms (200.00us)   1.28ms (128.40us)        10
#   nlp_grad_f  |   3.00ms (272.73us)   3.44ms (313.18us)        11
#   nlp_hess_l  |   6.00ms (666.67us)   6.05ms (672.11us)         9
#    nlp_jac_g  |   4.00ms (363.64us)   3.63ms (329.64us)        11
#        total  |  84.00ms ( 84.00ms)  85.25ms ( 85.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.61ms (329.21us)        14
#        nlp_g  |   2.00ms (142.86us)   3.08ms (220.07us)        14
#   nlp_grad_f  |   2.00ms (153.85us)   6.52ms (501.31us)        13
#   nlp_hess_l  |   9.00ms (818.18us)  14.51ms (  1.32ms)        11
#    nlp_jac_g  |   3.00ms (230.77us)   6.82ms (524.85us)        13
#        total  | 137.00ms (137.00ms) 146.25ms (146.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.80ms (175.19us)        16
#        nlp_g  |        0 (       0)   1.97ms (123.19us)        16
#   nlp_grad_f  |   2.00ms (117.65us)   5.34ms (314.06us)        17
#   nlp_hess_l  |  26.00ms (  1.73ms)  10.67ms (711.47us)        15
#    nlp_jac_g  |   8.00ms (470.59us)   5.68ms (333.94us)        17
#        total  | 124.00ms (124.00ms) 125.17ms (125.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 66.67us)   5.83ms (194.43us)        30
#        nlp_g  |   3.00ms (100.00us)   4.10ms (136.70us)        30
#   nlp_grad_f  |  15.00ms (600.00us)   8.38ms (335.36us)        25
#   nlp_hess_l  |   9.00ms (391.30us)  17.07ms (742.04us)        23
#    nlp_jac_g  |   5.00ms (200.00us)   8.52ms (340.92us)        25
#        total  | 251.00ms (251.00ms) 257.52ms (257.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (240.00us)   5.10ms (204.00us)        25
#        nlp_g  |   3.00ms (120.00us)   3.76ms (150.28us)        25
#   nlp_grad_f  |   6.00ms (240.00us)   9.22ms (368.88us)        25
#   nlp_hess_l  |  18.00ms (782.61us)  17.58ms (764.52us)        23
#    nlp_jac_g  |  14.00ms (560.00us)   9.88ms (395.40us)        25
#        total  | 254.00ms (254.00ms) 253.44ms (253.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   3.42ms (262.77us)        13
#        nlp_g  |   1.00ms ( 76.92us)   2.38ms (183.00us)        13
#   nlp_grad_f  |  14.00ms (  1.00ms)   7.14ms (510.14us)        14
#   nlp_hess_l  |   5.00ms (416.67us)  10.52ms (876.50us)        12
#    nlp_jac_g  |   3.00ms (214.29us)   6.24ms (445.64us)        14
#        total  | 136.00ms (136.00ms) 139.50ms (139.50ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (222.22us)   4.17ms (154.63us)        27
#        nlp_g  |   1.00ms ( 37.04us)   2.78ms (102.96us)        27
#   nlp_grad_f  |   3.00ms (136.36us)   6.76ms (307.09us)        22
#   nlp_hess_l  |   4.00ms (200.00us)  13.15ms (657.65us)        20
#    nlp_jac_g  |   2.00ms ( 90.91us)   7.00ms (318.09us)        22
#        total  | 217.00ms (217.00ms) 205.71ms (205.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (120.00us)   4.51ms (180.24us)        25
#        nlp_g  |   4.00ms (160.00us)   3.05ms (122.00us)        25
#   nlp_grad_f  |   9.00ms (346.15us)   7.78ms (299.19us)        26
#   nlp_hess_l  |  16.00ms (666.67us)  15.42ms (642.67us)        24
#    nlp_jac_g  |   9.00ms (346.15us)   7.98ms (306.77us)        26
#        total  | 269.00ms (269.00ms) 266.78ms (266.78ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (173.91us)   3.88ms (168.57us)        23
#        nlp_g  |   2.00ms ( 86.96us)   2.77ms (120.48us)        23
#   nlp_grad_f  |  10.00ms (416.67us)   7.15ms (297.79us)        24
#   nlp_hess_l  |  19.00ms (863.64us)  14.38ms (653.82us)        22
#    nlp_jac_g  |  10.00ms (416.67us)   7.58ms (315.87us)        24
#        total  | 233.00ms (233.00ms) 230.66ms (230.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.36ms (168.93us)        14
#        nlp_g  |   2.00ms (142.86us)   1.73ms (123.57us)        14
#   nlp_grad_f  |   3.00ms (200.00us)   4.74ms (315.87us)        15
#   nlp_hess_l  |  24.00ms (  1.85ms)   9.23ms (710.23us)        13
#    nlp_jac_g  |   2.00ms (133.33us)   5.11ms (340.93us)        15
#        total  |  99.00ms ( 99.00ms) 109.75ms (109.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   2.44ms (203.33us)        12
#        nlp_g  |   3.00ms (250.00us)   1.74ms (144.75us)        12
#   nlp_grad_f  |   3.00ms (230.77us)   4.88ms (375.62us)        13
#   nlp_hess_l  |   4.00ms (363.64us)   7.87ms (715.55us)        11
#    nlp_jac_g  |  17.00ms (  1.31ms)   4.98ms (383.08us)        13
#        total  | 102.00ms (102.00ms) 102.81ms (102.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (266.67us)   2.62ms (174.93us)        15
#        nlp_g  |   4.00ms (266.67us)   1.93ms (128.80us)        15
#   nlp_grad_f  |   4.00ms (250.00us)   5.53ms (345.87us)        16
#   nlp_hess_l  |  14.00ms (  1.00ms)  10.16ms (726.07us)        14
#    nlp_jac_g  |   4.00ms (250.00us)   5.65ms (353.44us)        16
#        total  | 119.00ms (119.00ms) 117.97ms (117.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.85ms (168.45us)        11
#        nlp_g  |   2.00ms (181.82us)   1.27ms (115.73us)        11
#   nlp_grad_f  |   2.00ms (166.67us)   3.52ms (293.17us)        12
#   nlp_hess_l  |   5.00ms (500.00us)   6.86ms (685.70us)        10
#    nlp_jac_g  |   7.00ms (583.33us)   3.68ms (306.92us)        12
#        total  |  85.00ms ( 85.00ms)  85.62ms ( 85.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (187.50us)   2.61ms (163.31us)        16
#        nlp_g  |   2.00ms (125.00us)   1.90ms (118.50us)        16
#   nlp_grad_f  |   4.00ms (235.29us)   5.02ms (295.29us)        17
#   nlp_hess_l  |   9.00ms (600.00us)   9.97ms (664.73us)        15
#    nlp_jac_g  |   5.00ms (294.12us)   5.36ms (315.35us)        17
#        total  | 130.00ms (130.00ms) 130.12ms (130.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.61ms (173.93us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.72ms (114.47us)        15
#   nlp_grad_f  |   4.00ms (250.00us)   4.84ms (302.69us)        16
#   nlp_hess_l  |   9.00ms (642.86us)  10.33ms (737.79us)        14
#    nlp_jac_g  |   5.00ms (312.50us)   5.44ms (339.75us)        16
#        total  | 119.00ms (119.00ms) 118.04ms (118.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (171.43us)   6.82ms (194.77us)        35
#        nlp_g  |   4.00ms (114.29us)   5.36ms (153.17us)        35
#   nlp_grad_f  |   7.00ms (194.44us)  11.92ms (331.06us)        36
#   nlp_hess_l  |  17.00ms (500.00us)  23.84ms (701.09us)        34
#    nlp_jac_g  |  11.00ms (305.56us)  12.28ms (341.14us)        36
#        total  | 367.00ms (367.00ms) 371.14ms (371.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (133.33us)   2.45ms (163.13us)        15
#        nlp_g  |        0 (       0)   1.74ms (116.13us)        15
#   nlp_grad_f  |   8.00ms (500.00us)   4.67ms (291.62us)        16
#   nlp_hess_l  |   7.00ms (500.00us)   8.79ms (628.14us)        14
#    nlp_jac_g  |   5.00ms (312.50us)   4.91ms (306.69us)        16
#        total  | 116.00ms (116.00ms) 115.69ms (115.69ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.07ms (159.23us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.49ms (114.69us)        13
#   nlp_grad_f  |   5.00ms (357.14us)   4.50ms (321.36us)        14
#   nlp_hess_l  |   6.00ms (500.00us)   8.08ms (673.25us)        12
#    nlp_jac_g  |   7.00ms (500.00us)   4.85ms (346.43us)        14
#        total  | 102.00ms (102.00ms) 102.03ms (102.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.82ms (151.92us)        12
#        nlp_g  |        0 (       0)   1.38ms (114.83us)        12
#   nlp_grad_f  |   5.00ms (384.62us)   3.94ms (302.85us)        13
#   nlp_hess_l  |  15.00ms (  1.36ms)   6.87ms (624.91us)        11
#    nlp_jac_g  |   3.00ms (230.77us)   4.31ms (331.77us)        13
#        total  |  91.00ms ( 91.00ms)  89.87ms ( 89.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (130.43us)   4.00ms (173.87us)        23
#        nlp_g  |   2.00ms ( 86.96us)   2.83ms (123.17us)        23
#   nlp_grad_f  |   4.00ms (166.67us)   7.08ms (295.00us)        24
#   nlp_hess_l  |  10.00ms (454.55us)  14.09ms (640.36us)        22
#    nlp_jac_g  |  12.00ms (500.00us)   8.27ms (344.62us)        24
#        total  | 222.00ms (222.00ms) 221.88ms (221.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (142.86us)   2.48ms (177.43us)        14
#        nlp_g  |   2.00ms (142.86us)   1.61ms (115.21us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   4.28ms (285.33us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   9.00ms (692.54us)        13
#    nlp_jac_g  |   6.00ms (400.00us)   4.65ms (310.27us)        15
#        total  | 110.00ms (110.00ms) 109.23ms (109.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   2.14ms (178.75us)        12
#        nlp_g  |   2.00ms (166.67us)   1.46ms (121.42us)        12
#   nlp_grad_f  |   5.00ms (384.62us)   4.47ms (343.85us)        13
#   nlp_hess_l  |   6.00ms (545.45us)   8.22ms (747.45us)        11
#    nlp_jac_g  |   3.00ms (230.77us)   4.58ms (352.62us)        13
#        total  |  96.00ms ( 96.00ms)  97.34ms ( 97.34ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (153.85us)   1.97ms (151.31us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.44ms (110.69us)        13
#   nlp_grad_f  |   5.00ms (357.14us)   4.08ms (291.36us)        14
#   nlp_hess_l  |   8.00ms (666.67us)   7.65ms (637.83us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.46ms (318.64us)        14
#        total  |  96.00ms ( 96.00ms)  96.26ms ( 96.26ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.76ms (160.18us)        11
#        nlp_g  |        0 (       0)   1.18ms (107.45us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.38ms (281.33us)        12
#   nlp_hess_l  |        0 (       0)   6.16ms (616.00us)        10
#    nlp_jac_g  |        0 (       0)   3.63ms (302.75us)        12
#        total  |  70.00ms ( 70.00ms)  83.70ms ( 83.70ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (176.47us)   3.61ms (212.18us)        17
#        nlp_g  |   1.00ms ( 58.82us)   2.47ms (145.59us)        17
#   nlp_grad_f  |   4.00ms (222.22us)   5.93ms (329.33us)        18
#   nlp_hess_l  |  10.00ms (625.00us)  12.43ms (776.81us)        16
#    nlp_jac_g  |   5.00ms (277.78us)   6.38ms (354.39us)        18
#        total  | 149.00ms (149.00ms) 152.88ms (152.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 57.14us)   6.21ms (177.34us)        35
#        nlp_g  |   2.00ms ( 57.14us)   4.40ms (125.83us)        35
#   nlp_grad_f  |  25.00ms (694.44us)  11.42ms (317.17us)        36
#   nlp_hess_l  |  12.00ms (352.94us)  21.86ms (642.85us)        34
#    nlp_jac_g  |  20.00ms (555.56us)  11.51ms (319.64us)        36
#        total  | 342.00ms (342.00ms) 341.56ms (341.56ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   2.01ms (154.38us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.41ms (108.46us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   3.97ms (283.93us)        14
#   nlp_hess_l  |   8.00ms (666.67us)   7.29ms (607.92us)        12
#    nlp_jac_g  |   3.00ms (214.29us)   4.32ms (308.93us)        14
#        total  |  98.00ms ( 98.00ms)  98.19ms ( 98.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.19ms (168.23us)        13
#        nlp_g  |        0 (       0)   1.53ms (117.85us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   4.27ms (305.21us)        14
#   nlp_hess_l  |   6.00ms (500.00us)   8.12ms (676.75us)        12
#    nlp_jac_g  |        0 (       0)   4.61ms (329.50us)        14
#        total  |  97.00ms ( 97.00ms) 102.86ms (102.86ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 5 の総コスト: 260.40
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 115.5118
