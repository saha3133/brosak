# %% [markdown]
# NNを元に2次関数の終端コストを決定

# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import torch
import torch.nn as nn
import torch.optim as optim
import time


import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)

# ==================================================================================
# シミュレーション全体の設定パラメータ
# ==================================================================================
N_ITERATIONS = 5
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE = np.array([10.0, 10.0])
N_MPC = 20
M_MPC = 25
OBSTACLE_INFO = {'pos': np.array([5.0, 5.0]), 'rad': 1.5}


# ----------------------------------------------------------------------------------
# TerminalCostNN & 学習関数
# ----------------------------------------------------------------------------------
class TerminalCostNN(nn.Module):
    def __init__(self, n_input):
        super(TerminalCostNN, self).__init__() #親クラスを初期化
        self.layers = nn.Sequential( #3層
            nn.Linear(n_input, 64), nn.ReLU(),
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.layers(x)

def train_terminal_cost_net(net, trajectory_data): #costs_to_go(ある地点からゴールにたどり着くまでどのくらいのコストがかかるか)、未来の累積コストの予測値を学習、trajectory_data(軌道と各ステージのコスト)
    if len(trajectory_data) < 10: return #データが10個未満ならスキップ
    print("NN: 終端コストの学習開始...")
    optimizer = optim.Adam(net.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    states = torch.tensor(np.array([d[0] for d in trajectory_data]), dtype=torch.float32)
    costs_to_go = []
    running_cost = 0
    for _, stage_cost in reversed(trajectory_data): #costs_to_goを終端から逆算して計算、最後のステップのコストから順に足し上げる
        running_cost += stage_cost
        costs_to_go.append(running_cost)
    costs_to_go.reverse()
    labels = torch.tensor(costs_to_go, dtype=torch.float32).view(-1, 1)
    for epoch in range(100):
        optimizer.zero_grad(); outputs = net(states); loss = criterion(outputs, labels)
        loss.backward(); optimizer.step()
    print(f"NN: 学習完了。最終損失: {loss.item():.4f}")


class TrueVehicle:
    def __init__(self, dt=0.1): self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u; drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt; vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2; py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])
class GPRModel:
    def __init__(self, nx, nu, dt, obstacle_info):
        self.nx, self.nu = nx, nu
        self.dt=DT
        self.obstacle_info=OBSTACLE_INFO
        self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu))
        self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx

    def add_data(self, x, u, x_next):
        # 公称モデルからの誤差（デルタ）を学習ターゲットにする
        delta_real = (x_next - x) / self.dt
        delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])])
        self.Y_data = np.vstack([self.Y_data, error])

    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始...")
        for i in range(self.nx): #各状態について独立に学習
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100)
            self.models[i] = model
        self.is_trained = True
        print("GPR: 学習完了")

    def predict(self, x, u):
        if not self.is_trained:
            return np.zeros(self.nx), np.ones(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        variances = np.array([m.predict(xu)[1][0, 0] if m else 1.0 for m in self.models])
        return means, variances

# ----------------------------------------------------------------------------------
# MPCController
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, M, dt, obstacle_info):
        self.nx, self.nu, self.N, self.M, self.dt = nx, nu, N, M, dt
        self.obstacle_info = obstacle_info; self.u_prev_sol = np.zeros((nu, N))

    def solve(self, x_current, gpr_model, x_goal, terminal_cost_net, is_first_iteration):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)

        # --- ステップ１：NNで「賢い目標地点」を大まかに探す ---
        if is_first_iteration:
            # 最初のイテレーションではNNが未学習なので、ゴールをそのまま使う
            smart_target = x_goal
        else:
            # 現在位置から周辺のいくつかの候補点を生成
            num_candidates = 20
            candidates_pos = np.random.randn(num_candidates, 2) * 2.0 + x_current[:2] #位置の候補をガウス分布からランダムに生成
            candidates_vel = np.zeros((num_candidates, 2))
            candidates = np.hstack([candidates_pos, candidates_vel]) #候補点に速度0を付けて状態に拡張
            
            # NNで各候補点のコストを評価
            candidates_torch = torch.tensor(candidates, dtype=torch.float32)
            with torch.no_grad():
                costs = terminal_cost_net(candidates_torch).numpy().flatten()
            
            # 最もコストが低い候補点を「賢い目標地点」とする
            smart_target = candidates_pos[np.argmin(costs)]
            

        error_mean, error_var = gpr_model.predict(x_current, np.zeros(self.nu))
        error_std = np.sqrt(np.maximum(error_var, 1e-6)); error_std_capped = np.minimum(error_std, 0.2) #負の分散を防ぐため　標準偏差が大きくなりすぎないように
        error_samples = np.random.normal(loc=error_mean, scale=error_std_capped, size=(self.M, self.nx)) #M個の外乱サンプルを生成
        
        all_scenario_costs = []
        for m in range(self.M):
            X_scenario = opti.variable(self.nx, self.N + 1); cost_scenario = 0 #状態列X_scenarioを最適化変数として定義
            opti.subject_to(X_scenario[:, 0] == x_current)
            for k in range(self.N):
                x_k, u_k = X_scenario[:, k], U[:, k]
                delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
                delta_pred = delta_nominal + error_samples[m, :] #外乱を加味した予測
                x_next_pred = x_k + delta_pred * self.dt
                opti.subject_to(X_scenario[:, k+1] == x_next_pred)
                cost_scenario += ca.sumsqr(x_k[:2] - x_goal) * self.dt + ca.sumsqr(u_k) * self.dt * 0.01
                if self.obstacle_info:
                    dist_to_obs = ca.norm_2(x_k[:2] - self.obstacle_info['pos'])
                    penalty = ca.fmax(0, self.obstacle_info['rad'] - dist_to_obs)
                    cost_scenario += 500.0 * penalty**2
            
            # --- ステップ２：MPCの終端コストとして、その「賢い目標地点」を目指す ---
            terminal_state = X_scenario[:, self.N]
            cost_scenario += ca.sumsqr(terminal_state[:2] - smart_target) * 10.0

            all_scenario_costs.append(cost_scenario) #このシナリオのコストをall_scenario_costsに追加
        
        #total_objective = ca.mean(ca.vertcat(*all_scenario_costs))
        total_objective = ca.sum1(ca.vertcat(*all_scenario_costs)) / len(all_scenario_costs) #すべてのシナリオのコストの平均を目的関数とする
        opti.minimize(total_objective)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))
        opti.set_initial(U, self.u_prev_sol)
        s_opts = {'print_level': 0}; opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}"); return np.zeros(self.nu)

# ----------------------------------------------------------------------------------
# Main Simulation Loop
# ----------------------------------------------------------------------------------
def main():
    vehicle = TrueVehicle(dt=DT)
    gpr_model = GPRModel(nx=NX, nu=NU,dt=DT, obstacle_info=OBSTACLE_INFO)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, M=M_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)
    terminal_cost_net = TerminalCostNN(n_input=NX)
    all_trajectories, final_costs = [], []
    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE); total_cost = 0
        iteration_data_for_gpr, iteration_data_for_cost_learning = [], []
        for step in range(SIM_STEPS):
            is_first_iter = (i == 0)
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE, terminal_cost_net, is_first_iter)
            x_next = vehicle.dynamics(current_x, u_optimal)
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data_for_gpr.append((current_x, u_optimal, x_next))
            iteration_data_for_cost_learning.append((current_x, stage_cost))
            current_x = x_next
            if np.linalg.norm(current_x[:2] - GOAL_STATE) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！"); break
        all_trajectories.append(np.array([d[0] for d in iteration_data_for_cost_learning]))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")
        for x, u, x_n in iteration_data_for_gpr:
            gpr_model.add_data(x, u, x_n)
        gpr_model.train()
        train_terminal_cost_net(terminal_cost_net, iteration_data_for_cost_learning)

    plt.figure(figsize=(10, 10))
    if OBSTACLE_INFO:
        obs_circle = plt.Circle(OBSTACLE_INFO['pos'], OBSTACLE_INFO['rad'], color='r', alpha=0.5, label='障害物')
        plt.gca().add_patch(obs_circle)
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE[0], GOAL_STATE[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡'); plt.legend(); plt.axis('equal'); plt.show()
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移'); plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト'); plt.xticks(range(1, N_ITERATIONS + 1)); plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (151.52us)   6.60ms (199.97us)        33
#        nlp_g  |   3.00ms ( 90.91us)   5.00ms (151.58us)        33
#   nlp_grad_f  |   5.00ms (147.06us)  10.68ms (314.00us)        34
#   nlp_hess_l  |  14.00ms (437.50us)  22.58ms (705.78us)        32
#    nlp_jac_g  |   6.00ms (176.47us)  12.05ms (354.29us)        34
#        total  | 383.00ms (383.00ms) 380.53ms (380.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (148.15us)   4.27ms (158.15us)        27
#        nlp_g  |   9.00ms (333.33us)   2.99ms (110.70us)        27
#   nlp_grad_f  |   5.00ms (178.57us)   7.73ms (276.25us)        28
#   nlp_hess_l  |  14.00ms (538.46us)  15.91ms (611.81us)        26
#    nlp_jac_g  |   8.00ms (285.71us)   8.16ms (291.36us)        28
#        total  | 250.00ms (250.00ms) 249.82ms (249.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 86.96us)   4.74ms (206.30us)        23
#        nlp_g  |   2.00ms ( 86.96us)   3.58ms (155.78us)        23
#   nlp_grad_f  |  10.00ms (416.67us)   9.15ms (381.33us)        24
#   nlp_hess_l  |  13.00ms (590.91us)  15.93ms (723.91us)        22
#    nlp_jac_g  |   6.00ms (250.00us)   9.46ms (394.00us)        24
#        total  | 248.00ms (248.00ms) 250.15ms (250.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (150.00us)   3.26ms (162.95us)        20
#        nlp_g  |   4.00ms (200.00us)   2.28ms (113.95us)        20
#   nlp_grad_f  |   3.00ms (142.86us)   5.94ms (282.76us)        21
#   nlp_hess_l  |  17.00ms (894.74us)  12.26ms (645.16us)        19
#    nlp_jac_g  |   4.00ms (190.48us)   6.61ms (314.62us)        21
#        total  | 167.00ms (167.00ms) 166.41ms (166.41ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (150.00us)   3.66ms (183.05us)        20
#        nlp_g  |   3.00ms (150.00us)   2.68ms (134.10us)        20
#   nlp_grad_f  |   9.00ms (428.57us)   6.91ms (328.95us)        21
#   nlp_hess_l  |   4.00ms (210.53us)  12.93ms (680.68us)        19
#    nlp_jac_g  |   9.00ms (428.57us)   6.96ms (331.24us)        21
#        total  | 173.00ms (173.00ms) 172.59ms (172.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.22ms (186.39us)        28
#        nlp_g  |   5.00ms (178.57us)   3.61ms (128.96us)        28
#   nlp_grad_f  |  23.00ms (793.10us)   9.60ms (331.07us)        29
#   nlp_hess_l  |  11.00ms (407.41us)  17.52ms (648.78us)        27
#    nlp_jac_g  |   4.00ms (137.93us)   9.83ms (338.86us)        29
#        total  | 286.00ms (286.00ms) 297.23ms (297.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (125.00us)   4.67ms (194.79us)        24
#        nlp_g  |   5.00ms (208.33us)   3.51ms (146.25us)        24
#   nlp_grad_f  |   8.00ms (320.00us)   8.26ms (330.48us)        25
#   nlp_hess_l  |  18.00ms (782.61us)  17.83ms (775.30us)        23
#    nlp_jac_g  |  11.00ms (440.00us)   9.82ms (392.72us)        25
#        total  | 235.00ms (235.00ms) 235.86ms (235.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (185.19us)   4.62ms (171.19us)        27
#        nlp_g  |   3.00ms (111.11us)   3.22ms (119.22us)        27
#   nlp_grad_f  |   4.00ms (142.86us)   8.76ms (312.89us)        28
#   nlp_hess_l  |  28.00ms (  1.08ms)  17.25ms (663.62us)        26
#    nlp_jac_g  |   6.00ms (214.29us)   9.03ms (322.50us)        28
#        total  | 266.00ms (266.00ms) 264.44ms (264.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (161.29us)   4.88ms (157.39us)        31
#        nlp_g  |   4.00ms (129.03us)   3.43ms (110.58us)        31
#   nlp_grad_f  |  25.00ms (781.25us)   9.11ms (284.81us)        32
#   nlp_hess_l  |  25.00ms (833.33us)  18.25ms (608.40us)        30
#    nlp_jac_g  |   9.00ms (281.25us)   9.99ms (312.34us)        32
#        total  | 287.00ms (287.00ms) 273.07ms (273.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (176.47us)   2.67ms (157.24us)        17
#        nlp_g  |   3.00ms (176.47us)   1.92ms (113.12us)        17
#   nlp_grad_f  |   3.00ms (166.67us)   5.63ms (312.89us)        18
#   nlp_hess_l  |  10.00ms (625.00us)  10.14ms (633.62us)        16
#    nlp_jac_g  |   7.00ms (388.89us)   5.75ms (319.50us)        18
#        total  | 133.00ms (133.00ms) 132.68ms (132.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   2.02ms (168.58us)        12
#        nlp_g  |   1.00ms ( 83.33us)   1.46ms (121.67us)        12
#   nlp_grad_f  |   2.00ms (153.85us)   4.50ms (346.08us)        13
#   nlp_hess_l  |  15.00ms (  1.36ms)   7.68ms (698.45us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   4.60ms (354.15us)        13
#        total  | 100.00ms (100.00ms)  97.42ms ( 97.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   2.08ms (173.33us)        12
#        nlp_g  |        0 (       0)   1.55ms (129.17us)        12
#   nlp_grad_f  |   4.00ms (307.69us)   4.21ms (323.69us)        13
#   nlp_hess_l  |   5.00ms (454.55us)   7.62ms (693.18us)        11
#    nlp_jac_g  |   6.00ms (461.54us)   4.49ms (345.54us)        13
#        total  |  94.00ms ( 94.00ms)  94.10ms ( 94.10ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.20ms (157.07us)        14
#        nlp_g  |        0 (       0)   1.49ms (106.50us)        14
#   nlp_grad_f  |        0 (       0)   4.17ms (278.07us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   7.87ms (605.15us)        13
#    nlp_jac_g  |   6.00ms (400.00us)   4.42ms (294.67us)        15
#        total  | 112.00ms (112.00ms) 112.92ms (112.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (142.86us)   2.19ms (156.36us)        14
#        nlp_g  |   3.00ms (214.29us)   1.55ms (110.71us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   4.70ms (313.33us)        15
#   nlp_hess_l  |   8.00ms (615.38us)   8.25ms (634.92us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   5.05ms (336.93us)        15
#        total  | 108.00ms (108.00ms) 108.44ms (108.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (133.33us)   2.85ms (189.73us)        15
#        nlp_g  |   6.00ms (400.00us)   1.98ms (131.87us)        15
#   nlp_grad_f  |   2.00ms (125.00us)   5.04ms (314.81us)        16
#   nlp_hess_l  |   8.00ms (571.43us)  10.15ms (725.29us)        14
#    nlp_jac_g  |   7.00ms (437.50us)   5.26ms (328.75us)        16
#        total  | 126.00ms (126.00ms) 125.55ms (125.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (285.71us)   2.33ms (166.71us)        14
#        nlp_g  |        0 (       0)   1.68ms (119.79us)        14
#   nlp_grad_f  |   3.00ms (200.00us)   4.78ms (318.67us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   8.58ms (660.38us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   5.12ms (341.27us)        15
#        total  | 118.00ms (118.00ms) 116.75ms (116.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.52ms (167.93us)        15
#        nlp_g  |  15.00ms (  1.00ms)   1.59ms (105.93us)        15
#   nlp_grad_f  |        0 (       0)   5.01ms (313.19us)        16
#   nlp_hess_l  |        0 (       0)   9.27ms (662.14us)        14
#    nlp_jac_g  |   2.00ms (125.00us)   5.22ms (326.44us)        16
#        total  | 117.00ms (117.00ms) 124.20ms (124.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.50ms (167.00us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.70ms (113.53us)        15
#   nlp_grad_f  |   3.00ms (187.50us)   4.61ms (288.37us)        16
#   nlp_hess_l  |   3.00ms (214.29us)   8.81ms (629.57us)        14
#    nlp_jac_g  |   7.00ms (437.50us)   4.98ms (311.12us)        16
#        total  | 104.00ms (104.00ms) 114.94ms (114.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (117.65us)   2.70ms (159.06us)        17
#        nlp_g  |   2.00ms (117.65us)   1.95ms (114.53us)        17
#   nlp_grad_f  |  15.00ms (833.33us)   5.28ms (293.28us)        18
#   nlp_hess_l  |  21.00ms (  1.31ms)  10.07ms (629.50us)        16
#    nlp_jac_g  |   2.00ms (111.11us)   5.69ms (316.22us)        18
#        total  | 117.00ms (117.00ms) 129.37ms (129.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 62.50us)   2.44ms (152.69us)        16
#        nlp_g  |   1.00ms ( 62.50us)   1.82ms (113.75us)        16
#   nlp_grad_f  |   6.00ms (352.94us)   4.72ms (277.41us)        17
#   nlp_hess_l  |  10.00ms (666.67us)   9.51ms (634.07us)        15
#    nlp_jac_g  |   2.00ms (117.65us)   5.21ms (306.47us)        17
#        total  | 121.00ms (121.00ms) 120.64ms (120.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.08ms (159.85us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.37ms (105.77us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.26ms (304.14us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.45ms (620.50us)        12
#    nlp_jac_g  |        0 (       0)   4.41ms (314.71us)        14
#        total  | 107.00ms (107.00ms) 102.98ms (102.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.15ms (153.57us)        14
#        nlp_g  |        0 (       0)   1.45ms (103.36us)        14
#   nlp_grad_f  |  16.00ms (  1.07ms)   4.37ms (291.07us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   7.90ms (607.77us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.58ms (305.33us)        15
#        total  | 116.00ms (116.00ms) 110.97ms (110.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   1.93ms (148.46us)        13
#        nlp_g  |        0 (       0)   1.37ms (105.54us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.72ms (265.57us)        14
#   nlp_hess_l  |   3.00ms (250.00us)   7.11ms (592.58us)        12
#    nlp_jac_g  |   5.00ms (357.14us)   4.13ms (295.36us)        14
#        total  | 107.00ms (107.00ms)  99.18ms ( 99.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.98ms (152.08us)        13
#        nlp_g  |        0 (       0)   1.38ms (106.54us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.82ms (272.64us)        14
#   nlp_hess_l  |   3.00ms (250.00us)   7.01ms (584.17us)        12
#    nlp_jac_g  |  19.00ms (  1.36ms)   4.07ms (290.64us)        14
#        total  |  88.00ms ( 88.00ms)  98.29ms ( 98.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.06ms (147.36us)        14
#        nlp_g  |   2.00ms (142.86us)   1.46ms (104.29us)        14
#   nlp_grad_f  |        0 (       0)   3.97ms (264.67us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   7.51ms (577.92us)        13
#    nlp_jac_g  |  20.00ms (  1.33ms)   4.27ms (285.00us)        15
#        total  | 104.00ms (104.00ms) 103.31ms (103.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.38ms (158.87us)        15
#        nlp_g  |        0 (       0)   1.73ms (115.60us)        15
#   nlp_grad_f  |   3.00ms (187.50us)   4.69ms (292.87us)        16
#   nlp_hess_l  |   9.00ms (642.86us)   9.43ms (673.43us)        14
#    nlp_jac_g  |   2.00ms (125.00us)   5.26ms (328.69us)        16
#        total  | 113.00ms (113.00ms) 115.60ms (115.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (153.85us)   2.20ms (169.08us)        13
#        nlp_g  |   2.00ms (153.85us)   1.58ms (121.62us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   4.34ms (310.00us)        14
#   nlp_hess_l  |   6.00ms (500.00us)   7.76ms (646.67us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   4.66ms (332.57us)        14
#        total  | 104.00ms (104.00ms) 101.19ms (101.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.22ms (158.50us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.52ms (108.43us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.81ms (320.93us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   8.10ms (623.08us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   4.87ms (324.53us)        15
#        total  | 103.00ms (103.00ms) 110.39ms (110.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (142.86us)   2.14ms (152.57us)        14
#        nlp_g  |        0 (       0)   1.52ms (108.79us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.45ms (296.87us)        15
#   nlp_hess_l  |   4.00ms (307.69us)   8.06ms (619.85us)        13
#    nlp_jac_g  |   5.00ms (333.33us)   4.65ms (310.07us)        15
#        total  | 100.00ms (100.00ms) 105.08ms (105.08ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.81ms (150.67us)        12
#        nlp_g  |        0 (       0)   1.20ms (100.42us)        12
#   nlp_grad_f  |  16.00ms (  1.23ms)   3.59ms (276.08us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   6.70ms (609.55us)        11
#    nlp_jac_g  |        0 (       0)   3.82ms (293.85us)        13
#        total  | 106.00ms (106.00ms)  92.76ms ( 92.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.40ms (160.13us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.68ms (112.27us)        15
#   nlp_grad_f  |   4.00ms (250.00us)   4.78ms (298.62us)        16
#   nlp_hess_l  |   9.00ms (642.86us)   8.89ms (634.71us)        14
#    nlp_jac_g  |   6.00ms (375.00us)   5.08ms (317.44us)        16
#        total  | 119.00ms (119.00ms) 118.65ms (118.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  18.00ms (  1.50ms)   1.91ms (158.92us)        12
#        nlp_g  |        0 (       0)   1.14ms ( 95.17us)        12
#   nlp_grad_f  |   2.00ms (153.85us)   3.51ms (270.15us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   6.62ms (602.27us)        11
#    nlp_jac_g  |   2.00ms (153.85us)   3.58ms (275.54us)        13
#        total  |  90.00ms ( 90.00ms)  89.54ms ( 89.54ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (272.73us)   1.89ms (172.00us)        11
#        nlp_g  |   2.00ms (181.82us)   1.26ms (114.36us)        11
#   nlp_grad_f  |        0 (       0)   3.69ms (307.25us)        12
#   nlp_hess_l  |  10.00ms (  1.00ms)   6.38ms (638.50us)        10
#    nlp_jac_g  |        0 (       0)   3.79ms (316.17us)        12
#        total  |  86.00ms ( 86.00ms)  87.25ms ( 87.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (111.11us)   1.48ms (164.56us)         9
#        nlp_g  |   1.00ms (111.11us)   1.03ms (114.11us)         9
#   nlp_grad_f  |        0 (       0)   3.23ms (322.80us)        10
#   nlp_hess_l  |   2.00ms (250.00us)   5.23ms (654.25us)         8
#    nlp_jac_g  |   2.00ms (200.00us)   3.51ms (350.70us)        10
#        total  |  73.00ms ( 73.00ms)  70.96ms ( 70.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   1.56ms (155.60us)        10
#        nlp_g  |   2.00ms (200.00us)   1.24ms (123.90us)        10
#   nlp_grad_f  |   1.00ms ( 90.91us)   3.37ms (306.36us)        11
#   nlp_hess_l  |   6.00ms (666.67us)   5.96ms (661.78us)         9
#    nlp_jac_g  |   4.00ms (363.64us)   3.64ms (330.91us)        11
#        total  |  81.00ms ( 81.00ms)  80.83ms ( 80.83ms)         1
# ステップ 35 でゴールに到達！
# イテレーション 1 の総コスト: 381.48
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 25788.9668
#
# ==================================================
# 反復学習: イテレーション 2/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.92ms (174.18us)        11
#        nlp_g  |   3.00ms (272.73us)   1.41ms (128.00us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.83ms (319.50us)        12
#   nlp_hess_l  |   3.00ms (300.00us)   6.45ms (644.80us)        10
#    nlp_jac_g  |   2.00ms (166.67us)   4.05ms (337.50us)        12
#        total  |  87.00ms ( 87.00ms)  91.11ms ( 91.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   1.61ms (160.80us)        10
#        nlp_g  |        0 (       0)   1.08ms (107.60us)        10
#   nlp_grad_f  |        0 (       0)   3.07ms (279.27us)        11
#   nlp_hess_l  |   1.00ms (111.11us)   5.70ms (633.33us)         9
#    nlp_jac_g  |        0 (       0)   3.30ms (300.09us)        11
#        total  |  92.00ms ( 92.00ms)  78.87ms ( 78.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.85ms (142.62us)        13
#        nlp_g  |   2.00ms (153.85us)   1.31ms (100.85us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.75ms (267.93us)        14
#   nlp_hess_l  |  17.00ms (  1.42ms)   6.58ms (548.25us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.04ms (288.29us)        14
#        total  | 100.00ms (100.00ms)  97.77ms ( 97.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.15ms (179.25us)        12
#        nlp_g  |        0 (       0)   1.52ms (126.58us)        12
#   nlp_grad_f  |  18.00ms (  1.38ms)   4.08ms (313.62us)        13
#   nlp_hess_l  |   6.00ms (545.45us)   7.18ms (652.91us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   4.06ms (312.69us)        13
#        total  | 110.00ms (110.00ms)  94.54ms ( 94.54ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 40.00us)   3.66ms (146.36us)        25
#        nlp_g  |        0 (       0)   2.52ms (100.76us)        25
#   nlp_grad_f  |   5.00ms (192.31us)   6.81ms (262.04us)        26
#   nlp_hess_l  |   6.00ms (250.00us)  13.48ms (561.71us)        24
#    nlp_jac_g  |   1.00ms ( 38.46us)   7.26ms (279.23us)        26
#        total  | 250.00ms (250.00ms) 235.83ms (235.83ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.47ms (154.37us)        16
#        nlp_g  |   1.00ms ( 62.50us)   1.66ms (103.62us)        16
#   nlp_grad_f  |   3.00ms (200.00us)   4.65ms (310.00us)        15
#   nlp_hess_l  |   5.00ms (384.62us)   8.31ms (639.31us)        13
#    nlp_jac_g  |        0 (       0)   4.70ms (313.27us)        15
#        total  | 114.00ms (114.00ms) 107.56ms (107.56ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.96ms (151.15us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.34ms (103.46us)        13
#   nlp_grad_f  |        0 (       0)   3.72ms (265.64us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.19ms (599.17us)        12
#    nlp_jac_g  |   3.00ms (214.29us)   4.07ms (290.79us)        14
#        total  |  99.00ms ( 99.00ms)  99.67ms ( 99.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.34ms (158.86us)        21
#        nlp_g  |        0 (       0)   2.46ms (117.38us)        21
#   nlp_grad_f  |   2.00ms ( 90.91us)   6.32ms (287.14us)        22
#   nlp_hess_l  |   2.00ms (100.00us)  12.35ms (617.30us)        20
#    nlp_jac_g  |        0 (       0)   6.77ms (307.77us)        22
#        total  | 199.00ms (199.00ms) 197.77ms (197.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (181.82us)   3.70ms (168.18us)        22
#        nlp_g  |        0 (       0)   2.72ms (123.73us)        22
#   nlp_grad_f  |   2.00ms ( 86.96us)   7.10ms (308.83us)        23
#   nlp_hess_l  |   2.00ms ( 95.24us)  13.88ms (660.95us)        21
#    nlp_jac_g  |   4.00ms (173.91us)   7.64ms (332.09us)        23
#        total  | 217.00ms (217.00ms) 217.11ms (217.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.39ms (171.07us)        14
#        nlp_g  |  31.00ms (  2.21ms)   1.68ms (120.14us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   5.01ms (334.27us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   8.80ms (676.92us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   5.31ms (354.20us)        15
#        total  | 131.00ms (131.00ms) 128.20ms (128.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.05ms (149.85us)        27
#        nlp_g  |        0 (       0)   2.96ms (109.63us)        27
#   nlp_grad_f  |        0 (       0)   7.02ms (292.50us)        24
#   nlp_hess_l  |  18.00ms (818.18us)  13.94ms (633.55us)        22
#    nlp_jac_g  |   4.00ms (166.67us)   7.80ms (324.96us)        24
#        total  | 220.00ms (220.00ms) 232.17ms (232.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   1.91ms (158.92us)        12
#        nlp_g  |        0 (       0)   1.27ms (106.25us)        12
#   nlp_grad_f  |   1.00ms ( 76.92us)   3.72ms (286.23us)        13
#   nlp_hess_l  |  21.00ms (  1.91ms)   6.66ms (605.18us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   3.92ms (301.46us)        13
#        total  |  98.00ms ( 98.00ms)  91.13ms ( 91.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   2.26ms (225.70us)        10
#        nlp_g  |   2.00ms (200.00us)   1.64ms (164.40us)        10
#   nlp_grad_f  |   4.00ms (363.64us)   4.22ms (383.91us)        11
#   nlp_hess_l  |   3.00ms (333.33us)   7.64ms (848.89us)         9
#    nlp_jac_g  |   5.00ms (454.55us)   4.71ms (428.18us)        11
#        total  | 102.00ms (102.00ms) 100.20ms (100.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 58.82us)   3.01ms (176.82us)        17
#        nlp_g  |   1.00ms ( 58.82us)   2.26ms (132.88us)        17
#   nlp_grad_f  |   5.00ms (277.78us)   5.94ms (329.78us)        18
#   nlp_hess_l  |  12.00ms (750.00us)  12.11ms (757.12us)        16
#    nlp_jac_g  |   4.00ms (222.22us)   6.41ms (355.94us)        18
#        total  | 138.00ms (138.00ms) 136.94ms (136.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 95.24us)   3.63ms (172.90us)        21
#        nlp_g  |   1.00ms ( 47.62us)   2.73ms (129.90us)        21
#   nlp_grad_f  |   5.00ms (227.27us)   6.78ms (308.27us)        22
#   nlp_hess_l  |   8.00ms (400.00us)  13.39ms (669.65us)        20
#    nlp_jac_g  |   8.00ms (363.64us)   7.33ms (333.36us)        22
#        total  | 190.00ms (190.00ms) 190.00ms (190.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (263.16us)   3.28ms (172.79us)        19
#        nlp_g  |   3.00ms (157.89us)   2.48ms (130.42us)        19
#   nlp_grad_f  |   9.00ms (450.00us)   6.55ms (327.30us)        20
#   nlp_hess_l  |  12.00ms (666.67us)  12.22ms (678.83us)        18
#    nlp_jac_g  |   5.00ms (250.00us)   7.01ms (350.70us)        20
#        total  | 182.00ms (182.00ms) 182.42ms (182.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (192.31us)   5.21ms (200.58us)        26
#        nlp_g  |   5.00ms (192.31us)   3.85ms (147.96us)        26
#   nlp_grad_f  |   6.00ms (222.22us)   9.35ms (346.19us)        27
#   nlp_hess_l  |  17.00ms (680.00us)  18.49ms (739.48us)        25
#    nlp_jac_g  |  10.00ms (370.37us)   9.91ms (367.15us)        27
#        total  | 273.00ms (273.00ms) 272.32ms (272.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.19ms (168.38us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.54ms (118.85us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   4.35ms (310.93us)        14
#   nlp_hess_l  |  11.00ms (916.67us)   8.11ms (676.08us)        12
#    nlp_jac_g  |   3.00ms (214.29us)   4.72ms (337.14us)        14
#        total  |  93.00ms ( 93.00ms) 105.13ms (105.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.11ms (162.00us)        13
#        nlp_g  |   4.00ms (307.69us)   1.50ms (115.54us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.75ms (267.79us)        14
#   nlp_hess_l  |   8.00ms (666.67us)   7.27ms (606.17us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   4.08ms (291.43us)        14
#        total  |  87.00ms ( 87.00ms)  98.40ms ( 98.40ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (200.00us)   2.55ms (170.07us)        15
#        nlp_g  |        0 (       0)   1.87ms (124.87us)        15
#   nlp_grad_f  |   3.00ms (187.50us)   4.95ms (309.31us)        16
#   nlp_hess_l  |  11.00ms (785.71us)   9.38ms (670.14us)        14
#    nlp_jac_g  |   2.00ms (125.00us)   5.26ms (328.56us)        16
#        total  | 126.00ms (126.00ms) 117.55ms (117.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 58.82us)   2.80ms (164.47us)        17
#        nlp_g  |        0 (       0)   2.01ms (118.53us)        17
#   nlp_grad_f  |   4.00ms (222.22us)   5.63ms (313.06us)        18
#   nlp_hess_l  |   8.00ms (500.00us)  10.34ms (646.56us)        16
#    nlp_jac_g  |   5.00ms (277.78us)   6.35ms (353.06us)        18
#        total  | 126.00ms (126.00ms) 126.18ms (126.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.80ms (164.94us)        17
#        nlp_g  |   1.00ms ( 58.82us)   2.13ms (125.53us)        17
#   nlp_grad_f  |   4.00ms (222.22us)   5.55ms (308.56us)        18
#   nlp_hess_l  |  22.00ms (  1.37ms)  10.59ms (661.81us)        16
#    nlp_jac_g  |  19.00ms (  1.06ms)   6.06ms (336.72us)        18
#        total  | 131.00ms (131.00ms) 130.97ms (130.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (266.67us)   2.42ms (161.13us)        15
#        nlp_g  |   2.00ms (133.33us)   1.73ms (115.20us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   4.86ms (304.06us)        16
#   nlp_hess_l  |   6.00ms (428.57us)   8.59ms (613.50us)        14
#    nlp_jac_g  |   6.00ms (375.00us)   5.29ms (330.87us)        16
#        total  | 115.00ms (115.00ms) 115.05ms (115.05ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (190.48us)   3.44ms (163.71us)        21
#        nlp_g  |   6.00ms (285.71us)   2.48ms (118.05us)        21
#   nlp_grad_f  |   3.00ms (136.36us)   6.45ms (293.18us)        22
#   nlp_hess_l  |  26.00ms (  1.30ms)  12.72ms (635.85us)        20
#    nlp_jac_g  |  17.00ms (772.73us)   6.93ms (315.09us)        22
#        total  | 164.00ms (164.00ms) 163.52ms (163.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (200.00us)   2.80ms (186.73us)        15
#        nlp_g  |        0 (       0)   1.85ms (123.53us)        15
#   nlp_grad_f  |   6.00ms (375.00us)   5.20ms (324.94us)        16
#   nlp_hess_l  |   9.00ms (642.86us)   9.10ms (650.29us)        14
#    nlp_jac_g  |   4.00ms (250.00us)   5.59ms (349.50us)        16
#        total  | 119.00ms (119.00ms) 119.05ms (119.05ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (153.85us)   2.40ms (184.54us)        13
#        nlp_g  |   2.00ms (153.85us)   1.78ms (136.92us)        13
#   nlp_grad_f  |   5.00ms (357.14us)   4.63ms (330.57us)        14
#   nlp_hess_l  |   7.00ms (583.33us)   8.61ms (717.17us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   5.07ms (362.14us)        14
#        total  | 110.00ms (110.00ms) 110.17ms (110.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (125.00us)   2.80ms (175.12us)        16
#        nlp_g  |   1.00ms ( 62.50us)   2.07ms (129.50us)        16
#   nlp_grad_f  |   4.00ms (235.29us)   5.49ms (323.24us)        17
#   nlp_hess_l  |   9.00ms (600.00us)  10.40ms (693.20us)        15
#    nlp_jac_g  |   3.00ms (176.47us)   5.98ms (351.94us)        17
#        total  | 129.00ms (129.00ms) 129.07ms (129.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.45ms (163.53us)        15
#        nlp_g  |   2.00ms (133.33us)   1.75ms (116.73us)        15
#   nlp_grad_f  |  11.00ms (687.50us)   4.95ms (309.56us)        16
#   nlp_hess_l  |   6.00ms (428.57us)   9.20ms (657.50us)        14
#    nlp_jac_g  |   3.00ms (187.50us)   5.21ms (325.87us)        16
#        total  | 121.00ms (121.00ms) 117.27ms (117.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.55ms (182.00us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.83ms (130.50us)        14
#   nlp_grad_f  |   7.00ms (466.67us)   5.10ms (340.33us)        15
#   nlp_hess_l  |   9.00ms (692.31us)   9.05ms (696.08us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   5.55ms (369.73us)        15
#        total  | 113.00ms (113.00ms) 114.76ms (114.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   2.05ms (171.17us)        12
#        nlp_g  |   1.00ms ( 83.33us)   1.45ms (120.92us)        12
#   nlp_grad_f  |   1.00ms ( 76.92us)   4.04ms (310.92us)        13
#   nlp_hess_l  |   6.00ms (545.45us)   7.66ms (696.09us)        11
#    nlp_jac_g  |   4.00ms (307.69us)   4.57ms (351.69us)        13
#        total  |  93.00ms ( 93.00ms)  93.59ms ( 93.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.49ms (178.21us)        14
#        nlp_g  |   2.00ms (142.86us)   1.77ms (126.21us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.72ms (314.47us)        15
#   nlp_hess_l  |  20.00ms (  1.54ms)   9.00ms (692.54us)        13
#    nlp_jac_g  |   6.00ms (400.00us)   5.04ms (335.87us)        15
#        total  | 114.00ms (114.00ms) 113.70ms (113.70ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 2 の総コスト: 260.99
# GPR: 学習開始...
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:243: RuntimeWarning:invalid value encountered in divide
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 5020.9751
#
# ==================================================
# 反復学習: イテレーション 3/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.32ms (178.46us)        13
#        nlp_g  |   2.00ms (153.85us)   1.53ms (117.77us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   4.29ms (306.57us)        14
#   nlp_hess_l  |   7.00ms (583.33us)   8.28ms (690.33us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   4.60ms (328.57us)        14
#        total  |  98.00ms ( 98.00ms) 100.03ms (100.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.61ms (200.62us)        13
#        nlp_g  |        0 (       0)   1.98ms (152.23us)        13
#   nlp_grad_f  |   5.00ms (357.14us)   4.93ms (352.07us)        14
#   nlp_hess_l  |  18.00ms (  1.50ms)   9.57ms (797.25us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   5.54ms (395.71us)        14
#        total  | 118.00ms (118.00ms) 107.61ms (107.61ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.12ms (176.33us)        12
#        nlp_g  |   3.00ms (250.00us)   1.54ms (128.08us)        12
#   nlp_grad_f  |   6.00ms (461.54us)   4.35ms (334.54us)        13
#   nlp_hess_l  |   6.00ms (545.45us)   7.84ms (712.55us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   4.55ms (349.77us)        13
#        total  |  81.00ms ( 81.00ms)  94.85ms ( 94.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (111.11us)   1.64ms (182.78us)         9
#        nlp_g  |        0 (       0)   1.23ms (136.44us)         9
#   nlp_grad_f  |   4.00ms (400.00us)   3.52ms (351.90us)        10
#   nlp_hess_l  |   3.00ms (375.00us)   5.48ms (685.25us)         8
#    nlp_jac_g  |   3.00ms (300.00us)   3.60ms (360.40us)        10
#        total  |  76.00ms ( 76.00ms)  76.58ms ( 76.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (153.85us)   4.88ms (187.69us)        26
#        nlp_g  |   4.00ms (153.85us)   3.33ms (127.92us)        26
#   nlp_grad_f  |   5.00ms (185.19us)   8.24ms (305.37us)        27
#   nlp_hess_l  |   9.00ms (360.00us)  16.78ms (671.12us)        25
#    nlp_jac_g  |   6.00ms (222.22us)   9.07ms (335.81us)        27
#        total  | 252.00ms (252.00ms) 251.05ms (251.05ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (157.89us)   3.27ms (172.32us)        19
#        nlp_g  |        0 (       0)   2.14ms (112.63us)        19
#   nlp_grad_f  |   4.00ms (210.53us)   5.51ms (290.05us)        19
#   nlp_hess_l  |   6.00ms (352.94us)  11.92ms (701.41us)        17
#    nlp_jac_g  |   4.00ms (210.53us)   5.81ms (305.74us)        19
#        total  | 148.00ms (148.00ms) 136.92ms (136.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (136.36us)   3.66ms (166.18us)        22
#        nlp_g  |        0 (       0)   2.61ms (118.59us)        22
#   nlp_grad_f  |   9.00ms (391.30us)   6.63ms (288.30us)        23
#   nlp_hess_l  |  12.00ms (571.43us)  14.08ms (670.29us)        21
#    nlp_jac_g  |   4.00ms (173.91us)   7.33ms (318.52us)        23
#        total  | 207.00ms (207.00ms) 206.58ms (206.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (227.27us)   3.80ms (172.59us)        22
#        nlp_g  |   1.00ms ( 45.45us)   2.67ms (121.59us)        22
#   nlp_grad_f  |   5.00ms (227.27us)   6.83ms (310.68us)        22
#   nlp_hess_l  |   7.00ms (350.00us)  13.54ms (677.10us)        20
#    nlp_jac_g  |   4.00ms (181.82us)   7.24ms (329.09us)        22
#        total  | 205.00ms (205.00ms) 204.47ms (204.47ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (318.18us)   4.49ms (204.14us)        22
#        nlp_g  |   2.00ms ( 90.91us)   3.14ms (142.77us)        22
#   nlp_grad_f  |   2.00ms ( 86.96us)   7.74ms (336.52us)        23
#   nlp_hess_l  |  16.00ms (761.90us)  17.67ms (841.38us)        21
#    nlp_jac_g  |   8.00ms (347.83us)   9.86ms (428.48us)        23
#        total  | 222.00ms (222.00ms) 221.48ms (221.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 50.00us)   3.51ms (175.40us)        20
#        nlp_g  |   1.00ms ( 50.00us)   2.69ms (134.50us)        20
#   nlp_grad_f  |   2.00ms (100.00us)   5.94ms (297.00us)        20
#   nlp_hess_l  |   7.00ms (388.89us)  12.67ms (703.72us)        18
#    nlp_jac_g  |   6.00ms (300.00us)   6.33ms (316.50us)        20
#        total  | 190.00ms (190.00ms) 189.48ms (189.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (166.67us)   3.09ms (171.61us)        18
#        nlp_g  |        0 (       0)   2.19ms (121.94us)        18
#   nlp_grad_f  |  10.00ms (526.32us)   5.72ms (300.84us)        19
#   nlp_hess_l  |   8.00ms (470.59us)  11.82ms (695.18us)        17
#    nlp_jac_g  |   4.00ms (210.53us)   6.75ms (355.11us)        19
#        total  | 179.00ms (179.00ms) 179.53ms (179.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (416.67us)   1.92ms (159.92us)        12
#        nlp_g  |        0 (       0)   1.34ms (111.75us)        12
#   nlp_grad_f  |   2.00ms (153.85us)   3.82ms (293.77us)        13
#   nlp_hess_l  |   6.00ms (545.45us)   7.13ms (648.55us)        11
#    nlp_jac_g  |   6.00ms (461.54us)   4.38ms (336.69us)        13
#        total  |  94.00ms ( 94.00ms)  93.86ms ( 93.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (333.33us)   1.54ms (170.78us)         9
#        nlp_g  |   7.00ms (777.78us)   1.08ms (120.00us)         9
#   nlp_grad_f  |        0 (       0)   3.39ms (338.70us)        10
#   nlp_hess_l  |  11.00ms (  1.38ms)   5.15ms (643.25us)         8
#    nlp_jac_g  |   4.00ms (400.00us)   3.32ms (332.50us)        10
#        total  |  70.00ms ( 70.00ms)  69.88ms ( 69.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   1.77ms (160.55us)        11
#        nlp_g  |        0 (       0)   1.30ms (118.27us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.72ms (310.00us)        12
#   nlp_hess_l  |   5.00ms (500.00us)   6.80ms (680.40us)        10
#    nlp_jac_g  |   3.00ms (250.00us)   4.14ms (345.17us)        12
#        total  |  84.00ms ( 84.00ms)  83.60ms ( 83.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (111.11us)   2.93ms (162.78us)        18
#        nlp_g  |        0 (       0)   2.17ms (120.56us)        18
#   nlp_grad_f  |   4.00ms (210.53us)   6.06ms (319.16us)        19
#   nlp_hess_l  |   7.00ms (411.76us)  11.43ms (672.53us)        17
#    nlp_jac_g  |   5.00ms (263.16us)   6.63ms (349.05us)        19
#        total  | 145.00ms (145.00ms) 145.93ms (145.93ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   1.87ms (155.50us)        12
#        nlp_g  |  17.00ms (  1.42ms)   1.43ms (119.25us)        12
#   nlp_grad_f  |   3.00ms (230.77us)   3.74ms (287.54us)        13
#   nlp_hess_l  |   6.00ms (545.45us)   6.81ms (618.82us)        11
#    nlp_jac_g  |   2.00ms (153.85us)   4.05ms (311.31us)        13
#        total  |  92.00ms ( 92.00ms)  92.37ms ( 92.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.69ms (168.44us)        16
#        nlp_g  |        0 (       0)   1.93ms (120.44us)        16
#   nlp_grad_f  |  10.00ms (588.24us)   4.93ms (290.24us)        17
#   nlp_hess_l  |   8.00ms (533.33us)   9.86ms (657.47us)        15
#    nlp_jac_g  |   4.00ms (235.29us)   5.26ms (309.71us)        17
#        total  | 125.00ms (125.00ms) 126.29ms (126.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.41ms (172.43us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.75ms (125.29us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   4.50ms (300.13us)        15
#   nlp_hess_l  |   5.00ms (384.62us)   8.61ms (662.38us)        13
#    nlp_jac_g  |   6.00ms (400.00us)   4.82ms (321.60us)        15
#        total  | 115.00ms (115.00ms) 108.42ms (108.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (162.16us)   6.36ms (171.86us)        37
#        nlp_g  |   4.00ms (108.11us)   4.64ms (125.38us)        37
#   nlp_grad_f  |   9.00ms (236.84us)  11.09ms (291.76us)        38
#   nlp_hess_l  |  20.00ms (555.56us)  23.18ms (643.86us)        36
#    nlp_jac_g  |  10.00ms (263.16us)  11.98ms (315.32us)        38
#        total  | 361.00ms (361.00ms) 360.37ms (360.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (137.93us)   4.73ms (162.97us)        29
#        nlp_g  |   1.00ms ( 34.48us)   3.28ms (113.07us)        29
#   nlp_grad_f  |   6.00ms (200.00us)   8.47ms (282.50us)        30
#   nlp_hess_l  |  12.00ms (428.57us)  17.90ms (639.32us)        28
#    nlp_jac_g  |   8.00ms (266.67us)   9.27ms (308.93us)        30
#        total  | 242.00ms (242.00ms) 242.80ms (242.80ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (160.00us)   3.95ms (158.16us)        25
#        nlp_g  |        0 (       0)   2.92ms (116.72us)        25
#   nlp_grad_f  |   2.00ms ( 76.92us)   7.36ms (283.15us)        26
#   nlp_hess_l  |  32.00ms (  1.33ms)  15.32ms (638.21us)        24
#    nlp_jac_g  |   4.00ms (153.85us)   7.86ms (302.15us)        26
#        total  | 204.00ms (204.00ms) 202.93ms (202.93ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 60.61us)   5.81ms (176.15us)        33
#        nlp_g  |   4.00ms (121.21us)   4.44ms (134.42us)        33
#   nlp_grad_f  |  20.00ms (588.24us)  10.05ms (295.68us)        34
#   nlp_hess_l  |  20.00ms (625.00us)  21.71ms (678.59us)        32
#    nlp_jac_g  |   9.00ms (264.71us)  10.99ms (323.38us)        34
#        total  | 323.00ms (323.00ms) 322.87ms (322.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (153.85us)   2.31ms (178.00us)        13
#        nlp_g  |        0 (       0)   1.66ms (127.54us)        13
#   nlp_grad_f  |   4.00ms (285.71us)   4.20ms (300.29us)        14
#   nlp_hess_l  |  19.00ms (  1.58ms)   8.07ms (672.92us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.52ms (322.57us)        14
#        total  |  99.00ms ( 99.00ms)  98.59ms ( 98.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (312.50us)   2.51ms (157.19us)        16
#        nlp_g  |        0 (       0)   1.78ms (111.25us)        16
#   nlp_grad_f  |   3.00ms (176.47us)   4.67ms (274.71us)        17
#   nlp_hess_l  |  11.00ms (733.33us)   9.11ms (607.53us)        15
#    nlp_jac_g  |        0 (       0)   4.98ms (293.06us)        17
#        total  | 124.00ms (124.00ms) 116.69ms (116.69ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   2.17ms (167.23us)        13
#        nlp_g  |   2.00ms (153.85us)   1.61ms (123.92us)        13
#   nlp_grad_f  |   4.00ms (285.71us)   3.93ms (280.43us)        14
#   nlp_hess_l  |   6.00ms (500.00us)   7.67ms (639.08us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   4.11ms (293.57us)        14
#        total  |  96.00ms ( 96.00ms)  96.84ms ( 96.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  12.00ms (923.08us)   2.15ms (165.08us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.48ms (113.77us)        13
#   nlp_grad_f  |  19.00ms (  1.36ms)   4.27ms (305.07us)        14
#   nlp_hess_l  |   6.00ms (500.00us)   7.92ms (659.92us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   4.56ms (325.57us)        14
#        total  | 100.00ms (100.00ms) 100.19ms (100.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (166.67us)   3.41ms (189.22us)        18
#        nlp_g  |   3.00ms (166.67us)   2.31ms (128.44us)        18
#   nlp_grad_f  |  10.00ms (526.32us)   6.03ms (317.32us)        19
#   nlp_hess_l  |  10.00ms (588.24us)  11.39ms (669.94us)        17
#    nlp_jac_g  |   3.00ms (157.89us)   5.97ms (314.11us)        19
#        total  | 135.00ms (135.00ms) 134.89ms (134.89ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (214.29us)   2.66ms (190.07us)        14
#        nlp_g  |        0 (       0)   1.90ms (135.64us)        14
#   nlp_grad_f  |   8.00ms (533.33us)   5.06ms (337.07us)        15
#   nlp_hess_l  |   8.00ms (615.38us)   9.37ms (720.54us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   5.53ms (368.53us)        15
#        total  | 109.00ms (109.00ms) 109.28ms (109.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.48ms (177.07us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.83ms (130.71us)        14
#   nlp_grad_f  |   5.00ms (333.33us)   4.63ms (308.87us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   9.41ms (723.92us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   4.90ms (326.60us)        15
#        total  | 108.00ms (108.00ms) 107.84ms (107.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.57ms (183.36us)        14
#        nlp_g  |   2.00ms (142.86us)   1.90ms (136.07us)        14
#   nlp_grad_f  |  17.00ms (  1.13ms)   4.96ms (330.67us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   9.54ms (734.08us)        13
#    nlp_jac_g  |  16.00ms (  1.07ms)   5.56ms (370.60us)        15
#        total  | 104.00ms (104.00ms) 110.49ms (110.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  18.00ms (  1.29ms)   2.37ms (169.64us)        14
#        nlp_g  |   2.00ms (142.86us)   1.70ms (121.29us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   4.60ms (306.47us)        15
#   nlp_hess_l  |   7.00ms (538.46us)   8.31ms (639.38us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   5.00ms (333.47us)        15
#        total  |  96.00ms ( 96.00ms) 104.81ms (104.81ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 3 の総コスト: 260.08
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 2638.8599
#
# ==================================================
# 反復学習: イテレーション 4/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.34ms (167.50us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.75ms (125.07us)        14
#   nlp_grad_f  |   5.00ms (333.33us)   4.52ms (301.07us)        15
#   nlp_hess_l  |   7.00ms (538.46us)   8.61ms (662.46us)        13
#    nlp_jac_g  |   7.00ms (466.67us)   4.88ms (325.67us)        15
#        total  | 107.00ms (107.00ms) 106.29ms (106.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   2.11ms (191.91us)        11
#        nlp_g  |        0 (       0)   1.55ms (141.09us)        11
#   nlp_grad_f  |   6.00ms (500.00us)   3.96ms (329.92us)        12
#   nlp_hess_l  |   7.00ms (700.00us)   7.29ms (729.00us)        10
#    nlp_jac_g  |   5.00ms (416.67us)   4.33ms (360.58us)        12
#        total  |  93.00ms ( 93.00ms)  93.70ms ( 93.70ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   2.05ms (171.25us)        12
#        nlp_g  |   2.00ms (166.67us)   1.54ms (128.50us)        12
#   nlp_grad_f  |   4.00ms (307.69us)   4.28ms (329.08us)        13
#   nlp_hess_l  |   8.00ms (727.27us)   7.46ms (677.91us)        11
#    nlp_jac_g  |   3.00ms (230.77us)   4.78ms (367.77us)        13
#        total  |  96.00ms ( 96.00ms)  96.06ms ( 96.06ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   1.77ms (161.36us)        11
#        nlp_g  |   1.00ms ( 90.91us)   1.16ms (105.55us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.38ms (281.50us)        12
#   nlp_hess_l  |  10.00ms (  1.00ms)   6.35ms (634.90us)        10
#    nlp_jac_g  |        0 (       0)   3.64ms (303.42us)        12
#        total  |  81.00ms ( 81.00ms)  84.96ms ( 84.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (156.25us)   5.26ms (164.50us)        32
#        nlp_g  |   1.00ms ( 31.25us)   3.58ms (111.75us)        32
#   nlp_grad_f  |   6.00ms (206.90us)   8.36ms (288.24us)        29
#   nlp_hess_l  |  16.00ms (592.59us)  18.69ms (692.15us)        27
#    nlp_jac_g  |   5.00ms (172.41us)   9.07ms (312.69us)        29
# ...
#        nlp_f  |   3.00ms (200.00us)   2.29ms (153.00us)        15
#        nlp_g  |   2.00ms (133.33us)   1.57ms (104.60us)        15
#   nlp_grad_f  |   2.00ms (125.00us)   4.59ms (287.06us)        16
#   nlp_hess_l  |  20.00ms (  1.43ms)   8.41ms (600.43us)        14
#    nlp_jac_g  |   6.00ms (375.00us)   5.07ms (316.81us)        16
#        total  | 116.00ms (116.00ms) 115.62ms (115.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.15ms (153.36us)        14
#        nlp_g  |        0 (       0)   1.51ms (108.21us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.43ms (295.27us)        15
#   nlp_hess_l  |        0 (       0)   8.52ms (655.54us)        13
#    nlp_jac_g  |        0 (       0)   4.60ms (307.00us)        15
#        total  | 100.00ms (100.00ms) 108.30ms (108.30ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 4 の総コスト: 260.76
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 721.5826
#
# ==================================================
# 反復学習: イテレーション 5/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.53ms (180.86us)        14
#        nlp_g  |   2.00ms (142.86us)   1.80ms (128.29us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.95ms (329.93us)        15
#   nlp_hess_l  |   3.00ms (230.77us)   9.13ms (702.08us)        13
#    nlp_jac_g  |  23.00ms (  1.53ms)   5.67ms (378.00us)        15
#        total  | 117.00ms (117.00ms) 111.07ms (111.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   1.77ms (177.00us)        10
#        nlp_g  |   2.00ms (200.00us)   1.22ms (122.00us)        10
#   nlp_grad_f  |   3.00ms (272.73us)   3.33ms (302.91us)        11
#   nlp_hess_l  |   8.00ms (888.89us)   6.16ms (684.67us)         9
#    nlp_jac_g  |   3.00ms (272.73us)   3.45ms (313.64us)        11
#        total  |  79.00ms ( 79.00ms)  78.86ms ( 78.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   1.88ms (188.50us)        10
#        nlp_g  |   1.00ms (100.00us)   1.37ms (136.90us)        10
#   nlp_grad_f  |        0 (       0)   3.57ms (324.36us)        11
#   nlp_hess_l  |  17.00ms (  1.89ms)   6.44ms (715.78us)         9
#    nlp_jac_g  |   2.00ms (181.82us)   3.96ms (360.18us)        11
#        total  |  80.00ms ( 80.00ms)  80.07ms ( 80.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.29ms (142.89us)         9
#        nlp_g  |        0 (       0) 873.00us ( 97.00us)         9
#   nlp_grad_f  |        0 (       0)   2.86ms (286.30us)        10
#   nlp_hess_l  |  15.00ms (  1.87ms)   4.60ms (575.62us)         8
#    nlp_jac_g  |  15.00ms (  1.50ms)   2.85ms (285.20us)        10
#        total  |  82.00ms ( 82.00ms)  68.97ms ( 68.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.60ms)   1.57ms (157.40us)        10
#        nlp_g  |   2.00ms (200.00us)   1.08ms (108.00us)        10
#   nlp_grad_f  |   1.00ms ( 90.91us)   2.99ms (272.27us)        11
#   nlp_hess_l  |   5.00ms (555.56us)   5.61ms (623.89us)         9
#    nlp_jac_g  |        0 (       0)   3.23ms (294.09us)        11
#        total  |  75.00ms ( 75.00ms)  75.79ms ( 75.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (193.55us)   4.86ms (156.77us)        31
#        nlp_g  |   1.00ms ( 32.26us)   3.31ms (106.74us)        31
#   nlp_grad_f  |   5.00ms (172.41us)   8.42ms (290.21us)        29
#   nlp_hess_l  |   9.00ms (333.33us)  17.13ms (634.30us)        27
#    nlp_jac_g  |  11.00ms (379.31us)   8.78ms (302.83us)        29
#        total  | 280.00ms (280.00ms) 280.18ms (280.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 86.96us)   3.69ms (160.57us)        23
#        nlp_g  |   1.00ms ( 43.48us)   2.63ms (114.30us)        23
#   nlp_grad_f  |   8.00ms (333.33us)   6.62ms (275.79us)        24
#   nlp_hess_l  |  22.00ms (  1.00ms)  13.54ms (615.41us)        22
#    nlp_jac_g  |   6.00ms (250.00us)   7.46ms (310.96us)        24
#        total  | 218.00ms (218.00ms) 216.09ms (216.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.60ms (158.76us)        29
#        nlp_g  |   2.00ms ( 68.97us)   3.04ms (104.97us)        29
#   nlp_grad_f  |        0 (       0)   7.85ms (280.46us)        28
#   nlp_hess_l  |  17.00ms (653.85us)  15.07ms (579.69us)        26
#    nlp_jac_g  |  17.00ms (607.14us)   8.04ms (287.25us)        28
#        total  | 269.00ms (269.00ms) 264.42ms (264.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.88ms (143.59us)        27
#        nlp_g  |  16.00ms (592.59us)   2.65ms ( 98.11us)        27
#   nlp_grad_f  |  16.00ms (592.59us)   7.18ms (265.85us)        27
#   nlp_hess_l  |        0 (       0)  14.06ms (562.28us)        25
#    nlp_jac_g  |        0 (       0)   7.61ms (281.96us)        27
#        total  | 217.00ms (217.00ms) 223.42ms (223.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.99ms (151.18us)        33
#        nlp_g  |   3.00ms ( 90.91us)   3.62ms (109.67us)        33
#   nlp_grad_f  |   5.00ms (161.29us)   8.65ms (278.90us)        31
#   nlp_hess_l  |  20.00ms (689.66us)  17.59ms (606.59us)        29
#    nlp_jac_g  |  17.00ms (548.39us)   9.03ms (291.45us)        31
#        total  | 315.00ms (315.00ms) 306.67ms (306.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.57ms (174.00us)        32
#        nlp_g  |   8.00ms (250.00us)   4.29ms (133.97us)        32
#   nlp_grad_f  |  15.00ms (500.00us)   9.41ms (313.60us)        30
#   nlp_hess_l  |  19.00ms (678.57us)  19.41ms (693.39us)        28
#    nlp_jac_g  |   7.00ms (233.33us)   9.86ms (328.63us)        30
#        total  | 324.00ms (324.00ms) 324.33ms (324.33ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 76.92us)   4.23ms (162.73us)        26
#        nlp_g  |   1.00ms ( 38.46us)   2.99ms (115.19us)        26
#   nlp_grad_f  |        0 (       0)   8.36ms (309.74us)        27
#   nlp_hess_l  |   8.00ms (320.00us)  16.26ms (650.56us)        25
#    nlp_jac_g  |        0 (       0)   8.81ms (326.37us)        27
#        total  | 261.00ms (261.00ms) 267.67ms (267.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (117.65us)   5.34ms (157.18us)        34
#        nlp_g  |   1.00ms ( 29.41us)   3.88ms (114.26us)        34
#   nlp_grad_f  |   2.00ms ( 62.50us)   9.33ms (291.56us)        32
#   nlp_hess_l  |   8.00ms (266.67us)  19.08ms (636.07us)        30
#    nlp_jac_g  |  10.00ms (312.50us)  10.17ms (317.91us)        32
#        total  | 352.00ms (352.00ms) 351.28ms (351.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 58.82us)   5.24ms (154.09us)        34
#        nlp_g  |   1.00ms ( 29.41us)   3.51ms (103.32us)        34
#   nlp_grad_f  |   4.00ms (137.93us)   8.70ms (300.14us)        29
#   nlp_hess_l  |   8.00ms (296.30us)  17.34ms (642.22us)        27
#    nlp_jac_g  |   5.00ms (172.41us)   9.12ms (314.38us)        29
#        total  | 301.00ms (301.00ms) 316.11ms (316.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   1.91ms (174.00us)        11
#        nlp_g  |   2.00ms (181.82us)   1.37ms (124.18us)        11
#   nlp_grad_f  |   2.00ms (166.67us)   3.69ms (307.75us)        12
#   nlp_hess_l  |   4.00ms (400.00us)   6.74ms (674.10us)        10
#    nlp_jac_g  |   3.00ms (250.00us)   4.04ms (336.33us)        12
#        total  | 101.00ms (101.00ms)  91.12ms ( 91.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (269.23us)   4.56ms (175.23us)        26
#        nlp_g  |   3.00ms (115.38us)   3.21ms (123.38us)        26
#   nlp_grad_f  |   6.00ms (230.77us)   7.90ms (304.04us)        26
#   nlp_hess_l  |  17.00ms (708.33us)  16.07ms (669.50us)        24
#    nlp_jac_g  |   8.00ms (307.69us)   8.34ms (320.69us)        26
#        total  | 262.00ms (262.00ms) 261.77ms (261.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (  1.31ms)   2.10ms (161.92us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.37ms (105.54us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   4.20ms (299.71us)        14
#   nlp_hess_l  |   5.00ms (416.67us)   7.72ms (643.75us)        12
#    nlp_jac_g  |   5.00ms (357.14us)   4.31ms (308.14us)        14
#        total  |  97.00ms ( 97.00ms)  97.16ms ( 97.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 47.62us)   3.20ms (152.38us)        21
#        nlp_g  |   3.00ms (142.86us)   2.20ms (105.00us)        21
#   nlp_grad_f  |   4.00ms (181.82us)   5.93ms (269.73us)        22
#   nlp_hess_l  |  20.00ms (  1.00ms)  12.60ms (629.80us)        20
#    nlp_jac_g  |  20.00ms (909.09us)   6.50ms (295.41us)        22
#        total  | 193.00ms (193.00ms) 193.28ms (193.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.34ms (155.73us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.75ms (116.47us)        15
#   nlp_grad_f  |   3.00ms (187.50us)   4.68ms (292.75us)        16
#   nlp_hess_l  |  18.00ms (  1.29ms)   8.78ms (627.29us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   5.11ms (319.69us)        16
#        total  | 116.00ms (116.00ms) 116.82ms (116.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   9.00ms (642.86us)   2.41ms (172.50us)        14
#        nlp_g  |        0 (       0)   1.66ms (118.93us)        14
#   nlp_grad_f  |   6.00ms (400.00us)   4.82ms (321.67us)        15
#   nlp_hess_l  |  10.00ms (769.23us)   8.62ms (662.92us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   5.45ms (363.67us)        15
#        total  | 107.00ms (107.00ms) 106.80ms (106.80ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (233.33us)   4.85ms (161.67us)        30
#        nlp_g  |        0 (       0)   3.53ms (117.60us)        30
#   nlp_grad_f  |  11.00ms (354.84us)   8.63ms (278.42us)        31
#   nlp_hess_l  |  20.00ms (689.66us)  17.59ms (606.52us)        29
#    nlp_jac_g  |   4.00ms (129.03us)   9.37ms (302.13us)        31
#        total  | 306.00ms (306.00ms) 297.68ms (297.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.34ms (167.21us)        14
#        nlp_g  |   5.00ms (357.14us)   1.60ms (114.14us)        14
#   nlp_grad_f  |   3.00ms (200.00us)   4.40ms (293.47us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   8.59ms (660.46us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   4.73ms (315.13us)        15
#        total  | 105.00ms (105.00ms) 105.49ms (105.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (173.91us)   3.76ms (163.57us)        23
#        nlp_g  |   1.00ms ( 43.48us)   2.61ms (113.57us)        23
#   nlp_grad_f  |   2.00ms ( 83.33us)   6.57ms (273.87us)        24
#   nlp_hess_l  |  10.00ms (454.55us)  13.78ms (626.18us)        22
#    nlp_jac_g  |   4.00ms (166.67us)   7.06ms (294.33us)        24
#        total  | 211.00ms (211.00ms) 212.13ms (212.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.22ms (158.86us)        14
#        nlp_g  |   3.00ms (214.29us)   1.61ms (114.93us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.46ms (297.47us)        15
#   nlp_hess_l  |   5.00ms (384.62us)   8.08ms (621.31us)        13
#    nlp_jac_g  |   7.00ms (466.67us)   4.73ms (315.27us)        15
#        total  | 103.00ms (103.00ms) 103.52ms (103.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (125.00us)   6.41ms (160.15us)        40
#        nlp_g  |   8.00ms (200.00us)   4.56ms (113.90us)        40
#   nlp_grad_f  |   7.00ms (170.73us)  11.23ms (273.93us)        41
#   nlp_hess_l  |  20.00ms (512.82us)  23.96ms (614.26us)        39
#    nlp_jac_g  |  12.00ms (292.68us)  11.92ms (290.76us)        41
#        total  | 372.00ms (372.00ms) 371.43ms (371.43ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.36ms (147.44us)        16
#        nlp_g  |   2.00ms (125.00us)   1.76ms (109.75us)        16
#   nlp_grad_f  |   1.00ms ( 58.82us)   4.73ms (278.06us)        17
#   nlp_hess_l  |   6.00ms (400.00us)   9.30ms (620.07us)        15
#    nlp_jac_g  |   4.00ms (235.29us)   5.05ms (297.06us)        17
#        total  | 109.00ms (109.00ms) 117.08ms (117.08ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 62.50us)   2.60ms (162.56us)        16
#        nlp_g  |        0 (       0)   1.73ms (108.31us)        16
#   nlp_grad_f  |  19.00ms (  1.12ms)   5.33ms (313.59us)        17
#   nlp_hess_l  |   4.00ms (266.67us)   9.73ms (648.73us)        15
#    nlp_jac_g  |   5.00ms (294.12us)   5.59ms (329.00us)        17
#        total  | 115.00ms (115.00ms) 122.01ms (122.01ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (357.14us)   2.10ms (149.86us)        14
#        nlp_g  |   2.00ms (142.86us)   1.42ms (101.50us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.03ms (268.47us)        15
#   nlp_hess_l  |  11.00ms (846.15us)   8.00ms (615.31us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   4.33ms (288.87us)        15
#        total  | 106.00ms (106.00ms) 106.23ms (106.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.19ms (168.31us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.47ms (112.92us)        13
#   nlp_grad_f  |   4.00ms (285.71us)   4.12ms (294.00us)        14
#   nlp_hess_l  |   5.00ms (416.67us)   8.11ms (675.83us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.51ms (322.07us)        14
#        total  | 101.00ms (101.00ms) 100.79ms (100.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   3.24ms (231.36us)        14
#        nlp_g  |   1.00ms ( 71.43us)   2.17ms (155.07us)        14
#   nlp_grad_f  |   5.00ms (333.33us)   5.32ms (355.00us)        15
#   nlp_hess_l  |   5.00ms (384.62us)   9.25ms (711.23us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   5.37ms (358.33us)        15
#        total  | 122.00ms (122.00ms) 125.39ms (125.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (166.67us)   6.37ms (177.00us)        36
#        nlp_g  |   2.00ms ( 55.56us)   4.61ms (127.97us)        36
#   nlp_grad_f  |   2.00ms ( 54.05us)  10.46ms (282.68us)        37
#   nlp_hess_l  |  19.00ms (542.86us)  21.76ms (621.74us)        35
#    nlp_jac_g  |   8.00ms (216.22us)  11.33ms (306.27us)        37
#        total  | 325.00ms (325.00ms) 324.90ms (324.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.64ms (188.36us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.86ms (133.00us)        14
#   nlp_grad_f  |   5.00ms (333.33us)   4.73ms (315.33us)        15
#   nlp_hess_l  |   9.00ms (692.31us)   9.40ms (723.38us)        13
#    nlp_jac_g  |   5.00ms (333.33us)   4.91ms (327.13us)        15
#        total  | 105.00ms (105.00ms) 112.04ms (112.04ms)         1
# ステップ 32 でゴールに到達！
# イテレーション 5 の総コスト: 260.10
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 120.8301
