# %% [markdown]
# NNを元に2次関数の終端コストを決定

# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import torch
import torch.nn as nn
import torch.optim as optim
import time


import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)

# ==================================================================================
# シミュレーション全体の設定パラメータ
# ==================================================================================
N_ITERATIONS = 10
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE = np.array([10.0, 10.0])
N_MPC = 20
M_MPC = 25
OBSTACLE_INFO = {'pos': np.array([5.0, 5.0]), 'rad': 1.5}


# ----------------------------------------------------------------------------------
# Component 1: TerminalCostNN & 学習関数
# ----------------------------------------------------------------------------------
class TerminalCostNN(nn.Module):
    def __init__(self, n_input):
        super(TerminalCostNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_input, 64), nn.ReLU(),
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.layers(x)

def train_terminal_cost_net(net, trajectory_data):
    if len(trajectory_data) < 10: return
    print("NN: 終端コストの学習開始...")
    optimizer = optim.Adam(net.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    states = torch.tensor(np.array([d[0] for d in trajectory_data]), dtype=torch.float32)
    costs_to_go = []
    running_cost = 0
    for _, stage_cost in reversed(trajectory_data):
        running_cost += stage_cost
        costs_to_go.append(running_cost)
    costs_to_go.reverse()
    labels = torch.tensor(costs_to_go, dtype=torch.float32).view(-1, 1)
    for epoch in range(100):
        optimizer.zero_grad(); outputs = net(states); loss = criterion(outputs, labels)
        loss.backward(); optimizer.step()
    print(f"NN: 学習完了。最終損失: {loss.item():.4f}")

# (TrueVehicle, GPRModelクラスは変更なし)
class TrueVehicle:
    def __init__(self, dt=0.1): self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u; drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt; vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2; py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])
class GPRModel:
    def __init__(self, nx, nu, dt, obstacle_info):
        self.nx, self.nu = nx, nu
        self.dt=DT
        self.obstacle_info=OBSTACLE_INFO
        self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu))
        self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx

    def add_data(self, x, u, x_next):
        # 公称モデルからの誤差（デルタ）を学習ターゲットにする
        delta_real = (x_next - x) / self.dt
        delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])])
        self.Y_data = np.vstack([self.Y_data, error])

    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始...")
        for i in range(self.nx):
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100)
            self.models[i] = model
        self.is_trained = True
        print("GPR: 学習完了")

    def predict(self, x, u):
        if not self.is_trained:
            return np.zeros(self.nx), np.ones(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        variances = np.array([m.predict(xu)[1][0, 0] if m else 1.0 for m in self.models])
        return means, variances

# ----------------------------------------------------------------------------------
# Component 3: MPCController
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, M, dt, obstacle_info):
        self.nx, self.nu, self.N, self.M, self.dt = nx, nu, N, M, dt
        self.obstacle_info = obstacle_info; self.u_prev_sol = np.zeros((nu, N))

    # ✅ 変更点：NNをアドバイザーとして使う方式に変更
    def solve(self, x_current, gpr_model, x_goal, terminal_cost_net, is_first_iteration):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)

        # --- ステップ１：NNで「賢い目標地点」を大まかに探す ---
        if is_first_iteration:
            # 最初のイテレーションではNNが未学習なので、ゴールをそのまま使う
            smart_target = x_goal
        else:
            # 現在位置から周辺のいくつかの候補点を生成
            num_candidates = 20
            candidates_pos = np.random.randn(num_candidates, 2) * 2.0 + x_current[:2]
            candidates_vel = np.zeros((num_candidates, 2))
            candidates = np.hstack([candidates_pos, candidates_vel])
            
            # NNで各候補点のコストを評価
            candidates_torch = torch.tensor(candidates, dtype=torch.float32)
            with torch.no_grad():
                costs = terminal_cost_net(candidates_torch).numpy().flatten()
            
            # 最もコストが低い候補点を「賢い目標地点」とする
            smart_target = candidates_pos[np.argmin(costs)]
            

        error_mean, error_var = gpr_model.predict(x_current, np.zeros(self.nu))
        error_std = np.sqrt(np.maximum(error_var, 1e-6)); error_std_capped = np.minimum(error_std, 0.2)
        error_samples = np.random.normal(loc=error_mean, scale=error_std_capped, size=(self.M, self.nx))
        
        all_scenario_costs = []
        for m in range(self.M):
            X_scenario = opti.variable(self.nx, self.N + 1); cost_scenario = 0
            opti.subject_to(X_scenario[:, 0] == x_current)
            for k in range(self.N):
                x_k, u_k = X_scenario[:, k], U[:, k]
                delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
                delta_pred = delta_nominal + error_samples[m, :]
                x_next_pred = x_k + delta_pred * self.dt
                opti.subject_to(X_scenario[:, k+1] == x_next_pred)
                cost_scenario += ca.sumsqr(x_k[:2] - x_goal) * self.dt + ca.sumsqr(u_k) * self.dt * 0.01
                if self.obstacle_info:
                    dist_to_obs = ca.norm_2(x_k[:2] - self.obstacle_info['pos'])
                    penalty = ca.fmax(0, self.obstacle_info['rad'] - dist_to_obs)
                    cost_scenario += 500.0 * penalty**2
            
            # --- ステップ２：MPCの終端コストとして、その「賢い目標地点」を目指す ---
            terminal_state = X_scenario[:, self.N]
            cost_scenario += ca.sumsqr(terminal_state[:2] - smart_target) * 10.0

            all_scenario_costs.append(cost_scenario)
        
        #total_objective = ca.mean(ca.vertcat(*all_scenario_costs))
        total_objective = ca.sum1(ca.vertcat(*all_scenario_costs)) / len(all_scenario_costs)
        opti.minimize(total_objective)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))
        opti.set_initial(U, self.u_prev_sol)
        s_opts = {'print_level': 0}; opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}"); return np.zeros(self.nu)

# ----------------------------------------------------------------------------------
# Main Simulation Loop
# ----------------------------------------------------------------------------------
def main():
    vehicle = TrueVehicle(dt=DT)
    gpr_model = GPRModel(nx=NX, nu=NU,dt=DT, obstacle_info=OBSTACLE_INFO)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, M=M_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)
    terminal_cost_net = TerminalCostNN(n_input=NX)
    all_trajectories, final_costs = [], []
    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE); total_cost = 0
        iteration_data_for_gpr, iteration_data_for_cost_learning = [], []
        for step in range(SIM_STEPS):
            is_first_iter = (i == 0)
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE, terminal_cost_net, is_first_iter)
            x_next = vehicle.dynamics(current_x, u_optimal)
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data_for_gpr.append((current_x, u_optimal, x_next))
            iteration_data_for_cost_learning.append((current_x, stage_cost))
            current_x = x_next
            if np.linalg.norm(current_x[:2] - GOAL_STATE) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！"); break
        all_trajectories.append(np.array([d[0] for d in iteration_data_for_cost_learning]))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")
        for x, u, x_n in iteration_data_for_gpr:
            gpr_model.add_data(x, u, x_n)
        gpr_model.train()
        train_terminal_cost_net(terminal_cost_net, iteration_data_for_cost_learning)
    # (可視化コードは変更なし)
    plt.figure(figsize=(10, 10))
    if OBSTACLE_INFO:
        obs_circle = plt.Circle(OBSTACLE_INFO['pos'], OBSTACLE_INFO['rad'], color='r', alpha=0.5, label='障害物')
        plt.gca().add_patch(obs_circle)
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE[0], GOAL_STATE[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡'); plt.legend(); plt.axis('equal'); plt.show()
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移'); plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト'); plt.xticks(range(1, N_ITERATIONS + 1)); plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/10
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.48ms (166.21us)        33
#        nlp_g  |   2.00ms ( 60.61us)   3.85ms (116.82us)        33
#   nlp_grad_f  |   3.00ms ( 88.24us)  10.20ms (300.12us)        34
#   nlp_hess_l  |   4.00ms (125.00us)  20.37ms (636.66us)        32
#    nlp_jac_g  |  19.00ms (558.82us)  11.39ms (335.09us)        34
#        total  | 352.00ms (352.00ms) 352.96ms (352.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.37ms (168.12us)        26
#        nlp_g  |   7.00ms (269.23us)   3.00ms (115.46us)        26
#   nlp_grad_f  |  16.00ms (592.59us)   8.31ms (307.67us)        27
#   nlp_hess_l  |   5.00ms (200.00us)  16.40ms (656.20us)        25
#    nlp_jac_g  |   9.00ms (333.33us)   8.98ms (332.67us)        27
#        total  | 263.00ms (263.00ms) 255.85ms (255.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.47ms (157.73us)        22
#        nlp_g  |        0 (       0)   2.50ms (113.86us)        22
#   nlp_grad_f  |        0 (       0)   6.84ms (297.61us)        23
#   nlp_hess_l  |   2.00ms ( 95.24us)  13.01ms (619.38us)        21
#    nlp_jac_g  |        0 (       0)   7.63ms (331.74us)        23
#        total  | 187.00ms (187.00ms) 188.64ms (188.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.82ms (160.83us)        30
#        nlp_g  |        0 (       0)   3.35ms (111.77us)        30
#   nlp_grad_f  |   2.00ms ( 64.52us)   8.96ms (288.97us)        31
#   nlp_hess_l  |  17.00ms (586.21us)  18.12ms (624.86us)        29
#    nlp_jac_g  |  17.00ms (548.39us)   9.71ms (313.29us)        31
#        total  | 301.00ms (301.00ms) 304.84ms (304.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.30ms (173.95us)        19
#        nlp_g  |        0 (       0)   2.21ms (116.16us)        19
#   nlp_grad_f  |        0 (       0)   5.98ms (299.20us)        20
#   nlp_hess_l  |   4.00ms (222.22us)  11.70ms (650.11us)        18
#    nlp_jac_g  |        0 (       0)   6.49ms (324.55us)        20
#        total  | 168.00ms (168.00ms) 155.55ms (155.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.83ms (152.58us)        12
#        nlp_g  |        0 (       0)   1.25ms (104.58us)        12
#   nlp_grad_f  |        0 (       0)   3.78ms (291.00us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   6.95ms (632.18us)        11
#    nlp_jac_g  |        0 (       0)   4.13ms (317.77us)        13
#        total  | 104.00ms (104.00ms)  98.51ms ( 98.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.01ms (167.92us)        12
#        nlp_g  |        0 (       0)   1.33ms (110.75us)        12
#   nlp_grad_f  |        0 (       0)   3.95ms (303.54us)        13
#   nlp_hess_l  |   2.00ms (181.82us)   7.32ms (665.55us)        11
#    nlp_jac_g  |        0 (       0)   4.14ms (318.62us)        13
#        total  | 110.00ms (110.00ms) 102.33ms (102.33ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.84ms (167.35us)        17
#        nlp_g  |        0 (       0)   1.96ms (115.29us)        17
#   nlp_grad_f  |        0 (       0)   5.07ms (317.19us)        16
#   nlp_hess_l  |        0 (       0)   9.44ms (674.29us)        14
#    nlp_jac_g  |        0 (       0)   5.46ms (341.50us)        16
#        total  | 135.00ms (135.00ms) 125.24ms (125.24ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.55ms (170.20us)        15
#        nlp_g  |        0 (       0)   1.64ms (109.27us)        15
#   nlp_grad_f  |   2.00ms (125.00us)   5.12ms (320.31us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us)   9.46ms (675.93us)        14
#    nlp_jac_g  |   2.00ms (125.00us)   5.46ms (341.12us)        16
#        total  | 128.00ms (128.00ms) 127.81ms (127.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.41ms (172.29us)        14
#        nlp_g  |        0 (       0)   1.74ms (124.21us)        14
#   nlp_grad_f  |        0 (       0)   4.90ms (326.40us)        15
#   nlp_hess_l  |        0 (       0)   9.03ms (694.85us)        13
#    nlp_jac_g  |        0 (       0)   5.15ms (343.20us)        15
#        total  | 118.00ms (118.00ms) 121.75ms (121.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.12ms (162.85us)        13
#        nlp_g  |   2.00ms (153.85us)   1.55ms (119.38us)        13
#   nlp_grad_f  |        0 (       0)   4.74ms (338.71us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   8.17ms (680.58us)        12
#    nlp_jac_g  |        0 (       0)   5.08ms (363.00us)        14
#        total  | 100.00ms (100.00ms) 110.74ms (110.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.58ms (172.00us)        15
#        nlp_g  |        0 (       0)   1.86ms (124.20us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   5.54ms (346.12us)        16
#   nlp_hess_l  |  14.00ms (  1.00ms)  10.02ms (715.50us)        14
#    nlp_jac_g  |        0 (       0)   5.77ms (360.37us)        16
#        total  | 123.00ms (123.00ms) 128.47ms (128.47ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.32ms (165.86us)        14
#        nlp_g  |        0 (       0)   1.68ms (120.07us)        14
#   nlp_grad_f  |        0 (       0)   4.63ms (309.00us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   8.67ms (667.08us)        13
#    nlp_jac_g  |        0 (       0)   4.87ms (324.80us)        15
#        total  | 116.00ms (116.00ms) 118.02ms (118.02ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.69ms (168.12us)        16
#        nlp_g  |        0 (       0)   1.95ms (121.94us)        16
#   nlp_grad_f  |   1.00ms ( 58.82us)   5.38ms (316.76us)        17
#   nlp_hess_l  |   4.00ms (266.67us)  10.06ms (670.87us)        15
#    nlp_jac_g  |        0 (       0)   5.75ms (338.35us)        17
#        total  | 141.00ms (141.00ms) 139.92ms (139.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.35ms (180.69us)        13
#        nlp_g  |        0 (       0)   1.60ms (122.92us)        13
#   nlp_grad_f  |        0 (       0)   4.50ms (321.43us)        14
#   nlp_hess_l  |  14.00ms (  1.17ms)   8.23ms (686.08us)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   5.06ms (361.43us)        14
#        total  | 117.00ms (117.00ms) 107.69ms (107.69ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.40ms (171.36us)        14
#        nlp_g  |        0 (       0)   1.67ms (119.43us)        14
#   nlp_grad_f  |        0 (       0)   4.71ms (314.13us)        15
#   nlp_hess_l  |        0 (       0)   8.37ms (644.00us)        13
#    nlp_jac_g  |        0 (       0)   4.89ms (325.87us)        15
#        total  | 115.00ms (115.00ms) 114.71ms (114.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.03ms (155.92us)        13
#        nlp_g  |        0 (       0)   1.40ms (107.92us)        13
#   nlp_grad_f  |        0 (       0)   4.00ms (285.50us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.42ms (618.58us)        12
#    nlp_jac_g  |  15.00ms (  1.07ms)   4.29ms (306.21us)        14
#        total  | 100.00ms (100.00ms) 103.48ms (103.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.08ms (173.67us)        12
#        nlp_g  |        0 (       0)   1.52ms (126.92us)        12
#   nlp_grad_f  |        0 (       0)   4.38ms (337.23us)        13
#   nlp_hess_l  |        0 (       0)   7.50ms (681.91us)        11
#    nlp_jac_g  |        0 (       0)   4.61ms (354.85us)        13
#        total  | 102.00ms (102.00ms) 103.79ms (103.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.38ms (158.93us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.65ms (110.00us)        15
#   nlp_grad_f  |        0 (       0)   5.07ms (317.06us)        16
#   nlp_hess_l  |  29.00ms (  2.07ms)   8.94ms (638.64us)        14
#    nlp_jac_g  |        0 (       0)   5.52ms (345.31us)        16
#        total  | 117.00ms (117.00ms) 118.54ms (118.54ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.31ms (153.73us)        15
#        nlp_g  |  15.00ms (  1.00ms)   1.60ms (106.67us)        15
#   nlp_grad_f  |        0 (       0)   4.56ms (285.19us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us)   8.62ms (615.43us)        14
#    nlp_jac_g  |  16.00ms (  1.00ms)   5.01ms (313.19us)        16
#        total  | 117.00ms (117.00ms) 121.46ms (121.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.12ms (163.46us)        13
#        nlp_g  |        0 (       0)   1.60ms (122.92us)        13
#   nlp_grad_f  |        0 (       0)   4.10ms (292.57us)        14
#   nlp_hess_l  |        0 (       0)   7.41ms (617.50us)        12
#    nlp_jac_g  |        0 (       0)   4.38ms (312.64us)        14
#        total  |  99.00ms ( 99.00ms) 106.99ms (106.99ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.01ms (154.31us)        13
#        nlp_g  |        0 (       0)   1.33ms (102.69us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.12ms (294.50us)        14
#   nlp_hess_l  |  16.00ms (  1.33ms)   7.48ms (623.17us)        12
#    nlp_jac_g  |        0 (       0)   4.35ms (310.43us)        14
#        total  | 100.00ms (100.00ms) 104.54ms (104.54ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.42ms (161.33us)        15
#        nlp_g  |        0 (       0)   1.65ms (109.87us)        15
#   nlp_grad_f  |        0 (       0)   4.83ms (302.00us)        16
#   nlp_hess_l  |        0 (       0)   8.84ms (631.21us)        14
#    nlp_jac_g  |  16.00ms (  1.00ms)   5.23ms (327.19us)        16
#        total  | 117.00ms (117.00ms) 119.19ms (119.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.35ms (168.21us)        14
#        nlp_g  |        0 (       0)   1.70ms (121.64us)        14
#   nlp_grad_f  |        0 (       0)   4.44ms (296.00us)        15
#   nlp_hess_l  |  32.00ms (  2.46ms)   7.86ms (604.54us)        13
#    nlp_jac_g  |  31.00ms (  2.07ms)   5.03ms (335.47us)        15
#        total  | 117.00ms (117.00ms) 115.81ms (115.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.15ms (165.69us)        13
#        nlp_g  |        0 (       0)   1.51ms (116.00us)        13
#   nlp_grad_f  |        0 (       0)   4.14ms (295.43us)        14
#   nlp_hess_l  |        0 (       0)   7.45ms (620.67us)        12
#    nlp_jac_g  |        0 (       0)   4.49ms (320.64us)        14
#        total  | 115.00ms (115.00ms) 106.94ms (106.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.07ms)   2.22ms (158.50us)        14
#        nlp_g  |        0 (       0)   1.43ms (102.43us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.25ms (283.13us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   7.63ms (586.62us)        13
#    nlp_jac_g  |        0 (       0)   4.49ms (299.53us)        15
#        total  | 116.00ms (116.00ms) 110.76ms (110.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.35ms (156.87us)        15
#        nlp_g  |        0 (       0)   1.58ms (105.07us)        15
#   nlp_grad_f  |  16.00ms (  1.00ms)   4.60ms (287.56us)        16
#   nlp_hess_l  |        0 (       0)   8.50ms (607.07us)        14
#    nlp_jac_g  |        0 (       0)   4.77ms (298.31us)        16
#        total  | 133.00ms (133.00ms) 120.76ms (120.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.51ms (151.10us)        10
#        nlp_g  |        0 (       0)   1.07ms (107.40us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   3.28ms (298.45us)        11
#   nlp_hess_l  |        0 (       0)   5.64ms (626.89us)         9
#    nlp_jac_g  |        0 (       0)   3.50ms (318.18us)        11
#        total  |  84.00ms ( 84.00ms)  82.67ms ( 82.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.23ms (153.50us)         8
#        nlp_g  |        0 (       0) 886.00us (110.75us)         8
#   nlp_grad_f  |  16.00ms (  1.78ms)   2.90ms (321.78us)         9
#   nlp_hess_l  |        0 (       0)   4.34ms (620.29us)         7
#    nlp_jac_g  |   1.00ms (111.11us)   3.00ms (333.33us)         9
#        total  |  67.00ms ( 67.00ms)  65.71ms ( 65.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.48ms (164.67us)         9
#        nlp_g  |        0 (       0) 985.00us (109.44us)         9
#   nlp_grad_f  |   1.00ms (100.00us)   3.27ms (327.10us)        10
#   nlp_hess_l  |        0 (       0)   5.62ms (702.12us)         8
#    nlp_jac_g  |   1.00ms (100.00us)   3.28ms (328.40us)        10
#        total  |  67.00ms ( 67.00ms)  75.27ms ( 75.27ms)         1
# ステップ 30 でゴールに到達！
# イテレーション 1 の総コスト: 275.38
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 11080.8496
#
# ==================================================
# 反復学習: イテレーション 2/10
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.70ms (154.55us)        11
#        nlp_g  |        0 (       0)   1.21ms (110.09us)        11
#   nlp_grad_f  |        0 (       0)   3.67ms (306.25us)        12
#   nlp_hess_l  |   2.00ms (200.00us)   6.30ms (630.30us)        10
#    nlp_jac_g  |        0 (       0)   3.78ms (315.17us)        12
#        total  |  81.00ms ( 81.00ms)  90.44ms ( 90.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.68ms (168.20us)        10
#        nlp_g  |        0 (       0)   1.10ms (109.80us)        10
#   nlp_grad_f  |        0 (       0)   3.12ms (283.27us)        11
#   nlp_hess_l  |   5.00ms (555.56us)   5.88ms (652.89us)         9
#    nlp_jac_g  |  31.00ms (  2.82ms)   3.45ms (313.45us)        11
#        total  |  85.00ms ( 85.00ms)  87.72ms ( 87.72ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.72ms (172.40us)        10
#        nlp_g  |        0 (       0)   1.23ms (123.20us)        10
#   nlp_grad_f  |        0 (       0)   3.63ms (330.27us)        11
#   nlp_hess_l  |   5.00ms (555.56us)   5.76ms (640.00us)         9
#    nlp_jac_g  |   2.00ms (181.82us)   3.93ms (357.45us)        11
#        total  |  81.00ms ( 81.00ms)  84.24ms ( 84.24ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.39ms (159.67us)        15
#        nlp_g  |        0 (       0)   1.70ms (113.27us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   4.64ms (290.06us)        16
#   nlp_hess_l  |   2.00ms (142.86us)   8.86ms (632.93us)        14
#    nlp_jac_g  |  31.00ms (  1.94ms)   5.19ms (324.44us)        16
#        total  | 135.00ms (135.00ms) 139.76ms (139.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.44ms (162.93us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.80ms (120.33us)        15
#   nlp_grad_f  |   2.00ms (125.00us)   5.34ms (333.81us)        16
#   nlp_hess_l  |   2.00ms (142.86us)   8.69ms (620.50us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   5.45ms (340.94us)        16
#        total  | 120.00ms (120.00ms) 120.93ms (120.93ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.73ms (157.55us)        11
#        nlp_g  |        0 (       0)   1.21ms (110.18us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.61ms (300.67us)        12
#   nlp_hess_l  |  15.00ms (  1.50ms)   6.35ms (634.80us)        10
#    nlp_jac_g  |        0 (       0)   3.83ms (319.33us)        12
#        total  |  90.00ms ( 90.00ms)  90.96ms ( 90.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.03ms (184.91us)        11
#        nlp_g  |        0 (       0)   1.37ms (124.55us)        11
#   nlp_grad_f  |        0 (       0)   3.84ms (320.08us)        12
#   nlp_hess_l  |   7.00ms (700.00us)   7.06ms (706.00us)        10
#    nlp_jac_g  |        0 (       0)   4.17ms (347.67us)        12
#        total  | 113.00ms (113.00ms) 100.67ms (100.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.27ms (148.77us)        22
#        nlp_g  |        0 (       0)   2.40ms (109.14us)        22
#   nlp_grad_f  |        0 (       0)   6.64ms (288.57us)        23
#   nlp_hess_l  |   4.00ms (190.48us)  12.76ms (607.62us)        21
#    nlp_jac_g  |   5.00ms (217.39us)   7.02ms (305.43us)        23
#        total  | 216.00ms (216.00ms) 225.62ms (225.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.95ms (163.83us)        18
#        nlp_g  |        0 (       0)   2.05ms (113.94us)        18
#   nlp_grad_f  |        0 (       0)   5.54ms (325.71us)        17
#   nlp_hess_l  |   4.00ms (266.67us)  10.19ms (679.20us)        15
#    nlp_jac_g  |   9.00ms (529.41us)   5.81ms (341.76us)        17
#        total  | 161.00ms (161.00ms) 150.89ms (150.89ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.04ms (152.10us)        20
#        nlp_g  |        0 (       0)   2.16ms (108.00us)        20
#   nlp_grad_f  |        0 (       0)   5.88ms (279.86us)        21
#   nlp_hess_l  |        0 (       0)  11.37ms (598.68us)        19
#    nlp_jac_g  |   2.00ms ( 95.24us)   6.22ms (296.38us)        21
#        total  | 183.00ms (183.00ms) 185.97ms (185.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   1.88ms (157.08us)        12
#        nlp_g  |        0 (       0)   1.29ms (107.25us)        12
#   nlp_grad_f  |        0 (       0)   3.88ms (298.23us)        13
#   nlp_hess_l  |   4.00ms (363.64us)   6.78ms (616.09us)        11
#    nlp_jac_g  |   2.00ms (153.85us)   4.04ms (310.92us)        13
#        total  |  89.00ms ( 89.00ms)  97.76ms ( 97.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.42ms (142.54us)        24
#        nlp_g  |        0 (       0)   2.33ms ( 97.04us)        24
#   nlp_grad_f  |   1.00ms ( 43.48us)   6.18ms (268.74us)        23
#   nlp_hess_l  |  16.00ms (761.90us)  12.36ms (588.48us)        21
#    nlp_jac_g  |   1.00ms ( 43.48us)   6.65ms (289.13us)        23
#        total  | 207.00ms (207.00ms) 206.37ms (206.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.00ms)   2.34ms (146.37us)        16
#        nlp_g  |   1.00ms ( 62.50us)   1.63ms (101.69us)        16
#   nlp_grad_f  |        0 (       0)   4.79ms (281.88us)        17
#   nlp_hess_l  |        0 (       0)   8.61ms (574.00us)        15
#    nlp_jac_g  |        0 (       0)   5.05ms (296.94us)        17
#        total  | 135.00ms (135.00ms) 142.17ms (142.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   1.58ms (158.50us)        10
#        nlp_g  |        0 (       0)   1.01ms (100.60us)        10
#   nlp_grad_f  |        0 (       0)   2.96ms (269.36us)        11
#   nlp_hess_l  |        0 (       0)   5.12ms (568.78us)         9
#    nlp_jac_g  |   1.00ms ( 90.91us)   3.31ms (301.27us)        11
#        total  |  83.00ms ( 83.00ms)  78.27ms ( 78.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.59ms (158.90us)        10
#        nlp_g  |        0 (       0)   1.14ms (114.30us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   3.22ms (292.36us)        11
#   nlp_hess_l  |        0 (       0)   5.64ms (626.56us)         9
#    nlp_jac_g  |        0 (       0)   3.55ms (322.91us)        11
#        total  |  83.00ms ( 83.00ms)  81.45ms ( 81.45ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.61ms (146.18us)        11
#        nlp_g  |        0 (       0)   1.23ms (111.64us)        11
#   nlp_grad_f  |        0 (       0)   3.55ms (296.17us)        12
#   nlp_hess_l  |        0 (       0)   6.01ms (601.20us)        10
#    nlp_jac_g  |        0 (       0)   3.86ms (321.67us)        12
#        total  |  81.00ms ( 81.00ms)  89.44ms ( 89.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.86ms (155.17us)        12
#        nlp_g  |        0 (       0)   1.32ms (110.08us)        12
#   nlp_grad_f  |        0 (       0)   3.61ms (277.38us)        13
#   nlp_hess_l  |  16.00ms (  1.45ms)   6.33ms (575.36us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   3.95ms (303.85us)        13
#        total  |  99.00ms ( 99.00ms)  96.67ms ( 96.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.00ms)   2.42ms (161.13us)        15
#        nlp_g  |        0 (       0)   1.59ms (106.13us)        15
#   nlp_grad_f  |        0 (       0)   4.64ms (290.06us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us)   8.58ms (612.93us)        14
#    nlp_jac_g  |   2.00ms (125.00us)   4.97ms (310.87us)        16
#        total  | 116.00ms (116.00ms) 122.11ms (122.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.09ms (160.77us)        13
#        nlp_g  |        0 (       0)   1.44ms (110.85us)        13
#   nlp_grad_f  |        0 (       0)   4.28ms (305.86us)        14
#   nlp_hess_l  |  16.00ms (  1.33ms)   7.44ms (619.92us)        12
#    nlp_jac_g  |        0 (       0)   4.40ms (314.57us)        14
#        total  | 116.00ms (116.00ms) 107.11ms (107.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.21ms (147.53us)        15
#        nlp_g  |        0 (       0)   1.63ms (108.93us)        15
#   nlp_grad_f  |        0 (       0)   4.48ms (279.87us)        16
#   nlp_hess_l  |  22.00ms (  1.57ms)   8.55ms (611.07us)        14
#    nlp_jac_g  |        0 (       0)   4.96ms (310.12us)        16
#        total  | 118.00ms (118.00ms) 122.47ms (122.47ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.20ms (169.08us)        13
#        nlp_g  |        0 (       0)   1.66ms (127.38us)        13
#   nlp_grad_f  |        0 (       0)   4.38ms (312.79us)        14
#   nlp_hess_l  |  15.00ms (  1.25ms)   7.81ms (650.50us)        12
#    nlp_jac_g  |        0 (       0)   4.56ms (325.86us)        14
#        total  | 116.00ms (116.00ms) 108.66ms (108.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.10ms (161.23us)        13
#        nlp_g  |        0 (       0)   1.55ms (119.31us)        13
#   nlp_grad_f  |        0 (       0)   4.12ms (294.00us)        14
#   nlp_hess_l  |        0 (       0)   7.51ms (626.00us)        12
#    nlp_jac_g  |        0 (       0)   4.44ms (316.86us)        14
#        total  |  97.00ms ( 97.00ms) 109.62ms (109.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.02ms (155.38us)        13
#        nlp_g  |        0 (       0)   1.37ms (105.54us)        13
#   nlp_grad_f  |  17.00ms (  1.21ms)   4.44ms (317.50us)        14
#   nlp_hess_l  |   3.00ms (250.00us)   7.72ms (643.25us)        12
#    nlp_jac_g  |  45.00ms (  3.21ms)   4.89ms (349.00us)        14
#        total  | 116.00ms (116.00ms) 109.45ms (109.45ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.23ms)   2.29ms (176.15us)        13
#        nlp_g  |        0 (       0)   1.34ms (103.15us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   4.17ms (297.93us)        14
#   nlp_hess_l  |   5.00ms (416.67us)   7.55ms (629.50us)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   4.45ms (317.71us)        14
#        total  | 104.00ms (104.00ms) 108.17ms (108.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.04ms (157.31us)        13
#        nlp_g  |        0 (       0)   1.36ms (104.38us)        13
#   nlp_grad_f  |        0 (       0)   4.05ms (289.57us)        14
#   nlp_hess_l  |  13.00ms (  1.08ms)   7.23ms (602.83us)        12
#    nlp_jac_g  |        0 (       0)   4.18ms (298.79us)        14
#        total  | 101.00ms (101.00ms) 102.49ms (102.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.47ms (176.29us)        14
#        nlp_g  |        0 (       0)   1.65ms (117.64us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.82ms (321.27us)        15
#   nlp_hess_l  |  21.00ms (  1.62ms)   8.31ms (639.00us)        13
#    nlp_jac_g  |        0 (       0)   5.17ms (344.73us)        15
#        total  | 115.00ms (115.00ms) 111.64ms (111.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.33ms (145.87us)        16
#        nlp_g  |   1.00ms ( 62.50us)   1.55ms ( 96.62us)        16
#   nlp_grad_f  |        0 (       0)   4.59ms (270.18us)        17
#   nlp_hess_l  |  20.00ms (  1.33ms)   8.52ms (567.93us)        15
#    nlp_jac_g  |        0 (       0)   4.86ms (286.00us)        17
#        total  | 124.00ms (124.00ms) 123.25ms (123.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.07ms (158.92us)        13
#        nlp_g  |        0 (       0)   1.38ms (106.46us)        13
#   nlp_grad_f  |        0 (       0)   3.99ms (284.86us)        14
#   nlp_hess_l  |        0 (       0)   7.23ms (602.67us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.44ms (317.21us)        14
#        total  | 116.00ms (116.00ms) 104.84ms (104.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.81ms (150.58us)        12
#        nlp_g  |        0 (       0)   1.29ms (107.83us)        12
#   nlp_grad_f  |  21.00ms (  1.62ms)   4.17ms (321.08us)        13
#   nlp_hess_l  |  19.00ms (  1.73ms)   6.75ms (613.27us)        11
#    nlp_jac_g  |        0 (       0)   4.26ms (327.46us)        13
#        total  |  94.00ms ( 94.00ms)  96.83ms ( 96.83ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   1.84ms (153.33us)        12
#        nlp_g  |        0 (       0)   1.30ms (108.50us)        12
#   nlp_grad_f  |        0 (       0)   4.00ms (307.38us)        13
#   nlp_hess_l  |        0 (       0)   6.98ms (634.82us)        11
#    nlp_jac_g  |   2.00ms (153.85us)   4.34ms (333.54us)        13
#        total  |  99.00ms ( 99.00ms) 101.26ms (101.26ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.97ms (164.58us)        12
#        nlp_g  |        0 (       0)   1.40ms (116.83us)        12
#   nlp_grad_f  |        0 (       0)   3.81ms (293.00us)        13
#   nlp_hess_l  |  17.00ms (  1.55ms)   7.20ms (654.45us)        11
#    nlp_jac_g  |        0 (       0)   3.94ms (302.77us)        13
#        total  | 100.00ms (100.00ms)  97.96ms ( 97.96ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 2 の総コスト: 260.50
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 5265.7998
#
# ==================================================
# 反復学習: イテレーション 3/10
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.99ms (165.67us)        12
#        nlp_g  |        0 (       0)   1.42ms (118.33us)        12
#   nlp_grad_f  |        0 (       0)   3.82ms (293.92us)        13
#   nlp_hess_l  |        0 (       0)   7.21ms (655.18us)        11
#    nlp_jac_g  |        0 (       0)   4.07ms (313.00us)        13
#        total  | 101.00ms (101.00ms)  99.38ms ( 99.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.48ms (164.89us)         9
#        nlp_g  |        0 (       0)   1.03ms (114.89us)         9
#   nlp_grad_f  |        0 (       0)   2.87ms (287.50us)        10
#   nlp_hess_l  |        0 (       0)   5.12ms (640.62us)         8
#    nlp_jac_g  |   2.00ms (200.00us)   3.03ms (302.90us)        10
#        total  |  63.00ms ( 63.00ms)  76.03ms ( 76.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.36ms (150.78us)         9
#        nlp_g  |        0 (       0) 923.00us (102.56us)         9
#   nlp_grad_f  |        0 (       0)   2.61ms (261.40us)        10
#   nlp_hess_l  |        0 (       0)   4.69ms (586.50us)         8
#    nlp_jac_g  |        0 (       0)   2.82ms (282.50us)        10
#        total  |  83.00ms ( 83.00ms)  71.08ms ( 71.08ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.53ms (152.60us)        10
#        nlp_g  |        0 (       0)   1.11ms (111.20us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   3.37ms (306.36us)        11
#   nlp_hess_l  |        0 (       0)   5.55ms (616.44us)         9
#    nlp_jac_g  |        0 (       0)   3.68ms (334.64us)        11
#        total  |  68.00ms ( 68.00ms)  78.73ms ( 78.73ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.15ms (165.88us)        25
#        nlp_g  |        0 (       0)   2.78ms (111.28us)        25
#   nlp_grad_f  |  16.00ms (615.38us)   7.34ms (282.35us)        26
#   nlp_hess_l  |   8.00ms (333.33us)  14.88ms (619.96us)        24
#    nlp_jac_g  |   1.00ms ( 38.46us)   7.93ms (304.96us)        26
#        total  | 257.00ms (257.00ms) 249.38ms (249.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.96ms (150.77us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.35ms (103.62us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.74ms (267.36us)        14
#   nlp_hess_l  |        0 (       0)   6.95ms (578.75us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.15ms (296.36us)        14
#        total  | 117.00ms (117.00ms) 104.62ms (104.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (  1.31ms)   2.16ms (166.08us)        13
#        nlp_g  |        0 (       0)   1.44ms (110.62us)        13
#   nlp_grad_f  |  16.00ms (  1.14ms)   4.18ms (298.79us)        14
#   nlp_hess_l  |   5.00ms (416.67us)   7.87ms (655.50us)        12
#    nlp_jac_g  |        0 (       0)   4.45ms (318.00us)        14
#        total  | 134.00ms (134.00ms) 127.51ms (127.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.01ms (158.26us)        19
#        nlp_g  |   1.00ms ( 52.63us)   2.01ms (105.95us)        19
#   nlp_grad_f  |        0 (       0)   5.78ms (289.10us)        20
#   nlp_hess_l  |   1.00ms ( 55.56us)  11.21ms (622.56us)        18
#    nlp_jac_g  |   1.00ms ( 50.00us)   5.99ms (299.65us)        20
#        total  | 183.00ms (183.00ms) 183.75ms (183.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 62.50us)   4.36ms (136.41us)        32
#        nlp_g  |        0 (       0)   2.98ms ( 93.00us)        32
#   nlp_grad_f  |        0 (       0)   6.95ms (267.42us)        26
#   nlp_hess_l  |        0 (       0)  13.74ms (572.54us)        24
#    nlp_jac_g  |  33.00ms (  1.27ms)   7.45ms (286.54us)        26
#        total  | 248.00ms (248.00ms) 242.09ms (242.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.97ms (156.47us)        19
#        nlp_g  |   2.00ms (105.26us)   2.00ms (105.37us)        19
#   nlp_grad_f  |        0 (       0)   5.61ms (280.75us)        20
#   nlp_hess_l  |   3.00ms (166.67us)  11.02ms (612.06us)        18
#    nlp_jac_g  |        0 (       0)   6.01ms (300.45us)        20
#        total  | 161.00ms (161.00ms) 154.15ms (154.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.72ms (160.24us)        17
#        nlp_g  |        0 (       0)   1.98ms (116.65us)        17
#   nlp_grad_f  |        0 (       0)   5.50ms (305.50us)        18
#   nlp_hess_l  |  31.00ms (  1.94ms)  10.26ms (641.31us)        16
#    nlp_jac_g  |   1.00ms ( 55.56us)   5.87ms (326.28us)        18
#        total  | 166.00ms (166.00ms) 165.31ms (165.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.36ms)   1.65ms (150.45us)        11
#        nlp_g  |        0 (       0)   1.11ms (101.00us)        11
#   nlp_grad_f  |        0 (       0)   3.49ms (291.17us)        12
#   nlp_hess_l  |  11.00ms (  1.10ms)   6.18ms (618.30us)        10
#    nlp_jac_g  |   1.00ms ( 83.33us)   3.72ms (310.08us)        12
#        total  |  89.00ms ( 89.00ms)  90.16ms ( 90.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.97ms (164.33us)        12
#        nlp_g  |        0 (       0)   1.37ms (114.00us)        12
#   nlp_grad_f  |   2.00ms (153.85us)   3.81ms (293.46us)        13
#   nlp_hess_l  |  40.00ms (  3.64ms)   7.19ms (653.27us)        11
#    nlp_jac_g  |        0 (       0)   4.21ms (324.08us)        13
#        total  |  92.00ms ( 92.00ms) 103.91ms (103.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.24ms (172.62us)        13
#        nlp_g  |        0 (       0)   1.54ms (118.69us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.27ms (305.29us)        14
#   nlp_hess_l  |  16.00ms (  1.33ms)   7.14ms (595.00us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.57ms (326.64us)        14
#        total  |  98.00ms ( 98.00ms) 105.80ms (105.80ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.75ms (158.91us)        11
#        nlp_g  |        0 (       0)   1.22ms (111.18us)        11
#   nlp_grad_f  |        0 (       0)   3.38ms (281.58us)        12
#   nlp_hess_l  |  11.00ms (  1.10ms)   6.17ms (617.30us)        10
#    nlp_jac_g  |        0 (       0)   3.78ms (315.25us)        12
#        total  |  77.00ms ( 77.00ms)  87.62ms ( 87.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.81ms (156.11us)        18
#        nlp_g  |        0 (       0)   1.99ms (110.44us)        18
#   nlp_grad_f  |   2.00ms (105.26us)   5.89ms (310.00us)        19
#   nlp_hess_l  |        0 (       0)  10.84ms (637.82us)        17
#    nlp_jac_g  |  17.00ms (894.74us)   6.12ms (321.95us)        19
#        total  | 133.00ms (133.00ms) 145.95ms (145.95ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.30ms (164.57us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.60ms (114.21us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.44ms (296.27us)        15
#   nlp_hess_l  |  10.00ms (769.23us)   8.24ms (633.69us)        13
#    nlp_jac_g  |        0 (       0)   4.76ms (317.07us)        15
#        total  | 117.00ms (117.00ms) 112.38ms (112.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.30ms (177.00us)        13
#        nlp_g  |        0 (       0)   1.57ms (120.85us)        13
#   nlp_grad_f  |        0 (       0)   4.49ms (321.00us)        14
#   nlp_hess_l  |        0 (       0)   7.94ms (661.58us)        12
#    nlp_jac_g  |        0 (       0)   4.78ms (341.64us)        14
#        total  | 116.00ms (116.00ms) 108.79ms (108.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.47ms (164.67us)        15
#        nlp_g  |        0 (       0)   1.72ms (115.00us)        15
#   nlp_grad_f  |        0 (       0)   4.86ms (303.56us)        16
#   nlp_hess_l  |        0 (       0)   8.98ms (641.71us)        14
#    nlp_jac_g  |        0 (       0)   5.01ms (313.12us)        16
#        total  | 125.00ms (125.00ms) 128.44ms (128.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.59ms (152.12us)        17
#        nlp_g  |        0 (       0)   1.75ms (102.71us)        17
#   nlp_grad_f  |        0 (       0)   5.15ms (285.89us)        18
#   nlp_hess_l  |        0 (       0)   9.35ms (584.12us)        16
#    nlp_jac_g  |  17.00ms (944.44us)   5.61ms (311.89us)        18
#        total  | 150.00ms (150.00ms) 151.03ms (151.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.15ms (165.69us)        13
#        nlp_g  |        0 (       0)   1.45ms (111.38us)        13
#   nlp_grad_f  |        0 (       0)   4.15ms (296.14us)        14
#   nlp_hess_l  |        0 (       0)   7.45ms (620.58us)        12
#    nlp_jac_g  |        0 (       0)   4.40ms (314.36us)        14
#        total  | 117.00ms (117.00ms) 103.57ms (103.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.19ms (168.54us)        13
#        nlp_g  |        0 (       0)   1.53ms (117.92us)        13
#   nlp_grad_f  |        0 (       0)   4.51ms (321.93us)        14
#   nlp_hess_l  |        0 (       0)   7.69ms (641.00us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.69ms (335.14us)        14
#        total  |  95.00ms ( 95.00ms) 107.63ms (107.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.25ms (173.08us)        13
#        nlp_g  |        0 (       0)   1.53ms (117.92us)        13
#   nlp_grad_f  |  10.00ms (714.29us)   4.47ms (319.07us)        14
#   nlp_hess_l  |  34.00ms (  2.83ms)   8.12ms (676.50us)        12
#    nlp_jac_g  |        0 (       0)   4.78ms (341.14us)        14
#        total  | 112.00ms (112.00ms) 105.92ms (105.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.38ms (169.93us)        14
#        nlp_g  |        0 (       0)   1.68ms (119.71us)        14
#   nlp_grad_f  |        0 (       0)   4.88ms (325.53us)        15
#   nlp_hess_l  |        0 (       0)   8.23ms (632.85us)        13
#    nlp_jac_g  |        0 (       0)   5.11ms (340.87us)        15
#        total  | 119.00ms (119.00ms) 117.11ms (117.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.59ms (172.73us)        15
#        nlp_g  |        0 (       0)   1.86ms (124.00us)        15
#   nlp_grad_f  |        0 (       0)   5.13ms (320.62us)        16
#   nlp_hess_l  |        0 (       0)   9.25ms (660.50us)        14
#    nlp_jac_g  |        0 (       0)   5.35ms (334.25us)        16
#        total  | 133.00ms (133.00ms) 124.94ms (124.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.50ms (166.80us)        15
#        nlp_g  |        0 (       0)   1.66ms (110.93us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   4.81ms (300.50us)        16
#   nlp_hess_l  |  12.00ms (857.14us)   8.72ms (622.57us)        14
#    nlp_jac_g  |        0 (       0)   5.10ms (318.94us)        16
#        total  | 115.00ms (115.00ms) 123.00ms (123.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.53ms (180.64us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.67ms (119.14us)        14
#   nlp_grad_f  |        0 (       0)   4.82ms (321.47us)        15
#   nlp_hess_l  |        0 (       0)   8.80ms (677.15us)        13
#    nlp_jac_g  |        0 (       0)   5.22ms (348.20us)        15
#        total  | 117.00ms (117.00ms) 118.36ms (118.36ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (937.50us)   2.54ms (158.81us)        16
#        nlp_g  |   1.00ms ( 62.50us)   1.75ms (109.50us)        16
#   nlp_grad_f  |        0 (       0)   5.11ms (300.35us)        17
#   nlp_hess_l  |   1.00ms ( 66.67us)   9.16ms (610.40us)        15
#    nlp_jac_g  |   1.00ms ( 58.82us)   5.19ms (305.06us)        17
#        total  | 133.00ms (133.00ms) 127.34ms (127.34ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.88ms (156.42us)        12
#        nlp_g  |        0 (       0)   1.28ms (106.42us)        12
#   nlp_grad_f  |        0 (       0)   3.76ms (289.23us)        13
#   nlp_hess_l  |   2.00ms (181.82us)   6.62ms (601.55us)        11
#    nlp_jac_g  |  16.00ms (  1.23ms)   3.96ms (304.38us)        13
#        total  | 100.00ms (100.00ms)  96.75ms ( 96.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 25.00us)   6.34ms (158.55us)        40
#        nlp_g  |  15.00ms (375.00us)   4.32ms (107.97us)        40
#   nlp_grad_f  |        0 (       0)  11.31ms (275.76us)        41
#   nlp_hess_l  |  18.00ms (461.54us)  23.73ms (608.49us)        39
#    nlp_jac_g  |  31.00ms (756.10us)  12.23ms (298.22us)        41
#        total  | 450.00ms (450.00ms) 452.32ms (452.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.55ms (182.21us)        14
#        nlp_g  |        0 (       0)   1.75ms (124.71us)        14
#   nlp_grad_f  |        0 (       0)   5.03ms (335.53us)        15
#   nlp_hess_l  |        0 (       0)   8.84ms (680.38us)        13
#    nlp_jac_g  |        0 (       0)   5.43ms (362.07us)        15
#        total  | 116.00ms (116.00ms) 118.48ms (118.48ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 3 の総コスト: 259.99
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 3142.6970
#
# ==================================================
# 反復学習: イテレーション 4/10
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.36ms (147.81us)        16
#        nlp_g  |        0 (       0)   1.67ms (104.37us)        16
#   nlp_grad_f  |        0 (       0)   4.95ms (291.41us)        17
#   nlp_hess_l  |        0 (       0)   9.25ms (616.53us)        15
#    nlp_jac_g  |        0 (       0)   5.07ms (298.12us)        17
#        total  | 133.00ms (133.00ms) 132.89ms (132.89ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.63ms (148.27us)        11
#        nlp_g  |   1.00ms ( 90.91us)   1.19ms (107.91us)        11
#   nlp_grad_f  |        0 (       0)   3.33ms (277.75us)        12
#   nlp_hess_l  |   1.00ms (100.00us)   5.96ms (596.50us)        10
#    nlp_jac_g  |        0 (       0)   3.41ms (284.00us)        12
#        total  |  85.00ms ( 85.00ms)  87.27ms ( 87.27ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.95ms (150.00us)        13
#        nlp_g  |        0 (       0)   1.30ms (100.38us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   3.92ms (279.71us)        14
#   nlp_hess_l  |   1.00ms ( 83.33us)   7.31ms (609.08us)        12
#    nlp_jac_g  |        0 (       0)   4.06ms (289.93us)        14
#        total  | 117.00ms (117.00ms) 106.91ms (106.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 37.04us)   4.14ms (153.19us)        27
#        nlp_g  |  15.00ms (555.56us)   2.79ms (103.19us)        27
#   nlp_grad_f  |        0 (       0)   7.75ms (276.75us)        28
#   nlp_hess_l  |  17.00ms (653.85us)  15.03ms (578.04us)        26
#    nlp_jac_g  |   1.00ms ( 35.71us)   8.52ms (304.18us)        28
#        total  | 267.00ms (267.00ms) 271.28ms (271.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.24ms (172.62us)        13
#        nlp_g  |        0 (       0)   1.53ms (117.85us)        13
#   nlp_grad_f  |        0 (       0)   4.42ms (315.71us)        14
#   nlp_hess_l  |  14.00ms (  1.17ms)   8.04ms (669.75us)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   4.73ms (338.00us)        14
#        total  | 109.00ms (109.00ms) 110.41ms (110.41ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.55ms (170.07us)        15
#        nlp_g  |        0 (       0)   1.80ms (120.13us)        15
#   nlp_grad_f  |        0 (       0)   5.03ms (314.62us)        16
#   nlp_hess_l  |  10.00ms (714.29us)   9.19ms (656.57us)        14
#    nlp_jac_g  |        0 (       0)   5.39ms (337.19us)        16
#        total  | 133.00ms (133.00ms) 124.46ms (124.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 25.64us)   6.24ms (159.92us)        39
#        nlp_g  |   1.00ms ( 25.64us)   4.10ms (105.23us)        39
#   nlp_grad_f  |   2.00ms ( 57.14us)  10.17ms (290.57us)        35
#   nlp_hess_l  |   5.00ms (151.52us)  20.51ms (621.48us)        33
#    nlp_jac_g  |  22.00ms (628.57us)  10.71ms (306.06us)        35
#        total  | 358.00ms (358.00ms) 368.12ms (368.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.42ms (161.07us)        15
#        nlp_g  |        0 (       0)   1.56ms (104.00us)        15
#   nlp_grad_f  |        0 (       0)   4.42ms (315.86us)        14
#   nlp_hess_l  |        0 (       0)   8.26ms (688.33us)        12
#    nlp_jac_g  |        0 (       0)   4.63ms (330.57us)        14
#        total  | 115.00ms (115.00ms) 107.33ms (107.33ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.45ms (157.05us)        22
#        nlp_g  |        0 (       0)   2.34ms (106.36us)        22
#   nlp_grad_f  |        0 (       0)   5.62ms (312.50us)        18
#   nlp_hess_l  |   2.00ms (125.00us)  10.31ms (644.25us)        16
#    nlp_jac_g  |        0 (       0)   5.76ms (320.28us)        18
#        total  | 170.00ms (170.00ms) 163.58ms (163.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.29ms (163.57us)        14
#        nlp_g  |        0 (       0)   1.45ms (103.71us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.46ms (297.13us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   8.02ms (617.00us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.68ms (312.13us)        15
#        total  | 125.00ms (125.00ms) 116.21ms (116.21ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
# ...
#        nlp_f  |   1.00ms ( 55.56us)   4.23ms (235.28us)        18
#        nlp_g  |   1.00ms ( 55.56us)   2.83ms (157.33us)        18
#   nlp_grad_f  |   4.00ms (210.53us)   7.35ms (386.84us)        19
#   nlp_hess_l  |   8.00ms (470.59us)  12.91ms (759.18us)        17
#    nlp_jac_g  |   2.00ms (105.26us)   7.47ms (393.16us)        19
#        total  | 155.00ms (155.00ms) 160.86ms (160.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (214.29us)   2.62ms (187.00us)        14
#        nlp_g  |   2.00ms (142.86us)   1.93ms (138.07us)        14
#   nlp_grad_f  |   3.00ms (200.00us)   4.83ms (322.20us)        15
#   nlp_hess_l  |   9.00ms (692.31us)   8.88ms (683.08us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   4.92ms (328.20us)        15
#        total  | 116.00ms (116.00ms) 116.42ms (116.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   1.85ms (184.80us)        10
#        nlp_g  |   1.00ms (100.00us)   1.40ms (140.40us)        10
#   nlp_grad_f  |   3.00ms (272.73us)   3.97ms (361.36us)        11
#   nlp_hess_l  |   5.00ms (555.56us)   6.31ms (700.78us)         9
#    nlp_jac_g  |   6.00ms (545.45us)   4.22ms (383.45us)        11
#        total  |  87.00ms ( 87.00ms)  86.47ms ( 86.47ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   2.64ms (202.77us)        13
#        nlp_g  |   4.00ms (307.69us)   1.82ms (140.31us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   4.61ms (329.07us)        14
#   nlp_hess_l  |   9.00ms (750.00us)   9.12ms (759.67us)        12
#    nlp_jac_g  |   7.00ms (500.00us)   4.62ms (330.00us)        14
#        total  | 110.00ms (110.00ms) 110.67ms (110.67ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 9 の総コスト: 260.64
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 27.5394
#
# ==================================================
# 反復学習: イテレーション 10/10
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.42ms (186.08us)        13
#        nlp_g  |   2.00ms (153.85us)   1.76ms (135.69us)        13
#   nlp_grad_f  |  20.00ms (  1.43ms)   5.04ms (360.36us)        14
#   nlp_hess_l  |   7.00ms (583.33us)   9.01ms (750.67us)        12
#    nlp_jac_g  |   7.00ms (500.00us)   5.28ms (377.07us)        14
#        total  | 128.00ms (128.00ms) 114.68ms (114.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   2.74ms (273.60us)        10
#        nlp_g  |   2.00ms (200.00us)   1.88ms (187.90us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   4.44ms (403.82us)        11
#   nlp_hess_l  |   9.00ms (  1.00ms)   8.15ms (906.00us)         9
#    nlp_jac_g  |   3.00ms (272.73us)   4.75ms (431.91us)        11
#        total  |  86.00ms ( 86.00ms)  88.31ms ( 88.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (100.00us)   1.98ms (198.30us)        10
#        nlp_g  |   1.00ms (100.00us)   1.33ms (133.30us)        10
#   nlp_grad_f  |   4.00ms (363.64us)   3.70ms (336.00us)        11
#   nlp_hess_l  |   6.00ms (666.67us)   6.01ms (667.67us)         9
#    nlp_jac_g  |   2.00ms (181.82us)   4.03ms (366.00us)        11
#        total  |  87.00ms ( 87.00ms)  87.08ms ( 87.08ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   2.76ms (230.08us)        12
#        nlp_g  |   2.00ms (166.67us)   2.00ms (166.75us)        12
#   nlp_grad_f  |   2.00ms (153.85us)   5.35ms (411.54us)        13
#   nlp_hess_l  |   6.00ms (545.45us)  10.11ms (919.09us)        11
#    nlp_jac_g  |   4.00ms (307.69us)   5.56ms (427.77us)        13
#        total  | 112.00ms (112.00ms) 112.72ms (112.72ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (160.00us)   3.76ms (150.44us)        25
#        nlp_g  |   1.00ms ( 40.00us)   2.60ms (104.08us)        25
#   nlp_grad_f  |   2.00ms ( 95.24us)   5.78ms (275.05us)        21
#   nlp_hess_l  |   7.00ms (368.42us)  11.77ms (619.37us)        19
#    nlp_jac_g  |   4.00ms (190.48us)   6.31ms (300.52us)        21
#        total  | 182.00ms (182.00ms) 182.49ms (182.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms (162.16us)   6.56ms (177.27us)        37
#        nlp_g  |  16.00ms (432.43us)   4.48ms (121.05us)        37
#   nlp_grad_f  |   8.00ms (258.06us)   9.89ms (319.10us)        31
#   nlp_hess_l  |  15.00ms (517.24us)  20.24ms (698.00us)        29
#    nlp_jac_g  |   8.00ms (258.06us)  10.51ms (339.13us)        31
#        total  | 335.00ms (335.00ms) 334.65ms (334.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.05ms (192.90us)        21
#        nlp_g  |   3.00ms (142.86us)   2.89ms (137.62us)        21
#   nlp_grad_f  |  28.00ms (  1.40ms)   7.40ms (370.00us)        20
#   nlp_hess_l  |  14.00ms (777.78us)  13.11ms (728.39us)        18
#    nlp_jac_g  |   7.00ms (350.00us)   8.03ms (401.75us)        20
#        total  | 225.00ms (225.00ms) 215.49ms (215.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (357.14us)   2.19ms (156.43us)        14
#        nlp_g  |        0 (       0)   1.62ms (115.79us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   4.77ms (318.20us)        15
#   nlp_hess_l  |  12.00ms (923.08us)   8.35ms (642.62us)        13
#    nlp_jac_g  |   2.00ms (133.33us)   4.93ms (328.87us)        15
#        total  | 113.00ms (113.00ms) 113.69ms (113.69ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.69ms (179.27us)        15
#        nlp_g  |   4.00ms (266.67us)   1.81ms (120.87us)        15
#   nlp_grad_f  |   5.00ms (333.33us)   4.96ms (330.60us)        15
#   nlp_hess_l  |   8.00ms (615.38us)   8.55ms (657.85us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   5.04ms (335.93us)        15
#        total  | 114.00ms (114.00ms) 114.71ms (114.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (142.86us)   4.44ms (211.57us)        21
#        nlp_g  |   1.00ms ( 47.62us)   2.94ms (140.14us)        21
#   nlp_grad_f  |   4.00ms (181.82us)   7.26ms (329.95us)        22
#   nlp_hess_l  |   4.00ms (200.00us)  14.24ms (712.20us)        20
#    nlp_jac_g  |  12.00ms (545.45us)   7.68ms (349.00us)        22
#        total  | 223.00ms (223.00ms) 227.21ms (227.21ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 95.24us)   4.40ms (209.33us)        21
#        nlp_g  |        0 (       0)   3.19ms (151.76us)        21
#   nlp_grad_f  |   6.00ms (272.73us)   8.23ms (374.27us)        22
#   nlp_hess_l  |   9.00ms (450.00us)  14.09ms (704.75us)        20
#    nlp_jac_g  |   6.00ms (272.73us)   8.06ms (366.41us)        22
#        total  | 250.00ms (250.00ms) 245.82ms (245.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  13.00ms (500.00us)   4.57ms (175.73us)        26
#        nlp_g  |  28.00ms (  1.08ms)   3.20ms (123.12us)        26
#   nlp_grad_f  |   2.00ms ( 83.33us)   7.67ms (319.46us)        24
#   nlp_hess_l  |  13.00ms (590.91us)  14.40ms (654.36us)        22
#    nlp_jac_g  |   7.00ms (291.67us)   8.07ms (336.21us)        24
#        total  | 267.00ms (267.00ms) 253.12ms (253.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.43ms (173.79us)        14
#        nlp_g  |   3.00ms (214.29us)   1.67ms (119.43us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.77ms (317.87us)        15
#   nlp_hess_l  |   5.00ms (384.62us)   8.88ms (683.31us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   5.11ms (341.00us)        15
#        total  | 119.00ms (119.00ms) 116.66ms (116.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  13.00ms (619.05us)   3.59ms (170.81us)        21
#        nlp_g  |        0 (       0)   2.74ms (130.48us)        21
#   nlp_grad_f  |  13.00ms (590.91us)   7.13ms (323.91us)        22
#   nlp_hess_l  |   3.00ms (150.00us)  12.88ms (643.80us)        20
#    nlp_jac_g  |  15.00ms (681.82us)   7.67ms (348.82us)        22
#        total  | 236.00ms (236.00ms) 237.17ms (237.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (214.29us)   2.48ms (177.29us)        14
#        nlp_g  |   2.00ms (142.86us)   1.69ms (120.57us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.82ms (321.60us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   7.96ms (612.15us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   4.97ms (331.60us)        15
#        total  | 112.00ms (112.00ms) 112.74ms (112.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   3.73ms (310.50us)        12
#        nlp_g  |   1.00ms ( 83.33us)   2.56ms (213.33us)        12
#   nlp_grad_f  |  19.00ms (  1.46ms)   5.88ms (452.62us)        13
#   nlp_hess_l  |   4.00ms (363.64us)  11.85ms (  1.08ms)        11
#    nlp_jac_g  |   2.00ms (153.85us)   6.17ms (474.62us)        13
#        total  | 125.00ms (125.00ms) 124.86ms (124.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   4.04ms (269.07us)        15
#        nlp_g  |   1.00ms ( 66.67us)   2.81ms (187.33us)        15
#   nlp_grad_f  |   8.00ms (500.00us)   6.55ms (409.19us)        16
#   nlp_hess_l  |   9.00ms (642.86us)  13.09ms (935.07us)        14
#    nlp_jac_g  |   8.00ms (500.00us)   7.06ms (441.00us)        16
#        total  | 155.00ms (155.00ms) 155.74ms (155.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.77ms (163.12us)        17
#        nlp_g  |        0 (       0)   1.91ms (112.53us)        17
#   nlp_grad_f  |   5.00ms (277.78us)   5.63ms (312.67us)        18
#   nlp_hess_l  |   4.00ms (250.00us)  10.72ms (670.06us)        16
#    nlp_jac_g  |  17.00ms (944.44us)   5.87ms (325.89us)        18
#        total  | 138.00ms (138.00ms) 138.68ms (138.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (235.29us)   2.84ms (166.94us)        17
#        nlp_g  |        0 (       0)   1.99ms (117.12us)        17
#   nlp_grad_f  |   6.00ms (333.33us)   5.48ms (304.56us)        18
#   nlp_hess_l  |  12.00ms (750.00us)  10.26ms (641.37us)        16
#    nlp_jac_g  |   7.00ms (388.89us)   5.68ms (315.33us)        18
#        total  | 139.00ms (139.00ms) 138.84ms (138.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.87ms (169.00us)        17
#        nlp_g  |   2.00ms (117.65us)   2.24ms (131.88us)        17
#   nlp_grad_f  |   7.00ms (388.89us)   5.70ms (316.56us)        18
#   nlp_hess_l  |  13.00ms (812.50us)  11.02ms (688.94us)        16
#    nlp_jac_g  |  18.00ms (  1.00ms)   6.14ms (341.22us)        18
#        total  | 162.00ms (162.00ms) 148.64ms (148.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 22.22us)   8.64ms (192.00us)        45
#        nlp_g  |        0 (       0)   6.04ms (134.16us)        45
#   nlp_grad_f  |   9.00ms (195.65us)  15.69ms (341.09us)        46
#   nlp_hess_l  |  29.00ms (659.09us)  29.09ms (661.05us)        44
#    nlp_jac_g  |   5.00ms (108.70us)  16.05ms (349.02us)        46
#        total  | 534.00ms (534.00ms) 538.15ms (538.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.04ms (157.31us)        13
#        nlp_g  |        0 (       0)   1.40ms (107.85us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.82ms (272.64us)        14
#   nlp_hess_l  |   4.00ms (333.33us)   7.49ms (623.92us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.20ms (300.00us)        14
#        total  | 113.00ms (113.00ms) 113.01ms (113.01ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   2.04ms (185.55us)        11
#        nlp_g  |   1.00ms ( 90.91us)   1.43ms (130.00us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.92ms (327.00us)        12
#   nlp_hess_l  |  17.00ms (  1.70ms)   7.23ms (723.30us)        10
#    nlp_jac_g  |        0 (       0)   4.12ms (343.50us)        12
#        total  | 100.00ms (100.00ms)  95.44ms ( 95.44ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.59ms (199.38us)        13
#        nlp_g  |        0 (       0)   1.74ms (133.69us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   5.08ms (363.07us)        14
#   nlp_hess_l  |   4.00ms (333.33us)   9.60ms (800.00us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   5.31ms (379.00us)        14
#        total  | 126.00ms (126.00ms) 120.38ms (120.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.18ms (176.94us)        18
#        nlp_g  |   1.00ms ( 55.56us)   2.11ms (117.33us)        18
#   nlp_grad_f  |        0 (       0)   5.99ms (315.26us)        19
#   nlp_hess_l  |   3.00ms (176.47us)  11.27ms (663.18us)        17
#    nlp_jac_g  |   7.00ms (368.42us)   6.36ms (334.89us)        19
#        total  | 157.00ms (157.00ms) 155.78ms (155.78ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.14ms)   2.70ms (193.00us)        14
#        nlp_g  |   4.00ms (285.71us)   1.90ms (135.43us)        14
#   nlp_grad_f  |  19.00ms (  1.27ms)   5.31ms (354.07us)        15
#   nlp_hess_l  |  21.00ms (  1.62ms)   8.58ms (659.85us)        13
#    nlp_jac_g  |  17.00ms (  1.13ms)   5.33ms (355.40us)        15
#        total  | 132.00ms (132.00ms) 118.26ms (118.26ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.28ms (163.21us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.81ms (129.43us)        14
#   nlp_grad_f  |   3.00ms (200.00us)   5.09ms (339.47us)        15
#   nlp_hess_l  |  15.00ms (  1.15ms)   8.71ms (669.77us)        13
#    nlp_jac_g  |  16.00ms (  1.07ms)   5.29ms (352.60us)        15
#        total  | 120.00ms (120.00ms) 120.61ms (120.61ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   2.74ms (228.50us)        12
#        nlp_g  |        0 (       0)   1.88ms (156.83us)        12
#   nlp_grad_f  |        0 (       0)   5.24ms (403.46us)        13
#   nlp_hess_l  |  22.00ms (  2.00ms)   9.95ms (904.45us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   5.31ms (408.31us)        13
#        total  | 120.00ms (120.00ms) 116.90ms (116.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.07ms)   2.91ms (193.93us)        15
#        nlp_g  |   1.00ms ( 66.67us)   2.09ms (139.53us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   5.61ms (350.56us)        16
#   nlp_hess_l  |   4.00ms (285.71us)  10.84ms (774.07us)        14
#    nlp_jac_g  |        0 (       0)   5.98ms (374.00us)        16
#        total  | 131.00ms (131.00ms) 136.53ms (136.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.66ms (204.69us)        13
#        nlp_g  |        0 (       0)   1.86ms (142.77us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   5.08ms (362.57us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   9.18ms (765.00us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   5.31ms (379.50us)        14
#        total  | 110.00ms (110.00ms) 114.67ms (114.67ms)         1
# ステップ 30 でゴールに到達！
# イテレーション 10 の総コスト: 259.47
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 4.3250
