# %% [markdown]
# Neural Certificates(未完成)

# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import torch
import torch.nn as nn
import torch.optim as optim
import time

import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)

# ==================================================================================
# シミュレーション全体の設定パラメータ
# ==================================================================================
N_ITERATIONS = 5
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE_POS = np.array([10.0, 10.0])
GOAL_STATE = np.hstack([GOAL_STATE_POS, 0, 0])
N_MPC = 10
M_MPC = 5
OBSTACLE_INFO = {'pos': np.array([5.0, 5.0]), 'rad': 1.5}
CERTIFICATE_C = 100.0
GAMMA = 0.98

# (NNCallback, CertificateNN, Pi_NN, train_certificate_net クラス/関数は変更なし)
class NNCallback(ca.Callback):
    def __init__(self, name, nn_model, opts={}):
        ca.Callback.__init__(self); self.nn_model = nn_model; self.construct(name, opts)
    def get_n_in(self): return 1
    def get_n_out(self): return 1
    def get_sparsity_in(self, i): return ca.Sparsity.dense(NX, 1)
    def get_sparsity_out(self, i): return ca.Sparsity.dense(1, 1)
    def eval(self, arg):
        x = np.array(arg[0]); x_torch = torch.tensor(x, dtype=torch.float32).T
        with torch.no_grad(): cost = self.nn_model(x_torch).numpy()
        return [cost]
class CertificateNN(nn.Module):
    def __init__(self, n_input):
        super(CertificateNN, self).__init__()
        self.w = nn.Sequential(nn.Linear(n_input, 64), nn.Tanh(), nn.Linear(64, 64), nn.Tanh(), nn.Linear(64, 4))
    def forward(self, x):
        w_x = self.w(x); return torch.sum(w_x**2, dim=1, keepdim=True)
class Pi_NN(nn.Module):
    def __init__(self, n_input, n_output):
        super(Pi_NN, self).__init__()
        self.layers = nn.Sequential(nn.Linear(n_input, 32), nn.Tanh(), nn.Linear(32, 32), nn.Tanh(), nn.Linear(32, n_output))
    def forward(self, x): return self.layers(x)
def train_certificate_net(v_net, pi_net, all_past_data, gpr_model, obstacle_info):
    if not all_past_data: return
    print("NN証明書: 学習開始...")
    params = list(v_net.parameters()) + list(pi_net.parameters())
    optimizer = optim.Adam(params, lr=1e-4)
    safe_states = torch.tensor(np.array([d[0] for d in all_past_data]), dtype=torch.float32)
    num_unsafe = len(safe_states) // 2
    unsafe_points = np.random.randn(num_unsafe, 2) * obstacle_info['rad'] + obstacle_info['pos']
    unsafe_states = torch.tensor(np.hstack([unsafe_points, np.zeros((num_unsafe, 2))]), dtype=torch.float32)
    def stage_cost_func(x, u):
        goal_pos_tensor = torch.tensor(GOAL_STATE_POS, dtype=torch.float32)
        pos_error = torch.sum((x[:, :2] - goal_pos_tensor)**2, dim=1, keepdim=True)
        input_cost = torch.sum(u**2, dim=1, keepdim=True)
        return pos_error * DT + input_cost * DT * 0.01
    def f_gpr(x, u):
        error_mean, _ = gpr_model.predict(x.detach().numpy(), u.detach().numpy())
        error_mean_tensor = torch.tensor(error_mean, dtype=torch.float32)
        delta_nominal = torch.cat([x[:, 2:], u], dim=1)
        delta_pred = delta_nominal + error_mean_tensor
        return x + delta_pred * DT
    for epoch in range(200):
        optimizer.zero_grad()
        loss_goal = v_net(torch.tensor(GOAL_STATE, dtype=torch.float32).unsqueeze(0))
        v_safe = v_net(safe_states); v_unsafe = v_net(unsafe_states)
        loss_safe_boundary = torch.mean(torch.relu(v_safe - CERTIFICATE_C))
        loss_unsafe_boundary = torch.mean(torch.relu(CERTIFICATE_C - v_unsafe))
        u_pi_safe = pi_net(safe_states); x_next_safe = f_gpr(safe_states, u_pi_safe)
        v_next_safe = v_net(x_next_safe); stage_costs = stage_cost_func(safe_states, u_pi_safe)
        loss_lyapunov = torch.mean(torch.relu(GAMMA * v_next_safe - v_safe + stage_costs))
        total_loss = loss_goal + loss_safe_boundary + loss_unsafe_boundary + loss_lyapunov
        total_loss.backward(); optimizer.step()
    print(f"NN証明書: 学習完了。最終損失: {total_loss.item():.4f}")

# (TrueVehicle, GPRModelクラスは変更なし)
class TrueVehicle:
    def __init__(self, dt=0.1): self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u; drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt; vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2; py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])
class GPRModel:
    def __init__(self, nx, nu):
        self.nx, self.nu = nx, nu; self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu)); self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx
    def add_data(self, x, u, x_next):
        delta_real = (x_next - x) / DT; delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])]); self.Y_data = np.vstack([self.Y_data, error])
    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始..."); self.is_trained = True
        for i in range(self.nx):
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100); self.models[i] = model
        print("GPR: 学習完了")
    def predict(self, x, u):
        if not self.is_trained: return np.zeros(self.nx), np.ones(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        variances = np.array([m.predict(xu)[1][0, 0] if m else 1.0 for m in self.models])
        return means, variances

# ----------------------------------------------------------------------------------
# Component 3: MPCController
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, M, dt, obstacle_info):
        self.nx, self.nu, self.N, self.M, self.dt = nx, nu, N, M, dt
        self.obstacle_info = obstacle_info; self.u_prev_sol = np.zeros((nu, N))

    def solve(self, x_current, gpr_model, x_goal_pos, certificate_net, is_first_iteration):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)
        terminal_cost_func = NNCallback('terminal_cost_func', certificate_net)
        error_mean, error_var = gpr_model.predict(x_current, np.zeros(self.nu))
        error_std = np.sqrt(np.maximum(error_var, 1e-6)); error_std_capped = np.minimum(error_std, 0.1)
        error_samples = np.random.normal(loc=error_mean, scale=error_std_capped, size=(self.M, self.nx))
        all_scenario_costs = []
        for m in range(self.M):
            X_scenario = opti.variable(self.nx, self.N + 1); cost_scenario = 0
            opti.subject_to(X_scenario[:, 0] == x_current)
            for k in range(self.N):
                x_k, u_k = X_scenario[:, k], U[:, k]
                delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
                delta_pred = delta_nominal + error_samples[m, :]
                x_next_pred = x_k + delta_pred * self.dt
                opti.subject_to(X_scenario[:, k+1] == x_next_pred)
                if is_first_iteration:
                    stage_pos_weight = 1.0; stage_input_weight = 0.5; obstacle_weight = 2000.0
                else:
                    stage_pos_weight = 1.0; stage_input_weight = 0.01; obstacle_weight = 500.0
                cost_scenario += ca.sumsqr(x_k[:2] - x_goal_pos) * self.dt * stage_pos_weight
                cost_scenario += ca.sumsqr(u_k) * self.dt * stage_input_weight
                if self.obstacle_info:
                    dist_to_obs = ca.norm_2(x_k[:2] - self.obstacle_info['pos'])
                    if is_first_iteration:
                        safety_margin = 0.8; keep_out_radius = self.obstacle_info['rad'] + safety_margin
                        opti.subject_to(dist_to_obs >= keep_out_radius)
                    else:
                        penalty = ca.fmax(0, self.obstacle_info['rad'] - dist_to_obs)
                        cost_scenario += obstacle_weight * penalty**2
            terminal_state = X_scenario[:, self.N]
            if is_first_iteration:
                cost_scenario += ca.sumsqr(terminal_state[:2] - x_goal_pos) * 10.0
            else:
                terminal_cost = terminal_cost_func(terminal_state)
                cost_scenario += terminal_cost
                terminal_constraint_violation = ca.fmax(0, terminal_cost - CERTIFICATE_C)
                cost_scenario += 1000.0 * terminal_constraint_violation
            all_scenario_costs.append(cost_scenario)

        #total_objective = ca.mean(ca.vertcat(*all_scenario_costs))
        total_objective = ca.sum1(ca.vertcat(*all_scenario_costs)) / len(all_scenario_costs)
        opti.minimize(total_objective)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))
        opti.set_initial(U, self.u_prev_sol)
        
        s_opts = {'print_level': 0}
        opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}"); return np.zeros(self.nu)

# (main関数は変更なし)
def main():
    vehicle = TrueVehicle(dt=DT); gpr_model = GPRModel(nx=NX, nu=NU)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, M=M_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)
    certificate_net = CertificateNN(n_input=NX); policy_net = Pi_NN(n_input=NX, n_output=NU)
    all_trajectories, final_costs = [], []; all_past_data = []
    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE); total_cost = 0; iteration_data = []
        for step in range(SIM_STEPS):
            is_first_iter = (i == 0)
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE_POS, certificate_net, is_first_iter)

            # # ✅ このデバッグコードを追加
            # if i == 1 and step == 0:
            #     print("\n--- デバッグ: イテレーション2の最初のステップで停止します ---")
            #     return # プログラムを終了

            x_next = vehicle.dynamics(current_x, u_optimal)
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE_POS)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data.append((current_x, u_optimal, x_next, stage_cost))
            current_x = x_next
            if np.linalg.norm(current_x[:2] - GOAL_STATE_POS) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！"); break
        current_trajectory_states = [d[0] for d in iteration_data]
        all_trajectories.append(np.array(current_trajectory_states))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")
        gpr_data_for_train = [(d[0], d[1], d[2]) for d in iteration_data]
        for x, u, x_n in gpr_data_for_train: gpr_model.add_data(x, u, x_n)
        gpr_model.train()
        cost_data_for_train = [(d[0], d[3]) for d in iteration_data]
        all_past_data.extend(cost_data_for_train)
        train_certificate_net(certificate_net, policy_net, all_past_data, gpr_model, OBSTACLE_INFO)

        # # ✅ このデバッグコードを追加
        # if i == 0: # 最初のイテレーション後のみ実行
        #     print("\n--- デバッグ: 学習後のNNの出力を確認 ---")
        #     # イテレーション1の軌道データを取得
        #     iter1_states = torch.tensor(all_trajectories[0], dtype=torch.float32)
        #     with torch.no_grad():
        #         # そのデータに対するNNの出力を表示
        #         v_values = certificate_net(iter1_states).numpy().flatten()
        #         print("軌道上のV(x)の値 (一部):", v_values[:5])
        #         print(f"最大値: {np.max(v_values):.2f}, 最小値: {np.min(v_values):.2f}")
        #     print("-------------------------------------\n")

    plt.figure(figsize=(10, 10))
    if OBSTACLE_INFO:
        obs_circle = plt.Circle(OBSTACLE_INFO['pos'], OBSTACLE_INFO['rad'], color='r', alpha=0.5, label='障害物')
        plt.gca().add_patch(obs_circle)
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE_POS[0], GOAL_STATE_POS[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡（論文ベースのNN証明書版）'); plt.legend(); plt.axis('equal'); plt.show()
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移'); plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト'); plt.xticks(range(1, N_ITERATIONS + 1)); plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  72.00us (  7.20us)        10
#        nlp_g  |        0 (       0) 113.00us ( 11.30us)        10
#   nlp_grad_f  |        0 (       0) 124.00us ( 11.27us)        11
#   nlp_hess_l  |        0 (       0) 210.00us ( 23.33us)         9
#    nlp_jac_g  |        0 (       0) 473.00us ( 43.00us)        11
#        total  |   7.00ms (  7.00ms)  11.09ms ( 11.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  54.00us (  6.75us)         8
#        nlp_g  |        0 (       0)  80.00us ( 10.00us)         8
#   nlp_grad_f  |        0 (       0) 108.00us ( 12.00us)         9
#   nlp_hess_l  |        0 (       0) 164.00us ( 23.43us)         7
#    nlp_jac_g  |        0 (       0) 367.00us ( 40.78us)         9
#        total  |        0 (       0)   8.71ms (  8.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  57.00us (  7.12us)         8
#        nlp_g  |   1.00ms (125.00us) 159.00us ( 19.87us)         8
#   nlp_grad_f  |        0 (       0) 101.00us ( 11.22us)         9
#   nlp_hess_l  |        0 (       0) 195.00us ( 27.86us)         7
#    nlp_jac_g  |        0 (       0) 417.00us ( 46.33us)         9
#        total  |   1.00ms (  1.00ms)   8.65ms (  8.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 102.00us (  6.80us)        15
#        nlp_g  |        0 (       0) 217.00us ( 14.47us)        15
#   nlp_grad_f  |        0 (       0) 162.00us ( 10.12us)        16
#   nlp_hess_l  |        0 (       0) 369.00us ( 26.36us)        14
#    nlp_jac_g  |        0 (       0) 632.00us ( 39.50us)        16
#        total  |  26.00ms ( 26.00ms)  16.50ms ( 16.50ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 118.00us (  6.94us)        17
#        nlp_g  |        0 (       0) 190.00us ( 11.18us)        17
#   nlp_grad_f  |        0 (       0) 195.00us ( 10.83us)        18
#   nlp_hess_l  |        0 (       0) 363.00us ( 22.69us)        16
#    nlp_jac_g  |   1.00ms ( 55.56us) 740.00us ( 41.11us)        18
#        total  |  19.00ms ( 19.00ms)  19.46ms ( 19.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 125.00us (  7.35us)        17
#        nlp_g  |        0 (       0) 181.00us ( 10.65us)        17
#   nlp_grad_f  |        0 (       0) 196.00us ( 10.89us)        18
#   nlp_hess_l  |        0 (       0) 401.00us ( 25.06us)        16
#    nlp_jac_g  |   7.00ms (388.89us) 868.00us ( 48.22us)        18
#        total  |  15.00ms ( 15.00ms)  17.94ms ( 17.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 143.00us (  7.15us)        20
#        nlp_g  |        0 (       0) 219.00us ( 10.95us)        20
#   nlp_grad_f  |   1.00ms ( 47.62us) 235.00us ( 11.19us)        21
#   nlp_hess_l  |        0 (       0) 430.00us ( 22.63us)        19
#    nlp_jac_g  |        0 (       0) 954.00us ( 45.43us)        21
#        total  |  22.00ms ( 22.00ms)  22.31ms ( 22.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 123.00us (  6.47us)        19
#        nlp_g  |        0 (       0) 192.00us ( 10.11us)        19
#   nlp_grad_f  |        0 (       0) 208.00us ( 10.40us)        20
#   nlp_hess_l  |        0 (       0) 402.00us ( 22.33us)        18
#    nlp_jac_g  |        0 (       0) 822.00us ( 41.10us)        20
#        total  |  16.00ms ( 16.00ms)  20.75ms ( 20.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (695.65us) 153.00us (  6.65us)        23
#        nlp_g  |        0 (       0) 234.00us ( 10.17us)        23
#   nlp_grad_f  |        0 (       0) 244.00us ( 10.17us)        24
#   nlp_hess_l  |        0 (       0) 478.00us ( 21.73us)        22
#    nlp_jac_g  |        0 (       0) 973.00us ( 40.54us)        24
#        total  |  33.00ms ( 33.00ms)  23.62ms ( 23.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 146.00us (  6.95us)        21
#        nlp_g  |        0 (       0) 208.00us (  9.90us)        21
#   nlp_grad_f  |        0 (       0) 216.00us (  9.82us)        22
#   nlp_hess_l  |        0 (       0) 436.00us ( 21.80us)        20
#    nlp_jac_g  |        0 (       0) 923.00us ( 41.95us)        22
#        total  |  23.00ms ( 23.00ms)  21.94ms ( 21.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 236.00us (  6.94us)        34
#        nlp_g  |        0 (       0) 383.00us ( 11.26us)        34
#   nlp_grad_f  |        0 (       0) 379.00us ( 10.83us)        35
#   nlp_hess_l  |   1.00ms ( 30.30us) 780.00us ( 23.64us)        33
#    nlp_jac_g  |        0 (       0)   1.55ms ( 44.17us)        35
#        total  |  41.00ms ( 41.00ms)  40.65ms ( 40.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 201.00us (  6.93us)        29
#        nlp_g  |        0 (       0) 295.00us ( 10.17us)        29
#   nlp_grad_f  |        0 (       0) 328.00us ( 10.93us)        30
#   nlp_hess_l  |   8.00ms (285.71us) 603.00us ( 21.54us)        28
#    nlp_jac_g  |   5.00ms (166.67us)   1.31ms ( 43.63us)        30
#        total  |  33.00ms ( 33.00ms)  32.63ms ( 32.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 229.00us (  6.54us)        35
#        nlp_g  |        0 (       0) 377.00us ( 10.77us)        35
#   nlp_grad_f  |        0 (       0) 366.00us ( 10.17us)        36
#   nlp_hess_l  |        0 (       0) 740.00us ( 21.76us)        34
#    nlp_jac_g  |        0 (       0)   1.51ms ( 42.03us)        36
#        total  |  34.00ms ( 34.00ms)  42.06ms ( 42.06ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 260.00us (  6.84us)        38
#        nlp_g  |        0 (       0) 424.00us ( 11.16us)        38
#   nlp_grad_f  |        0 (       0) 418.00us ( 10.72us)        39
#   nlp_hess_l  |        0 (       0) 927.00us ( 25.05us)        37
#    nlp_jac_g  |        0 (       0)   1.64ms ( 41.97us)        39
#        total  |  59.00ms ( 59.00ms)  46.28ms ( 46.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 22.22us) 314.00us (  6.98us)        45
#        nlp_g  |        0 (       0) 499.00us ( 11.09us)        45
#   nlp_grad_f  |        0 (       0) 489.00us ( 10.63us)        46
#   nlp_hess_l  |   2.00ms ( 45.45us)   1.13ms ( 25.64us)        44
#    nlp_jac_g  |   1.00ms ( 21.74us)   2.03ms ( 44.11us)        46
#        total  |  38.00ms ( 38.00ms)  51.50ms ( 51.50ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 263.00us (  7.31us)        36
#        nlp_g  |        0 (       0) 385.00us ( 10.69us)        36
#   nlp_grad_f  |        0 (       0) 389.00us ( 10.51us)        37
#   nlp_hess_l  |        0 (       0) 747.00us ( 21.34us)        35
#    nlp_jac_g  |        0 (       0)   1.60ms ( 43.24us)        37
#        total  |  30.00ms ( 30.00ms)  37.15ms ( 37.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 287.00us (  6.83us)        42
#        nlp_g  |        0 (       0) 426.00us ( 10.14us)        42
#   nlp_grad_f  |        0 (       0) 421.00us (  9.79us)        43
#   nlp_hess_l  |        0 (       0) 878.00us ( 21.41us)        41
#    nlp_jac_g  |        0 (       0)   1.73ms ( 40.19us)        43
#        total  |  49.00ms ( 49.00ms)  43.60ms ( 43.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 518.00us (  7.00us)        74
#        nlp_g  |        0 (       0) 764.00us ( 10.32us)        74
#   nlp_grad_f  |        0 (       0) 607.00us ( 11.04us)        55
#   nlp_hess_l  |   1.00ms ( 20.41us)   1.16ms ( 23.65us)        49
#    nlp_jac_g  |        0 (       0)   2.59ms ( 42.54us)        61
#        total  |  61.00ms ( 61.00ms)  60.51ms ( 60.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 594.00us (  6.25us)        95
#        nlp_g  |        0 (       0) 876.00us (  9.22us)        95
#   nlp_grad_f  |        0 (       0) 688.00us (  9.97us)        69
#   nlp_hess_l  |        0 (       0)   1.31ms ( 22.14us)        59
#    nlp_jac_g  |        0 (       0)   3.16ms ( 41.01us)        77
#        total  |  68.00ms ( 68.00ms)  74.16ms ( 74.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 11.49us) 581.00us (  6.68us)        87
#        nlp_g  |        0 (       0) 852.00us (  9.79us)        87
#   nlp_grad_f  |        0 (       0) 648.00us (  9.97us)        65
#   nlp_hess_l  |  16.00ms (275.86us)   1.31ms ( 22.52us)        58
#    nlp_jac_g  |   1.00ms ( 13.51us)   3.07ms ( 41.50us)        74
#        total  |  76.00ms ( 76.00ms)  74.70ms ( 74.70ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 260.00us (  6.50us)        40
#        nlp_g  |        0 (       0) 417.00us ( 10.42us)        40
#   nlp_grad_f  |        0 (       0) 380.00us ( 10.56us)        36
#   nlp_hess_l  |   3.00ms ( 90.91us) 746.00us ( 22.61us)        33
#    nlp_jac_g  |   3.00ms ( 81.08us)   1.59ms ( 42.92us)        37
#        total  |  38.00ms ( 38.00ms)  36.56ms ( 36.56ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 27.03us) 222.00us (  6.00us)        37
#        nlp_g  |        0 (       0) 351.00us (  9.49us)        37
#   nlp_grad_f  |   1.00ms ( 33.33us) 295.00us (  9.83us)        30
#   nlp_hess_l  |   1.00ms ( 38.46us) 570.00us ( 21.92us)        26
#    nlp_jac_g  |   1.00ms ( 31.25us)   1.30ms ( 40.56us)        32
#        total  |  31.00ms ( 31.00ms)  31.29ms ( 31.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 442.00us (  6.14us)        72
#        nlp_g  |        0 (       0) 655.00us (  9.10us)        72
#   nlp_grad_f  |        0 (       0) 596.00us ( 11.46us)        52
#   nlp_hess_l  |        0 (       0)   1.13ms ( 25.09us)        45
#    nlp_jac_g  |   3.00ms ( 52.63us)   2.52ms ( 44.30us)        57
#        total  |  56.00ms ( 56.00ms)  55.46ms ( 55.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 296.00us (  6.73us)        44
#        nlp_g  |        0 (       0) 469.00us ( 10.66us)        44
#   nlp_grad_f  |        0 (       0) 389.00us ( 10.51us)        37
#   nlp_hess_l  |        0 (       0) 873.00us ( 26.45us)        33
#    nlp_jac_g  |   1.00ms ( 24.39us)   1.78ms ( 43.51us)        41
#        total  |  48.00ms ( 48.00ms)  42.94ms ( 42.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 331.00us (  6.76us)        49
#        nlp_g  |        0 (       0) 485.00us (  9.90us)        49
#   nlp_grad_f  |   1.00ms ( 29.41us) 367.00us ( 10.79us)        34
#   nlp_hess_l  |        0 (       0) 833.00us ( 26.03us)        32
#    nlp_jac_g  |   3.00ms ( 75.00us)   1.80ms ( 45.10us)        40
#        total  |  41.00ms ( 41.00ms)  40.85ms ( 40.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 258.00us (  6.79us)        38
#        nlp_g  |        0 (       0) 404.00us ( 10.63us)        38
#   nlp_grad_f  |        0 (       0) 293.00us ( 11.27us)        26
#   nlp_hess_l  |        0 (       0) 636.00us ( 26.50us)        24
#    nlp_jac_g  |   2.00ms ( 66.67us)   1.23ms ( 41.17us)        30
#        total  |  30.00ms ( 30.00ms)  31.07ms ( 31.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 319.00us (  7.25us)        44
#        nlp_g  |        0 (       0) 454.00us ( 10.32us)        44
#   nlp_grad_f  |        0 (       0) 323.00us ( 10.77us)        30
#   nlp_hess_l  |   2.00ms ( 68.97us) 757.00us ( 26.10us)        29
#    nlp_jac_g  |   4.00ms (114.29us)   1.68ms ( 48.03us)        35
#        total  |  38.00ms ( 38.00ms)  37.95ms ( 37.95ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 20.41us) 331.00us (  6.76us)        49
#        nlp_g  |        0 (       0) 479.00us (  9.78us)        49
#   nlp_grad_f  |        0 (       0) 348.00us ( 10.24us)        34
#   nlp_hess_l  |   1.00ms ( 27.78us) 842.00us ( 23.39us)        36
#    nlp_jac_g  |        0 (       0)   1.82ms ( 43.31us)        42
#        total  |  47.00ms ( 47.00ms)  47.31ms ( 47.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 300.00us (  6.98us)        43
#        nlp_g  |        0 (       0) 510.00us ( 11.86us)        43
#   nlp_grad_f  |        0 (       0) 367.00us ( 14.68us)        25
#   nlp_hess_l  |   1.00ms ( 27.78us) 818.00us ( 22.72us)        36
#    nlp_jac_g  |        0 (       0)   1.80ms ( 42.93us)        42
#        total  |  52.00ms ( 52.00ms)  52.46ms ( 52.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 376.00us (  6.60us)        57
#        nlp_g  |        0 (       0) 603.00us ( 10.58us)        57
#   nlp_grad_f  |   3.00ms (111.11us) 312.00us ( 11.56us)        27
#   nlp_hess_l  |        0 (       0)   1.10ms ( 26.21us)        42
#    nlp_jac_g  |   4.00ms ( 83.33us)   2.05ms ( 42.77us)        48
#        total  |  66.00ms ( 66.00ms)  63.84ms ( 63.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 439.00us (  6.97us)        63
#        nlp_g  |        0 (       0) 706.00us ( 11.21us)        63
#   nlp_grad_f  |        0 (       0) 240.00us ( 10.43us)        23
#   nlp_hess_l  |   4.00ms ( 71.43us)   1.48ms ( 26.45us)        56
#    nlp_jac_g  |  12.00ms (200.00us)   2.63ms ( 43.78us)        60
#        total  |  91.00ms ( 91.00ms)  90.83ms ( 90.83ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 343.00us (  7.00us)        49
#        nlp_g  |        0 (       0) 603.00us ( 12.31us)        49
#   nlp_grad_f  |        0 (       0) 323.00us ( 11.96us)        27
#   nlp_hess_l  |        0 (       0)   1.03ms ( 23.93us)        43
#    nlp_jac_g  |   1.00ms ( 21.28us)   2.12ms ( 45.13us)        47
#        total  |  64.00ms ( 64.00ms)  63.77ms ( 63.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 337.00us (  7.33us)        46
#        nlp_g  |        0 (       0) 506.00us ( 11.00us)        46
#   nlp_grad_f  |        0 (       0) 259.00us ( 11.26us)        23
#   nlp_hess_l  |        0 (       0) 919.00us ( 23.56us)        39
#    nlp_jac_g  |        0 (       0)   1.88ms ( 43.63us)        43
#        total  |  54.00ms ( 54.00ms)  58.84ms ( 58.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 280.00us (  6.83us)        41
#        nlp_g  |        0 (       0) 434.00us ( 10.59us)        41
#   nlp_grad_f  |        0 (       0) 287.00us ( 10.25us)        28
#   nlp_hess_l  |        0 (       0) 844.00us ( 23.44us)        36
#    nlp_jac_g  |   1.00ms ( 25.00us)   1.72ms ( 43.00us)        40
#        total  |  50.00ms ( 50.00ms)  49.72ms ( 49.72ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 311.00us (  7.23us)        43
#        nlp_g  |   1.00ms ( 23.26us) 489.00us ( 11.37us)        43
#   nlp_grad_f  |   1.00ms ( 41.67us) 268.00us ( 11.17us)        24
#   nlp_hess_l  |        0 (       0) 900.00us ( 23.08us)        39
#    nlp_jac_g  |   1.00ms ( 23.26us)   1.95ms ( 45.37us)        43
#        total  |  56.00ms ( 56.00ms)  57.85ms ( 57.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 257.00us (  7.14us)        36
#        nlp_g  |        0 (       0) 387.00us ( 10.75us)        36
#   nlp_grad_f  |        0 (       0) 240.00us ( 11.43us)        21
#   nlp_hess_l  |        0 (       0) 725.00us ( 23.39us)        31
#    nlp_jac_g  |        0 (       0)   1.47ms ( 42.11us)        35
#        total  |  51.00ms ( 51.00ms)  46.13ms ( 46.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 209.00us (  6.74us)        31
#        nlp_g  |        0 (       0) 326.00us ( 10.52us)        31
#   nlp_grad_f  |        0 (       0) 249.00us ( 12.45us)        20
#   nlp_hess_l  |        0 (       0) 635.00us ( 23.52us)        27
#    nlp_jac_g  |        0 (       0)   1.35ms ( 43.68us)        31
#        total  |  40.00ms ( 40.00ms)  39.67ms ( 39.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 310.00us (  7.05us)        44
#        nlp_g  |        0 (       0) 485.00us ( 11.02us)        44
#   nlp_grad_f  |        0 (       0) 315.00us ( 12.12us)        26
#   nlp_hess_l  |   4.00ms (108.11us) 881.00us ( 23.81us)        37
#    nlp_jac_g  |   1.00ms ( 24.39us)   1.81ms ( 44.10us)        41
#        total  |  54.00ms ( 54.00ms)  54.02ms ( 54.02ms)         1
# ステップ 38 でゴールに到達！
# イテレーション 1 の総コスト: 288.01
# GPR: 学習開始...
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:166: RuntimeWarning:overflow encountered in divide
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in square
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:138: RuntimeWarning:invalid value encountered in add
# GPR: 学習完了
# NN証明書: 学習開始...
# NN証明書: 学習完了。最終損失: 95.0128
#
# ==================================================
# 反復学習: イテレーション 2/5
# ==================================================
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# イテレーション 2 の総コスト: 2000.00
# GPR: 学習開始...
# GPR: 学習完了
# NN証明書: 学習開始...
# NN証明書: 学習完了。最終損失: 74.7046
#
# ==================================================
# 反復学習: イテレーション 3/5
# ==================================================
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# イテレーション 3 の総コスト: 2000.00
# GPR: 学習開始...
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\rbf.py:178: RuntimeWarning:invalid value encountered in multiply
# GPR: 学習完了
# NN証明書: 学習開始...
# NN証明書: 学習完了。最終損失: 21.9331
#
# ==================================================
# 反復学習: イテレーション 4/5
# ==================================================
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# イテレーション 4 の総コスト: 2000.00
# GPR: 学習開始...
# GPR: 学習完了
# NN証明書: 学習開始...
# NN証明書: 学習完了。最終損失: 5.9501
#
# ==================================================
# 反復学習: イテレーション 5/5
# ==================================================
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# MPC: 最適化失敗。x=[0. 0. 0. 0.]
# イテレーション 5 の総コスト: 2000.00
# GPR: 学習開始...
# GPR: 学習完了
# NN証明書: 学習開始...
# NN証明書: 学習完了。最終損失: 1.9566
