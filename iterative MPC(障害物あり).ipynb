# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import time

import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)

N_ITERATIONS = 4
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE = np.array([10.0, 10.0])
N_MPC = 20
OBSTACLE_INFO = {'pos': np.array([5.0, 5.0]), 'rad': 1.5}

# ----------------------------------------------------------------------------------
# 真のシステム
# ----------------------------------------------------------------------------------
class TrueVehicle:
    def __init__(self, dt=0.1):
        self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u
        # GPRが学習すべき、モデル化されていない非線形項
        drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt
        vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2
        py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])

# ----------------------------------------------------------------------------------
# ガウス過程回帰モデル (ダイナミクス学習)
# ----------------------------------------------------------------------------------
class GPRModel:
    def __init__(self, nx, nu, dt, obstacle_info):
        self.nx, self.nu = nx, nu
        self.dt=DT
        self.obstacle_info=OBSTACLE_INFO
        self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu))
        self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx

    def add_data(self, x, u, x_next):
        # nominalモデルからの誤差（デルタ）を学習ターゲットにする
        delta_real = (x_next - x) / self.dt
        delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])])
        self.Y_data = np.vstack([self.Y_data, error])

    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始...")
        for i in range(self.nx):
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100)
            self.models[i] = model
        self.is_trained = True
        print("GPR: 学習完了")

    def predict(self, x, u):
        if not self.is_trained:
            return np.zeros(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        return means

# ----------------------------------------------------------------------------------
# MPCコントローラ
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, dt, obstacle_info):
        self.nx, self.nu, self.N, self.dt = nx, nu, N, dt
        self.obstacle_info = obstacle_info
        self.u_prev_sol = np.zeros((nu, N))

    def solve(self, x_current, gpr_model, x_goal):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)
        X = opti.variable(self.nx, self.N + 1)
        
        cost = 0
        opti.subject_to(X[:, 0] == x_current)

        error_mean = gpr_model.predict(x_current, np.zeros(self.nu))
        
        for k in range(self.N):
            x_k, u_k = X[:, k], U[:, k]
            delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
            delta_pred = delta_nominal + error_mean
            x_next_pred = x_k + delta_pred * self.dt
            opti.subject_to(X[:, k+1] == x_next_pred)

            cost += ca.sumsqr(x_k[:2] - x_goal) * self.dt
            cost += ca.sumsqr(u_k) * self.dt * 0.01
            if self.obstacle_info is not None:
                dist_to_obs = ca.norm_2(x_k[:2] - self.obstacle_info['pos'])
                # 障害物半径の内側に入った分だけ、2乗に比例したペナルティを課す
                penalty = ca.fmax(0, self.obstacle_info['rad'] - dist_to_obs)
                cost += 500.0 * penalty**2

        cost += ca.sumsqr(X[:2, self.N] - x_goal) * 20.0

        opti.minimize(cost)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))

        opti.set_initial(X, np.tile(x_current, (self.N + 1, 1)).T)
        opti.set_initial(U, self.u_prev_sol)
        
        s_opts = {'print_level': 0}
        opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}, error: {e}")
            return np.zeros(self.nu)

# ----------------------------------------------------------------------------------
# Main Simulation Loop
# ----------------------------------------------------------------------------------
def main():
    vehicle = TrueVehicle(dt=DT)
    gpr_model = GPRModel(nx=NX, nu=NU, dt=DT, obstacle_info=OBSTACLE_INFO)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)

    all_trajectories, final_costs = [], []

    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE)
        total_cost = 0
        iteration_data = []

        for step in range(SIM_STEPS):
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE)
            x_next = vehicle.dynamics(current_x, u_optimal)
            
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data.append((current_x, u_optimal, x_next))
            current_x = x_next

            if np.linalg.norm(current_x[:2] - GOAL_STATE) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！")
                break
        
        all_trajectories.append(np.array([d[0] for d in iteration_data]))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")

        for x, u, x_n in iteration_data:
            gpr_model.add_data(x, u, x_n)
        gpr_model.train()

    # --- 結果の可視化 ---
    plt.figure(figsize=(10, 10))
    if OBSTACLE_INFO is not None:
        obs_circle = plt.Circle(OBSTACLE_INFO['pos'], OBSTACLE_INFO['rad'], color='r', alpha=0.5, label='障害物')
        plt.gca().add_patch(obs_circle)
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE[0], GOAL_STATE[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡')
    plt.legend()
    plt.axis('equal')
    plt.show()

    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移')
    plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト')
    plt.xticks(range(1, N_ITERATIONS + 1))
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/4
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       
ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  70.00us (  4.67us)        15
#        nlp_g  |        0 (       0)  55.00us (  3.67us)        15
#   nlp_grad_f  |        0 (       0) 126.00us (  7.87us)        16
#   nlp_hess_l  |        0 (       0) 201.00us ( 14.36us)        14
#    nlp_jac_g  |        0 (       0) 149.00us (  9.31us)        16
#        total  |  14.00ms ( 14.00ms)   9.81ms (  9.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  65.00us (  4.33us)        15
#        nlp_g  |        0 (       0)  48.00us (  3.20us)        15
#   nlp_grad_f  |        0 (       0) 139.00us (  8.69us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us) 185.00us ( 13.21us)        14
#    nlp_jac_g  |        0 (       0) 145.00us (  9.06us)        16
#        total  |   9.00ms (  9.00ms)   9.46ms (  9.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  69.00us (  4.60us)        15
#        nlp_g  |        0 (       0)  53.00us (  3.53us)        15
#   nlp_grad_f  |        0 (       0) 135.00us (  8.44us)        16
#   nlp_hess_l  |        0 (       0) 201.00us ( 14.36us)        14
#    nlp_jac_g  |        0 (       0) 154.00us (  9.62us)        16
#        total  |   9.00ms (  9.00ms)   9.73ms (  9.73ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 108.00us (  6.75us)        16
#        nlp_g  |        0 (       0)  71.00us (  4.44us)        16
#   nlp_grad_f  |        0 (       0) 146.00us (  8.59us)        17
#   nlp_hess_l  |        0 (       0) 221.00us ( 14.73us)        15
#    nlp_jac_g  |        0 (       0) 171.00us ( 10.06us)        17
#        total  |  10.00ms ( 10.00ms)  10.64ms ( 10.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  78.00us (  5.20us)        15
#        nlp_g  |        0 (       0)  66.00us (  4.40us)        15
#   nlp_grad_f  |        0 (       0) 148.00us (  9.25us)        16
#   nlp_hess_l  |        0 (       0) 262.00us ( 18.71us)        14
#    nlp_jac_g  |        0 (       0) 164.00us ( 10.25us)        16
#        total  |  11.00ms ( 11.00ms)  10.38ms ( 10.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  55.00us (  4.23us)        13
#        nlp_g  |        0 (       0)  41.00us (  3.15us)        13
#   nlp_grad_f  |        0 (       0) 107.00us (  7.64us)        14
#   nlp_hess_l  |        0 (       0) 168.00us ( 14.00us)        12
#    nlp_jac_g  |        0 (       0) 130.00us (  9.29us)        14
#        total  |   8.00ms (  8.00ms)   8.06ms (  8.06ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  51.00us (  4.25us)        12
#        nlp_g  |        0 (       0)  35.00us (  2.92us)        12
#   nlp_grad_f  |        0 (       0)  96.00us (  7.38us)        13
#   nlp_hess_l  |        0 (       0) 145.00us ( 13.18us)        11
#    nlp_jac_g  |        0 (       0) 113.00us (  8.69us)        13
#        total  |   8.00ms (  8.00ms)   7.48ms (  7.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  47.00us (  4.27us)        11
#        nlp_g  |        0 (       0)  35.00us (  3.18us)        11
#   nlp_grad_f  |        0 (       0)  86.00us (  7.17us)        12
#   nlp_hess_l  |   1.00ms (100.00us) 149.00us ( 14.90us)        10
#    nlp_jac_g  |        0 (       0) 102.00us (  8.50us)        12
#        total  |   6.00ms (  6.00ms)   7.05ms (  7.05ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  55.00us (  4.58us)        12
#        nlp_g  |        0 (       0)  37.00us (  3.08us)        12
#   nlp_grad_f  |        0 (       0)  95.00us (  7.31us)        13
#   nlp_hess_l  |        0 (       0) 158.00us ( 14.36us)        11
#    nlp_jac_g  |        0 (       0) 126.00us (  9.69us)        13
#        total  |   7.00ms (  7.00ms)   7.57ms (  7.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  55.00us (  5.00us)        11
#        nlp_g  |        0 (       0)  51.00us (  4.64us)        11
#   nlp_grad_f  |        0 (       0) 101.00us (  8.42us)        12
#   nlp_hess_l  |        0 (       0) 157.00us ( 15.70us)        10
#    nlp_jac_g  |        0 (       0) 145.00us ( 12.08us)        12
#        total  |   7.00ms (  7.00ms)   7.60ms (  7.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  44.00us (  4.89us)         9
#        nlp_g  |        0 (       0)  26.00us (  2.89us)         9
#   nlp_grad_f  |        0 (       0)  73.00us (  7.30us)        10
#   nlp_hess_l  |        0 (       0) 112.00us ( 14.00us)         8
#    nlp_jac_g  |        0 (       0)  94.00us (  9.40us)        10
#        total  |        0 (       0)   5.66ms (  5.66ms)         1
# ステップ 28 でゴールに到達！
# イテレーション 2 の総コスト: 271.63
# GPR: 学習開始...
# GPR: 学習完了
#
# ==================================================
# 反復学習: イテレーション 3/4
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 47.62us)  93.00us (  4.43us)        21
#        nlp_g  |        0 (       0)  73.00us (  3.48us)        21
#   nlp_grad_f  |        0 (       0) 170.00us (  7.73us)        22
#   nlp_hess_l  |        0 (       0) 346.00us ( 17.30us)        20
#    nlp_jac_g  |        0 (       0) 197.00us (  8.95us)        22
#        total  |  15.00ms ( 15.00ms)  15.25ms ( 15.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  71.00us (  4.18us)        17
#        nlp_g  |        0 (       0)  55.00us (  3.24us)        17
#   nlp_grad_f  |        0 (       0) 134.00us (  7.44us)        18
#   nlp_hess_l  |   2.00ms (125.00us) 220.00us ( 13.75us)        16
#    nlp_jac_g  |        0 (       0) 152.00us (  8.44us)        18
#        total  |  11.00ms ( 11.00ms)  10.96ms ( 10.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  86.00us (  4.53us)        19
#        nlp_g  |        0 (       0)  60.00us (  3.16us)        19
#   nlp_grad_f  |        0 (       0) 140.00us (  7.00us)        20
#   nlp_hess_l  |        0 (       0) 268.00us ( 14.89us)        18
#    nlp_jac_g  |        0 (       0) 170.00us (  8.50us)        20
#        total  |  12.00ms ( 12.00ms)  11.53ms ( 11.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  75.00us (  4.41us)        17
#        nlp_g  |        0 (       0)  54.00us (  3.18us)        17
#   nlp_grad_f  |        0 (       0) 137.00us (  7.61us)        18
#   nlp_hess_l  |        0 (       0) 237.00us ( 14.81us)        16
#    nlp_jac_g  |        0 (       0) 155.00us (  8.61us)        18
#        total  |   2.00ms (  2.00ms)  10.80ms ( 10.80ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  88.00us (  5.18us)        17
#        nlp_g  |        0 (       0)  80.00us (  4.71us)        17
#   nlp_grad_f  |        0 (       0) 149.00us (  8.28us)        18
#   nlp_hess_l  |        0 (       0) 258.00us ( 16.12us)        16
#    nlp_jac_g  |        0 (       0) 171.00us (  9.50us)        18
#        total  |  12.00ms ( 12.00ms)  11.74ms ( 11.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  82.00us (  4.10us)        20
#        nlp_g  |        0 (       0)  59.00us (  2.95us)        20
#   nlp_grad_f  |        0 (       0) 162.00us (  8.10us)        20
#   nlp_hess_l  |        0 (       0) 249.00us ( 13.83us)        18
#    nlp_jac_g  |        0 (       0) 187.00us (  9.35us)        20
#        total  |  11.00ms ( 11.00ms)  11.80ms ( 11.80ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       
ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  69.00us (  4.60us)        15
#        nlp_g  |        0 (       0)  53.00us (  3.53us)        15
#   nlp_grad_f  |        0 (       0) 128.00us (  8.00us)        16
#   nlp_hess_l  |        0 (       0) 204.00us ( 14.57us)        14
#    nlp_jac_g  |        0 (       0) 151.00us (  9.44us)        16
#        total  |   9.00ms (  9.00ms)   9.63ms (  9.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  57.00us (  4.38us)        13
#        nlp_g  |        0 (       0)  42.00us (  3.23us)        13
#   nlp_grad_f  |        0 (       0) 103.00us (  7.36us)        14
#   nlp_hess_l  |        0 (       0) 178.00us ( 14.83us)        12
#    nlp_jac_g  |        0 (       0) 122.00us (  8.71us)        14
#        total  |   8.00ms (  8.00ms)   8.23ms (  8.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 142.00us (  8.35us)        17
#        nlp_g  |        0 (       0) 105.00us (  6.18us)        17
#   nlp_grad_f  |        0 (       0) 233.00us ( 12.94us)        18
#   nlp_hess_l  |        0 (       0) 342.00us ( 21.37us)        16
#    nlp_jac_g  |        0 (       0) 235.00us ( 13.06us)        18
#        total  |  13.00ms ( 13.00ms)  13.22ms ( 13.22ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  67.00us (  4.47us)        15
#        nlp_g  |        0 (       0)  50.00us (  3.33us)        15
#   nlp_grad_f  |        0 (       0) 116.00us (  7.25us)        16
#   nlp_hess_l  |        0 (       0) 212.00us ( 15.14us)        14
#    nlp_jac_g  |        0 (       0) 141.00us (  8.81us)        16
#        total  |        0 (       0)   9.52ms (  9.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  68.00us (  4.53us)        15
#        nlp_g  |        0 (       0)  47.00us (  3.13us)        15
#   nlp_grad_f  |        0 (       0) 113.00us (  7.06us)        16
#   nlp_hess_l  |        0 (       0) 189.00us ( 13.50us)        14
#    nlp_jac_g  |        0 (       0) 139.00us (  8.69us)        16
#        total  |   2.00ms (  2.00ms)   9.70ms (  9.70ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  81.00us (  5.40us)        15
#        nlp_g  |        0 (       0)  61.00us (  4.07us)        15
#   nlp_grad_f  |        0 (       0) 125.00us (  7.81us)        16
#   nlp_hess_l  |        0 (       0) 206.00us ( 14.71us)        14
#    nlp_jac_g  |        0 (       0) 146.00us (  9.12us)        16
#        total  |  14.00ms ( 14.00ms)   9.57ms (  9.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  75.00us (  4.69us)        16
#        nlp_g  |        0 (       0)  48.00us (  3.00us)        16
#   nlp_grad_f  |        0 (       0) 125.00us (  7.35us)        17
#   nlp_hess_l  |        0 (       0) 196.00us ( 13.07us)        15
#    nlp_jac_g  |        0 (       0) 140.00us (  8.24us)        17
#        total  |  10.00ms ( 10.00ms)   9.65ms (  9.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  63.00us (  4.20us)        15
#        nlp_g  |        0 (       0)  47.00us (  3.13us)        15
#   nlp_grad_f  |        0 (       0) 117.00us (  7.31us)        16
#   nlp_hess_l  |        0 (       0) 200.00us ( 14.29us)        14
#    nlp_jac_g  |        0 (       0) 148.00us (  9.25us)        16
#        total  |  17.00ms ( 17.00ms)   9.25ms (  9.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  55.00us (  4.23us)        13
#        nlp_g  |        0 (       0)  44.00us (  3.38us)        13
#   nlp_grad_f  |        0 (       0) 106.00us (  7.57us)        14
#   nlp_hess_l  |        0 (       0) 192.00us ( 16.00us)        12
#    nlp_jac_g  |        0 (       0) 124.00us (  8.86us)        14
#        total  |   7.00ms (  7.00ms)   8.00ms (  8.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  52.00us (  4.33us)        12
#        nlp_g  |        0 (       0)  44.00us (  3.67us)        12
#   nlp_grad_f  |        0 (       0) 104.00us (  8.00us)        13
#   nlp_hess_l  |        0 (       0) 169.00us ( 15.36us)        11
#    nlp_jac_g  |        0 (       0) 129.00us (  9.92us)        13
#        total  |   8.00ms (  8.00ms)   8.20ms (  8.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  50.00us (  4.55us)        11
#        nlp_g  |        0 (       0)  34.00us (  3.09us)        11
#   nlp_grad_f  |        0 (       0)  84.00us (  7.00us)        12
#   nlp_hess_l  |        0 (       0) 146.00us ( 14.60us)        10
#    nlp_jac_g  |        0 (       0) 105.00us (  8.75us)        12
#        total  |   7.00ms (  7.00ms)   6.90ms (  6.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  57.00us (  4.75us)        12
#        nlp_g  |        0 (       0)  47.00us (  3.92us)        12
#   nlp_grad_f  |        0 (       0)  99.00us (  7.62us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us) 176.00us ( 16.00us)        11
#    nlp_jac_g  |        0 (       0) 127.00us (  9.77us)        13
#        total  |   7.00ms (  7.00ms)   7.82ms (  7.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  47.00us (  4.27us)        11
#        nlp_g  |        0 (       0)  38.00us (  3.45us)        11
#   nlp_grad_f  |        0 (       0)  88.00us (  7.33us)        12
#   nlp_hess_l  |   2.00ms (200.00us) 141.00us ( 14.10us)        10
#    nlp_jac_g  |   2.00ms (166.67us) 109.00us (  9.08us)        12
#        total  |   8.00ms (  8.00ms)   6.85ms (  6.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  36.00us (  4.00us)         9
#        nlp_g  |        0 (       0)  33.00us (  3.67us)         9
#   nlp_grad_f  |        0 (       0)  73.00us (  7.30us)        10
#   nlp_hess_l  |        0 (       0) 114.00us ( 14.25us)         8
#    nlp_jac_g  |        0 (       0)  83.00us (  8.30us)        10
#        total  |        0 (       0)   5.60ms (  5.60ms)         1
# ステップ 28 でゴールに到達！
# イテレーション 3 の総コスト: 271.63
# GPR: 学習開始...
# GPR: 学習完了
#
# ==================================================
# 反復学習: イテレーション 4/4
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  95.00us (  4.52us)        21
#        nlp_g  |        0 (       0)  68.00us (  3.24us)        21
#   nlp_grad_f  |   1.00ms ( 45.45us) 161.00us (  7.32us)        22
#   nlp_hess_l  |        0 (       0) 291.00us ( 14.55us)        20
#    nlp_jac_g  |   1.00ms ( 45.45us) 204.00us (  9.27us)        22
#        total  |  16.00ms ( 16.00ms)  15.18ms ( 15.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  83.00us (  4.88us)        17
#        nlp_g  |        0 (       0)  55.00us (  3.24us)        17
#   nlp_grad_f  |        0 (       0) 137.00us (  7.61us)        18
#   nlp_hess_l  |        0 (       0) 230.00us ( 14.37us)        16
#    nlp_jac_g  |        0 (       0) 165.00us (  9.17us)        18
#        total  |  10.00ms ( 10.00ms)  10.89ms ( 10.89ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  80.00us (  4.21us)        19
#        nlp_g  |        0 (       0)  61.00us (  3.21us)        19
#   nlp_grad_f  |        0 (       0) 140.00us (  7.00us)        20
#   nlp_hess_l  |        0 (       0) 246.00us ( 13.67us)        18
#    nlp_jac_g  |        0 (       0) 163.00us (  8.15us)        20
#        total  |  16.00ms ( 16.00ms)  11.75ms ( 11.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  72.00us (  4.24us)        17
#        nlp_g  |        0 (       0)  59.00us (  3.47us)        17
#   nlp_grad_f  |        0 (       0) 131.00us (  7.28us)        18
#   nlp_hess_l  |        0 (       0) 232.00us ( 14.50us)        16
#    nlp_jac_g  |        0 (       0) 148.00us (  8.22us)        18
#        total  |  10.00ms ( 10.00ms)  10.62ms ( 10.62ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  76.00us (  4.47us)        17
#        nlp_g  |        0 (       0)  63.00us (  3.71us)        17
#   nlp_grad_f  |        0 (       0) 145.00us (  8.06us)        18
#   nlp_hess_l  |        0 (       0) 219.00us ( 13.69us)        16
#    nlp_jac_g  |        0 (       0) 161.00us (  8.94us)        18
#        total  |  19.00ms ( 19.00ms)  10.97ms ( 10.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  90.00us (  4.09us)        22
#        nlp_g  |        0 (       0)  68.00us (  3.09us)        22
#   nlp_grad_f  |        0 (       0) 154.00us (  7.70us)        20
#   nlp_hess_l  |        0 (       0) 251.00us ( 13.94us)        18
#    nlp_jac_g  |        0 (       0) 178.00us (  8.90us)        20
#        total  |  17.00ms ( 17.00ms)  12.10ms ( 12.10ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  90.00us (  3.91us)        23
#        nlp_g  |        0 (       0)  63.00us (  2.74us)        23
#   nlp_grad_f  |        0 (       0) 141.00us (  7.05us)        20
#   nlp_hess_l  |        0 (       0) 241.00us ( 13.39us)        18
#    nlp_jac_g  |        0 (       0) 160.00us (  8.00us)        20
#        total  |        0 (       0)  11.45ms ( 11.45ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  96.00us (  4.36us)        22
#        nlp_g  |        0 (       0)  68.00us (  3.09us)        22
#   nlp_grad_f  |        0 (       0) 140.00us (  7.00us)        20
#   nlp_hess_l  |        0 (       0) 252.00us ( 14.00us)        18
#    nlp_jac_g  |        0 (       0) 184.00us (  9.20us)        20
#        total  |  26.00ms ( 26.00ms)  12.56ms ( 12.56ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 111.00us (  4.27us)        26
#        nlp_g  |        0 (       0)  92.00us (  3.54us)        26
#   nlp_grad_f  |        0 (       0) 173.00us (  9.11us)        19
#   nlp_hess_l  |   1.00ms ( 58.82us) 385.00us ( 22.65us)        17
#    nlp_jac_g  |        0 (       0) 179.00us (  9.42us)        19
#        total  |  22.00ms ( 22.00ms)  12.03ms ( 12.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  87.00us (  4.83us)        18
#        nlp_g  |        0 (       0)  71.00us (  3.94us)        18
#   nlp_grad_f  |        0 (       0) 157.00us (  8.26us)        19
#   nlp_hess_l  |   1.00ms ( 58.82us) 254.00us ( 14.94us)        17
#    nlp_jac_g  |        0 (       0) 172.00us (  9.05us)        19
#        total  |  11.00ms ( 11.00ms)  12.13ms ( 12.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 102.00us (  4.64us)        22
#        nlp_g  |        0 (       0)  71.00us (  3.23us)        22
#   nlp_grad_f  |        0 (       0) 150.00us (  7.14us)        21
#   nlp_hess_l  |   1.00ms ( 52.63us) 257.00us ( 13.53us)        19
#    nlp_jac_g  |        0 (       0) 264.00us ( 12.57us)        21
#        total  |  13.00ms ( 13.00ms)  12.84ms ( 12.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  72.00us (  4.50us)        16
#        nlp_g  |        0 (       0)  54.00us (  3.37us)        16
#   nlp_grad_f  |        0 (       0) 130.00us (  7.65us)        17
#   nlp_hess_l  |        0 (       0) 211.00us ( 14.07us)        15
#    nlp_jac_g  |        0 (       0) 151.00us (  8.88us)        17
#        total  |  11.00ms ( 11.00ms)  10.29ms ( 10.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  70.00us (  4.37us)        16
#        nlp_g  |        0 (       0)  51.00us (  3.19us)        16
#   nlp_grad_f  |        0 (       0) 124.00us (  7.29us)        17
#   nlp_hess_l  |   1.00ms ( 66.67us) 210.00us ( 14.00us)        15
#    nlp_jac_g  |        0 (       0) 156.00us (  9.18us)        17
#        total  |   6.00ms (  6.00ms)   9.91ms (  9.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  75.00us (  4.41us)        17
#        nlp_g  |        0 (       0)  52.00us (  3.06us)        17
#   nlp_grad_f  |        0 (       0) 145.00us (  8.06us)        18
#   nlp_hess_l  |        0 (       0) 216.00us ( 13.50us)        16
#    nlp_jac_g  |        0 (       0) 157.00us (  8.72us)        18
#        total  |  14.00ms ( 14.00ms)  10.59ms ( 10.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  83.00us (  5.53us)        15
#        nlp_g  |        0 (       0)  63.00us (  4.20us)        15
#   nlp_grad_f  |        0 (       0) 121.00us (  7.56us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us) 235.00us ( 16.79us)        14
#    nlp_jac_g  |        0 (       0) 143.00us (  8.94us)        16
#        total  |  11.00ms ( 11.00ms)  10.60ms ( 10.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  56.00us (  4.31us)        13
#        nlp_g  |        0 (       0)  43.00us (  3.31us)        13
#   nlp_grad_f  |        0 (       0) 105.00us (  7.50us)        14
#   nlp_hess_l  |        0 (       0) 158.00us ( 13.17us)        12
#    nlp_jac_g  |   2.00ms (142.86us) 120.00us (  8.57us)        14
#        total  |   9.00ms (  9.00ms)   8.19ms (  8.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  71.00us (  4.18us)        17
#        nlp_g  |   1.00ms ( 58.82us)  53.00us (  3.12us)        17
#   nlp_grad_f  |        0 (       0) 136.00us (  7.56us)        18
#   nlp_hess_l  |        0 (       0) 209.00us ( 13.06us)        16
#    nlp_jac_g  |        0 (       0) 160.00us (  8.89us)        18
#        total  |  11.00ms ( 11.00ms)  10.53ms ( 10.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  73.00us (  4.87us)        15
#        nlp_g  |        0 (       0)  48.00us (  3.20us)        15
#   nlp_grad_f  |        0 (       0) 130.00us (  8.12us)        16
#   nlp_hess_l  |        0 (       0) 207.00us ( 14.79us)        14
#    nlp_jac_g  |        0 (       0) 143.00us (  8.94us)        16
#        total  |   9.00ms (  9.00ms)   9.55ms (  9.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  62.00us (  4.13us)        15
#        nlp_g  |        0 (       0)  46.00us (  3.07us)        15
#   nlp_grad_f  |        0 (       0) 113.00us (  7.06us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us) 190.00us ( 13.57us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us) 143.00us (  8.94us)        16
#        total  |  10.00ms ( 10.00ms)   9.39ms (  9.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  59.00us (  3.93us)        15
#        nlp_g  |        0 (       0)  45.00us (  3.00us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us) 117.00us (  7.31us)        16
#   nlp_hess_l  |        0 (       0) 179.00us ( 12.79us)        14
#    nlp_jac_g  |        0 (       0) 144.00us (  9.00us)        16
#        total  |  10.00ms ( 10.00ms)   9.31ms (  9.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  69.00us (  4.31us)        16
#        nlp_g  |        0 (       0)  54.00us (  3.37us)        16
#   nlp_grad_f  |        0 (       0) 160.00us (  9.41us)        17
#   nlp_hess_l  |        0 (       0) 210.00us ( 14.00us)        15
#    nlp_jac_g  |        0 (       0) 153.00us (  9.00us)        17
#        total  |  10.00ms ( 10.00ms)  10.21ms ( 10.21ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  65.00us (  4.33us)        15
#        nlp_g  |        0 (       0)  50.00us (  3.33us)        15
#   nlp_grad_f  |        0 (       0) 118.00us (  7.37us)        16
#   nlp_hess_l  |        0 (       0) 203.00us ( 14.50us)        14
#    nlp_jac_g  |        0 (       0) 142.00us (  8.87us)        16
#        total  |   9.00ms (  9.00ms)   9.54ms (  9.54ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  57.00us (  4.38us)        13
#        nlp_g  |        0 (       0)  44.00us (  3.38us)        13
#   nlp_grad_f  |        0 (       0) 105.00us (  7.50us)        14
#   nlp_hess_l  |   1.00ms ( 83.33us) 170.00us ( 14.17us)        12
#    nlp_jac_g  |        0 (       0) 127.00us (  9.07us)        14
#        total  |   9.00ms (  9.00ms)   8.39ms (  8.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  50.00us (  4.17us)        12
#        nlp_g  |        0 (       0)  35.00us (  2.92us)        12
#   nlp_grad_f  |        0 (       0)  99.00us (  7.62us)        13
#   nlp_hess_l  |        0 (       0) 159.00us ( 14.45us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us) 113.00us (  8.69us)        13
#        total  |   7.00ms (  7.00ms)   7.36ms (  7.36ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  52.00us (  4.73us)        11
#        nlp_g  |        0 (       0)  41.00us (  3.73us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us) 104.00us (  8.67us)        12
#   nlp_hess_l  |        0 (       0) 177.00us ( 17.70us)        10
#    nlp_jac_g  |        0 (       0) 106.00us (  8.83us)        12
#        total  |   5.00ms (  5.00ms)   7.66ms (  7.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  55.00us (  4.58us)        12
#        nlp_g  |        0 (       0)  41.00us (  3.42us)        12
#   nlp_grad_f  |        0 (       0)  93.00us (  7.15us)        13
#   nlp_hess_l  |        0 (       0) 146.00us ( 13.27us)        11
#    nlp_jac_g  |        0 (       0) 109.00us (  8.38us)        13
#        total  |   4.00ms (  4.00ms)   7.49ms (  7.49ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  46.00us (  4.18us)        11
#        nlp_g  |        0 (       0)  37.00us (  3.36us)        11
#   nlp_grad_f  |        0 (       0)  95.00us (  7.92us)        12
#   nlp_hess_l  |        0 (       0) 129.00us ( 12.90us)        10
#    nlp_jac_g  |        0 (       0) 103.00us (  8.58us)        12
#        total  |  17.00ms ( 17.00ms)   7.11ms (  7.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  44.00us (  4.89us)         9
#        nlp_g  |        0 (       0)  30.00us (  3.33us)         9
#   nlp_grad_f  |        0 (       0)  83.00us (  8.30us)        10
#   nlp_hess_l  |        0 (       0) 116.00us ( 14.50us)         8
#    nlp_jac_g  |        0 (       0)  98.00us (  9.80us)        10
#        total  |   1.00ms (  1.00ms)   5.74ms (  5.74ms)         1
# ステップ 28 でゴールに到達！
# イテレーション 4 の総コスト: 271.63
# GPR: 学習開始...
# GPR: 学習完了
