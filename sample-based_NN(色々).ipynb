# %% [markdown]
# 色々変える用

# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import torch
import torch.nn as nn
import torch.optim as optim
import time


import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)

# ==================================================================================
# シミュレーション全体の設定パラメータ
# ==================================================================================
N_ITERATIONS = 5
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE = np.array([10.0, 10.0])
N_MPC = 20
M_MPC = 35
OBSTACLE_INFO = {'pos': np.array([4.0, 2.0]), 'rad': 2.0}


# ----------------------------------------------------------------------------------
# TerminalCostNN & 学習関数
# ----------------------------------------------------------------------------------
class TerminalCostNN(nn.Module):
    def __init__(self, n_input):
        super(TerminalCostNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_input, 64), nn.ReLU(),
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.layers(x)

def train_terminal_cost_net(net, trajectory_data):
    if len(trajectory_data) < 10: return
    print("NN: 終端コストの学習開始...")
    optimizer = optim.Adam(net.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    states = torch.tensor(np.array([d[0] for d in trajectory_data]), dtype=torch.float32)
    costs_to_go = []
    running_cost = 0
    for _, stage_cost in reversed(trajectory_data):
        running_cost += stage_cost
        costs_to_go.append(running_cost)
    costs_to_go.reverse()
    labels = torch.tensor(costs_to_go, dtype=torch.float32).view(-1, 1)
    for epoch in range(100):
        optimizer.zero_grad(); outputs = net(states); loss = criterion(outputs, labels)
        loss.backward(); optimizer.step()
    print(f"NN: 学習完了。最終損失: {loss.item():.4f}")

class TrueVehicle:
    def __init__(self, dt=0.1): self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u; drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt; vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2; py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])
class GPRModel:
    def __init__(self, nx, nu, dt, obstacle_info):
        self.nx, self.nu = nx, nu
        self.dt=DT
        self.obstacle_info=OBSTACLE_INFO
        self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu))
        self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx

    def add_data(self, x, u, x_next):
        delta_real = (x_next - x) / self.dt
        delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])])
        self.Y_data = np.vstack([self.Y_data, error])

    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始...")
        for i in range(self.nx):
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100)
            self.models[i] = model
        self.is_trained = True
        print("GPR: 学習完了")

    def predict(self, x, u):
        if not self.is_trained:
            return np.zeros(self.nx), np.ones(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        variances = np.array([m.predict(xu)[1][0, 0] if m else 1.0 for m in self.models])
        return means, variances

# ----------------------------------------------------------------------------------
# MPCController
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, M, dt, obstacle_info):
        self.nx, self.nu, self.N, self.M, self.dt = nx, nu, N, M, dt
        self.obstacle_info = obstacle_info; self.u_prev_sol = np.zeros((nu, N))

    # NNをアドバイザーとして使う方式に変更
    def solve(self, x_current, gpr_model, x_goal, terminal_cost_net, is_first_iteration):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)

        # NNで「賢い目標地点」を大まかに探す 
        if is_first_iteration:
            # 最初のイテレーションではNNが未学習なので、ゴールをそのまま使う
            smart_target = x_goal
        else:
            # 現在位置から周辺のいくつかの候補点を生成
            num_candidates = 20
            candidates_pos = np.random.randn(num_candidates, 2) * 2.0 + x_current[:2]
            candidates_vel = np.zeros((num_candidates, 2))
            candidates = np.hstack([candidates_pos, candidates_vel])
            
            # NNで各候補点のコストを評価
            candidates_torch = torch.tensor(candidates, dtype=torch.float32)
            with torch.no_grad():
                costs = terminal_cost_net(candidates_torch).numpy().flatten()
            
            # 最もコストが低い候補点を「賢い目標地点」とする
            smart_target = candidates_pos[np.argmin(costs)]

        error_mean, error_var = gpr_model.predict(x_current, np.zeros(self.nu))
        error_std = np.sqrt(np.maximum(error_var, 1e-6)); error_std_capped = np.minimum(error_std, 0.2)
        error_samples = np.random.normal(loc=error_mean, scale=error_std_capped, size=(self.M, self.nx))
        
        all_scenario_costs = []
        for m in range(self.M):
            X_scenario = opti.variable(self.nx, self.N + 1); cost_scenario = 0
            opti.subject_to(X_scenario[:, 0] == x_current)
            for k in range(self.N):
                x_k, u_k = X_scenario[:, k], U[:, k]
                delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
                delta_pred = delta_nominal + error_samples[m, :]
                x_next_pred = x_k + delta_pred * self.dt
                opti.subject_to(X_scenario[:, k+1] == x_next_pred)
                cost_scenario += ca.sumsqr(x_k[:2] - x_goal) * self.dt + ca.sumsqr(u_k) * self.dt * 0.01
                if self.obstacle_info:
                    dist_to_obs = ca.norm_2(x_k[:2] - self.obstacle_info['pos'])
                    penalty = ca.fmax(0, self.obstacle_info['rad'] - dist_to_obs)
                    cost_scenario += 500.0 * penalty**2
            
            # MPCの終端コストとして、その「賢い目標地点」を目指す 
            terminal_state = X_scenario[:, self.N]
            cost_scenario += ca.sumsqr(terminal_state[:2] - smart_target) * 10.0

            all_scenario_costs.append(cost_scenario)
        
        #total_objective = ca.mean(ca.vertcat(*all_scenario_costs))
        total_objective = ca.sum1(ca.vertcat(*all_scenario_costs)) / len(all_scenario_costs)
        opti.minimize(total_objective)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))
        opti.set_initial(U, self.u_prev_sol)
        s_opts = {'print_level': 0}; opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}"); return np.zeros(self.nu)

# ----------------------------------------------------------------------------------
# Main Simulation Loop
# ----------------------------------------------------------------------------------
def main():
    vehicle = TrueVehicle(dt=DT)
    gpr_model = GPRModel(nx=NX, nu=NU,dt=DT, obstacle_info=OBSTACLE_INFO)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, M=M_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)
    terminal_cost_net = TerminalCostNN(n_input=NX)
    all_trajectories, final_costs = [], []
    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE); total_cost = 0
        iteration_data_for_gpr, iteration_data_for_cost_learning = [], []
        for step in range(SIM_STEPS):
            is_first_iter = (i == 0)
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE, terminal_cost_net, is_first_iter)
            x_next = vehicle.dynamics(current_x, u_optimal)
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data_for_gpr.append((current_x, u_optimal, x_next))
            iteration_data_for_cost_learning.append((current_x, stage_cost))
            current_x = x_next
            if np.linalg.norm(current_x[:2] - GOAL_STATE) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！"); break
        all_trajectories.append(np.array([d[0] for d in iteration_data_for_cost_learning]))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")
        for x, u, x_n in iteration_data_for_gpr:
            gpr_model.add_data(x, u, x_n)
        gpr_model.train()
        train_terminal_cost_net(terminal_cost_net, iteration_data_for_cost_learning)
    plt.figure(figsize=(10, 10))
    if OBSTACLE_INFO:
        obs_circle = plt.Circle(OBSTACLE_INFO['pos'], OBSTACLE_INFO['rad'], color='r', alpha=0.5, label='障害物')
        plt.gca().add_patch(obs_circle)
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE[0], GOAL_STATE[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡（NNアドバイザー方式）'); plt.legend(); plt.axis('equal'); plt.show()
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移'); plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト'); plt.xticks(range(1, N_ITERATIONS + 1)); plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (125.00us)   6.80ms (283.33us)        24
#        nlp_g  |   3.00ms (125.00us)   4.63ms (193.00us)        24
#   nlp_grad_f  |   2.00ms ( 80.00us)  10.12ms (404.96us)        25
#   nlp_hess_l  |  10.00ms (434.78us)  22.74ms (988.52us)        23
#    nlp_jac_g  |  20.00ms (800.00us)  11.70ms (467.96us)        25
#        total  | 334.00ms (334.00ms) 323.43ms (323.43ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (125.00us)  10.44ms (326.16us)        32
#        nlp_g  |  14.00ms (437.50us)   7.38ms (230.47us)        32
#   nlp_grad_f  |  19.00ms (575.76us)  15.89ms (481.55us)        33
#   nlp_hess_l  |  37.00ms (  1.19ms)  35.11ms (  1.13ms)        31
#    nlp_jac_g  |  17.00ms (515.15us)  17.69ms (536.09us)        33
#        total  | 383.00ms (383.00ms) 375.04ms (375.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  10.00ms (434.78us)   5.92ms (257.35us)        23
#        nlp_g  |   3.00ms (130.43us)   4.04ms (175.61us)        23
#   nlp_grad_f  |   7.00ms (291.67us)  10.22ms (425.67us)        24
#   nlp_hess_l  |  23.00ms (  1.05ms)  21.31ms (968.77us)        22
#    nlp_jac_g  |  13.00ms (541.67us)  11.01ms (458.79us)        24
#        total  | 249.00ms (249.00ms) 248.76ms (248.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   3.12ms (260.08us)        12
#        nlp_g  |   2.00ms (166.67us)   2.18ms (181.75us)        12
#   nlp_grad_f  |   8.00ms (615.38us)   5.69ms (438.00us)        13
#   nlp_hess_l  |  14.00ms (  1.27ms)  11.43ms (  1.04ms)        11
#    nlp_jac_g  |   5.00ms (384.62us)   6.11ms (469.69us)        13
#        total  | 133.00ms (133.00ms) 133.21ms (133.21ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  18.00ms (  1.20ms)   3.85ms (256.60us)        15
#        nlp_g  |        0 (       0)   2.48ms (165.20us)        15
#   nlp_grad_f  |   3.00ms (187.50us)   6.55ms (409.31us)        16
#   nlp_hess_l  |   7.00ms (500.00us)  13.74ms (981.43us)        14
#    nlp_jac_g  |  12.00ms (750.00us)   7.10ms (443.81us)        16
#        total  | 174.00ms (174.00ms) 167.84ms (167.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.23ms)   3.72ms (286.54us)        13
#        nlp_g  |        0 (       0)   2.75ms (211.23us)        13
#   nlp_grad_f  |  17.00ms (  1.21ms)   6.35ms (453.36us)        14
#   nlp_hess_l  |  17.00ms (  1.42ms)  12.54ms (  1.05ms)        12
#    nlp_jac_g  |   7.00ms (500.00us)   7.17ms (511.93us)        14
#        total  | 149.00ms (149.00ms) 149.83ms (149.83ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (187.50us)   4.81ms (300.75us)        16
#        nlp_g  |   1.00ms ( 62.50us)   3.17ms (198.25us)        16
#   nlp_grad_f  |   6.00ms (352.94us)   7.50ms (441.18us)        17
#   nlp_hess_l  |   8.00ms (533.33us)  15.70ms (  1.05ms)        15
#    nlp_jac_g  |   5.00ms (294.12us)   8.08ms (475.12us)        17
#        total  | 182.00ms (182.00ms) 181.15ms (181.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   3.22ms (292.45us)        11
#        nlp_g  |        0 (       0)   2.05ms (186.82us)        11
#   nlp_grad_f  |  16.00ms (  1.33ms)   4.95ms (412.50us)        12
#   nlp_hess_l  |   7.00ms (700.00us)  10.68ms (  1.07ms)        10
#    nlp_jac_g  |  11.00ms (916.67us)   5.44ms (453.33us)        12
#        total  | 126.00ms (126.00ms) 127.61ms (127.61ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   4.00ms (307.69us)        13
#        nlp_g  |   2.00ms (153.85us)   2.82ms (217.15us)        13
#   nlp_grad_f  |   4.00ms (285.71us)   6.51ms (465.29us)        14
#   nlp_hess_l  |   7.00ms (583.33us)  13.69ms (  1.14ms)        12
#    nlp_jac_g  |  11.00ms (785.71us)   6.78ms (484.50us)        14
#        total  | 178.00ms (178.00ms) 173.09ms (173.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (142.86us)   3.75ms (268.00us)        14
#        nlp_g  |  15.00ms (  1.07ms)   2.62ms (187.14us)        14
#   nlp_grad_f  |   3.00ms (200.00us)   7.07ms (471.27us)        15
#   nlp_hess_l  |   4.00ms (307.69us)  14.12ms (  1.09ms)        13
#    nlp_jac_g  |   2.00ms (133.33us)   7.75ms (516.60us)        15
#        total  | 164.00ms (164.00ms) 159.13ms (159.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.25ms (250.00us)        13
#        nlp_g  |  16.00ms (  1.23ms)   2.22ms (171.08us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   5.90ms (421.64us)        14
#   nlp_hess_l  |  17.00ms (  1.42ms)  11.95ms (995.83us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   6.43ms (459.64us)        14
#        total  | 148.00ms (148.00ms) 143.29ms (143.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   3.51ms (269.85us)        13
#        nlp_g  |   1.00ms ( 76.92us)   2.51ms (193.23us)        13
#   nlp_grad_f  |  10.00ms (714.29us)   6.29ms (449.21us)        14
#   nlp_hess_l  |   4.00ms (333.33us)  12.14ms (  1.01ms)        12
#    nlp_jac_g  |   7.00ms (500.00us)   6.82ms (487.36us)        14
#        total  | 153.00ms (153.00ms) 153.55ms (153.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   3.36ms (258.77us)        13
#        nlp_g  |   4.00ms (307.69us)   2.33ms (179.15us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   5.86ms (418.86us)        14
#   nlp_hess_l  |  13.00ms (  1.08ms)  11.77ms (981.08us)        12
#    nlp_jac_g  |   9.00ms (642.86us)   6.52ms (465.57us)        14
#        total  | 147.00ms (147.00ms) 147.04ms (147.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   3.36ms (280.33us)        12
#        nlp_g  |   1.00ms ( 83.33us)   2.28ms (190.25us)        12
#   nlp_grad_f  |   5.00ms (384.62us)   6.08ms (467.85us)        13
#   nlp_hess_l  |  25.00ms (  2.27ms)  11.93ms (  1.08ms)        11
#    nlp_jac_g  |   3.00ms (230.77us)   6.41ms (492.85us)        13
#        total  | 144.00ms (144.00ms) 143.73ms (143.73ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   3.25ms (271.17us)        12
#        nlp_g  |   2.00ms (166.67us)   2.35ms (195.75us)        12
#   nlp_grad_f  |   9.00ms (692.31us)   6.12ms (471.00us)        13
#   nlp_hess_l  |  13.00ms (  1.18ms)  11.90ms (  1.08ms)        11
#    nlp_jac_g  |   3.00ms (230.77us)   6.80ms (523.08us)        13
#        total  | 139.00ms (139.00ms) 138.16ms (138.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (142.86us)   3.39ms (242.14us)        14
#        nlp_g  |   1.00ms ( 71.43us)   2.42ms (173.21us)        14
#   nlp_grad_f  |   6.00ms (400.00us)   6.55ms (436.87us)        15
#   nlp_hess_l  |   7.00ms (538.46us)  12.86ms (988.92us)        13
#    nlp_jac_g  |   8.00ms (533.33us)   7.04ms (469.27us)        15
#        total  | 149.00ms (149.00ms) 154.19ms (154.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  14.00ms (  1.17ms)   3.63ms (302.33us)        12
#        nlp_g  |        0 (       0)   2.46ms (205.25us)        12
#   nlp_grad_f  |   1.00ms ( 76.92us)   6.71ms (516.38us)        13
#   nlp_hess_l  |   3.00ms (272.73us)  12.11ms (  1.10ms)        11
#    nlp_jac_g  |  18.00ms (  1.38ms)   7.25ms (557.38us)        13
#        total  | 133.00ms (133.00ms) 146.68ms (146.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.02ms (286.86us)        14
#        nlp_g  |   1.00ms ( 71.43us)   2.82ms (201.50us)        14
#   nlp_grad_f  |        0 (       0)   7.30ms (486.80us)        15
#   nlp_hess_l  |  15.00ms (  1.15ms)  13.98ms (  1.08ms)        13
#    nlp_jac_g  |  14.00ms (933.33us)   7.93ms (528.53us)        15
#        total  | 181.00ms (181.00ms) 181.00ms (181.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.09ms (237.54us)        13
#        nlp_g  |        0 (       0)   2.12ms (162.85us)        13
#   nlp_grad_f  |  15.00ms (  1.07ms)   5.58ms (398.57us)        14
#   nlp_hess_l  |  30.00ms (  2.50ms)  11.13ms (927.33us)        12
#    nlp_jac_g  |        0 (       0)   6.01ms (429.64us)        14
#        total  | 150.00ms (150.00ms) 151.96ms (151.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.98ms (265.60us)        15
#        nlp_g  |  17.00ms (  1.13ms)   2.84ms (189.13us)        15
#   nlp_grad_f  |   4.00ms (250.00us)   7.36ms (460.19us)        16
#   nlp_hess_l  |   8.00ms (571.43us)  15.23ms (  1.09ms)        14
#    nlp_jac_g  |   9.00ms (562.50us)   8.43ms (527.00us)        16
#        total  | 189.00ms (189.00ms) 181.71ms (181.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.08ms (280.18us)        11
#        nlp_g  |        0 (       0)   2.06ms (187.73us)        11
#   nlp_grad_f  |   4.00ms (333.33us)   5.48ms (456.92us)        12
#   nlp_hess_l  |   3.00ms (300.00us)  11.54ms (  1.15ms)        10
#    nlp_jac_g  |  19.00ms (  1.58ms)   6.37ms (530.67us)        12
#        total  | 145.00ms (145.00ms) 136.32ms (136.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   3.36ms (258.31us)        13
#        nlp_g  |   1.00ms ( 76.92us)   2.50ms (192.08us)        13
#   nlp_grad_f  |   4.00ms (285.71us)   6.39ms (456.50us)        14
#   nlp_hess_l  |   8.00ms (666.67us)  12.08ms (  1.01ms)        12
#    nlp_jac_g  |   6.00ms (428.57us)   6.94ms (495.57us)        14
#        total  | 158.00ms (158.00ms) 157.79ms (157.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.19ms (299.57us)        14
#        nlp_g  |        0 (       0)   2.91ms (207.93us)        14
#   nlp_grad_f  |  15.00ms (  1.00ms)   7.50ms (499.87us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)  14.02ms (  1.08ms)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   7.99ms (532.93us)        15
#        total  | 184.00ms (184.00ms) 176.75ms (176.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  31.00ms (  2.21ms)   3.72ms (265.57us)        14
#        nlp_g  |  15.00ms (  1.07ms)   2.81ms (200.93us)        14
#   nlp_grad_f  |  16.00ms (  1.07ms)   6.46ms (430.93us)        15
#   nlp_hess_l  |  16.00ms (  1.23ms)  12.48ms (959.69us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   6.73ms (448.47us)        15
#        total  | 150.00ms (150.00ms) 161.54ms (161.54ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.07ms (362.07us)        14
#        nlp_g  |   1.00ms ( 71.43us)   3.52ms (251.43us)        14
#   nlp_grad_f  |        0 (       0)   8.64ms (576.20us)        15
#   nlp_hess_l  |  16.00ms (  1.23ms)  15.75ms (  1.21ms)        13
#    nlp_jac_g  |        0 (       0)   9.00ms (599.73us)        15
#        total  | 200.00ms (200.00ms) 196.45ms (196.45ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   3.72ms (266.00us)        14
#        nlp_g  |   7.00ms (500.00us)   2.69ms (191.86us)        14
#   nlp_grad_f  |   6.00ms (461.54us)   5.84ms (449.15us)        13
#   nlp_hess_l  |  13.00ms (  1.18ms)  12.14ms (  1.10ms)        11
#    nlp_jac_g  |   5.00ms (384.62us)   6.54ms (503.31us)        13
#        total  | 145.00ms (145.00ms) 145.22ms (145.22ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.90ms (362.37us)         8
#        nlp_g  |        0 (       0)   2.05ms (256.75us)         8
#   nlp_grad_f  |   1.00ms (111.11us)   5.60ms (622.00us)         9
#   nlp_hess_l  |  16.00ms (  2.29ms)   8.64ms (  1.23ms)         7
#    nlp_jac_g  |  15.00ms (  1.67ms)   5.37ms (596.33us)         9
#        total  | 102.00ms (102.00ms) 107.93ms (107.93ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.31ms (330.00us)         7
#        nlp_g  |        0 (       0)   1.56ms (223.14us)         7
#   nlp_grad_f  |   1.00ms (125.00us)   4.57ms (571.87us)         8
#   nlp_hess_l  |   2.00ms (333.33us)   7.88ms (  1.31ms)         6
#    nlp_jac_g  |        0 (       0)   4.85ms (606.37us)         8
#        total  |  99.00ms ( 99.00ms)  96.56ms ( 96.56ms)         1
# ステップ 28 でゴールに到達！
# イテレーション 1 の総コスト: 258.80
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 9654.7139
#
# ==================================================
# 反復学習: イテレーション 2/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 80.00us)   7.70ms (308.08us)        25
#        nlp_g  |   1.00ms ( 40.00us)   5.41ms (216.28us)        25
#   nlp_grad_f  |  27.00ms (  1.04ms)  13.47ms (518.27us)        26
#   nlp_hess_l  |  12.00ms (500.00us)  26.62ms (  1.11ms)        24
#    nlp_jac_g  |   6.00ms (230.77us)  14.60ms (561.42us)        26
#        total  | 398.00ms (398.00ms) 392.85ms (392.85ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 37.04us)   8.62ms (319.37us)        27
#        nlp_g  |        0 (       0)   5.60ms (207.52us)        27
#   nlp_grad_f  |  17.00ms (653.85us)  12.97ms (498.92us)        26
#   nlp_hess_l  |  33.00ms (  1.37ms)  24.41ms (  1.02ms)        24
#    nlp_jac_g  |   2.00ms ( 76.92us)  13.69ms (526.62us)        26
#        total  | 331.00ms (331.00ms) 332.52ms (332.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   5.00ms (385.00us)        13
#        nlp_g  |        0 (       0)   3.47ms (267.00us)        13
#   nlp_grad_f  |        0 (       0)   9.22ms (658.43us)        14
#   nlp_hess_l  |   3.00ms (250.00us)  15.61ms (  1.30ms)        12
#    nlp_jac_g  |  31.00ms (  2.21ms)   9.21ms (657.50us)        14
#        total  | 200.00ms (200.00ms) 212.23ms (212.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (212.12us)  11.47ms (347.48us)        33
#        nlp_g  |   1.00ms ( 30.30us)   7.61ms (230.55us)        33
#   nlp_grad_f  |  15.00ms (441.18us)  17.61ms (517.85us)        34
#   nlp_hess_l  |  38.00ms (  1.19ms)  35.29ms (  1.10ms)        32
#    nlp_jac_g  |  15.00ms (441.18us)  18.53ms (545.12us)        34
#        total  | 533.00ms (533.00ms) 530.00ms (530.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   9.00ms (236.84us)  11.36ms (298.87us)        38
#        nlp_g  |   8.00ms (210.53us)   7.87ms (207.00us)        38
#   nlp_grad_f  |  15.00ms (416.67us)  16.33ms (453.61us)        36
#   nlp_hess_l  |  35.00ms (  1.03ms)  35.36ms (  1.04ms)        34
#    nlp_jac_g  |  19.00ms (527.78us)  17.73ms (492.42us)        36
#        total  | 506.00ms (506.00ms) 505.98ms (505.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (200.00us)   7.06ms (282.28us)        25
#        nlp_g  |   4.00ms (160.00us)   5.05ms (201.84us)        25
#   nlp_grad_f  |  11.00ms (423.08us)  11.95ms (459.81us)        26
#   nlp_hess_l  |  28.00ms (  1.17ms)  25.64ms (  1.07ms)        24
#    nlp_jac_g  |   9.00ms (346.15us)  13.02ms (500.65us)        26
#        total  | 350.00ms (350.00ms) 356.55ms (356.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  10.00ms (434.78us)   8.36ms (363.39us)        23
#        nlp_g  |   4.00ms (173.91us)   5.86ms (254.78us)        23
#   nlp_grad_f  |  14.00ms (583.33us)  13.43ms (559.42us)        24
#   nlp_hess_l  |  27.00ms (  1.23ms)  26.23ms (  1.19ms)        22
#    nlp_jac_g  |  11.00ms (458.33us)  14.09ms (587.12us)        24
#        total  | 350.00ms (350.00ms) 350.12ms (350.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (137.93us)   8.90ms (306.79us)        29
#        nlp_g  |   3.00ms (103.45us)   6.18ms (213.24us)        29
#   nlp_grad_f  |   5.00ms (166.67us)  14.19ms (473.00us)        30
#   nlp_hess_l  |  74.00ms (  2.64ms)  28.70ms (  1.02ms)        28
#    nlp_jac_g  |  37.00ms (  1.23ms)  14.89ms (496.30us)        30
#        total  | 445.00ms (445.00ms) 438.29ms (438.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (285.71us)   4.60ms (328.79us)        14
#        nlp_g  |   4.00ms (285.71us)   2.92ms (208.79us)        14
#   nlp_grad_f  |   6.00ms (400.00us)   6.72ms (448.20us)        15
#   nlp_hess_l  |  13.00ms (  1.00ms)  14.27ms (  1.10ms)        13
#    nlp_jac_g  |  10.00ms (666.67us)   7.47ms (498.33us)        15
#        total  | 192.00ms (192.00ms) 192.65ms (192.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   8.00ms (347.83us)   6.57ms (285.83us)        23
#        nlp_g  |   4.00ms (173.91us)   4.37ms (189.91us)        23
#   nlp_grad_f  |   7.00ms (350.00us)  10.24ms (512.00us)        20
#   nlp_hess_l  |  17.00ms (944.44us)  19.67ms (  1.09ms)        18
#    nlp_jac_g  |   9.00ms (450.00us)  10.87ms (543.65us)        20
#        total  | 284.00ms (284.00ms) 280.02ms (280.02ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (235.29us)   4.87ms (286.65us)        17
#        nlp_g  |   3.00ms (176.47us)   3.35ms (197.35us)        17
#   nlp_grad_f  |   9.00ms (500.00us)   7.95ms (441.44us)        18
#   nlp_hess_l  |  14.00ms (875.00us)  16.28ms (  1.02ms)        16
#    nlp_jac_g  |   8.00ms (444.44us)   8.83ms (490.72us)        18
#        total  | 256.00ms (256.00ms) 256.63ms (256.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 52.63us)   4.93ms (259.26us)        19
#        nlp_g  |        0 (       0)   3.43ms (180.42us)        19
#   nlp_grad_f  |   2.00ms (100.00us)   9.16ms (458.05us)        20
#   nlp_hess_l  |  17.00ms (944.44us)  19.07ms (  1.06ms)        18
#    nlp_jac_g  |  18.00ms (900.00us)   9.98ms (498.95us)        20
#        total  | 283.00ms (283.00ms) 276.87ms (276.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (548.39us)  10.80ms (348.39us)        31
#        nlp_g  |        0 (       0)   7.42ms (239.29us)        31
#   nlp_grad_f  |  19.00ms (593.75us)  18.44ms (576.28us)        32
#   nlp_hess_l  |  73.00ms (  2.43ms)  37.17ms (  1.24ms)        30
#    nlp_jac_g  |  22.00ms (687.50us)  19.25ms (601.47us)        32
#        total  | 514.00ms (514.00ms) 504.71ms (504.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (447.37us)  10.91ms (287.05us)        38
#        nlp_g  |        0 (       0)   7.36ms (193.68us)        38
#   nlp_grad_f  |  16.00ms (410.26us)  17.23ms (441.87us)        39
#   nlp_hess_l  |  63.00ms (  1.70ms)  36.74ms (992.95us)        37
#    nlp_jac_g  |   2.00ms ( 51.28us)  18.78ms (481.67us)        39
#        total  | 517.00ms (517.00ms) 529.28ms (529.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (111.11us)   7.79ms (288.67us)        27
#        nlp_g  |        0 (       0)   5.47ms (202.56us)        27
#   nlp_grad_f  |  23.00ms (821.43us)  12.51ms (446.64us)        28
#   nlp_hess_l  |   3.00ms (115.38us)  26.85ms (  1.03ms)        26
#    nlp_jac_g  |  24.00ms (857.14us)  13.55ms (484.04us)        28
#        total  | 400.00ms (400.00ms) 388.89ms (388.89ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  18.00ms (391.30us)  14.31ms (311.13us)        46
#        nlp_g  |   9.00ms (195.65us)  10.00ms (217.39us)        46
#   nlp_grad_f  |  41.00ms (872.34us)  22.99ms (489.06us)        47
#   nlp_hess_l  |  47.00ms (  1.04ms)  45.29ms (  1.01ms)        45
#    nlp_jac_g  |   5.00ms (106.38us)  22.73ms (483.68us)        47
#        total  | 778.00ms (778.00ms) 777.57ms (777.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  37.00ms (740.00us)  12.45ms (249.10us)        50
#        nlp_g  |  27.00ms (540.00us)   9.36ms (187.16us)        50
#   nlp_grad_f  |  18.00ms (352.94us)  20.34ms (398.90us)        51
#   nlp_hess_l  |  25.00ms (510.20us)  45.93ms (937.39us)        49
#    nlp_jac_g  |  38.00ms (745.10us)  22.12ms (433.73us)        51
#        total  | 800.00ms (800.00ms) 795.88ms (795.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.96ms (282.57us)        14
#        nlp_g  |   1.00ms ( 71.43us)   2.93ms (209.64us)        14
#   nlp_grad_f  |        0 (       0)   7.12ms (474.40us)        15
#   nlp_hess_l  |  15.00ms (  1.15ms)  13.70ms (  1.05ms)        13
#    nlp_jac_g  |  19.00ms (  1.27ms)   8.04ms (535.93us)        15
#        total  | 183.00ms (183.00ms) 171.40ms (171.40ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (800.00us)   6.41ms (320.55us)        20
#        nlp_g  |  15.00ms (750.00us)   4.39ms (219.50us)        20
#   nlp_grad_f  |   2.00ms ( 95.24us)  11.19ms (533.00us)        21
#   nlp_hess_l  |  28.00ms (  1.47ms)  20.59ms (  1.08ms)        19
#    nlp_jac_g  |   3.00ms (142.86us)  11.44ms (544.95us)        21
#        total  | 285.00ms (285.00ms) 293.96ms (293.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (125.00us)   5.17ms (322.94us)        16
#        nlp_g  |        0 (       0)   3.41ms (213.25us)        16
#   nlp_grad_f  |        0 (       0)   8.97ms (527.82us)        17
#   nlp_hess_l  |   1.00ms ( 66.67us)  16.79ms (  1.12ms)        15
#    nlp_jac_g  |  18.00ms (  1.06ms)   8.80ms (517.71us)        17
#        total  | 217.00ms (217.00ms) 215.76ms (215.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.67ms (291.87us)        16
#        nlp_g  |   1.00ms ( 62.50us)   3.41ms (213.44us)        16
#   nlp_grad_f  |   2.00ms (117.65us)   8.47ms (498.06us)        17
#   nlp_hess_l  |  16.00ms (  1.07ms)  16.77ms (  1.12ms)        15
#    nlp_jac_g  |        0 (       0)   9.32ms (548.53us)        17
#        total  | 209.00ms (209.00ms) 211.23ms (211.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.83ms (273.79us)        14
#        nlp_g  |        0 (       0)   2.73ms (194.86us)        14
#   nlp_grad_f  |  14.00ms (933.33us)   6.96ms (464.33us)        15
#   nlp_hess_l  |  19.00ms (  1.46ms)  13.41ms (  1.03ms)        13
#    nlp_jac_g  |  10.00ms (666.67us)   7.60ms (506.87us)        15
#        total  | 177.00ms (177.00ms) 176.23ms (176.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (133.33us)   4.81ms (320.93us)        15
#        nlp_g  |        0 (       0)   3.27ms (218.20us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   8.04ms (502.81us)        16
#   nlp_hess_l  |  28.00ms (  2.00ms)  15.55ms (  1.11ms)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   8.32ms (520.19us)        16
#        total  | 187.00ms (187.00ms) 199.84ms (199.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.45ms (287.42us)        12
#        nlp_g  |  16.00ms (  1.33ms)   2.41ms (200.92us)        12
#   nlp_grad_f  |   3.00ms (230.77us)   6.31ms (485.77us)        13
#   nlp_hess_l  |  19.00ms (  1.73ms)  12.36ms (  1.12ms)        11
#    nlp_jac_g  |  15.00ms (  1.15ms)   6.94ms (534.23us)        13
#        total  | 152.00ms (152.00ms) 153.41ms (153.41ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.35ms (257.38us)        13
#        nlp_g  |   2.00ms (153.85us)   2.36ms (181.23us)        13
#   nlp_grad_f  |   5.00ms (357.14us)   5.95ms (424.79us)        14
#   nlp_hess_l  |   7.00ms (583.33us)  11.55ms (962.58us)        12
#    nlp_jac_g  |  20.00ms (  1.43ms)   6.73ms (480.50us)        14
#        total  | 155.00ms (155.00ms) 154.75ms (154.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.80ms (292.23us)        13
#        nlp_g  |   2.00ms (153.85us)   2.55ms (196.15us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   6.74ms (481.57us)        14
#   nlp_hess_l  |   4.00ms (333.33us)  13.84ms (  1.15ms)        12
#    nlp_jac_g  |  17.00ms (  1.21ms)   7.52ms (537.36us)        14
#        total  | 164.00ms (164.00ms) 163.74ms (163.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (200.00us)   4.43ms (295.60us)        15
#        nlp_g  |   1.00ms ( 66.67us)   3.06ms (203.73us)        15
#   nlp_grad_f  |   4.00ms (250.00us)   8.51ms (532.06us)        16
#   nlp_hess_l  |  22.00ms (  1.57ms)  15.76ms (  1.13ms)        14
#    nlp_jac_g  |   5.00ms (312.50us)   8.60ms (537.81us)        16
#        total  | 186.00ms (186.00ms) 194.34ms (194.34ms)         1
# ステップ 27 でゴールに到達！
# イテレーション 2 の総コスト: 251.41
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 5568.6533
#
# ==================================================
# 反復学習: イテレーション 3/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   7.22ms (277.73us)        26
#        nlp_g  |  33.00ms (  1.27ms)   4.90ms (188.54us)        26
#   nlp_grad_f  |   1.00ms ( 45.45us)  10.57ms (480.68us)        22
#   nlp_hess_l  |  17.00ms (850.00us)  20.38ms (  1.02ms)        20
#    nlp_jac_g  |        0 (       0)  11.24ms (511.00us)        22
#        total  | 272.00ms (272.00ms) 275.32ms (275.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (259.26us)   8.40ms (311.19us)        27
#        nlp_g  |   8.00ms (296.30us)   5.85ms (216.78us)        27
#   nlp_grad_f  |  11.00ms (392.86us)  13.37ms (477.50us)        28
#   nlp_hess_l  |  25.00ms (961.54us)  27.75ms (  1.07ms)        26
#    nlp_jac_g  |  14.00ms (500.00us)  14.46ms (516.54us)        28
#        total  | 398.00ms (398.00ms) 388.15ms (388.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  23.00ms (793.10us)   9.26ms (319.17us)        29
#        nlp_g  |   3.00ms (103.45us)   6.37ms (219.55us)        29
#   nlp_grad_f  |   8.00ms (285.71us)  13.76ms (491.50us)        28
#   nlp_hess_l  |  25.00ms (961.54us)  29.43ms (  1.13ms)        26
#    nlp_jac_g  |  33.00ms (  1.18ms)  15.29ms (546.25us)        28
#        total  | 488.00ms (488.00ms) 474.39ms (474.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.51ms (346.69us)        13
#        nlp_g  |        0 (       0)   3.07ms (235.92us)        13
#   nlp_grad_f  |   6.00ms (428.57us)   7.35ms (524.93us)        14
#   nlp_hess_l  |   6.00ms (500.00us)  14.56ms (  1.21ms)        12
#    nlp_jac_g  |        0 (       0)   7.79ms (556.21us)        14
#        total  | 200.00ms (200.00ms) 197.76ms (197.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.77ms (238.30us)        20
#        nlp_g  |        0 (       0)   3.26ms (163.15us)        20
#   nlp_grad_f  |  18.00ms (947.37us)   8.19ms (430.89us)        19
#   nlp_hess_l  |   2.00ms (117.65us)  16.36ms (962.24us)        17
#    nlp_jac_g  |   1.00ms ( 52.63us)   8.68ms (456.74us)        19
#        total  | 201.00ms (201.00ms) 213.18ms (213.18ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (266.67us)   4.11ms (274.33us)        15
#        nlp_g  |   6.00ms (400.00us)   2.97ms (198.13us)        15
#   nlp_grad_f  |   6.00ms (375.00us)   7.23ms (452.00us)        16
#   nlp_hess_l  |  15.00ms (  1.07ms)  14.42ms (  1.03ms)        14
#    nlp_jac_g  |   8.00ms (500.00us)   8.15ms (509.69us)        16
#        total  | 172.00ms (172.00ms) 172.77ms (172.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (210.53us)   5.08ms (267.53us)        19
#        nlp_g  |   2.00ms (105.26us)   3.38ms (177.84us)        19
#   nlp_grad_f  |   3.00ms (150.00us)   8.61ms (430.45us)        20
#   nlp_hess_l  |  23.00ms (  1.28ms)  18.08ms (  1.00ms)        18
#    nlp_jac_g  |   4.00ms (200.00us)   9.03ms (451.50us)        20
#        total  | 272.00ms (272.00ms) 282.33ms (282.33ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (  1.42ms)   4.47ms (372.17us)        12
#        nlp_g  |   6.00ms (500.00us)   3.32ms (276.67us)        12
#   nlp_grad_f  |   5.00ms (384.62us)   6.99ms (537.69us)        13
#   nlp_hess_l  |  20.00ms (  1.82ms)  14.31ms (  1.30ms)        11
#    nlp_jac_g  |   3.00ms (230.77us)   7.64ms (588.00us)        13
#        total  | 158.00ms (158.00ms) 157.82ms (157.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.64ms (273.24us)        17
#        nlp_g  |        0 (       0)   3.17ms (186.47us)        17
#   nlp_grad_f  |  18.00ms (  1.00ms)   8.28ms (460.28us)        18
#   nlp_hess_l  |  27.00ms (  1.69ms)  16.52ms (  1.03ms)        16
#    nlp_jac_g  |  37.00ms (  2.06ms)   8.82ms (490.06us)        18
#        total  | 193.00ms (193.00ms) 204.57ms (204.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.52ms (251.80us)        10
#        nlp_g  |        0 (       0)   1.70ms (169.70us)        10
#   nlp_grad_f  |  15.00ms (  1.36ms)   4.31ms (392.09us)        11
#   nlp_hess_l  |  11.00ms (  1.22ms)   8.75ms (972.11us)         9
#    nlp_jac_g  |   2.00ms (181.82us)   5.15ms (468.45us)        11
#        total  | 134.00ms (134.00ms) 124.65ms (124.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (200.00us)   3.11ms (310.80us)        10
#        nlp_g  |   9.00ms (900.00us)   1.87ms (186.90us)        10
#   nlp_grad_f  |   1.00ms ( 90.91us)   5.01ms (455.55us)        11
#   nlp_hess_l  |  12.00ms (  1.33ms)  10.65ms (  1.18ms)         9
#    nlp_jac_g  |   8.00ms (727.27us)   5.61ms (509.73us)        11
#        total  | 132.00ms (132.00ms) 125.91ms (125.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   7.48ms (311.83us)        24
#        nlp_g  |   3.00ms (125.00us)   4.72ms (196.83us)        24
#   nlp_grad_f  |  35.00ms (  1.40ms)  11.72ms (468.96us)        25
#   nlp_hess_l  |   9.00ms (391.30us)  25.47ms (  1.11ms)        23
#    nlp_jac_g  |  11.00ms (440.00us)  12.64ms (505.64us)        25
#        total  | 351.00ms (351.00ms) 347.21ms (347.21ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms (111.11us)   2.30ms (255.33us)         9
#        nlp_g  |        0 (       0)   1.64ms (182.11us)         9
#   nlp_grad_f  |   2.00ms (200.00us)   4.40ms (440.00us)        10
#   nlp_hess_l  |        0 (       0)   7.42ms (927.75us)         8
#    nlp_jac_g  |   1.00ms (100.00us)   4.85ms (485.20us)        10
#        total  |  98.00ms ( 98.00ms) 107.76ms (107.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.76ms (275.60us)        10
#        nlp_g  |   1.00ms (100.00us)   1.72ms (171.90us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   4.53ms (411.91us)        11
#   nlp_hess_l  |        0 (       0)  10.06ms (  1.12ms)         9
#    nlp_jac_g  |   1.00ms ( 90.91us)   4.95ms (450.36us)        11
#        total  | 132.00ms (132.00ms) 121.63ms (121.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   4.87ms (374.31us)        13
#        nlp_g  |   2.00ms (153.85us)   3.00ms (231.08us)        13
#   nlp_grad_f  |  12.00ms (857.14us)   6.95ms (496.50us)        14
#   nlp_hess_l  |   2.00ms (166.67us)  13.93ms (  1.16ms)        12
#    nlp_jac_g  |   4.00ms (285.71us)   7.33ms (523.86us)        14
#        total  | 165.00ms (165.00ms) 167.34ms (167.34ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.60ms (240.00us)        15
#        nlp_g  |        0 (       0)   2.37ms (158.27us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   6.46ms (404.06us)        16
#   nlp_hess_l  |  17.00ms (  1.21ms)  13.50ms (964.36us)        14
#    nlp_jac_g  |   1.00ms ( 62.50us)   6.94ms (433.81us)        16
#        total  | 168.00ms (168.00ms) 178.82ms (178.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  33.00ms (  1.00ms)   8.88ms (269.21us)        33
#        nlp_g  |   1.00ms ( 30.30us)   6.47ms (196.00us)        33
#   nlp_grad_f  |   4.00ms (117.65us)  14.21ms (418.09us)        34
#   nlp_hess_l  |  21.00ms (656.25us)  30.17ms (942.97us)        32
#    nlp_jac_g  |   4.00ms (117.65us)  15.32ms (450.68us)        34
#        total  | 483.00ms (483.00ms) 472.74ms (472.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 50.00us)  10.86ms (271.62us)        40
#        nlp_g  |   1.00ms ( 25.00us)   7.54ms (188.57us)        40
#   nlp_grad_f  |   5.00ms (121.95us)  17.26ms (421.02us)        41
#   nlp_hess_l  |   9.00ms (230.77us)  37.00ms (948.72us)        39
#    nlp_jac_g  |  23.00ms (560.98us)  18.71ms (456.44us)        41
#        total  | 610.00ms (610.00ms) 599.12ms (599.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.52ms (271.00us)        13
#        nlp_g  |        0 (       0)   2.57ms (197.54us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   6.45ms (461.07us)        14
#   nlp_hess_l  |        0 (       0)  11.05ms (920.75us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   7.07ms (504.71us)        14
#        total  | 158.00ms (158.00ms) 154.98ms (154.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 86.96us)   6.41ms (278.52us)        23
#        nlp_g  |   1.00ms ( 43.48us)   4.58ms (199.35us)        23
#   nlp_grad_f  |   6.00ms (250.00us)  10.51ms (437.75us)        24
#   nlp_hess_l  |  23.00ms (  1.05ms)  20.27ms (921.23us)        22
#    nlp_jac_g  |   3.00ms (125.00us)  11.04ms (459.87us)        24
#        total  | 332.00ms (332.00ms) 326.93ms (326.93ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.42ms (294.73us)        15
#        nlp_g  |        0 (       0)   3.47ms (231.60us)        15
#   nlp_grad_f  |        0 (       0)   8.33ms (520.87us)        16
#   nlp_hess_l  |  16.00ms (  1.14ms)  14.83ms (  1.06ms)        14
#    nlp_jac_g  |  16.00ms (  1.00ms)   8.54ms (533.94us)        16
#        total  | 185.00ms (185.00ms) 188.77ms (188.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.47ms (322.06us)        17
#        nlp_g  |        0 (       0)   3.72ms (219.06us)        17
#   nlp_grad_f  |        0 (       0)   9.29ms (516.11us)        18
#   nlp_hess_l  |  16.00ms (  1.00ms)  19.90ms (  1.24ms)        16
#    nlp_jac_g  |        0 (       0)  10.35ms (574.83us)        18
#        total  | 217.00ms (217.00ms) 214.66ms (214.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 90.91us)   7.45ms (338.68us)        22
#        nlp_g  |        0 (       0)   5.22ms (237.27us)        22
#   nlp_grad_f  |   1.00ms ( 43.48us)  13.12ms (570.35us)        23
#   nlp_hess_l  |  20.00ms (952.38us)  26.38ms (  1.26ms)        21
#    nlp_jac_g  |  16.00ms (695.65us)  13.95ms (606.48us)        23
#        total  | 330.00ms (330.00ms) 321.98ms (321.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   3.97ms (305.69us)        13
#        nlp_g  |  19.00ms (  1.46ms)   2.85ms (219.54us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   6.81ms (486.79us)        14
#   nlp_hess_l  |   4.00ms (333.33us)  12.69ms (  1.06ms)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   7.45ms (532.36us)        14
#        total  | 165.00ms (165.00ms) 164.09ms (164.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   4.55ms (349.92us)        13
#        nlp_g  |        0 (       0)   3.09ms (237.85us)        13
#   nlp_grad_f  |  33.00ms (  2.36ms)   7.71ms (550.43us)        14
#   nlp_hess_l  |  18.00ms (  1.50ms)  14.12ms (  1.18ms)        12
#    nlp_jac_g  |   2.00ms (142.86us)   7.63ms (544.71us)        14
#        total  | 170.00ms (170.00ms) 169.63ms (169.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.14ms)   4.68ms (334.57us)        14
#        nlp_g  |        0 (       0)   3.09ms (220.79us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   8.46ms (564.13us)        15
#   nlp_hess_l  |  15.00ms (  1.15ms)  16.93ms (  1.30ms)        13
#    nlp_jac_g  |  10.00ms (666.67us)   8.72ms (581.07us)        15
#        total  | 206.00ms (206.00ms) 199.92ms (199.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   3.53ms (252.43us)        14
#        nlp_g  |   2.00ms (142.86us)   2.46ms (175.57us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   6.12ms (408.20us)        15
#   nlp_hess_l  |   4.00ms (307.69us)  12.47ms (959.23us)        13
#    nlp_jac_g  |   8.00ms (533.33us)   6.89ms (459.07us)        15
#        total  | 159.00ms (159.00ms) 158.71ms (158.71ms)         1
# ステップ 27 でゴールに到達！
# イテレーション 3 の総コスト: 250.84
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 2187.1333
#
# ==================================================
# 反復学習: イテレーション 4/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (121.21us)  11.04ms (334.45us)        33
#        nlp_g  |   3.00ms ( 90.91us)   7.34ms (222.33us)        33
#   nlp_grad_f  |   9.00ms (290.32us)  16.70ms (538.61us)        31
#   nlp_hess_l  |  46.00ms (  1.59ms)  33.08ms (  1.14ms)        29
#    nlp_jac_g  |  18.00ms (580.65us)  16.87ms (544.06us)        31
#        total  | 431.00ms (431.00ms) 433.52ms (433.52ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   8.00ms (500.00us)   5.20ms (325.12us)        16
#        nlp_g  |        0 (       0)   3.21ms (200.81us)        16
#   nlp_grad_f  |   3.00ms (176.47us)   8.69ms (511.29us)        17
#   nlp_hess_l  |  14.00ms (933.33us)  16.44ms (  1.10ms)        15
#    nlp_jac_g  |  21.00ms (  1.24ms)   8.88ms (522.29us)        17
#        total  | 208.00ms (208.00ms) 202.98ms (202.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   8.00ms (210.53us)  12.76ms (335.74us)        38
#        nlp_g  |   4.00ms (105.26us)   8.54ms (224.68us)        38
#   nlp_grad_f  |  25.00ms (641.03us)  21.39ms (548.41us)        39
#   nlp_hess_l  |  36.00ms (972.97us)  42.72ms (  1.15ms)        37
#    nlp_jac_g  |  28.00ms (717.95us)  22.45ms (575.56us)        39
#        total  | 562.00ms (562.00ms) 556.98ms (556.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 74.07us)   7.84ms (290.26us)        27
#        nlp_g  |   2.00ms ( 74.07us)   5.43ms (201.07us)        27
#   nlp_grad_f  |  18.00ms (642.86us)  13.10ms (467.75us)        28
#   nlp_hess_l  |   5.00ms (192.31us)  26.83ms (  1.03ms)        26
#    nlp_jac_g  |  20.00ms (714.29us)  13.70ms (489.46us)        28
#        total  | 379.00ms (379.00ms) 379.14ms (379.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  18.00ms (750.00us)   6.96ms (289.83us)        24
#        nlp_g  |   3.00ms (125.00us)   5.03ms (209.46us)        24
#   nlp_grad_f  |  16.00ms (640.00us)  11.02ms (441.00us)        25
#   nlp_hess_l  |  15.00ms (652.17us)  25.26ms (  1.10ms)        23
#    nlp_jac_g  |   8.00ms (320.00us)  12.69ms (507.52us)        25
#        total  | 357.00ms (357.00ms) 359.59ms (359.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  30.00ms (  1.87ms)   4.41ms (275.87us)        16
#        nlp_g  |  17.00ms (  1.06ms)   3.10ms (193.94us)        16
#   nlp_grad_f  |   4.00ms (235.29us)   7.81ms (459.65us)        17
#   nlp_hess_l  |  21.00ms (  1.40ms)  16.86ms (  1.12ms)        15
#    nlp_jac_g  |   1.00ms ( 58.82us)   8.53ms (501.94us)        17
#        total  | 201.00ms (201.00ms) 201.70ms (201.70ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 32.26us)   9.50ms (306.45us)        31
#        nlp_g  |   6.00ms (193.55us)   6.54ms (211.00us)        31
#   nlp_grad_f  |   6.00ms (187.50us)  15.66ms (489.34us)        32
#   nlp_hess_l  |  59.00ms (  1.97ms)  34.22ms (  1.14ms)        30
#    nlp_jac_g  |   5.00ms (156.25us)  16.76ms (523.72us)        32
#        total  | 500.00ms (500.00ms) 504.23ms (504.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.30ms (299.64us)        11
#        nlp_g  |   1.00ms ( 90.91us)   2.14ms (194.73us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   6.04ms (503.00us)        12
#   nlp_hess_l  |  34.00ms (  3.40ms)  10.87ms (  1.09ms)        10
#    nlp_jac_g  |        0 (       0)   6.40ms (533.75us)        12
#        total  | 139.00ms (139.00ms) 137.31ms (137.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.75ms (374.80us)        10
#        nlp_g  |        0 (       0)   2.12ms (212.50us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   5.31ms (483.00us)        11
#   nlp_hess_l  |  29.00ms (  3.22ms)  11.44ms (  1.27ms)         9
#    nlp_jac_g  |  18.00ms (  1.64ms)   5.80ms (526.91us)        11
#        total  | 157.00ms (157.00ms) 145.00ms (145.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.09ms (282.72us)        18
#        nlp_g  |  18.00ms (  1.00ms)   3.80ms (211.11us)        18
#   nlp_grad_f  |  15.00ms (789.47us)   9.07ms (477.63us)        19
#   nlp_hess_l  |  37.00ms (  2.18ms)  17.47ms (  1.03ms)        17
#    nlp_jac_g  |   4.00ms (210.53us)   9.29ms (488.68us)        19
#        total  | 250.00ms (250.00ms) 246.91ms (246.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.02ms (301.80us)        10
#        nlp_g  |   3.00ms (300.00us)   2.23ms (223.20us)        10
#   nlp_grad_f  |  16.00ms (  1.45ms)   5.79ms (526.00us)        11
#   nlp_hess_l  |  19.00ms (  2.11ms)  10.67ms (  1.19ms)         9
#    nlp_jac_g  |   6.00ms (545.45us)   6.45ms (586.00us)        11
#        total  | 151.00ms (151.00ms) 136.32ms (136.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.45ms)   3.31ms (301.27us)        11
#        nlp_g  |        0 (       0)   2.38ms (216.27us)        11
#   nlp_grad_f  |   2.00ms (166.67us)   5.61ms (467.17us)        12
#   nlp_hess_l  |  20.00ms (  2.00ms)  10.02ms (  1.00ms)        10
#    nlp_jac_g  |   3.00ms (250.00us)   5.73ms (477.33us)        12
#        total  | 124.00ms (124.00ms) 133.39ms (133.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  25.00ms (  1.25ms)   5.73ms (286.30us)        20
#        nlp_g  |  15.00ms (750.00us)   3.82ms (190.95us)        20
#   nlp_grad_f  |  14.00ms (666.67us)   8.89ms (423.33us)        21
#   nlp_hess_l  |  19.00ms (  1.00ms)  18.28ms (962.21us)        19
#    nlp_jac_g  |   3.00ms (142.86us)   9.99ms (475.71us)        21
#        total  | 283.00ms (283.00ms) 276.30ms (276.30ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.45ms)   3.63ms (329.64us)        11
#        nlp_g  |        0 (       0)   2.31ms (210.27us)        11
#   nlp_grad_f  |  18.00ms (  1.50ms)   5.56ms (463.08us)        12
#   nlp_hess_l  |   3.00ms (300.00us)   9.80ms (980.10us)        10
#    nlp_jac_g  |   3.00ms (250.00us)   5.71ms (475.50us)        12
#        total  | 147.00ms (147.00ms) 138.60ms (138.60ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.81ms (280.90us)        10
#        nlp_g  |        0 (       0)   1.93ms (192.70us)        10
#   nlp_grad_f  |   2.00ms (181.82us)   5.30ms (481.73us)        11
#   nlp_hess_l  |   1.00ms (111.11us)   9.56ms (  1.06ms)         9
#    nlp_jac_g  |  16.00ms (  1.45ms)   5.40ms (491.00us)        11
#        total  | 116.00ms (116.00ms) 122.10ms (122.10ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.33ms (302.45us)        11
#        nlp_g  |        0 (       0)   2.21ms (200.64us)        11
#   nlp_grad_f  |  15.00ms (  1.25ms)   5.32ms (443.75us)        12
#   nlp_hess_l  |  17.00ms (  1.70ms)   9.22ms (922.20us)        10
#    nlp_jac_g  |   2.00ms (166.67us)   5.16ms (430.08us)        12
#        total  | 126.00ms (126.00ms) 126.53ms (126.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.21ms (291.82us)        11
#        nlp_g  |   1.00ms ( 90.91us)   2.23ms (202.73us)        11
#   nlp_grad_f  |  17.00ms (  1.42ms)   5.76ms (480.25us)        12
#   nlp_hess_l  |   2.00ms (200.00us)  10.30ms (  1.03ms)        10
#    nlp_jac_g  |   2.00ms (166.67us)   6.20ms (516.58us)        12
#        total  | 149.00ms (149.00ms) 141.14ms (141.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (100.00us)   7.01ms (350.45us)        20
#        nlp_g  |        0 (       0)   4.82ms (240.85us)        20
#   nlp_grad_f  |   4.00ms (190.48us)  10.98ms (522.86us)        21
#   nlp_hess_l  |   1.00ms ( 52.63us)  22.36ms (  1.18ms)        19
#    nlp_jac_g  |   5.00ms (238.10us)  12.16ms (579.10us)        21
#        total  | 283.00ms (283.00ms) 282.11ms (282.11ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.62ms (308.00us)        15
#        nlp_g  |        0 (       0)   3.26ms (217.27us)        15
#   nlp_grad_f  |  16.00ms (  1.00ms)   7.47ms (467.00us)        16
#   nlp_hess_l  |  17.00ms (  1.21ms)  14.92ms (  1.07ms)        14
#    nlp_jac_g  |   3.00ms (187.50us)   7.83ms (489.12us)        16
#        total  | 186.00ms (186.00ms) 178.92ms (178.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.07ms)   4.58ms (305.47us)        15
#        nlp_g  |        0 (       0)   2.89ms (193.00us)        15
#   nlp_grad_f  |   2.00ms (125.00us)   6.66ms (416.06us)        16
#   nlp_hess_l  |  16.00ms (  1.14ms)  14.43ms (  1.03ms)        14
#    nlp_jac_g  |   2.00ms (125.00us)   7.33ms (458.37us)        16
#        total  | 182.00ms (182.00ms) 172.94ms (172.94ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   4.29ms (330.23us)        13
#        nlp_g  |   2.00ms (153.85us)   2.85ms (219.00us)        13
#   nlp_grad_f  |   2.00ms (142.86us)   6.48ms (463.07us)        14
#   nlp_hess_l  |  19.00ms (  1.58ms)  12.89ms (  1.07ms)        12
#    nlp_jac_g  |   5.00ms (357.14us)   7.32ms (522.79us)        14
#        total  | 165.00ms (165.00ms) 160.58ms (160.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (  1.06ms)   5.32ms (332.44us)        16
#        nlp_g  |   2.00ms (125.00us)   3.57ms (223.31us)        16
#   nlp_grad_f  |   5.00ms (294.12us)   8.26ms (486.12us)        17
#   nlp_hess_l  |  28.00ms (  1.87ms)  17.98ms (  1.20ms)        15
#    nlp_jac_g  |  20.00ms (  1.18ms)   9.03ms (531.12us)        17
#        total  | 190.00ms (190.00ms) 190.07ms (190.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   4.76ms (366.15us)        13
#        nlp_g  |   2.00ms (153.85us)   3.09ms (237.92us)        13
#   nlp_grad_f  |   7.00ms (500.00us)   7.51ms (536.71us)        14
#   nlp_hess_l  |   9.00ms (750.00us)  15.08ms (  1.26ms)        12
#    nlp_jac_g  |   5.00ms (357.14us)   8.00ms (571.64us)        14
#        total  | 164.00ms (164.00ms) 159.35ms (159.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   4.90ms (376.92us)        13
#        nlp_g  |   2.00ms (153.85us)   3.26ms (250.85us)        13
#   nlp_grad_f  |  14.00ms (  1.00ms)   7.38ms (526.79us)        14
#   nlp_hess_l  |  15.00ms (  1.25ms)  13.71ms (  1.14ms)        12
#    nlp_jac_g  |   2.00ms (142.86us)   7.67ms (548.07us)        14
#        total  | 169.00ms (169.00ms) 162.23ms (162.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.14ms)   4.55ms (325.14us)        14
#        nlp_g  |   1.00ms ( 71.43us)   3.13ms (223.29us)        14
#   nlp_grad_f  |   5.00ms (333.33us)   7.13ms (475.27us)        15
#   nlp_hess_l  |  22.00ms (  1.69ms)  13.40ms (  1.03ms)        13
#    nlp_jac_g  |   3.00ms (200.00us)   7.33ms (488.60us)        15
#        total  | 174.00ms (174.00ms) 163.96ms (163.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (200.00us)   5.02ms (334.93us)        15
#        nlp_g  |   5.00ms (333.33us)   3.52ms (234.53us)        15
#   nlp_grad_f  |   7.00ms (437.50us)   8.34ms (521.31us)        16
#   nlp_hess_l  |  14.00ms (  1.00ms)  15.90ms (  1.14ms)        14
#    nlp_jac_g  |   8.00ms (500.00us)   9.01ms (563.12us)        16
#        total  | 181.00ms (181.00ms) 186.46ms (186.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  10.00ms (500.00us)   7.25ms (362.70us)        20
#        nlp_g  |        0 (       0)   4.83ms (241.45us)        20
#   nlp_grad_f  |  16.00ms (761.90us)  11.33ms (539.57us)        21
#   nlp_hess_l  |  13.00ms (684.21us)  23.70ms (  1.25ms)        19
#    nlp_jac_g  |  18.00ms (857.14us)  12.53ms (596.71us)        21
#        total  | 250.00ms (250.00ms) 250.54ms (250.54ms)         1
# ステップ 27 でゴールに到達！
# イテレーション 4 の総コスト: 250.74
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 639.7261
#
# ==================================================
# 反復学習: イテレーション 5/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  11.51ms (359.81us)        32
#        nlp_g  |  16.00ms (500.00us)   8.56ms (267.59us)        32
#   nlp_grad_f  |  47.00ms (  1.42ms)  18.09ms (548.24us)        33
#   nlp_hess_l  |  89.00ms (  2.87ms)  38.12ms (  1.23ms)        31
#    nlp_jac_g  |  18.00ms (545.45us)  19.17ms (580.85us)        33
#        total  | 464.00ms (464.00ms) 468.68ms (468.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   7.40ms (352.62us)        21
#        nlp_g  |        0 (       0)   5.18ms (246.71us)        21
#   nlp_grad_f  |   2.00ms ( 95.24us)  11.13ms (530.14us)        21
#   nlp_hess_l  |  18.00ms (947.37us)  23.09ms (  1.22ms)        19
#    nlp_jac_g  |  18.00ms (857.14us)  11.95ms (569.29us)        21
#        total  | 286.00ms (286.00ms) 273.63ms (273.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms ( 93.75us)  11.37ms (355.37us)        32
#        nlp_g  |   1.00ms ( 31.25us)   7.89ms (246.53us)        32
#   nlp_grad_f  |  16.00ms (484.85us)  16.26ms (492.73us)        33
#   nlp_hess_l  |  63.00ms (  2.03ms)  35.96ms (  1.16ms)        31
#    nlp_jac_g  |   5.00ms (151.52us)  18.33ms (555.45us)        33
#        total  | 516.00ms (516.00ms) 512.59ms (512.59ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)  10.36ms (334.16us)        31
#        nlp_g  |        0 (       0)   7.33ms (236.39us)        31
#   nlp_grad_f  |  11.00ms (379.31us)  16.00ms (551.79us)        29
#   nlp_hess_l  |  24.00ms (888.89us)  32.89ms (  1.22ms)        27
#    nlp_jac_g  |  45.00ms (  1.55ms)  17.11ms (589.97us)        29
#        total  | 391.00ms (391.00ms) 402.96ms (402.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  19.00ms (  1.27ms)   6.87ms (458.00us)        15
#        nlp_g  |        0 (       0)   4.77ms (318.00us)        15
#   nlp_grad_f  |  33.00ms (  2.06ms)  11.16ms (697.62us)        16
#   nlp_hess_l  |  39.00ms (  2.79ms)  21.31ms (  1.52ms)        14
#    nlp_jac_g  |  33.00ms (  2.06ms)  11.69ms (730.56us)        16
#        total  | 234.00ms (234.00ms) 246.65ms (246.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   9.00ms (562.50us)   5.94ms (371.25us)        16
#        nlp_g  |        0 (       0)   4.19ms (261.62us)        16
#   nlp_grad_f  |        0 (       0)   9.60ms (564.94us)        17
#   nlp_hess_l  |  49.00ms (  3.27ms)  18.76ms (  1.25ms)        15
#    nlp_jac_g  |  16.00ms (941.18us)   9.95ms (585.18us)        17
#        total  | 216.00ms (216.00ms) 210.04ms (210.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.00ms (333.33us)   7.20ms (342.95us)        21
#        nlp_g  |   9.00ms (428.57us)   5.03ms (239.71us)        21
#   nlp_grad_f  |   6.00ms (272.73us)  11.82ms (537.09us)        22
#   nlp_hess_l  |  26.00ms (  1.30ms)  23.72ms (  1.19ms)        20
#    nlp_jac_g  |  29.00ms (  1.32ms)  12.45ms (566.14us)        22
#        total  | 318.00ms (318.00ms) 317.03ms (317.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   4.13ms (294.71us)        14
#        nlp_g  |  11.00ms (785.71us)   2.95ms (210.93us)        14
#   nlp_grad_f  |   9.00ms (600.00us)   6.55ms (436.87us)        15
#   nlp_hess_l  |   5.00ms (384.62us)  13.75ms (  1.06ms)        13
#    nlp_jac_g  |   6.00ms (400.00us)   7.60ms (506.87us)        15
#        total  | 200.00ms (200.00ms) 191.04ms (191.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   4.29ms (357.17us)        12
#        nlp_g  |  16.00ms (  1.33ms)   3.15ms (262.33us)        12
#   nlp_grad_f  |   2.00ms (153.85us)   6.70ms (515.38us)        13
#   nlp_hess_l  |   7.00ms (636.36us)  13.23ms (  1.20ms)        11
#    nlp_jac_g  |  19.00ms (  1.46ms)   7.59ms (583.62us)        13
#        total  | 162.00ms (162.00ms) 151.57ms (151.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.86ms (317.44us)         9
#        nlp_g  |        0 (       0)   1.85ms (205.22us)         9
#   nlp_grad_f  |  16.00ms (  1.60ms)   4.50ms (450.30us)        10
#   nlp_hess_l  |   3.00ms (375.00us)   9.01ms (  1.13ms)         8
#    nlp_jac_g  |   3.00ms (300.00us)   5.01ms (500.80us)        10
#        total  | 116.00ms (116.00ms) 111.79ms (111.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (111.11us)   6.03ms (335.06us)        18
#        nlp_g  |   1.00ms ( 55.56us)   3.91ms (217.00us)        18
#   nlp_grad_f  |  19.00ms (  1.00ms)  10.03ms (528.11us)        19
#   nlp_hess_l  |   5.00ms (294.12us)  20.28ms (  1.19ms)        17
#    nlp_jac_g  |  19.00ms (  1.00ms)  10.58ms (556.74us)        19
#        total  | 275.00ms (275.00ms) 274.64ms (274.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   3.22ms (292.36us)        11
#        nlp_g  |  15.00ms (  1.36ms)   2.25ms (204.82us)        11
#   nlp_grad_f  |   2.00ms (166.67us)   5.62ms (468.33us)        12
#   nlp_hess_l  |   3.00ms (300.00us)  10.02ms (  1.00ms)        10
#    nlp_jac_g  |   3.00ms (250.00us)   5.89ms (490.50us)        12
#        total  | 148.00ms (148.00ms) 138.35ms (138.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.23ms (293.27us)        11
#        nlp_g  |        0 (       0)   2.36ms (215.00us)        11
#   nlp_grad_f  |  16.00ms (  1.33ms)   6.17ms (514.50us)        12
#   nlp_hess_l  |  12.00ms (  1.20ms)  10.66ms (  1.07ms)        10
#    nlp_jac_g  |   1.00ms ( 83.33us)   7.01ms (584.00us)        12
#        total  | 138.00ms (138.00ms) 144.82ms (144.82ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (  1.89ms)   3.02ms (336.11us)         9
#        nlp_g  |        0 (       0)   2.08ms (231.33us)         9
#   nlp_grad_f  |   2.00ms (200.00us)   5.32ms (532.50us)        10
#   nlp_hess_l  |   5.00ms (625.00us)   9.90ms (  1.24ms)         8
#    nlp_jac_g  |   3.00ms (300.00us)   5.79ms (579.00us)        10
#        total  | 118.00ms (118.00ms) 124.16ms (124.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   2.64ms (239.82us)        11
#        nlp_g  |        0 (       0)   1.70ms (154.73us)        11
#   nlp_grad_f  |  18.00ms (  1.50ms)   4.99ms (415.92us)        12
#   nlp_hess_l  |   2.00ms (200.00us)   9.63ms (962.80us)        10
#    nlp_jac_g  |   2.00ms (166.67us)   5.44ms (453.00us)        12
#        total  | 125.00ms (125.00ms) 125.38ms (125.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (333.33us)   4.28ms (285.20us)        15
#        nlp_g  |        0 (       0)   2.87ms (191.53us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   7.98ms (498.50us)        16
#   nlp_hess_l  |   8.00ms (571.43us)  17.06ms (  1.22ms)        14
#    nlp_jac_g  |  10.00ms (625.00us)   9.03ms (564.31us)        16
#        total  | 183.00ms (183.00ms) 193.61ms (193.61ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (285.71us)   4.36ms (311.79us)        14
#        nlp_g  |   1.00ms ( 71.43us)   2.95ms (210.79us)        14
#   nlp_grad_f  |        0 (       0)   8.18ms (545.07us)        15
#   nlp_hess_l  |   6.00ms (461.54us)  15.09ms (  1.16ms)        13
#    nlp_jac_g  |  21.00ms (  1.40ms)   8.39ms (559.47us)        15
#        total  | 198.00ms (198.00ms) 187.09ms (187.09ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (133.33us)   4.11ms (274.07us)        15
#        nlp_g  |   2.00ms (133.33us)   2.81ms (187.20us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   7.33ms (458.37us)        16
#   nlp_hess_l  |  34.00ms (  2.43ms)  14.40ms (  1.03ms)        14
#    nlp_jac_g  |  18.00ms (  1.12ms)   7.51ms (469.31us)        16
#        total  | 182.00ms (182.00ms) 182.34ms (182.34ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.54ms (294.92us)        12
#        nlp_g  |   1.00ms ( 83.33us)   2.51ms (209.08us)        12
#   nlp_grad_f  |        0 (       0)   6.83ms (525.15us)        13
#   nlp_hess_l  |  32.00ms (  2.91ms)  12.11ms (  1.10ms)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   7.25ms (557.85us)        13
#        total  | 133.00ms (133.00ms) 143.78ms (143.78ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.34ms (355.80us)        15
#        nlp_g  |   2.00ms (133.33us)   3.69ms (246.33us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   9.43ms (589.12us)        16
#   nlp_hess_l  |  33.00ms (  2.36ms)  18.22ms (  1.30ms)        14
#    nlp_jac_g  |   6.00ms (375.00us)   9.87ms (616.94us)        16
#        total  | 208.00ms (208.00ms) 212.04ms (212.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (187.50us)   5.24ms (327.50us)        16
#        nlp_g  |   2.00ms (125.00us)   3.61ms (225.69us)        16
#   nlp_grad_f  |   1.00ms ( 58.82us)   9.32ms (548.18us)        17
#   nlp_hess_l  |  23.00ms (  1.53ms)  19.37ms (  1.29ms)        15
#    nlp_jac_g  |  12.00ms (705.88us)  10.06ms (591.88us)        17
#        total  | 219.00ms (219.00ms) 209.12ms (209.12ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 62.50us)   4.42ms (276.00us)        16
#        nlp_g  |        0 (       0)   3.01ms (188.44us)        16
#   nlp_grad_f  |  20.00ms (  1.18ms)   8.32ms (489.41us)        17
#   nlp_hess_l  |   4.00ms (266.67us)  15.81ms (  1.05ms)        15
#    nlp_jac_g  |   4.00ms (235.29us)   9.07ms (533.65us)        17
#        total  | 201.00ms (201.00ms) 212.26ms (212.26ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.60ms (276.69us)        13
#        nlp_g  |        0 (       0)   2.51ms (193.46us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   6.67ms (476.57us)        14
#   nlp_hess_l  |  15.00ms (  1.25ms)  12.95ms (  1.08ms)        12
#    nlp_jac_g  |   3.00ms (214.29us)   7.23ms (516.43us)        14
#        total  | 183.00ms (183.00ms) 170.83ms (170.83ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (153.85us)   3.81ms (292.77us)        13
#        nlp_g  |   2.00ms (153.85us)   2.60ms (200.08us)        13
#   nlp_grad_f  |   5.00ms (357.14us)   6.55ms (468.07us)        14
#   nlp_hess_l  |  22.00ms (  1.83ms)  12.01ms (  1.00ms)        12
#    nlp_jac_g  |   4.00ms (285.71us)   6.51ms (465.14us)        14
#        total  | 162.00ms (162.00ms) 162.71ms (162.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (153.85us)   4.41ms (339.38us)        13
#        nlp_g  |   2.00ms (153.85us)   3.06ms (235.54us)        13
#   nlp_grad_f  |  16.00ms (  1.14ms)   8.08ms (577.21us)        14
#   nlp_hess_l  |  17.00ms (  1.42ms)  15.67ms (  1.31ms)        12
#    nlp_jac_g  |   3.00ms (214.29us)   8.52ms (608.64us)        14
#        total  | 184.00ms (184.00ms) 181.38ms (181.38ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.53ms (323.71us)        14
#        nlp_g  |   1.00ms ( 71.43us)   3.35ms (239.57us)        14
#   nlp_grad_f  |  19.00ms (  1.27ms)   8.51ms (567.67us)        15
#   nlp_hess_l  |  19.00ms (  1.46ms)  15.47ms (  1.19ms)        13
#    nlp_jac_g  |   3.00ms (200.00us)   9.23ms (615.07us)        15
#        total  | 184.00ms (184.00ms) 182.41ms (182.41ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.00ms (230.77us)   4.27ms (328.54us)        13
#        nlp_g  |        0 (       0)   2.91ms (224.00us)        13
#   nlp_grad_f  |   3.00ms (214.29us)   7.57ms (540.64us)        14
#   nlp_hess_l  |   9.00ms (750.00us)  14.14ms (  1.18ms)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   7.68ms (548.79us)        14
#        total  | 183.00ms (183.00ms) 176.42ms (176.42ms)         1
# ステップ 27 でゴールに到達！
# イテレーション 5 の総コスト: 251.26
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 51.5292
