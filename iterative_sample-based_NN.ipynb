# %% [markdown]
# NNを元に2次関数の終端コストを決定

# %%
import numpy as np
import matplotlib.pyplot as plt
import GPy
import casadi as ca
import torch
import torch.nn as nn
import torch.optim as optim
import time


import japanize_matplotlib
plt.rcParams['font.size'] = 14
plt.rcParams['axes.grid'] = True
plt.rcParams['figure.figsize'] = (8, 8)

# ==================================================================================
# シミュレーション全体の設定パラメータ
# ==================================================================================
N_ITERATIONS = 5
SIM_STEPS = 100
DT = 0.1
NX, NU = 4, 2
START_STATE = np.array([0.0, 0.0, 0.0, 0.0])
GOAL_STATE = np.array([10.0, 10.0])
N_MPC = 20
M_MPC = 25
OBSTACLE_INFO = {'pos': np.array([5.0, 5.0]), 'rad': 1.5}


# ----------------------------------------------------------------------------------
# Component 1: TerminalCostNN & 学習関数
# ----------------------------------------------------------------------------------
class TerminalCostNN(nn.Module):
    def __init__(self, n_input):
        super(TerminalCostNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(n_input, 64), nn.ReLU(),
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, 1)
        )
    def forward(self, x):
        return self.layers(x)

def train_terminal_cost_net(net, trajectory_data):
    if len(trajectory_data) < 10: return
    print("NN: 終端コストの学習開始...")
    optimizer = optim.Adam(net.parameters(), lr=0.001)
    criterion = nn.MSELoss()
    states = torch.tensor(np.array([d[0] for d in trajectory_data]), dtype=torch.float32)
    costs_to_go = []
    running_cost = 0
    for _, stage_cost in reversed(trajectory_data):
        running_cost += stage_cost
        costs_to_go.append(running_cost)
    costs_to_go.reverse()
    labels = torch.tensor(costs_to_go, dtype=torch.float32).view(-1, 1)
    for epoch in range(100):
        optimizer.zero_grad(); outputs = net(states); loss = criterion(outputs, labels)
        loss.backward(); optimizer.step()
    print(f"NN: 学習完了。最終損失: {loss.item():.4f}")

# (TrueVehicle, GPRModelクラスは変更なし)
class TrueVehicle:
    def __init__(self, dt=0.1): self.dt = dt
    def dynamics(self, x, u):
        px, py, vx, vy = x; ax, ay = u; drag = 0.1
        vx_next = vx + (ax - drag * vx**2) * self.dt; vy_next = vy + (ay - drag * vy**2) * self.dt
        px_next = px + vx * self.dt + 0.5 * ax * self.dt**2; py_next = py + vy * self.dt + 0.5 * ay * self.dt**2
        return np.array([px_next, py_next, vx_next, vy_next])
class GPRModel:
    def __init__(self, nx, nu, dt, obstacle_info):
        self.nx, self.nu = nx, nu
        self.dt=DT
        self.obstacle_info=OBSTACLE_INFO
        self.is_trained = False
        self.X_data = np.empty((0, self.nx + self.nu))
        self.Y_data = np.empty((0, self.nx))
        self.models = [None] * self.nx

    def add_data(self, x, u, x_next):
        # 公称モデルからの誤差（デルタ）を学習ターゲットにする
        delta_real = (x_next - x) / self.dt
        delta_nominal = np.array([x[2], x[3], u[0], u[1]])
        error = delta_real - delta_nominal
        self.X_data = np.vstack([self.X_data, np.hstack([x, u])])
        self.Y_data = np.vstack([self.Y_data, error])

    def train(self):
        if len(self.X_data) < 10: return
        print("GPR: 学習開始...")
        for i in range(self.nx):
            kernel = GPy.kern.RBF(input_dim=self.nx + self.nu, ARD=True)
            model = GPy.models.GPRegression(self.X_data, self.Y_data[:, i:i+1], kernel)
            model.optimize(messages=False, max_iters=100)
            self.models[i] = model
        self.is_trained = True
        print("GPR: 学習完了")

    def predict(self, x, u):
        if not self.is_trained:
            return np.zeros(self.nx), np.ones(self.nx)
        xu = np.hstack([x, u]).reshape(1, -1)
        means = np.array([m.predict(xu)[0][0, 0] if m else 0 for m in self.models])
        variances = np.array([m.predict(xu)[1][0, 0] if m else 1.0 for m in self.models])
        return means, variances

# ----------------------------------------------------------------------------------
# Component 3: MPCController
# ----------------------------------------------------------------------------------
class MPCController:
    def __init__(self, nx, nu, N, M, dt, obstacle_info):
        self.nx, self.nu, self.N, self.M, self.dt = nx, nu, N, M, dt
        self.obstacle_info = obstacle_info; self.u_prev_sol = np.zeros((nu, N))

    # ✅ 変更点：NNをアドバイザーとして使う方式に変更
    def solve(self, x_current, gpr_model, x_goal, terminal_cost_net, is_first_iteration):
        opti = ca.Opti()
        U = opti.variable(self.nu, self.N)

        # --- ステップ１：NNで「賢い目標地点」を大まかに探す ---
        if is_first_iteration:
            # 最初のイテレーションではNNが未学習なので、ゴールをそのまま使う
            smart_target = x_goal
        else:
            # 現在位置から周辺のいくつかの候補点を生成
            num_candidates = 20
            candidates_pos = np.random.randn(num_candidates, 2) * 2.0 + x_current[:2]
            candidates_vel = np.zeros((num_candidates, 2))
            candidates = np.hstack([candidates_pos, candidates_vel])
            
            # NNで各候補点のコストを評価
            candidates_torch = torch.tensor(candidates, dtype=torch.float32)
            with torch.no_grad():
                costs = terminal_cost_net(candidates_torch).numpy().flatten()
            
            # 最もコストが低い候補点を「賢い目標地点」とする
            smart_target = candidates_pos[np.argmin(costs)]

        error_mean, error_var = gpr_model.predict(x_current, np.zeros(self.nu))
        error_std = np.sqrt(np.maximum(error_var, 1e-6)); error_std_capped = np.minimum(error_std, 0.2)
        error_samples = np.random.normal(loc=error_mean, scale=error_std_capped, size=(self.M, self.nx))
        
        all_scenario_costs = []
        for m in range(self.M):
            X_scenario = opti.variable(self.nx, self.N + 1); cost_scenario = 0
            opti.subject_to(X_scenario[:, 0] == x_current)
            for k in range(self.N):
                x_k, u_k = X_scenario[:, k], U[:, k]
                delta_nominal = ca.vertcat(x_k[2], x_k[3], u_k[0], u_k[1])
                delta_pred = delta_nominal + error_samples[m, :]
                x_next_pred = x_k + delta_pred * self.dt
                opti.subject_to(X_scenario[:, k+1] == x_next_pred)
                cost_scenario += ca.sumsqr(x_k[:2] - x_goal) * self.dt + ca.sumsqr(u_k) * self.dt * 0.01
                if self.obstacle_info:
                    dist_to_obs = ca.norm_2(x_k[:2] - self.obstacle_info['pos'])
                    penalty = ca.fmax(0, self.obstacle_info['rad'] - dist_to_obs)
                    cost_scenario += 500.0 * penalty**2
            
            # --- ステップ２：MPCの終端コストとして、その「賢い目標地点」を目指す ---
            terminal_state = X_scenario[:, self.N]
            cost_scenario += ca.sumsqr(terminal_state[:2] - smart_target) * 10.0

            all_scenario_costs.append(cost_scenario)
        
        #total_objective = ca.mean(ca.vertcat(*all_scenario_costs))
        total_objective = ca.sum1(ca.vertcat(*all_scenario_costs)) / len(all_scenario_costs)
        opti.minimize(total_objective)
        opti.subject_to(opti.bounded(-5.0, U, 5.0))
        opti.set_initial(U, self.u_prev_sol)
        s_opts = {'print_level': 0}; opti.solver('ipopt', {}, s_opts)

        try:
            sol = opti.solve()
            self.u_prev_sol = np.hstack((sol.value(U)[:, 1:], sol.value(U)[:, -1].reshape(-1, 1)))
            return sol.value(U[:, 0])
        except Exception as e:
            print(f"MPC: 最適化失敗。x={x_current}"); return np.zeros(self.nu)

# ----------------------------------------------------------------------------------
# Main Simulation Loop
# ----------------------------------------------------------------------------------
def main():
    vehicle = TrueVehicle(dt=DT)
    gpr_model = GPRModel(nx=NX, nu=NU,dt=DT, obstacle_info=OBSTACLE_INFO)
    mpc = MPCController(nx=NX, nu=NU, N=N_MPC, M=M_MPC, dt=DT, obstacle_info=OBSTACLE_INFO)
    terminal_cost_net = TerminalCostNN(n_input=NX)
    all_trajectories, final_costs = [], []
    for i in range(N_ITERATIONS):
        print(f"\n{'='*50}\n反復学習: イテレーション {i+1}/{N_ITERATIONS}\n{'='*50}")
        current_x = np.copy(START_STATE); total_cost = 0
        iteration_data_for_gpr, iteration_data_for_cost_learning = [], []
        for step in range(SIM_STEPS):
            is_first_iter = (i == 0)
            u_optimal = mpc.solve(current_x, gpr_model, GOAL_STATE, terminal_cost_net, is_first_iter)
            x_next = vehicle.dynamics(current_x, u_optimal)
            stage_cost = (np.sum((current_x[:2] - GOAL_STATE)**2) + np.sum(u_optimal**2) * 0.01) * DT
            total_cost += stage_cost
            iteration_data_for_gpr.append((current_x, u_optimal, x_next))
            iteration_data_for_cost_learning.append((current_x, stage_cost))
            current_x = x_next
            if np.linalg.norm(current_x[:2] - GOAL_STATE) < 0.5:
                print(f"ステップ {step+1} でゴールに到達！"); break
        all_trajectories.append(np.array([d[0] for d in iteration_data_for_cost_learning]))
        final_costs.append(total_cost)
        print(f"イテレーション {i+1} の総コスト: {total_cost:.2f}")
        for x, u, x_n in iteration_data_for_gpr:
            gpr_model.add_data(x, u, x_n)
        gpr_model.train()
        train_terminal_cost_net(terminal_cost_net, iteration_data_for_cost_learning)
    # (可視化コードは変更なし)
    plt.figure(figsize=(10, 10))
    if OBSTACLE_INFO:
        obs_circle = plt.Circle(OBSTACLE_INFO['pos'], OBSTACLE_INFO['rad'], color='r', alpha=0.5, label='障害物')
        plt.gca().add_patch(obs_circle)
    plt.plot(START_STATE[0], START_STATE[1], 'go', markersize=15, label='スタート')
    plt.plot(GOAL_STATE[0], GOAL_STATE[1], 'm*', markersize=20, label='ゴール')
    for i, traj in enumerate(all_trajectories):
        plt.plot(traj[:, 0], traj[:, 1], '-o', markersize=3, label=f'イテレーション {i+1}')
    plt.title('走行軌跡（NNアドバイザー方式）'); plt.legend(); plt.axis('equal'); plt.show()
    plt.figure(figsize=(8, 5))
    plt.plot(range(1, N_ITERATIONS + 1), final_costs, '-ro')
    plt.title('イテレーションごとの総コストの推移'); plt.xlabel('イテレーション回数')
    plt.ylabel('総コスト'); plt.xticks(range(1, N_ITERATIONS + 1)); plt.show()

if __name__ == '__main__':
    main()
# Out:
# ==================================================
# 反復学習: イテレーション 1/5
# ==================================================
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.16ms (161.31us)        32
#        nlp_g  |        0 (       0)   3.75ms (117.22us)        32
#   nlp_grad_f  |   1.00ms ( 30.30us)   9.43ms (285.88us)        33
#   nlp_hess_l  |  10.00ms (322.58us)  20.31ms (655.06us)        31
#    nlp_jac_g  |   2.00ms ( 60.61us)  10.29ms (311.97us)        33
#        total  | 317.00ms (317.00ms) 320.57ms (320.57ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.20ms (145.45us)        22
#        nlp_g  |  45.00ms (  2.05ms)   2.60ms (118.41us)        22
#   nlp_grad_f  |        0 (       0)   6.25ms (271.78us)        23
#   nlp_hess_l  |   6.00ms (285.71us)  11.72ms (558.00us)        21
#    nlp_jac_g  |   2.00ms ( 86.96us)   6.96ms (302.70us)        23
#        total  | 187.00ms (187.00ms) 175.01ms (175.01ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.73ms (155.58us)        24
#        nlp_g  |  14.00ms (583.33us)   2.65ms (110.54us)        24
#   nlp_grad_f  |  24.00ms (960.00us)   7.04ms (281.76us)        25
#   nlp_hess_l  |  21.00ms (913.04us)  13.66ms (594.04us)        23
#    nlp_jac_g  |   8.00ms (320.00us)   7.36ms (294.48us)        25
#        total  | 233.00ms (233.00ms) 227.20ms (227.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 35.71us)   4.38ms (156.29us)        28
#        nlp_g  |        0 (       0)   3.13ms (111.89us)        28
#   nlp_grad_f  |        0 (       0)   8.11ms (279.62us)        29
#   nlp_hess_l  |  16.00ms (592.59us)  16.25ms (601.89us)        27
#    nlp_jac_g  |        0 (       0)   8.66ms (298.59us)        29
#        total  | 258.00ms (258.00ms) 266.77ms (266.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.87ms (151.32us)        19
#        nlp_g  |   1.00ms ( 52.63us)   1.96ms (103.21us)        19
#   nlp_grad_f  |        0 (       0)   5.34ms (267.20us)        20
#   nlp_hess_l  |  16.00ms (888.89us)  10.36ms (575.83us)        18
#    nlp_jac_g  |        0 (       0)   5.90ms (295.25us)        20
#        total  | 147.00ms (147.00ms) 148.84ms (148.84ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.49ms (160.43us)        28
#        nlp_g  |        0 (       0)   3.14ms (112.25us)        28
#   nlp_grad_f  |        0 (       0)   8.51ms (293.34us)        29
#   nlp_hess_l  |  31.00ms (  1.15ms)  16.46ms (609.52us)        27
#    nlp_jac_g  |   1.00ms ( 34.48us)   8.95ms (308.72us)        29
#        total  | 266.00ms (266.00ms) 260.25ms (260.25ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.25ms (149.93us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.55ms (103.07us)        15
#   nlp_grad_f  |        0 (       0)   4.25ms (265.62us)        16
#   nlp_hess_l  |   3.00ms (214.29us)   7.91ms (564.86us)        14
#    nlp_jac_g  |  16.00ms (  1.00ms)   4.76ms (297.62us)        16
#        total  | 118.00ms (118.00ms) 111.76ms (111.76ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.88ms (144.31us)        13
#        nlp_g  |        0 (       0)   1.35ms (104.15us)        13
#   nlp_grad_f  |        0 (       0)   3.84ms (274.43us)        14
#   nlp_hess_l  |        0 (       0)   7.01ms (583.83us)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   4.06ms (289.93us)        14
#        total  | 100.00ms (100.00ms)  97.00ms ( 97.00ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.51ms (147.71us)        17
#        nlp_g  |        0 (       0)   1.84ms (108.47us)        17
#   nlp_grad_f  |   1.00ms ( 55.56us)   5.24ms (291.11us)        18
#   nlp_hess_l  |  14.00ms (875.00us)   9.70ms (606.00us)        16
#    nlp_jac_g  |   1.00ms ( 55.56us)   5.59ms (310.67us)        18
#        total  | 117.00ms (117.00ms) 126.19ms (126.19ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.92ms (147.85us)        13
#        nlp_g  |        0 (       0)   1.37ms (105.46us)        13
#   nlp_grad_f  |  14.00ms (  1.00ms)   4.28ms (305.50us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.46ms (622.08us)        12
#    nlp_jac_g  |        0 (       0)   4.58ms (327.36us)        14
#        total  | 100.00ms (100.00ms)  99.15ms ( 99.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 50.00us)   2.86ms (143.20us)        20
#        nlp_g  |        0 (       0)   2.04ms (102.10us)        20
#   nlp_grad_f  |        0 (       0)   5.22ms (274.84us)        19
#   nlp_hess_l  |  18.00ms (  1.06ms)   9.96ms (586.06us)        17
#    nlp_jac_g  |        0 (       0)   5.62ms (295.84us)        19
#        total  | 130.00ms (130.00ms) 137.67ms (137.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  14.00ms (  1.00ms)   2.21ms (158.00us)        14
#        nlp_g  |        0 (       0)   1.44ms (103.14us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.26ms (283.93us)        15
#   nlp_hess_l  |        0 (       0)   8.23ms (632.92us)        13
#    nlp_jac_g  |        0 (       0)   4.58ms (305.20us)        15
#        total  | 116.00ms (116.00ms) 109.35ms (109.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.12ms (151.21us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.47ms (105.36us)        14
#   nlp_grad_f  |        0 (       0)   4.14ms (276.07us)        15
#   nlp_hess_l  |  13.00ms (  1.00ms)   7.75ms (596.46us)        13
#    nlp_jac_g  |  17.00ms (  1.13ms)   4.45ms (296.40us)        15
#        total  |  99.00ms ( 99.00ms) 108.46ms (108.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.23ms (148.47us)        15
#        nlp_g  |        0 (       0)   1.56ms (104.33us)        15
#   nlp_grad_f  |        0 (       0)   4.47ms (279.44us)        16
#   nlp_hess_l  |        0 (       0)   8.08ms (576.86us)        14
#    nlp_jac_g  |  16.00ms (  1.00ms)   4.83ms (301.75us)        16
#        total  | 122.00ms (122.00ms) 114.23ms (114.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (937.50us)   2.45ms (153.06us)        16
#        nlp_g  |        0 (       0)   1.70ms (106.44us)        16
#   nlp_grad_f  |   1.00ms ( 58.82us)   4.75ms (279.71us)        17
#   nlp_hess_l  |   3.00ms (200.00us)   8.92ms (594.67us)        15
#    nlp_jac_g  |  16.00ms (941.18us)   5.22ms (307.24us)        17
#        total  | 134.00ms (134.00ms) 120.10ms (120.10ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.11ms (150.57us)        14
#        nlp_g  |        0 (       0)   1.50ms (107.29us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.53ms (302.20us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   8.15ms (627.00us)        13
#    nlp_jac_g  |   2.00ms (133.33us)   4.80ms (320.27us)        15
#        total  | 101.00ms (101.00ms) 108.68ms (108.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.37ms (169.50us)        14
#        nlp_g  |        0 (       0)   1.50ms (106.93us)        14
#   nlp_grad_f  |        0 (       0)   4.45ms (297.00us)        15
#   nlp_hess_l  |        0 (       0)   8.18ms (629.00us)        13
#    nlp_jac_g  |        0 (       0)   4.83ms (322.27us)        15
#        total  | 117.00ms (117.00ms) 110.22ms (110.22ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.90ms (146.38us)        13
#        nlp_g  |        0 (       0)   1.28ms ( 98.23us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.95ms (282.14us)        14
#   nlp_hess_l  |   4.00ms (333.33us)   7.19ms (598.92us)        12
#    nlp_jac_g  |  32.00ms (  2.29ms)   4.10ms (292.71us)        14
#        total  | 116.00ms (116.00ms) 100.58ms (100.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.41ms (150.87us)        16
#        nlp_g  |  15.00ms (937.50us)   1.74ms (108.62us)        16
#   nlp_grad_f  |  17.00ms (  1.00ms)   4.59ms (270.18us)        17
#   nlp_hess_l  |  20.00ms (  1.33ms)   9.04ms (602.67us)        15
#    nlp_jac_g  |   5.00ms (294.12us)   5.02ms (295.24us)        17
#        total  | 133.00ms (133.00ms) 125.35ms (125.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (454.55us)   1.78ms (161.91us)        11
#        nlp_g  |  16.00ms (  1.45ms)   1.19ms (108.18us)        11
#   nlp_grad_f  |        0 (       0)   3.27ms (272.67us)        12
#   nlp_hess_l  |   1.00ms (100.00us)   6.12ms (611.60us)        10
#    nlp_jac_g  |        0 (       0)   3.67ms (306.08us)        12
#        total  |  84.00ms ( 84.00ms)  83.69ms ( 83.69ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.48ms (165.20us)        15
#        nlp_g  |        0 (       0)   1.66ms (110.80us)        15
#   nlp_grad_f  |   1.00ms ( 62.50us)   4.70ms (293.69us)        16
#   nlp_hess_l  |  23.00ms (  1.64ms)   8.77ms (626.36us)        14
#    nlp_jac_g  |        0 (       0)   4.93ms (308.37us)        16
#        total  | 108.00ms (108.00ms) 112.55ms (112.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.27ms (151.27us)        15
#        nlp_g  |        0 (       0)   1.60ms (106.53us)        15
#   nlp_grad_f  |        0 (       0)   4.86ms (303.87us)        16
#   nlp_hess_l  |   2.00ms (142.86us)   8.31ms (593.93us)        14
#    nlp_jac_g  |        0 (       0)   5.15ms (321.81us)        16
#        total  | 120.00ms (120.00ms) 117.04ms (117.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.74ms (133.62us)        13
#        nlp_g  |        0 (       0)   1.24ms ( 95.54us)        13
#   nlp_grad_f  |        0 (       0)   3.51ms (250.57us)        14
#   nlp_hess_l  |        0 (       0)   6.39ms (532.58us)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   3.80ms (271.29us)        14
#        total  |  98.00ms ( 98.00ms)  93.41ms ( 93.41ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.06ms (158.15us)        13
#        nlp_g  |        0 (       0)   1.54ms (118.38us)        13
#   nlp_grad_f  |        0 (       0)   4.22ms (301.64us)        14
#   nlp_hess_l  |        0 (       0)   7.07ms (589.33us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   4.64ms (331.29us)        14
#        total  | 100.00ms (100.00ms)  99.26ms ( 99.26ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.16ms (154.29us)        14
#        nlp_g  |        0 (       0)   1.56ms (111.21us)        14
#   nlp_grad_f  |        0 (       0)   4.38ms (292.13us)        15
#   nlp_hess_l  |        0 (       0)   8.29ms (637.46us)        13
#    nlp_jac_g  |   4.00ms (266.67us)   4.69ms (312.73us)        15
#        total  | 112.00ms (112.00ms) 108.65ms (108.65ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.12ms (240.08us)        13
#        nlp_g  |   1.00ms ( 76.92us)   2.22ms (170.54us)        13
#   nlp_grad_f  |        0 (       0)   5.53ms (395.00us)        14
#   nlp_hess_l  |  13.00ms (  1.08ms)  10.31ms (859.17us)        12
#    nlp_jac_g  |   5.00ms (357.14us)   6.09ms (434.79us)        14
#        total  | 136.00ms (136.00ms) 129.53ms (129.53ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.15ms)   2.01ms (154.62us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.33ms (102.31us)        13
#   nlp_grad_f  |        0 (       0)   3.95ms (282.43us)        14
#   nlp_hess_l  |   2.00ms (166.67us)   7.14ms (595.00us)        12
#    nlp_jac_g  |        0 (       0)   4.10ms (292.86us)        14
#        total  |  99.00ms ( 99.00ms)  97.14ms ( 97.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.00ms)   2.39ms (149.12us)        16
#        nlp_g  |   2.00ms (125.00us)   1.70ms (106.25us)        16
#   nlp_grad_f  |        0 (       0)   5.08ms (299.12us)        17
#   nlp_hess_l  |  16.00ms (  1.07ms)   8.80ms (586.47us)        15
#    nlp_jac_g  |        0 (       0)   5.54ms (326.18us)        17
#        total  | 116.00ms (116.00ms) 119.95ms (119.95ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.03ms (156.54us)        13
#        nlp_g  |  16.00ms (  1.23ms)   1.50ms (115.15us)        13
#   nlp_grad_f  |        0 (       0)   4.09ms (292.29us)        14
#   nlp_hess_l  |   1.00ms ( 83.33us)   7.11ms (592.83us)        12
#    nlp_jac_g  |   4.00ms (285.71us)   4.47ms (319.43us)        14
#        total  |  99.00ms ( 99.00ms)  97.95ms ( 97.95ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0) 985.00us (140.71us)         7
#        nlp_g  |        0 (       0) 722.00us (103.14us)         7
#   nlp_grad_f  |        0 (       0)   2.15ms (268.25us)         8
#   nlp_hess_l  |   1.00ms (166.67us)   3.59ms (598.83us)         6
#    nlp_jac_g  |   1.00ms (125.00us)   2.40ms (299.50us)         8
#        total  |  50.00ms ( 50.00ms)  52.97ms ( 52.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.23ms (153.87us)         8
#        nlp_g  |        0 (       0) 996.00us (124.50us)         8
#   nlp_grad_f  |        0 (       0)   2.83ms (314.22us)         9
#   nlp_hess_l  |        0 (       0)   4.37ms (624.57us)         7
#    nlp_jac_g  |        0 (       0)   3.12ms (346.89us)         9
#        total  |  66.00ms ( 66.00ms)  63.01ms ( 63.01ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.03ms (171.17us)         6
#        nlp_g  |        0 (       0) 739.00us (123.17us)         6
#   nlp_grad_f  |        0 (       0)   2.43ms (347.14us)         7
#   nlp_hess_l  |        0 (       0)   3.81ms (762.40us)         5
#    nlp_jac_g  |   1.00ms (142.86us)   2.76ms (394.00us)         7
#        total  |  50.00ms ( 50.00ms)  50.17ms ( 50.17ms)         1
# ステップ 32 でゴールに到達！
# イテレーション 1 の総コスト: 314.81
# GPR: 学習開始...
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:166: RuntimeWarning:overflow encountered in divide
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:138: RuntimeWarning:invalid value encountered in add
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\rbf.py:178: RuntimeWarning:invalid value encountered in multiply
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in square
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 15305.3066
#
# ==================================================
# 反復学習: イテレーション 2/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.94ms (176.18us)        11
#        nlp_g  |        0 (       0)   1.26ms (114.82us)        11
#   nlp_grad_f  |   2.00ms (166.67us)   3.83ms (319.00us)        12
#   nlp_hess_l  |        0 (       0)   6.56ms (655.70us)        10
#    nlp_jac_g  |   2.00ms (166.67us)   4.06ms (338.25us)        12
#        total  |  80.00ms ( 80.00ms)  86.91ms ( 86.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.60ms)   1.75ms (174.60us)        10
#        nlp_g  |        0 (       0)   1.10ms (110.30us)        10
#   nlp_grad_f  |        0 (       0)   3.51ms (318.73us)        11
#   nlp_hess_l  |  28.00ms (  3.11ms)   6.26ms (695.67us)         9
#    nlp_jac_g  |        0 (       0)   3.77ms (342.64us)        11
#        total  |  67.00ms ( 67.00ms)  79.91ms ( 79.91ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.61ms (179.00us)         9
#        nlp_g  |        0 (       0)   1.08ms (119.89us)         9
#   nlp_grad_f  |        0 (       0)   3.21ms (321.30us)        10
#   nlp_hess_l  |  14.00ms (  1.75ms)   5.68ms (710.50us)         8
#    nlp_jac_g  |        0 (       0)   3.50ms (350.40us)        10
#        total  |  72.00ms ( 72.00ms)  71.28ms ( 71.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.67ms (152.09us)        11
#        nlp_g  |   1.00ms ( 90.91us)   1.21ms (109.82us)        11
#   nlp_grad_f  |        0 (       0)   3.58ms (298.33us)        12
#   nlp_hess_l  |  21.00ms (  2.10ms)   6.19ms (619.10us)        10
#    nlp_jac_g  |        0 (       0)   3.70ms (308.58us)        12
#        total  |  81.00ms ( 81.00ms)  82.96ms ( 82.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.58ms (175.89us)         9
#        nlp_g  |   5.00ms (555.56us)   1.27ms (141.33us)         9
#   nlp_grad_f  |   1.00ms (100.00us)   3.16ms (316.40us)        10
#   nlp_hess_l  |  16.00ms (  2.00ms)   5.01ms (626.25us)         8
#    nlp_jac_g  |   3.00ms (300.00us)   4.22ms (422.10us)        10
#        total  |  71.00ms ( 71.00ms)  73.17ms ( 73.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.83ms (166.18us)        11
#        nlp_g  |        0 (       0)   1.36ms (123.82us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.81ms (317.42us)        12
#   nlp_hess_l  |   1.00ms (100.00us)   6.59ms (659.00us)        10
#    nlp_jac_g  |        0 (       0)   3.96ms (329.75us)        12
#        total  |  83.00ms ( 83.00ms)  86.32ms ( 86.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.71ms (155.82us)        11
#        nlp_g  |        0 (       0)   1.17ms (106.82us)        11
#   nlp_grad_f  |        0 (       0)   3.56ms (296.33us)        12
#   nlp_hess_l  |   2.00ms (200.00us)   6.34ms (634.40us)        10
#    nlp_jac_g  |        0 (       0)   3.78ms (315.33us)        12
#        total  |  95.00ms ( 95.00ms)  89.04ms ( 89.04ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.08ms (156.96us)        26
#        nlp_g  |        0 (       0)   2.92ms (112.50us)        26
#   nlp_grad_f  |  22.00ms (846.15us)   7.95ms (305.65us)        26
#   nlp_hess_l  |  28.00ms (  1.17ms)  15.15ms (631.33us)        24
#    nlp_jac_g  |        0 (       0)   8.42ms (323.73us)        26
#        total  | 231.00ms (231.00ms) 240.16ms (240.16ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.70ms (180.27us)        15
#        nlp_g  |        0 (       0)   1.74ms (115.80us)        15
#   nlp_grad_f  |  13.00ms (812.50us)   5.21ms (325.56us)        16
#   nlp_hess_l  |   8.00ms (571.43us)   9.11ms (650.93us)        14
#    nlp_jac_g  |        0 (       0)   5.46ms (341.25us)        16
#        total  | 126.00ms (126.00ms) 115.32ms (115.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   1.87ms (155.75us)        12
#        nlp_g  |        0 (       0)   1.32ms (109.67us)        12
#   nlp_grad_f  |        0 (       0)   3.83ms (294.38us)        13
#   nlp_hess_l  |  11.00ms (  1.00ms)   6.90ms (626.91us)        11
#    nlp_jac_g  |   6.00ms (461.54us)   4.15ms (319.23us)        13
#        total  |  94.00ms ( 94.00ms)  94.35ms ( 94.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.18ms (159.25us)        20
#        nlp_g  |        0 (       0)   2.34ms (117.15us)        20
#   nlp_grad_f  |        0 (       0)   6.23ms (296.90us)        21
#   nlp_hess_l  |   7.00ms (368.42us)  11.78ms (620.21us)        19
#    nlp_jac_g  |   1.00ms ( 47.62us)   6.56ms (312.29us)        21
#        total  | 167.00ms (167.00ms) 167.72ms (167.72ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (222.22us)   2.87ms (159.39us)        18
#        nlp_g  |        0 (       0)   1.95ms (108.11us)        18
#   nlp_grad_f  |   3.00ms (157.89us)   5.44ms (286.21us)        19
#   nlp_hess_l  |  16.00ms (941.18us)  10.54ms (619.88us)        17
#    nlp_jac_g  |        0 (       0)   5.84ms (307.58us)        19
#        total  | 144.00ms (144.00ms) 153.48ms (153.48ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.01ms (167.25us)        12
#        nlp_g  |        0 (       0)   1.43ms (119.08us)        12
#   nlp_grad_f  |  21.00ms (  1.62ms)   4.41ms (339.31us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   7.52ms (684.00us)        11
#    nlp_jac_g  |  17.00ms (  1.31ms)   4.81ms (369.85us)        13
#        total  | 119.00ms (119.00ms) 113.98ms (113.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.40ms (141.41us)        17
#        nlp_g  |        0 (       0)   1.69ms ( 99.41us)        17
#   nlp_grad_f  |        0 (       0)   4.11ms (316.38us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   7.33ms (666.18us)        11
#    nlp_jac_g  |        0 (       0)   4.33ms (333.46us)        13
#        total  | 114.00ms (114.00ms) 111.47ms (111.47ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.12ms (162.85us)        13
#        nlp_g  |        0 (       0)   1.56ms (120.15us)        13
#   nlp_grad_f  |        0 (       0)   4.47ms (319.36us)        14
#   nlp_hess_l  |  14.00ms (  1.17ms)   7.36ms (613.58us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   4.84ms (345.93us)        14
#        total  | 102.00ms (102.00ms)  99.98ms ( 99.98ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   5.00ms (238.10us)   3.34ms (158.90us)        21
#        nlp_g  |   3.00ms (142.86us)   2.27ms (108.05us)        21
#   nlp_grad_f  |   4.00ms (181.82us)   6.22ms (282.86us)        22
#   nlp_hess_l  |  15.00ms (750.00us)  11.35ms (567.40us)        20
#    nlp_jac_g  |   4.00ms (181.82us)   6.48ms (294.36us)        22
#        total  | 195.00ms (195.00ms) 195.42ms (195.42ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   1.98ms (179.91us)        11
#        nlp_g  |        0 (       0)   1.22ms (111.00us)        11
#   nlp_grad_f  |   1.00ms ( 83.33us)   3.96ms (329.67us)        12
#   nlp_hess_l  |   5.00ms (500.00us)   6.56ms (656.50us)        10
#    nlp_jac_g  |   7.00ms (583.33us)   3.98ms (331.33us)        12
#        total  |  84.00ms ( 84.00ms)  84.21ms ( 84.21ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.35ms (159.62us)        21
#        nlp_g  |  16.00ms (761.90us)   2.63ms (125.05us)        21
#   nlp_grad_f  |  15.00ms (681.82us)   7.09ms (322.41us)        22
#   nlp_hess_l  |  16.00ms (800.00us)  12.67ms (633.55us)        20
#    nlp_jac_g  |   1.00ms ( 45.45us)   7.00ms (318.32us)        22
#        total  | 200.00ms (200.00ms) 191.23ms (191.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.10ms (161.92us)        13
#        nlp_g  |        0 (       0)   1.47ms (113.00us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.29ms (306.14us)        14
#   nlp_hess_l  |   5.00ms (416.67us)   7.43ms (619.33us)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   4.50ms (321.57us)        14
#        total  |  98.00ms ( 98.00ms) 104.28ms (104.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.25ms (160.43us)        14
#        nlp_g  |        0 (       0)   1.54ms (110.29us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.59ms (305.73us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   8.18ms (629.62us)        13
#    nlp_jac_g  |        0 (       0)   4.75ms (316.80us)        15
#        total  |  95.00ms ( 95.00ms) 106.17ms (106.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.50ms (178.79us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.61ms (115.29us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.96ms (331.00us)        15
#   nlp_hess_l  |        0 (       0)   8.51ms (654.38us)        13
#    nlp_jac_g  |   2.00ms (133.33us)   5.13ms (341.73us)        15
#        total  | 116.00ms (116.00ms) 114.31ms (114.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.49ms (177.71us)        14
#        nlp_g  |        0 (       0)   1.92ms (137.50us)        14
#   nlp_grad_f  |        0 (       0)   4.71ms (313.80us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   8.78ms (675.46us)        13
#    nlp_jac_g  |   3.00ms (200.00us)   5.31ms (353.80us)        15
#        total  | 111.00ms (111.00ms) 111.31ms (111.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.43ms (164.70us)        33
#        nlp_g  |   4.00ms (121.21us)   3.88ms (117.45us)        33
#   nlp_grad_f  |   1.00ms ( 29.41us)   9.91ms (291.35us)        34
#   nlp_hess_l  |  11.00ms (343.75us)  20.82ms (650.69us)        32
#    nlp_jac_g  |   5.00ms (147.06us)  10.60ms (311.68us)        34
#        total  | 333.00ms (333.00ms) 333.28ms (333.28ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (285.71us)   2.37ms (169.64us)        14
#        nlp_g  |        0 (       0)   1.67ms (119.14us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.74ms (315.73us)        15
#   nlp_hess_l  |        0 (       0)   8.69ms (668.08us)        13
#    nlp_jac_g  |        0 (       0)   5.03ms (335.60us)        15
#        total  | 117.00ms (117.00ms) 113.93ms (113.93ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.23ms (159.57us)        14
#        nlp_g  |        0 (       0)   1.58ms (112.79us)        14
#   nlp_grad_f  |        0 (       0)   4.52ms (301.27us)        15
#   nlp_hess_l  |   6.00ms (461.54us)   7.97ms (612.92us)        13
#    nlp_jac_g  |        0 (       0)   4.91ms (327.47us)        15
#        total  | 120.00ms (120.00ms) 109.13ms (109.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms (166.67us)   2.13ms (177.33us)        12
#        nlp_g  |        0 (       0)   1.36ms (113.17us)        12
#   nlp_grad_f  |   4.00ms (307.69us)   4.04ms (310.77us)        13
#   nlp_hess_l  |   2.00ms (181.82us)   7.49ms (680.55us)        11
#    nlp_jac_g  |   4.00ms (307.69us)   4.64ms (357.31us)        13
#        total  |  95.00ms ( 95.00ms)  94.17ms ( 94.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.80ms (163.73us)        11
#        nlp_g  |        0 (       0)   1.27ms (115.64us)        11
#   nlp_grad_f  |        0 (       0)   3.79ms (315.92us)        12
#   nlp_hess_l  |  19.00ms (  1.90ms)   6.73ms (673.30us)        10
#    nlp_jac_g  |        0 (       0)   3.98ms (331.67us)        12
#        total  |  83.00ms ( 83.00ms)  88.07ms ( 88.07ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.20ms (156.86us)        14
#        nlp_g  |        0 (       0)   1.60ms (114.21us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   4.80ms (319.73us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   8.20ms (630.85us)        13
#    nlp_jac_g  |  14.00ms (933.33us)   5.38ms (359.00us)        15
#        total  | 115.00ms (115.00ms) 112.10ms (112.10ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   2.31ms (192.75us)        12
#        nlp_g  |        0 (       0)   1.59ms (132.58us)        12
#   nlp_grad_f  |        0 (       0)   4.31ms (331.38us)        13
#   nlp_hess_l  |   4.00ms (363.64us)   7.46ms (677.91us)        11
#    nlp_jac_g  |  15.00ms (  1.15ms)   4.67ms (359.38us)        13
#        total  | 116.00ms (116.00ms) 105.96ms (105.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (  1.14ms)   2.59ms (185.07us)        14
#        nlp_g  |        0 (       0)   1.66ms (118.57us)        14
#   nlp_grad_f  |        0 (       0)   4.70ms (313.13us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   8.59ms (661.08us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   5.19ms (346.07us)        15
#        total  | 118.00ms (118.00ms) 112.33ms (112.33ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.41ms (172.07us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.72ms (122.71us)        14
#   nlp_grad_f  |        0 (       0)   5.01ms (334.33us)        15
#   nlp_hess_l  |   4.00ms (307.69us)   8.63ms (663.62us)        13
#    nlp_jac_g  |        0 (       0)   4.97ms (331.07us)        15
#        total  | 123.00ms (123.00ms) 112.18ms (112.18ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 2 の総コスト: 260.60
# GPR: 学習開始...
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:166: RuntimeWarning:overflow encountered in divide
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in square
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\stationary.py:138: RuntimeWarning:invalid value encountered in add
#  c:\Users\sakurai\abc\Lib\site-packages\GPy\kern\src\rbf.py:178: RuntimeWarning:invalid value encountered in multiply
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 4662.5591
#
# ==================================================
# 反復学習: イテレーション 3/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.06ms (158.69us)        13
#        nlp_g  |        0 (       0)   1.39ms (107.15us)        13
#   nlp_grad_f  |   4.00ms (285.71us)   4.31ms (308.00us)        14
#   nlp_hess_l  |   3.00ms (250.00us)   7.25ms (604.00us)        12
#    nlp_jac_g  |        0 (       0)   4.58ms (327.36us)        14
#        total  |  99.00ms ( 99.00ms)  99.14ms ( 99.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.87ms (170.18us)        11
#        nlp_g  |   1.00ms ( 90.91us)   1.25ms (113.82us)        11
#   nlp_grad_f  |        0 (       0)   3.79ms (315.75us)        12
#   nlp_hess_l  |  20.00ms (  2.00ms)   6.66ms (665.80us)        10
#    nlp_jac_g  |        0 (       0)   4.05ms (337.58us)        12
#        total  |  85.00ms ( 85.00ms)  86.67ms ( 86.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.97ms (164.33us)        12
#        nlp_g  |        0 (       0)   1.54ms (128.25us)        12
#   nlp_grad_f  |        0 (       0)   4.36ms (335.69us)        13
#   nlp_hess_l  |  13.00ms (  1.18ms)   7.64ms (694.45us)        11
#    nlp_jac_g  |   2.00ms (153.85us)   4.71ms (362.23us)        13
#        total  |  93.00ms ( 93.00ms)  97.15ms ( 97.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.80ms (174.75us)        16
#        nlp_g  |        0 (       0)   1.94ms (121.44us)        16
#   nlp_grad_f  |  15.00ms (882.35us)   5.74ms (337.76us)        17
#   nlp_hess_l  |   8.00ms (533.33us)   9.89ms (659.40us)        15
#    nlp_jac_g  |   2.00ms (117.65us)   5.96ms (350.47us)        17
#        total  | 126.00ms (126.00ms) 126.88ms (126.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.19ms (168.77us)        13
#        nlp_g  |   1.00ms ( 76.92us)   1.57ms (121.08us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.72ms (336.86us)        14
#   nlp_hess_l  |  15.00ms (  1.25ms)   7.75ms (645.92us)        12
#    nlp_jac_g  |        0 (       0)   4.90ms (349.93us)        14
#        total  | 103.00ms (103.00ms) 101.63ms (101.63ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.96ms (177.91us)        11
#        nlp_g  |        0 (       0)   1.26ms (114.64us)        11
#   nlp_grad_f  |        0 (       0)   3.84ms (320.17us)        12
#   nlp_hess_l  |   6.00ms (600.00us)   7.09ms (709.20us)        10
#    nlp_jac_g  |   4.00ms (333.33us)   4.28ms (356.67us)        12
#        total  |  85.00ms ( 85.00ms)  86.97ms ( 86.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.00ms ( 45.45us)   7.19ms (163.45us)        44
#        nlp_g  |  17.00ms (386.36us)   5.05ms (114.70us)        44
#   nlp_grad_f  |   3.00ms ( 69.77us)  13.69ms (318.44us)        43
#   nlp_hess_l  |  18.00ms (439.02us)  26.54ms (647.32us)        41
#    nlp_jac_g  |  17.00ms (395.35us)  13.92ms (323.81us)        43
#        total  | 420.00ms (420.00ms) 422.13ms (422.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.24ms (156.89us)        27
#        nlp_g  |   1.00ms ( 37.04us)   3.12ms (115.41us)        27
#   nlp_grad_f  |        0 (       0)   6.90ms (299.83us)        23
#   nlp_hess_l  |   5.00ms (238.10us)  13.65ms (650.00us)        21
#    nlp_jac_g  |  15.00ms (652.17us)   7.68ms (334.09us)        23
#        total  | 211.00ms (211.00ms) 209.13ms (209.13ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 62.50us)   2.53ms (157.87us)        16
#        nlp_g  |        0 (       0)   1.67ms (104.31us)        16
#   nlp_grad_f  |        0 (       0)   4.81ms (283.24us)        17
#   nlp_hess_l  |   7.00ms (466.67us)   9.22ms (614.73us)        15
#    nlp_jac_g  |   2.00ms (117.65us)   5.17ms (304.12us)        17
#        total  | 138.00ms (138.00ms) 148.51ms (148.51ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 26.32us)   6.68ms (175.84us)        38
#        nlp_g  |        0 (       0)   4.79ms (126.16us)        38
#   nlp_grad_f  |   4.00ms (102.56us)  12.44ms (319.08us)        39
#   nlp_hess_l  |  31.00ms (837.84us)  24.86ms (671.76us)        37
#    nlp_jac_g  |   6.00ms (153.85us)  13.78ms (353.41us)        39
#        total  | 403.00ms (403.00ms) 409.75ms (409.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.89ms (169.22us)        23
#        nlp_g  |        0 (       0)   2.75ms (119.65us)        23
#   nlp_grad_f  |   1.00ms ( 47.62us)   6.83ms (325.48us)        21
#   nlp_hess_l  |  24.00ms (  1.26ms)  12.53ms (659.32us)        19
#    nlp_jac_g  |   9.00ms (428.57us)   7.54ms (358.90us)        21
#        total  | 189.00ms (189.00ms) 181.97ms (181.97ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.73ms (170.69us)        16
#        nlp_g  |  31.00ms (  1.94ms)   1.97ms (123.19us)        16
#   nlp_grad_f  |   1.00ms ( 58.82us)   5.30ms (311.82us)        17
#   nlp_hess_l  |   5.00ms (333.33us)  10.39ms (693.00us)        15
#    nlp_jac_g  |        0 (       0)   6.02ms (354.12us)        17
#        total  | 162.00ms (162.00ms) 152.87ms (152.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.85ms (158.28us)        18
#        nlp_g  |   1.00ms ( 55.56us)   1.89ms (105.06us)        18
#   nlp_grad_f  |   2.00ms (105.26us)   5.70ms (299.79us)        19
#   nlp_hess_l  |  16.00ms (941.18us)  10.39ms (611.24us)        17
#    nlp_jac_g  |  15.00ms (789.47us)   6.30ms (331.47us)        19
#        total  | 166.00ms (166.00ms) 179.23ms (179.23ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (607.14us)   4.60ms (164.46us)        28
#        nlp_g  |  15.00ms (535.71us)   3.10ms (110.68us)        28
#   nlp_grad_f  |   2.00ms ( 74.07us)   8.62ms (319.33us)        27
#   nlp_hess_l  |   2.00ms ( 80.00us)  16.87ms (675.00us)        25
#    nlp_jac_g  |  14.00ms (518.52us)   9.39ms (347.93us)        27
#        total  | 264.00ms (264.00ms) 259.35ms (259.35ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.50ms (166.47us)        15
#        nlp_g  |  16.00ms (  1.07ms)   1.70ms (113.67us)        15
#   nlp_grad_f  |        0 (       0)   4.73ms (295.44us)        16
#   nlp_hess_l  |        0 (       0)   8.69ms (621.00us)        14
#    nlp_jac_g  |        0 (       0)   4.86ms (303.56us)        16
#        total  | 128.00ms (128.00ms) 116.86ms (116.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.80ms (163.82us)        11
#        nlp_g  |        0 (       0)   1.28ms (116.64us)        11
#   nlp_grad_f  |  16.00ms (  1.33ms)   3.95ms (329.08us)        12
#   nlp_hess_l  |  12.00ms (  1.20ms)   6.64ms (663.90us)        10
#    nlp_jac_g  |        0 (       0)   4.00ms (333.42us)        12
#        total  |  84.00ms ( 84.00ms)  85.58ms ( 85.58ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 33.33us)   5.06ms (168.77us)        30
#        nlp_g  |        0 (       0)   3.52ms (117.47us)        30
#   nlp_grad_f  |  14.00ms (451.61us)   9.60ms (309.77us)        31
#   nlp_hess_l  |   3.00ms (103.45us)  19.12ms (659.28us)        29
#    nlp_jac_g  |        0 (       0)  10.16ms (327.65us)        31
#        total  | 316.00ms (316.00ms) 316.17ms (316.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.03ms (156.54us)        13
#        nlp_g  |  16.00ms (  1.23ms)   1.42ms (109.15us)        13
#   nlp_grad_f  |        0 (       0)   4.17ms (297.86us)        14
#   nlp_hess_l  |   4.00ms (333.33us)   7.59ms (632.83us)        12
#    nlp_jac_g  |        0 (       0)   4.37ms (312.14us)        14
#        total  | 109.00ms (109.00ms) 100.31ms (100.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 34.48us)   4.58ms (158.00us)        29
#        nlp_g  |  16.00ms (551.72us)   3.31ms (114.03us)        29
#   nlp_grad_f  |   2.00ms ( 66.67us)   8.58ms (286.13us)        30
#   nlp_hess_l  |   6.00ms (214.29us)  17.25ms (616.25us)        28
#    nlp_jac_g  |   2.00ms ( 66.67us)   9.27ms (309.10us)        30
#        total  | 281.00ms (281.00ms) 281.31ms (281.31ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.81ms (165.24us)        17
#        nlp_g  |   1.00ms ( 58.82us)   2.13ms (125.59us)        17
#   nlp_grad_f  |        0 (       0)   5.82ms (323.39us)        18
#   nlp_hess_l  |  13.00ms (812.50us)  10.80ms (674.87us)        16
#    nlp_jac_g  |        0 (       0)   6.28ms (348.72us)        18
#        total  | 133.00ms (133.00ms) 132.17ms (132.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.30ms (164.36us)        14
#        nlp_g  |        0 (       0)   1.53ms (109.07us)        14
#   nlp_grad_f  |   4.00ms (266.67us)   4.58ms (305.33us)        15
#   nlp_hess_l  |   8.00ms (615.38us)   8.56ms (658.62us)        13
#    nlp_jac_g  |   2.00ms (133.33us)   4.80ms (320.20us)        15
#        total  | 108.00ms (108.00ms) 108.68ms (108.68ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.76ms (162.65us)        17
#        nlp_g  |        0 (       0)   1.86ms (109.29us)        17
#   nlp_grad_f  |        0 (       0)   5.58ms (310.28us)        18
#   nlp_hess_l  |   2.00ms (125.00us)  10.35ms (646.69us)        16
#    nlp_jac_g  |   1.00ms ( 55.56us)   6.07ms (337.17us)        18
#        total  | 133.00ms (133.00ms) 134.08ms (134.08ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.03ms (144.71us)        14
#        nlp_g  |        0 (       0)   1.70ms (121.36us)        14
#   nlp_grad_f  |        0 (       0)   4.23ms (281.93us)        15
#   nlp_hess_l  |        0 (       0)   7.58ms (583.00us)        13
#    nlp_jac_g  |  16.00ms (  1.07ms)   4.76ms (317.13us)        15
#        total  | 117.00ms (117.00ms) 109.99ms (109.99ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.93ms (148.23us)        13
#        nlp_g  |        0 (       0)   1.36ms (104.38us)        13
#   nlp_grad_f  |        0 (       0)   4.04ms (288.71us)        14
#   nlp_hess_l  |  16.00ms (  1.33ms)   7.03ms (585.83us)        12
#    nlp_jac_g  |  15.00ms (  1.07ms)   4.60ms (328.64us)        14
#        total  | 100.00ms (100.00ms)  98.32ms ( 98.32ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   3.84ms (153.72us)        25
#        nlp_g  |        0 (       0)   3.02ms (120.96us)        25
#   nlp_grad_f  |   1.00ms ( 38.46us)   7.85ms (301.85us)        26
#   nlp_hess_l  |  16.00ms (666.67us)  14.46ms (602.42us)        24
#    nlp_jac_g  |        0 (       0)   8.27ms (318.04us)        26
#        total  | 217.00ms (217.00ms) 217.77ms (217.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.06ms (147.21us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.46ms (104.14us)        14
#   nlp_grad_f  |        0 (       0)   4.25ms (283.67us)        15
#   nlp_hess_l  |  16.00ms (  1.23ms)   8.12ms (624.46us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.50ms (300.33us)        15
#        total  | 100.00ms (100.00ms) 106.39ms (106.39ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.22ms (148.00us)        15
#        nlp_g  |  16.00ms (  1.07ms)   1.51ms (100.53us)        15
#   nlp_grad_f  |        0 (       0)   4.46ms (278.94us)        16
#   nlp_hess_l  |  16.00ms (  1.14ms)   8.94ms (638.86us)        14
#    nlp_jac_g  |        0 (       0)   4.99ms (312.00us)        16
#        total  | 117.00ms (117.00ms) 114.73ms (114.73ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.23ms (159.57us)        14
#        nlp_g  |        0 (       0)   1.49ms (106.79us)        14
#   nlp_grad_f  |        0 (       0)   4.34ms (289.07us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   7.25ms (557.38us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.65ms (310.27us)        15
#        total  | 117.00ms (117.00ms) 107.34ms (107.34ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.23ms (159.21us)        14
#        nlp_g  |        0 (       0)   1.58ms (113.14us)        14
#   nlp_grad_f  |        0 (       0)   4.82ms (321.67us)        15
#   nlp_hess_l  |  17.00ms (  1.31ms)   8.00ms (615.23us)        13
#    nlp_jac_g  |        0 (       0)   5.15ms (343.13us)        15
#        total  | 100.00ms (100.00ms) 103.86ms (103.86ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.60ms (162.37us)        16
#        nlp_g  |        0 (       0)   1.81ms (113.06us)        16
#   nlp_grad_f  |        0 (       0)   5.21ms (306.35us)        17
#   nlp_hess_l  |        0 (       0)   9.14ms (609.53us)        15
#    nlp_jac_g  |        0 (       0)   5.44ms (320.18us)        17
#        total  | 115.00ms (115.00ms) 122.75ms (122.75ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 83.33us)   1.84ms (153.33us)        12
#        nlp_g  |        0 (       0)   1.22ms (102.08us)        12
#   nlp_grad_f  |   1.00ms ( 76.92us)   3.55ms (273.23us)        13
#   nlp_hess_l  |        0 (       0)   6.70ms (609.55us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   3.79ms (291.23us)        13
#        total  |  84.00ms ( 84.00ms)  92.96ms ( 92.96ms)         1
# ステップ 31 でゴールに到達！
# イテレーション 3 の総コスト: 259.34
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 2767.5559
#
# ==================================================
# 反復学習: イテレーション 4/5
# ==================================================
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.03ms (169.08us)        12
#        nlp_g  |        0 (       0)   1.33ms (110.75us)        12
#   nlp_grad_f  |        0 (       0)   4.02ms (309.08us)        13
#   nlp_hess_l  |   2.00ms (181.82us)   6.73ms (611.82us)        11
#    nlp_jac_g  |   1.00ms ( 76.92us)   4.09ms (314.92us)        13
#        total  |  84.00ms ( 84.00ms)  91.79ms ( 91.79ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 90.91us)   1.63ms (148.64us)        11
#        nlp_g  |        0 (       0)   1.10ms (100.00us)        11
#   nlp_grad_f  |        0 (       0)   3.46ms (288.42us)        12
#   nlp_hess_l  |   2.00ms (200.00us)   5.82ms (581.60us)        10
#    nlp_jac_g  |  12.00ms (  1.00ms)   3.75ms (312.75us)        12
#        total  |  84.00ms ( 84.00ms)  83.15ms ( 83.15ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.31ms (144.37us)        16
#        nlp_g  |   1.00ms ( 62.50us)   1.57ms ( 98.00us)        16
#   nlp_grad_f  |        0 (       0)   4.55ms (267.94us)        17
#   nlp_hess_l  |   4.00ms (266.67us)   9.02ms (601.40us)        15
#    nlp_jac_g  |  13.00ms (764.71us)   4.99ms (293.41us)        17
#        total  | 131.00ms (131.00ms) 132.29ms (132.29ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.39ms (155.00us)         9
#        nlp_g  |        0 (       0) 923.00us (102.56us)         9
#   nlp_grad_f  |        0 (       0)   2.91ms (291.00us)        10
#   nlp_hess_l  |        0 (       0)   5.09ms (636.00us)         8
#    nlp_jac_g  |  15.00ms (  1.50ms)   3.17ms (317.50us)        10
#        total  |  66.00ms ( 66.00ms)  70.55ms ( 70.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.91ms (159.08us)        12
#        nlp_g  |        0 (       0)   1.44ms (119.75us)        12
#   nlp_grad_f  |        0 (       0)   4.06ms (312.69us)        13
#   nlp_hess_l  |        0 (       0)   6.90ms (627.45us)        11
#    nlp_jac_g  |        0 (       0)   4.62ms (355.62us)        13
#        total  | 118.00ms (118.00ms) 114.74ms (114.74ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
# ...
#    nlp_jac_g  |        0 (       0)   3.30ms (299.82us)        11
#        total  |  67.00ms ( 67.00ms)  75.70ms ( 75.70ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.55ms (169.93us)        15
#        nlp_g  |   1.00ms ( 66.67us)   1.68ms (112.27us)        15
#   nlp_grad_f  |        0 (       0)   4.65ms (290.44us)        16
#   nlp_hess_l  |  17.00ms (  1.21ms)   8.33ms (595.14us)        14
#    nlp_jac_g  |        0 (       0)   4.83ms (302.06us)        16
#        total  | 117.00ms (117.00ms) 116.03ms (116.03ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  16.00ms (888.89us)   2.88ms (159.89us)        18
#        nlp_g  |        0 (       0)   1.95ms (108.39us)        18
#   nlp_grad_f  |        0 (       0)   5.24ms (275.58us)        19
#   nlp_hess_l  |  16.00ms (941.18us)  10.18ms (598.59us)        17
#    nlp_jac_g  |        0 (       0)   5.62ms (295.58us)        19
#        total  | 182.00ms (182.00ms) 173.01ms (173.01ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 22.22us)   6.71ms (149.20us)        45
#        nlp_g  |        0 (       0)   4.79ms (106.40us)        45
#   nlp_grad_f  |        0 (       0)  11.72ms (272.67us)        43
#   nlp_hess_l  |  61.00ms (  1.49ms)  24.18ms (589.73us)        41
#    nlp_jac_g  |  15.00ms (348.84us)  12.33ms (286.79us)        43
#        total  | 465.00ms (465.00ms) 452.90ms (452.90ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.22ms (148.27us)        15
#        nlp_g  |        0 (       0)   1.52ms (101.33us)        15
#   nlp_grad_f  |   2.00ms (133.33us)   4.39ms (292.47us)        15
#   nlp_hess_l  |        0 (       0)   7.66ms (589.54us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.67ms (311.53us)        15
#        total  | 100.00ms (100.00ms) 115.14ms (115.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 41.67us)   3.53ms (147.12us)        24
#        nlp_g  |        0 (       0)   2.65ms (110.46us)        24
#   nlp_grad_f  |  17.00ms (680.00us)   7.10ms (283.92us)        25
#   nlp_hess_l  |  15.00ms (652.17us)  13.70ms (595.52us)        23
#    nlp_jac_g  |  16.00ms (640.00us)   7.73ms (309.04us)        25
#        total  | 216.00ms (216.00ms) 214.95ms (214.95ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.48ms (155.25us)        16
#        nlp_g  |        0 (       0)   1.71ms (107.00us)        16
#   nlp_grad_f  |   3.00ms (176.47us)   5.54ms (325.65us)        17
#   nlp_hess_l  |  16.00ms (  1.07ms)   8.94ms (595.93us)        15
#    nlp_jac_g  |  32.00ms (  1.88ms)   5.41ms (318.53us)        17
#        total  | 150.00ms (150.00ms) 148.88ms (148.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 66.67us)   2.30ms (153.33us)        15
#        nlp_g  |        0 (       0)   1.65ms (109.73us)        15
#   nlp_grad_f  |        0 (       0)   4.47ms (279.56us)        16
#   nlp_hess_l  |  16.00ms (  1.14ms)   8.34ms (595.64us)        14
#    nlp_jac_g  |        0 (       0)   4.74ms (296.31us)        16
#        total  | 150.00ms (150.00ms) 141.64ms (141.64ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.07ms (137.87us)        15
#        nlp_g  |        0 (       0)   1.47ms ( 97.80us)        15
#   nlp_grad_f  |   3.00ms (230.77us)   3.97ms (305.23us)        13
#   nlp_hess_l  |   1.00ms ( 90.91us)   6.43ms (584.45us)        11
#    nlp_jac_g  |        0 (       0)   4.05ms (311.23us)        13
#        total  | 100.00ms (100.00ms) 104.43ms (104.43ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.50ms)   1.52ms (152.30us)        10
#        nlp_g  |        0 (       0)   1.28ms (127.90us)        10
#   nlp_grad_f  |   1.00ms ( 90.91us)   3.30ms (300.45us)        11
#   nlp_hess_l  |        0 (       0)   5.44ms (604.22us)         9
#    nlp_jac_g  |        0 (       0)   3.51ms (318.82us)        11
#        total  |  64.00ms ( 64.00ms)  76.81ms ( 76.81ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.47ms (154.25us)        16
#        nlp_g  |        0 (       0)   1.72ms (107.31us)        16
#   nlp_grad_f  |        0 (       0)   5.08ms (298.82us)        17
#   nlp_hess_l  |   1.00ms ( 66.67us)   9.00ms (600.07us)        15
#    nlp_jac_g  |  16.00ms (941.18us)   5.06ms (297.94us)        17
#        total  | 150.00ms (150.00ms) 155.77ms (155.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.00ms)   2.42ms (161.07us)        15
#        nlp_g  |        0 (       0)   1.68ms (112.20us)        15
#   nlp_grad_f  |        0 (       0)   5.05ms (315.69us)        16
#   nlp_hess_l  |   1.00ms ( 71.43us)   8.57ms (612.43us)        14
#    nlp_jac_g  |        0 (       0)   5.12ms (320.00us)        16
#        total  | 133.00ms (133.00ms) 142.66ms (142.66ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.67ms (151.82us)        11
#        nlp_g  |        0 (       0)   1.16ms (105.18us)        11
#   nlp_grad_f  |        0 (       0)   3.39ms (282.75us)        12
#   nlp_hess_l  |        0 (       0)   5.67ms (566.60us)        10
#    nlp_jac_g  |        0 (       0)   3.51ms (292.83us)        12
#        total  |  83.00ms ( 83.00ms)  84.46ms ( 84.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   4.65ms (166.00us)        28
#        nlp_g  |        0 (       0)   3.13ms (111.79us)        28
#   nlp_grad_f  |  16.00ms (551.72us)   8.64ms (298.03us)        29
#   nlp_hess_l  |   1.00ms ( 37.04us)  17.44ms (645.78us)        27
#    nlp_jac_g  |   1.00ms ( 34.48us)   9.18ms (316.69us)        29
#        total  | 285.00ms (285.00ms) 276.46ms (276.46ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   5.24ms (163.69us)        32
#        nlp_g  |        0 (       0)   3.66ms (114.31us)        32
#   nlp_grad_f  |   1.00ms ( 30.30us)   9.58ms (290.33us)        33
#   nlp_hess_l  |  16.00ms (516.13us)  18.69ms (603.00us)        31
#    nlp_jac_g  |  15.00ms (454.55us)  10.15ms (307.73us)        33
#        total  | 317.00ms (317.00ms) 317.96ms (317.96ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.19ms (168.54us)        13
#        nlp_g  |        0 (       0)   1.52ms (117.15us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.84ms (345.79us)        14
#   nlp_hess_l  |   1.00ms ( 83.33us)   7.79ms (649.00us)        12
#    nlp_jac_g  |  16.00ms (  1.14ms)   4.69ms (335.21us)        14
#        total  | 119.00ms (119.00ms) 119.55ms (119.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.14ms (164.77us)        13
#        nlp_g  |        0 (       0)   1.41ms (108.31us)        13
#   nlp_grad_f  |        0 (       0)   3.86ms (275.64us)        14
#   nlp_hess_l  |  15.00ms (  1.25ms)   7.45ms (621.08us)        12
#    nlp_jac_g  |  15.00ms (  1.07ms)   4.12ms (294.14us)        14
#        total  | 100.00ms (100.00ms)  99.92ms ( 99.92ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.08ms (159.69us)        13
#        nlp_g  |        0 (       0)   1.44ms (110.77us)        13
#   nlp_grad_f  |        0 (       0)   4.08ms (291.21us)        14
#   nlp_hess_l  |   1.00ms ( 83.33us)   7.54ms (628.25us)        12
#    nlp_jac_g  |  17.00ms (  1.21ms)   4.50ms (321.57us)        14
#        total  | 100.00ms (100.00ms)  98.20ms ( 98.20ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.33ms (166.43us)        14
#        nlp_g  |   1.00ms ( 71.43us)   1.52ms (108.36us)        14
#   nlp_grad_f  |        0 (       0)   4.15ms (276.40us)        15
#   nlp_hess_l  |        0 (       0)   8.17ms (628.15us)        13
#    nlp_jac_g  |        0 (       0)   4.34ms (289.13us)        15
#        total  | 117.00ms (117.00ms) 109.87ms (109.87ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00ms (298.25us)   8.50ms (149.05us)        57
#        nlp_g  |        0 (       0)   6.11ms (107.16us)        57
#   nlp_grad_f  |  18.00ms (310.34us)  15.90ms (274.16us)        58
#   nlp_hess_l  |  65.00ms (  1.16ms)  32.95ms (588.32us)        56
#    nlp_jac_g  |   2.00ms ( 34.48us)  16.70ms (287.91us)        58
#        total  | 633.00ms (633.00ms) 642.67ms (642.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.38ms (169.86us)        14
#        nlp_g  |        0 (       0)   1.58ms (113.21us)        14
#   nlp_grad_f  |   1.00ms ( 66.67us)   4.79ms (319.47us)        15
#   nlp_hess_l  |        0 (       0)   8.14ms (626.23us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.83ms (321.93us)        15
#        total  | 114.00ms (114.00ms) 106.37ms (106.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   1.93ms (137.93us)        14
#        nlp_g  |        0 (       0)   1.41ms (100.71us)        14
#   nlp_grad_f  |  16.00ms (  1.07ms)   4.28ms (285.53us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   7.22ms (555.38us)        13
#    nlp_jac_g  |        0 (       0)   4.59ms (305.80us)        15
#        total  | 101.00ms (101.00ms) 102.24ms (102.24ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.20ms (157.43us)        14
#        nlp_g  |        0 (       0)   1.56ms (111.57us)        14
#   nlp_grad_f  |  16.00ms (  1.07ms)   4.72ms (314.40us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   7.43ms (571.46us)        13
#    nlp_jac_g  |        0 (       0)   5.22ms (347.80us)        15
#        total  |  98.00ms ( 98.00ms) 108.17ms (108.17ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.19ms (156.79us)        14
#        nlp_g  |        0 (       0)   1.45ms (103.64us)        14
#   nlp_grad_f  |        0 (       0)   4.18ms (278.73us)        15
#   nlp_hess_l  |   1.00ms ( 76.92us)   7.69ms (591.46us)        13
#    nlp_jac_g  |        0 (       0)   4.48ms (298.60us)        15
#        total  | 100.00ms (100.00ms) 103.56ms (103.56ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.33ms (155.27us)        15
#        nlp_g  |        0 (       0)   1.71ms (114.07us)        15
#   nlp_grad_f  |        0 (       0)   5.05ms (315.81us)        16
#   nlp_hess_l  |   4.00ms (285.71us)   9.31ms (665.00us)        14
#    nlp_jac_g  |   6.00ms (375.00us)   5.33ms (333.25us)        16
#        total  | 114.00ms (114.00ms) 114.77ms (114.77ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.25ms (173.23us)        13
#        nlp_g  |        0 (       0)   1.57ms (120.54us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   4.48ms (319.86us)        14
#   nlp_hess_l  |  12.00ms (  1.00ms)   7.95ms (662.67us)        12
#    nlp_jac_g  |   2.00ms (142.86us)   5.30ms (378.93us)        14
#        total  | 100.00ms (100.00ms) 101.55ms (101.55ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   2.28ms (175.23us)        13
#        nlp_g  |        0 (       0)   1.55ms (119.46us)        13
#   nlp_grad_f  |        0 (       0)   4.71ms (336.50us)        14
#   nlp_hess_l  |  12.00ms (  1.00ms)   7.60ms (633.00us)        12
#    nlp_jac_g  |        0 (       0)   4.82ms (344.29us)        14
#        total  | 100.00ms (100.00ms) 102.05ms (102.05ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  15.00ms (  1.25ms)   1.91ms (159.50us)        12
#        nlp_g  |        0 (       0)   1.31ms (109.58us)        12
#   nlp_grad_f  |        0 (       0)   4.03ms (310.38us)        13
#   nlp_hess_l  |   2.00ms (181.82us)   6.79ms (617.18us)        11
#    nlp_jac_g  |        0 (       0)   4.27ms (328.46us)        13
#        total  |  83.00ms ( 83.00ms)  92.67ms ( 92.67ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 76.92us)   1.96ms (150.85us)        13
#        nlp_g  |        0 (       0)   1.33ms (102.38us)        13
#   nlp_grad_f  |        0 (       0)   3.99ms (284.79us)        14
#   nlp_hess_l  |  10.00ms (833.33us)   6.92ms (576.92us)        12
#    nlp_jac_g  |        0 (       0)   4.28ms (305.57us)        14
#        total  |  83.00ms ( 83.00ms)  98.71ms ( 98.71ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.01ms (154.77us)        13
#        nlp_g  |        0 (       0)   1.41ms (108.85us)        13
#   nlp_grad_f  |   1.00ms ( 71.43us)   3.93ms (281.00us)        14
#   nlp_hess_l  |   3.00ms (250.00us)   7.85ms (654.17us)        12
#    nlp_jac_g  |   1.00ms ( 71.43us)   4.18ms (298.29us)        14
#        total  | 106.00ms (106.00ms) 100.14ms (100.14ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.00ms ( 71.43us)   2.40ms (171.57us)        14
#        nlp_g  |  15.00ms (  1.07ms)   1.72ms (122.64us)        14
#   nlp_grad_f  |   2.00ms (133.33us)   4.80ms (319.73us)        15
#   nlp_hess_l  |   2.00ms (153.85us)   8.46ms (651.00us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   5.15ms (343.53us)        15
#        total  | 101.00ms (101.00ms) 106.37ms (106.37ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.77ms (162.88us)        17
#        nlp_g  |   1.00ms ( 58.82us)   1.92ms (113.00us)        17
#   nlp_grad_f  |   1.00ms ( 55.56us)   5.65ms (313.67us)        18
#   nlp_hess_l  |   8.00ms (500.00us)  10.19ms (637.06us)        16
#    nlp_jac_g  |   2.00ms (111.11us)   5.87ms (326.22us)        18
#        total  | 122.00ms (122.00ms) 131.61ms (131.61ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   9.97ms (155.80us)        64
#        nlp_g  |        0 (       0)   6.98ms (109.05us)        64
#   nlp_grad_f  |        0 (       0)  19.43ms (298.97us)        65
#   nlp_hess_l  |  58.00ms (920.63us)  38.58ms (612.44us)        63
#    nlp_jac_g  |   4.00ms ( 61.54us)  20.68ms (318.20us)        65
#        total  | 583.00ms (583.00ms) 583.88ms (583.88ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   4.00ms (363.64us)   1.86ms (169.09us)        11
#        nlp_g  |        0 (       0)   1.24ms (112.36us)        11
#   nlp_grad_f  |   2.00ms (166.67us)   3.84ms (320.08us)        12
#   nlp_hess_l  |   1.00ms (100.00us)   6.45ms (645.00us)        10
#    nlp_jac_g  |        0 (       0)   4.06ms (338.08us)        12
#        total  |  79.00ms ( 79.00ms)  86.01ms ( 86.01ms)         1
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |        0 (       0)   2.06ms (147.29us)        14
#        nlp_g  |        0 (       0)   1.46ms (104.21us)        14
#   nlp_grad_f  |        0 (       0)   4.38ms (292.00us)        15
#   nlp_hess_l  |        0 (       0)   7.83ms (602.08us)        13
#    nlp_jac_g  |   1.00ms ( 66.67us)   4.65ms (309.93us)        15
#        total  |  98.00ms ( 98.00ms) 106.40ms (106.40ms)         1
# ステップ 39 でゴールに到達！
# イテレーション 5 の総コスト: 260.48
# GPR: 学習開始...
# GPR: 学習完了
# NN: 終端コストの学習開始...
# NN: 学習完了。最終損失: 59.2522
